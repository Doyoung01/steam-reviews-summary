# %%
import re

def detect_all_eng(text):
    if not isinstance(text, str):
        return ''
    
    text = re.sub(r'[0-9]', '', text)
    
    if re.fullmatch(r"[A-Za-z\s]*", text):
        return False
    else:
        return text

# %%
def remove_invalid_reviews(df, column_name):
    try:
        filtered_df = df[df[column_name].apply(lambda text: isinstance(text, str) and text.strip() != '')]
        return filtered_df
    except Exception as e:
        print(f"Error: {e}")
        return df

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch

# 예측 수행 함수
def predict(texts):
    model = AutoModelForSequenceClassification.from_pretrained("./hate_speech_model")
    tokenizer = AutoTokenizer.from_pretrained("./hate_speech_model")

    # 입력 데이터 토크나이징 및 디바이스 이동
    encodings = tokenizer(
        texts,
        padding=True,
        truncation=True,
        max_length=128,
        return_tensors="pt",
        add_special_tokens=True,
        stride=32,
    )

    # 모델 추론
    with torch.no_grad():  # 예측 시에는 Gradient 계산 비활성화
        outputs = model(
            input_ids=encodings["input_ids"],
            attention_mask=encodings["attention_mask"]
        )
    logits = outputs.logits

    probabilities = torch.softmax(logits, dim=-1).numpy()

    # 클래스와 확률 추출
    predictions = []
    for text, prob in zip(texts, probabilities):
        max_prob = max(prob)  # 가장 높은 확률
        max_label = prob.argmax()  # 가장 높은 확률의 클래스(숫자)
        predictions.append({"text": text, "label": max_label, "probability": max_prob})

    return predictions

# %% [markdown]
# # 비속어 데이터셋으로 필터링 하기

# %%
import pandas as pd

badwords = pd.read_csv('./Dataset/badwords.csv')['badwords'].dropna().tolist()

# %%
import re

def filtering_with_csv(text):
    if not isinstance(text, str):
        return ''
    
    badwords_pattern = re.compile(r'\b(' + '|'.join(map(re.escape, badwords)) + r')\b')
    filtered_text = badwords_pattern.sub('###', text)

    return filtered_text

# %%
import pandas as pd

# 입력 데이터
labeled = pd.read_csv('./output/output_overwatch_first_labeled.csv')
labeled.drop(['Unnamed: 0.1', 'Unnamed: 0'], axis=1, inplace=True)

labeled['review'] = labeled['review'].apply(detect_all_eng)
labeled['review'] = labeled['review'].apply(filtering_with_csv)
labeled = remove_invalid_reviews(labeled, 'review')
labeled['hate'] = labeled['hate'].apply(lambda x: int(x) if pd.notnull(x) else 8)

labeled_texts = labeled['review'].tolist()
hate = labeled['hate'].tolist()
voted_up = labeled['voted_up'].tolist()

# %%
predictions = predict(labeled_texts)
print("Predictions:", predictions[:5])
# Out:
# Predictions: [{'text': '핵 잡아', 'label': 8, 'probability': 0.99730444}, {'text': '진짜 지금가지 해본 게임 중 가장 최악이다', 'label': 8, 'probability': 0.9960257}, {'text': '거이 준상이 수능 점수', 'label': 8, 'probability': 0.9978613}, {'text': '정신병 걸림', 'label': 8, 'probability': 0.9966826}, {'text': '진짜 개좆같네 팀원들이 싹다 ### ### 아오 ### 패버리고 싶다 ### 키리코 개쌔끼는 지가 딜런줄 알아 ### 그ㅜ래놓고 힐  ### ### 아오 로드호그 ### 킬 어시 뒤짐 ### 진짜 지금 생각해보니까 ### 빡치네 ### 보고있냐 ###', 'label': 3, 'probability': 0.98356116}]

# %%
diff = 0
for i, result in enumerate(predictions):
    if result['label'] != hate[i]:
        print(f"문장: {result['text']}")
        print(f"기존 클래스: {hate[i]}, 판단된 클래스: {result['label']}, 확률: {result['probability']:.2f}")
        print()
        diff += 1
        
print(f"기존과 예측이 달라진 개수: {diff}")
# Out:
# 문장: ###
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 그까짓 힘으로 감히 빨리 한국 영웅 더 주세요 ### 안에 안 주면 블리자드 앞에 오물풍선 투척함
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: ### ### 재미없는 게임 애들이 하는지 도 이해가 안감
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 주노가 재미있다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 병신게임 빠대 탈주 페널티 없애라
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.70
#
# 문장: 주먹 주먹 주먹 주먹 주먹 주먹 주먹
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: ㅈ망겜ㅋㅋ
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.95
#
# 문장: 걍 모르겠고 배틀넷 로그인 자체가 진짜 뭣같음
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.93
#
# 문장: 애들 패치를 하면 누구는 각성하는데 누군는 ㅂ신이 되는거냐
# 기존 클래스: 0, 판단된 클래스: 3, 확률: 0.97
#
# 문장: 탈출은 지능순입니다 유저 수준이 너무 떨어지고 게임도 다 망해서 유저가 없어요 항상 중국인 껴있습니다 즐기는 사람들은 다 접고 성질 더러운 진짜들만 남은 게임입니다 혹시라도 복귀 할까 싶으면 마음 접으시길 바랍니다
# 기존 클래스: 3, 판단된 클래스: 0, 확률: 0.73
#
# 문장: 캐릭터 디자인 BGM 타격감이 뛰어나고 미국 카툰식 화풍도 깔끔한 느낌을 준다 협동 슈터게임으로서 게임성 자체는 완벽에 가깝다고 생각한다 그에 반해 협동 게임 특유의 정치질 게이머가 많다는 점과 과도하게 비싼 부분결제 요소는 꽤나 거슬리는 편이다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.98
#
# 문장: 솜브라 패치는 진짜 말도 안된다 이러면 누가 솜브라 씀 할거면 제대로 해라 제발
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 좆버워치
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.97
#
# 문장: 유저 수질 좀만 더 유지하면 롤이랑 비비겠네ㅋㅋㅋㅋ
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 거듭된 패치로 그나마 게임이 되긴함
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 병x같은 운영이 게임 말아 먹은 케이스 게임을 하고 나면 블리자드 망했으면 좋겠다는 생각을 하게함
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.85
#
# 문장: 게임이 안 좋은 점 업데이트 이후 추천 레벨 이상 사설게임 만들 수 오버워치 같은 은장 금장 거 없어짐 피 ### 늘어남 거리데미지 ### 걍 맘에 안듬 게임을 자꾸 쳐 망쳐놓음 오버워치 ### 한 유저가 극대노함
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.56
#
# 문장: 얘네가 뭔잘못을 했냐 신규 모드라면서 팀포 그대로 배낀 PVE를 만들겠다고 했다가 취소라도 했냐 트레일러도 팀포mvm 그대로 배끼기라도 했냐 한정스킨이라고 못쳐박다가 갑자기 상점에 돈주고 사게 쳐내기라도 했냐솔까 근데 이건 난 좋음ㅋㅋ 신캐들을 무조건 배패로 쳐풀어서 좆같게 하기라도 했냐 별 애미없는 모드는 쳐내면서 하나무라를 없애기라도 했냐 후 억까는 자제해주세요 지랄이고 할만함
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.97
#
# 문장: 내 사랑
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 뭐지 그윽한 똥내는 거기에 중독되어버린 나는
# 기존 클래스: 0, 판단된 클래스: 8, 확률: 0.92
#
# 문장: 게임 킬때마다 다운로드때매 분 넘게 기다려야됨 재미는 있는데 이런거좀 곤쳐줬으면
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 이거 게임 아니다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 재미있당
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: ㅈ망겜
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.96
#
# 문장: 오버워치 E스포츠에 한국 게임단이 없는 이유가 한국 리그만 보면 다 외국기업이여 그만큼 운영을 x나게 못한다는거죠 라이엇 블리자드
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.51
#
# 문장: ㅈ망겜
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.96
#
# 문장: 이거 왜케 평가가 안좋음 난 재미있던데
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: ㅈ망겜
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.96
#
# 문장: 얘들이 너무 못해서 재미가 없다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.99
#
# 문장: 망
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 병신겜 친구랑 하는거 하지마세요
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.66
#
# 문장: 재미땅ㅎㅎ
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 이만한 겜은 없다
# 기존 클래스: 4, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 볗스ㅟㄴ게임이 뭔 게임 실행할때마다 콘텐츠를 설치한다고 분인가 게임도 못하냐 재부팅할때마다 무결성검사해도 아무것도안뜨는데 뭘 설치를 쳐한다고 재부팅할때마다 ㅈ랄이신지 대단한게임납셧네
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 살다살다 오버워치를 스팀에서 플레이를 다하네 오래살고 볼일이다 틀딱아님
# 기존 클래스: 8, 판단된 클래스: 4, 확률: 0.98
#
# 문장: 재밌음 근데 이 더 재밌었음
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 솔직히 배그해보고 발로 해보고 FPS게임들 가지 다 해봤는데 개인적으로 점만점에 점정도로 나쁘지않고 재밌음
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 왜인지는 모르겠는데 계집년들이 좋아하는 게임 반반한 계집 사냥하러 종종 하는 게임 계집들 안했으면 하지도 않을 겜
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.97
#
# 문장: 뭐 개병신 ### 같은 게임이 다 있냐 ### 게임 만든 ### 엄마 ### 따고 ### 안에다가 주먹 넣고 돌려 버리고 싶네 ### ### 겜 개 좆같아서 쳐 지운다 씨발새끼야 아론 캘러 븅신새끼야 블리자드 직원 전부다 일자로 세워둔 윈스타 테슬라 건으로 조져서 아앙 아앙 신음 ㅈㄴ게 내게 하고 싶네 이시발새끼들아 게임 좆망해서 유저 수 나가 떨어지니까 주노 엉덩이 디자인 개꼴리게 쳐 내는게 세 게임이 맞냐 시발새끼야 세가 없는 ### 조선시대 선비들이 쳐 하는 게임 개보자 같은 게임에 몇백시간 투자한 내 인생이 후회된다 발로란트보다 나은점이 하나도 없는 게임 내일 블리자드 본사 찾아가서 거기서 불 지르고 오줌 싼다 내가 이렇게 화났냐면 ### 탱커 다이아 승급전 앞두고 연패했는데 그건 그렇다 치는데 연패 끊는 판이었는데 갑자기 오버워치 개튕겨서 분 정지 쳐 당하고 점수는  그대로 쳐 깍아가고 게임은 렉 하나도 안 걸리고 원할하게 돌아가는데 유독 게임만 쳐 튕기고 서버와 연결이 끊기는지 모르겠음 패작한 ### 핵 쳐 쓰는 새끼들은 밴 쳐 안 때리고 나같이 던지는 새끼한테 욕 몇번 했다고 달 정지 쳐 하는게 맞는거냐 욕설 정지 벌써 번인가 쳐 당했다 무튼 이제 놔줄 때가 된거 오버워치 개좆찐따 퇴물 새끼야 잘 살지 말고 이따가 덤프트럭에 치어서 죽어버려라 ### 씨발새끼야
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 재미는
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 스팀 처음이자 마지막으로 리뷰 남겨본다 좋았던 부분은 다 도려내고 진짜 개병신겜 됐네
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.97
#
# 문장: 중국인이랑 매칭 안 시키면 나름 괜찮음
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.98
#
# 문장: 로그인창 사람인증 만든새끼 누구냐 뭔 오래 걸리는걸 단계나 만들어 걍 안해
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.96
#
# 문장: ### 재밌다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 로그인 과정 개 복잡함 예전 생각나서 해봤는데 ㅈ노잼
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.78
#
# 문장: 위도우메이커 재밌어요
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 섹스하고싶다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 확실히 옛날 맛에서 중국산 조미료를 추가한 느낌임 옛날의 잊을수 없는 신선함과 재미에서 새로들어온 건강에 ㅈ나 안좋은데 뭔가가 맛있는 맛이 추가가 됨 중국산 조미료라 해서 몸에 안좋은거 의식하고 먹으면 꺼린데 무시하고 하면 재밌음 근데 건강에 안좋은만큼 오래하면 질릴듯 가끔씩 생각날때마다 해주면 확실히 재밌을꺼임 점차 나아지는 모습 보이니깐 굿임
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.57
#
# 문장: ez가 언제부터 욕인가요
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: ㅄ정공겜
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.78
#
# 문장: 오버워치에 비해 영웅도 맵도 많아졌지만 재미 자체가 없어짐
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.99
#
# 문장: 망겜인거 같습니다 개인적인 생각이므로 깊히 생각 해주지 마시길 바람니다 정IN호
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 빠대까지 매칭 줄인다고 티어 분포로 잡아버리는 매칭 개좆병신게임
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 좇같은 핵쟁이병신같은 뉴비 개같은플레이 조작법 오버워치
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 개쌉존잼 꼭해봄셈
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.87
#
# 문장: 가끔 두세달에 한두판씩하면 재밌음
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: ㅈ망겜 왜함
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.97
#
# 문장: 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 ### 터진 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 좆망 겜 ###
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 옵치만 년차 지겹지만 겜하려고 컴퓨터 키면 옵치부터 킬려함 습관이 되버림 옛날이 더 재밌었지만 아쉬운거지
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.99
#
# 문장: 망겜인데 재밌음
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 외국인들만 엄청 많고 재미도 갈수록 점점 떨어짐 년도가 제일 좋았어요 gg
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.98
#
# 문장: 개병신 같은거 계정 연동 이딴식으로 병신같이 해둘거였으면 그냥 스팀에 쳐 내지를 마 ### 하자년들이 그냥 지들이 계속 떡락하는지 이유를 모르나보네 ### 그냥 롤한테 계속 뒷구멍 따이는 이유를 모르는구나 아니다 그냥 이리 하러가죠 이터널 리턴 접속해서 루미아섬 사랑 해주세요 감사합니다ㅗㅗ
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.99
#
# 문장: 오버워치 아나 출시 때부터 한 유저입니다 오버워치 도 정말 많은 기대를 했죠 기대는 정확했습니다 아오 너무 재밌더라구요 오랜만에 해서 그런지 경쟁 매칭이 분 걸리더라구요 정말 좋았습니다 손을 풀 수 있는 시간까지 마련해주는 게임 이런거 잘 없거든요 정말 희귀합니다 유저들이 제가 게임을 못할 조언을 해줍니다 접어라 ### 쳐 접어라 이렇게 조언을 해주곤 합니다 정말 감사하신 분들입니다 게임 사용자 지정 게임이 메인인 게임인거 같은데 정말 컨텐츠가 풍부하고 마인크래프트와 샌드박스식 게임처럼 많은 것이 가능한 게임인 것을 알게 되었습니다 신캐들도 정말 매력적이에요 주노라던가 주노라던가 주노라던가 뭐 두더지도 있고 사이버 오줌싸개도 있고 정말 매력적이고 다양한 신캐들이 저를 반겨주었습니다 오랜만에 게임을 이렇게 재미있게 한 것은 이번이 처음입니다 정말 감사합니다 저는 블루 아카이브 하러 가보겠습니다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 안하는지 모르겠음 너무 재밌는데 많이들 하길 바라요
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 개좆망겜
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 하고싶은 캐릭 업적으로 막아두는 ㅄ겜 롤이나 발로는 게임하면 재화 주고 그걸로 내가 원하는 캐릭 살 수라도 있지 업적으로 막아두는거는 진짜 그냥 판수박아 무조건 게임 많이 해 이거 이상도 이하도 아님 그냥 악질임 이러니 도 망하고 도 메이저 겜이 못 되지
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.53
#
# 문장: 남탓의 게임화
# 기존 클래스: 0, 판단된 클래스: 8, 확률: 0.99
#
# 문장: h 포르노 공장 h
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.99
#
# 문장: 즐겜하기 좋음
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 병신겜
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.59
#
# 문장: 벤처 지워라
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.98
#
# 문장: 개좆롤 하다가 추억삼아 옵치 와봤는데 그렇게 망겜소리 듣는 옵치가 롤보다 재밌노
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.97
#
# 문장: 게임 수준 압도적으로 부정적 평판 압도적으로 부정적 게임사 압도적으로 부정적 운영 수준 압도적으로 부정적 밸런스 패치 수준 압도적으로 부정적 DLC 가격 압도적으로 부정적 팀빨 수준 압도적으로 부정적 최적화 수준 압도적으로 부정적 서버핑 수준 압도적으로 부정적 경쟁돌리는데 핑터져서 졌다 개망겜이 서버가 감자라서 안들어가졌는데 이걸 경쟁밴을 때리네 어지간한 망겜도 이정도는 아닐거다 제발 섭종했으면 좋겠다 병신을 위해 기가를 투자할 가치따위는 없다 제발 대규모 그룹 경기 만든새끼는 사냐 그냥 뒤지는게 답이다 세상에 게임은 없었다 이것은 게임인가 산업폐기물인가 스팀에서 깔았는데 배틀넷 계정 연동에 평가가 부정적에서 올라가지도 못하는데 이정도면 스팀에서 내리는게 맞지 않을까
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.96
#
# 문장: 애증으로 하고 있지만 이제와서 새로 할 훌륭한 게임은 아닙니다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: ㅈ같이 재미없네
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 오랜만에 하니까 추억돋고 좋네요
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 주노가 너무 이뻐용
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 블자에서 는 죄악이다 조만간 오버워치리저렉션 나오고 더지랄난다에 블자사장 ### 쪽을 검
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.97
#
# 문장: 굳
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 리황 진짜 씹간지네
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 개버러지 게임 ### 벤처 개새끼가 뒤질려고 환장했나 니거새끼 돈없어서 임플란트도 못하는새끼가 돌이나 씹어먹고
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 공겜
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 인증 망겜
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.96
#
# 문장: 가볍게 게임하기 좋음
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 죽지도 않았던 겜이지만 사후지원을 해야하는지 잘 보여주는 병신갓겜
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.77
#
# 문장: 블리자드 게임 완전 좆망게임
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 하지마세요
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 병신게임 배틀넷 계정 관리에 문제가있으니까 플레이하는데 지장생김
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.74
#
# 문장: ㅈ병신겜 매칭돌리면 우리팀에 무조건 던지는놈이나 포꼬있음
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.97
#
# 문장: 진짜잘만든갓겜운영도참잘함
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 개븅신겜
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 비응신 유저들의 ### 정치질 능력 게임사의 엄청난 운영 개똥겜
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.66
#
# 문장: ### ### ### 게임 ### 뭔 게임이 되야 하던가 말던가 하지 십새가
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.96
#
# 문장: 개재밋음
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 오버워치는 정말 실망스럽습니다 블리자드의 지나친 PC주의는 게임의 재미를 심각하게 저해하고 있습니다 게임 내에서 표현을 사용하더라도 엄격하게 제재를 가하는 운영 방식은 정당한 이유 없이 플레이어들을 억압하고 결과로 인해 많은 유저들이 불합리한 제재를 받고 있습니다 게임 컨텐츠 자체도 실망스럽습니다 오버워치과 비교해 큰 변화가 없고 새로운 요소들도 대부분 기존의 시스템을 재활용하는 수준에 불과합니다 게임의 핵심적인 문제점은 개선되지 않은 채로 남아 있으며 블리자드가 플레이어들의 의견을 제대로 반영하지 않는 같아 매우 실망스럽습니다 블리자드는 고객 지원에 대한 문제도 해결하지 못하고 있습니다 고객 문의에 대한 대응이 느리고 불투명한 제재 결정 과정으로 인해 유저들이 불만을 표출할 수 있는 방법이 제한되어 있습니다 이로 인해 플레이어들의 신뢰를 잃어가고 있습니다 운영 방식과 컨텐츠 수준으로는 게임의 미래가 어둡다고 생각하며 다시는 게임을 플레이하지 않을 것입니다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 이게임은 오리사가 제일 강합니다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.96
#
# 문장: 오버워치 의 장점 영구 무료화 엔진 업그레이드 신규 영웅 신규 전장 신규 스킨 신규 컨텐츠 VS 영웅 일부 리메이크 임무 미션 추가 오버워치 의 단점 앞서 말한 장점들은 굳이 편 아니었어도 편으로 충분히 할 수 있었음 스킨 구매 전리품 삭제 현질 시스템으로 변경 스킨 가격 K물가급 고작 이것들 준비한다고 편 없데이트 기간 ### 굳이 편 아니었어도 편으로 다 엎을 수 있던 것들인데 괜히 옵치로 엔진 바꿔서 지랄하겠다고 선언한 뒤 민심 안 좋을까봐 준비하던 거 그나마 편에서는 못보고 편에서 크게 보여줄 수 있던거 PVE 모드 PVE 모드는 ### 반 전에 개발 중단 그걸 이제 말함 아예 취소 된 건 아니고 전작의 인 협동 플레이 처럼 한다 이게 웬 걸 정신 못 차렸나 이걸 유료로 비싸게 쳐 팔아 먹고 앉아 있네 PVE 모드 취소 이유 우린 아직도 LGBTQ 뇌절에 맛 들렸는데 그게 소홀해질까봐 PVE 아몰랑 귀차나 시전함 추가 소식 ### 월 일 부로 PVE 개발 축소도 아닌 그냥 전면 취소됨 어이는 커녕 기대가 싹 다 뒤져서 알아서들 하라 사실상 망하는 자체가 불가능한 게임을 이렇게 망하게 만드는 것도 능력 잘하는 짓이다 블리자드 ㅇㅐㅁㅣD진ㅅㅐㄲㅣ들아 진작에 D졌구나
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.55
#
# 문장: 너무재밌고 가끔식화나긴하지만 최고에요
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 매칭 시스템 만든 개발자는 필히 자살하길 바란다 개 ### 새끼들 옵치에서 로 넘버링 한 이유가 뭐냐 도대체 개 버러지같은 게임
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 엉덩이
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.97
#
# 문장: 렉 도 없어서 하기 좋음
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 장점을 상쇄시키는 개발속도가 이모든 평가를 압부로 만들게함 pve삭제 ok 디렉터 관점 괜찮아 나름 좋은 방향의 고집과 개발방향을 알수있었음 ok 신캐주기 개월 신맵과 신캐를 개월 단위로 나와야지 수지타산이 맞지 pvp만 집중하고 개발팀도 포기안하고 계속 새로운 시도를 준비중인거면 그속도가 빨라져야 정상인데 애들은 pve접은 이후에도 개발속도는 나아지질 않고 배틀패스는 독특한 취향으로 계속나오고 유저 니즈도 미국중심으로 운영중 이게 운영중심은 어디국가든 상관없지만 나름 한국에서도 꽤하고있고 옵치전성기 한획을 도왔던 나라인데 요즘들어 정성이 부족한느낌 요약업뎃빨리좀
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 발로란트보다 재밌음
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.99
#
# 문장: si진ping시발새끼야
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.99
#
# 문장: 맛있는똥
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 리뷰 남길라고 깔았다 씨이이발럼들아
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 둠피 개씹사기
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.97
#
# 문장: 탱커는 부담감 높다고 개 징징 딜러는 ### 내가 다 해줬는데 다 뭐함 뻔뻔 힐러는 오빠들 뒤좀 봐줘하면서 절대로 픽 안바꾸고 지 상황 모르는 무능함
# 기존 클래스: 8, 판단된 클래스: 5, 확률: 0.66
#
# 문장: 굳이 똥을 찍어먹어봐야한다는 사람한테 강추 난 스캇충이였나봄
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.88
#
# 문장: ### 전으로 돌려
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 화나서 삭제했다가도 화났는지 잊은 후 다시깔고야 마는 게임
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 게임을 유료로 팔아 쳐먹는 거 돈 주고 사다가 안에 가챠까지 질러놨는데 밸붕에 개차반운영인거 업데이트로 해결할 생각은 안하고 섭종과 라는 숫자 붙여서 vs 인거 vs 로 바꿔서 출시해놓고 처음부터 다시 과금하세요 와중에 ㅈㄹ맞은 정치적올바름 마소가 액블 인수한지 일이 더 넘었는데 아직까지 지경이면 마소의 액블 인수는 액블의 발전에 아무 도움이 안된다는거지
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.97
#
# 문장: 겜 첨하는데 브론즈 새끼들이 일겜에서 패드립 날린다 처 패버리고 싶노
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 망겜인데 노력을 하니까 봐줄 까
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.99
#
# 문장: ### 비슷한 등급끼리 붙여주던가 자꾸 티어 ### 차이나는 애들만 적팀으로 만나냐 블리자드 애미뒤진 병신새끼들아
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 씨발련아 사람 맞다고 겜보다 인증이 더어렵네 개 ㅈ같은 블리자드 년들아
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.99
#
# 문장: 망겜
# 기존 클래스: 0, 판단된 클래스: 8, 확률: 0.99
#
# 문장: 어린 시절의 추억이 떠오른다 재밌긴 하다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: h 만에 게임 하려면 늦은시간에 돌리지 마라 h 친구랑 돌리는데 짱ㄲㅐ 새끼들 명이랑 매칭되서 쪽도 못쓰고 개 발렸다 내 인생 처음으로 이렇게나 쪽도 못쓰고 진건 처음이였다
# 기존 클래스: 8, 판단된 클래스: 0, 확률: 0.92
#
# 문장: 개성있는 캐릭터와 매력적인 세계관 지금도 촌스럽지 않은 그래픽 롱런할 수 있는 요소들과 기회가 많은 작품인데도 이렇게 망쳐놓는 경우는 진짜 대단하다 끝내 pve 스토리모드는 제작진의 개발 역량 부족을 스스로 인정한 결과로 안 나오게 됨
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: ### 초보 망겜
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.98
#
# 문장: 인생게임이지 뭐
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 퍼즐게임인가요 진짜 빡치네요 로그인만 분했어요 다 맞게풀었는데 안되냐고요 진짜 사람 빡치게하는 게임 만들지마세요 빡치니까는
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 오버워치 ㅆ발 개새끼들아 로그인할때 저딴거 추가했냐 시발장ㅇH인같은 블리자드 ㄱH년들아 나가 뒤져라 ㅅ발
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 한판 이기면 귀신같이 처발리는 매칭만 뜸 한판하면 하기 싫어지는 ### 겜
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.55
#
# 문장: 캬 갓겜
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 주노 빵댕이 ### 탐남
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.98
#
# 문장: ### 느그옵 느그옵 퇴물이네
# 기존 클래스: 8, 판단된 클래스: 4, 확률: 0.64
#
# 문장: 본 게임이 재미없는 갓겜 이게임사는 누구보다 워크샵유즈맵 만 잘냄 지네들 본편 게임에나 집중하지 pve 낸다고 개 지 랄은 다해놓고 지들은 한참 광고할때 중지했다 카드라 이게 ### 게임사가 맞냐 사기꾼들 모여있는 회사지 여캐는 뽑아내는것같음 음지에서 보자
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.96
#
# 문장: 토르비욘 작작 고
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.99
#
# 문장: 개씹좆좆
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.96
#
# 문장: 오랜만에 다시 해보고 느끼는 점은 게임자체가 재미보다는 스트레스를 더 준다는 재밌는 영웅을 플레이하면서 느끼는 쾌락은 잠시뿐이고 대부분의 시간은 상대편의 조롱을 듣거나 같은 편의 남탓을 듣거나 의미없는 싸움으로 보낸다 게임의 근본적인 문제점은 팀플레이 게임에서 비롯되는 스트레스다 간만에 다시 해보고 과거의 내가 게임을 스트레스를 받았는지 알게됐다 모든 게임은 유저가 열심히 한 합당한 보상을 준다 유저를 오래 붙잡고 있는 게임들은 대부분이 점을 따르고 있고 부분이라도 즐거움을 느낄 수 있는 탈출구가 항상 존재한다 게임은 내가 아무리 열심히 했다 해도 같은 편에게는 내 실수 한번이 더 부각되고 칭찬보다는 야단을 많이 맞는다 개인의 실력차이를 떠나서 시스템은 게임을 하는 내내 즐거움이 아니라 스트레스 지수를 더 키운다 플레이어가 한번의 게임에 정성을 쏟았다면 그만큼 게임은 플레이어에게 칭찬을 아끼지 않아야 하고 자신의 시간을 쓴 쾌락을 보상으로 주어야한다 오버워치는 게임의 철칙이 무너져있다 분 남짓한 경기속에서 내 캐릭터를 움직이고 열심히 화면을 좇아 무언가를 해낸 흔적들은 승리나 패배라는 글자하나에 의미없게 된다 언제나 승리는 가볍고 패배는 무겁다 게임엔 승리외에 즐거움을 느낄 수 있는 탈출구가 존재하지도 않는다 PVP게임에서 즐거움을 느낄 수 있는 부분은 내가 좋아하는 영웅을 숙련하고 상대방을 제압하는 데에서 온다고 생각하는데 숙련의 과정이 게임에서의 롤 플레잉과는 다르게 상당히 엄격한 팀플레이 속에 있고 철저하게 평가받는 시스템 상에 존재하기에 우리는 그것들을 게임처럼 즐기며 숙련할 수 없다 게임을 하다보면 즐거운 경기도 가끔 내가 팀을 승리로 이끌고 고수가 된 거기서 오는 쾌락은 지극히 짧으며 대부분은 패배로 점철된 우울한 경기를 보내거나 상대편의 의미없는 조롱이나 같은 편의 지적을 들어야한다 오버워치라는 게임은 하면 할 수록 스트레스라는 지옥으로 빨려들어가는 듯한 느낌을 준다 잭팟 한번을 잊지 못해서 도박장을 반복해서 출입하는 사람처럼 작은 쾌락을 주는 단 한번의 상황을 마주하려고 스트레스 받는 나머지 게임을 참고 하는 것은 자체로 나에 대한 고문이 아닐까하는 생각에 나는 게임을 삭제했다 여태까지 많은 FPS게임들을 해봤지만 오버워치만큼 스트레스 받는 게임은 단언코 없었다고 확신 할 수 있을만큼 게임은 정신건강에 치명적이다 나는 게임을 추천하지 않는다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 느그애미
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.94
#
# 문장: 판부터 팀 싸우고 욕하고 ㅈ망 겜 더러워서 안한다
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.95
#
# 문장: 그냥 보다는 아쉽지만 도 개성이 있어서 재미있음
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 잼난당
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 진짜 개 병ㅅlㄴ 게임
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 이야 평가 오랜만에 하면 재밌긴하다 PVE만 잘만들고 스팀 출시 했으면 평가는 좋았을껀데
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: ㅄ겜
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.92
#
# 문장: 정치겜
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.96
#
# 문장: 그래봤자 오버워치
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 매칭 진짜 ### ### 문제많다 블자 개ㅅㅐ끼들아 부계 양학 패작 씨발련들아
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 이보다 나쁜 게임은 있을 수 없다 핵 시발련들 실력도 안되면서 왜쓰냐 최악의 게임
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 일반 오류입니다 ㅅ발
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.97
#
# 문장: 로그인이 안됌
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: ### 안되잖아 개새기야
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.97
#
# 문장: 잦같은게임 븅진같은게임
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.94
#
# 문장: 바스티온 버프좀
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.99
#
# 문장: ### 전 옵치는 이러지 않았던 거 같은데 게임회사 맛탱이가 가버림 한 정말 열심히 했고 애착을 가졌던 게임이지만 처참한 상태가 되어버린 게 안타까울 따름임 사건사고가 터져도 항상 응원했던 블리자드이지만 이제는 돌이킬 수 없는 강을 건너버렸다 옛 정때문에라도 긍정적 평가를 주지만 있는 게임이라도 잘 운영해라 블쟈야 제발
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 압도적으로 부정적
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 팀빨 ### 병신겜
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.68
#
# 문장: 니네보다 중국공산당이 더 나을거같네요 씨발것들아
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.89
#
# 문장: 음 옵치 돈주고 산 흑우 없제
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.99
#
# 문장: 오버워치 이었을 떄가 더 좋았던거 같아요
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 재밌음
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 역사에 남을 것이다 배설물 게임
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.98
#
# 문장: 뜌따뜌따 메이 장인이 될거야
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 저혈압 치료게임
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.97
#
# 문장: tq게임 계정만들때 게인정보 다넣었는데 tq지네들이 처리를 못한다면서 wf발광을 떨어서 ㄹㅇ진짜싫다
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.94
#
# 문장: 병신겜
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.59
#
# 문장: 서버도 터져 팀도 터져 아론켈러도 터졌으면
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 병신같은 게임이 하필 팀플레이로 처 나와서 더 지랄맞음 인간혐오생성기 ### 상대가 입터는건 게임이나 똑같은데 상대팀중 한명 핀포인트 잡아서 집단 여론 린치 때리는 좆같은 게임은 오버워치밖에 없을거다 ### 욕을 안하면 내가 욕먹고 욕을 해도 내가 욕먹는 ### 대가리에 낙진 떨어지는 게임 가장 잘하는 새끼가 가장 정치당하고 ### 못하는 고아새끼들이 뻔뻔해지는데 매칭시스템이 개 좆같아서 ### 한명 이상이 기본이고 티어를 절대 못올림 내가 중립적으로 나의 에임이 부족한지 포지션이 잘못 되었는지 다 살펴보고 객관적으로 많이도 생각해 봤는데 ### 감 안좋은 판이 한 판중 한번인데도 ### 절대 탈출 못함 처음부터 다혈질인 ### 한번 뭐라하면 던지는 ### 걍 트롤년 ### 못하는 말많은 ### 주변에 시비만 터는 ### 죄다 한꺼번에 정신병원마냥 모여서는 티어안에 서식하는데 이딴 새끼들이 안나올리도 없어서 올릴 수 있을거라는 희망을 공중폭격후 뒤처리해서 분해시켜버림 정신에 생기는게 빠르겠음 그냥 안하는게 맞는 게임임 운영을 잘하는 것도 아니고 프로필 비공개에 스트리머 모드같은 ### ### 팔등분 시키는 패치나 진행하고 게임 세부적 정보 공개는 ### 꺼리는데 ### 게임 데이터안에 직박구리 파일 처 모아둔 것도 아니고 우리끼리 분석하고 게임좀 굴려본다니까 ### 병신짓 하고 LGBT ### 진짜 장난하자는 거지 티어가 절대 안오르고 트롤년들은 점점 보여서 걔네한테 한마디씩좀 하니까 채팅금지시키고 나아가 게임정지를 먹이는데 그냥 탈출했어야 했음 당시에 정지한다고만 써있고 이유가 명시되어 있질 않아서 문의넣으니까 뽕을 키리코한테 주네 이딴게 ### 이유랍시고 내뱉고 있고 븅신같은 재제시스템이 저딴 트롤들이랑 악질 새끼들을 잡아 처 내쫒아야지 고통받는 사람한테 엿을 추가로 맥이는건지 도저히 생각해봐도 악마같은 새끼들이 따로 없음 진짜 그냥 개 처망했으면 좋겠고 제발 오래가지 마라 질병게임아
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.99
#
# 문장: 유저들의 인성수준이 나오는 줫망겜 탑티어급이다 많이하지도않은 유저로서 플레이를 하고있지만 잘좀하라는 팀원들의 욕짓거리와 비아냥대는 사기저하 적들은 쉽네 허접이네 라는 말들만 많아서 하지말라는지 알아가는 느낌이드는것같다 걍 게임은 애초에 하질 말라는 씹망겜이 맞다 게임이라는 말도 담으면 안될듯 게임도 아니야 이건
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.97
#
# 문장: 고인물들의 세계에 던져진 피지컬 F급
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.97
#
# 문장: 회사의 좆같은 운영과 인식을 빼면 모든게 완벽한 갓겜
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: ### ㅈ망 핵 ㅈ망 매판 만나는 잼민이들 패작 ㅈ망
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.93
#
# 문장: 조ㅈ망겜
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 망
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 되도록이면 주말이나 휴일에는 하지마세요 왜냐고요 하지 말라면 하지 마세요
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 노잼
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 게임은 질병이 아니다 게임은 질병에 가깝다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 재미음서
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 진짜
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 인증절차 미친거냐 개 줫가이 만들어놨네 망겜이라고
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.97
#
# 문장: 병신같은 게임
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.82
#
# 문장: 안그래도 캐릭터수 ㅈ도없는데 다잠궈놓고 판수채우면 풀어드려요
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.93
#
# 문장: 레킹볼하게  다시 돌려내
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 하다보면 시간아까움
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: ### 뭐만하면 콘텐츠 다운 이지랄 하는데 게임할맛이 ### 없네 개좆같은 게임
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 좆망겜
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 오버워치부터 년부터 해서  월에 접었다 그마도 번 찍어보고 마스터에서 주로 살다가 다이아도 갔다가 그랬는데 접은 지 개월이 넘게 지난 지금 유투버들 보면 다 죽은 자식 ### 만지고 있더라 병신같고 병신들이 많고 병신같은 판이 넘쳐나는 것을 보고 나는 잘 접었다고 생각했다 천시간 가까이 했었지만 그만큼 사랑했던 게임이지만 떠나보내길 잘한 게임이다
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.93
#
# 문장: 그냥 이해가안됨
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 재미있다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 히히 재미있당
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 재밌어요
# 기존 클래스: 0, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 보안문자 개좆같아서 정떨어지는 게임
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 병신소굴
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 욕을 먹긴해도 할만한겜이 이거밖에 없다ㄹㅇ
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 병신같은 매치메이킹 트롤 패작 핵 성추행 말고 잘하는게 없는 회사
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.91
#
# 문장: 로그인이 보통 애미가 뒤진게 아니네 천생고아해라
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.91
#
# 문장: 오랜만에 복귀해보았는데 오버워치에서딜둠피가부활한것같은기분이들었음 밴처라는것을 상대할떼 암살을시도할떼 하이리시크하이리턴이없음 아나유저입장에서 반응해서 수면총꺼내드는순간에죽어있음 또는 자리야같은 탱이 도와주거나 라이프위버가 커버해주면 그냥딸깍하고 우리쪽아나죽어있음 궁이너무쉬움 연발에 편적공격 좌우봐꿔서 공격가능 너무쉬움 수면총 꺼내는속도가 초더빨랏음좋겠음 아니면수면총두발주던가 명이물러오면그냥죽음 하나재워도 하나가죽이러감 탱이랑맞다이하는데 비비는딜러는 딜러가아님 평좌평이면 탱커근이면 딸피됨 그러고땅속으로들어가서 살아남음 오버워치에서 둠피뗴문에뭐시기당한거기억못하고 또이딴거만듬 일단재우면 죽는각이보여야하는데 안죽음 수면 평타 힐벤 평타 해도살아남음 힐조금이라도들어가면 살아남음 저쪽은 리스크없이죽이러가는데 내쪽은살아남으려면리스크있어야함 수면빠지던가 힐밴빠쟈서 버티던가하면 딴놈이와서나죽이러옴 같은딜러도마찬가지임 암살콤보맞으면 평등하게죽음 거리를안주고싶어도 맵떼문이라던가 화물이라던가 하면거리줘야함 무조건죽음 일단밴처어느정도할줄알면 그냥딸깍으로 힐러 하나삭제가능 이러고도 오버워치 서비스종료시키고 정신못차리고만든게 밴쳐라는생각이듬 평가는 별반개줄려고했는데 옛정을생각해서 별개에서 개해서 별한개줄려고함
# 기존 클래스: 0, 판단된 클래스: 8, 확률: 0.98
#
# 문장: 중국인들 쫌 자기들끼리 겜하게 해라 짜증나 한국서버에는 와서 해 말도 안통하는데
# 기존 클래스: 8, 판단된 클래스: 0, 확률: 0.74
#
# 문장: 패치 개망겜
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.98
#
# 문장: 허구한 날 무료급식소 찾아와서 줄서서 배식받는 입장에 뚫린 입이라고 배급해주는 음식의 수준에 투정부리고 불평해대는 걸뱅이새끼들 마냥 온갖 천애고아새끼들이 플레이가 본인 입맛대로 안되면 현란한 채팅 뽐내며 본인 정신질환자다 자랑하는 게임ㅋㅋ 외 보빨한남과 여왕벌 힐러 혜지듀오 패작 정신병자 핵쟁이 온갖 ### 외눈박이새끼들을 판마다 매칭시켜주는 좆병신 랜덤박스같은게임ㅋㅋ ### 쓰레기같은 게임ㅋㅋ오버워치탈출은 지능순ㅋㅋ
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.51
#
# 문장: 개노잼 사람들도 별로없음 근데 영웅은 판해야 풀리는 새끼들도 있음 애초에 뉴비 유입도 안되게 해놨네 게임보다 못나가는 이유가 이건 과학이다 오버워치는 이제 망겜이 맞다
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 짱개들 종일 핵쓰면서 게임해도 제제 안하는 개똥겜
# 기존 클래스: 3, 판단된 클래스: 0, 확률: 0.98
#
# 문장: 에휴
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 벨런스 문제를 떠나서 유저들이 병신임 유저들이 망친게임
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.82
#
# 문장: 오버워치 사랑해요
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 운영해야 게임을 망칠 수 있을까를 사흘밤낮으로 고민한 결과물
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 음 오랜만에 똥겜 상태좀 보러왔는데요 아직 똥이네요 감사합니다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: ### ㅈ병신 게임 새로 시작해보고 싶어서 들어왔는데 인증 개어렵게 꾸역꾸역 개 다 완벽하게 했는데 안된다는거야 병신년들 인증 처 했으면 게임하게 해줘야지 뭔 퍼즐을 처 풀게하냐 이러면 나같은 새로운 유입도 없고 운영도 ㅈ병신같이 하고 엿이나 처먹어라 개병신년들
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 로그인 줫같이 만들어놨네 휴면계정 풀려고 본인인증 시키더니 성명 작성 하라해놓고 한글타자 못쓰게 하는건 고도로 엿먹이냐 블리자드 ㅅ발아
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 돌리면 매칭되는데 친구랑 같이돌리면 십발분 넘게 매칭 안됨 병 쉰
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 내 대 초반을 갈아 넣었던 게임 추억의 게임을 더럽히다니 블리자드 병신들은 비추나 먹어라
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.97
#
# 문장: 개 ### 게임 오류하나 못잡을거면 스팀 버전을 대체 왜내는거임 좆같은 월급루팡 새끼들
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 재미는 있는데 예전 같지는 않다 더 블라자드는 수면 위로 뜨지 못할거
# 기존 클래스: 5, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 발로란트 보다 재밌음 롤할때 멘탈터지면 하기좋은게임
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 왜욕하는진 잘 모르겠는데 둠이나 다시 딜로 만들어라 게이들아
# 기존 클래스: 8, 판단된 클래스: 5, 확률: 0.82
#
# 문장: 갓겜
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 시발이게헤드
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.92
#
# 문장: 망겜
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.99
#
# 문장: 운영 ㅈ도 못하네
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 메르시야 듣지마 넌 누가 뭐래도 최고의 힐러야
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.99
#
# 문장: 병신겜
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.59
#
# 문장: ### 회원가입 존나오래 걸리네썅이렇게 오버워치를 하려던 또하나의 뉴비가 사라진다
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.94
#
# 문장: 걍해 할게임없으면해
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.99
#
# 문장: 예전에 중딩때만해도 빛나던 게임이 어쩌다 이렇게된걸까
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 사실상 패작부계양학핵 얘들이 접속자 절반 정상인이 절반 이거 어쩔라고 그러는거야
# 기존 클래스: 0, 판단된 클래스: 8, 확률: 0.98
#
# 문장: ### ### 배틀넷 ### ### 거 로그인 ### 힘드네 간단하고 쉽게 만들어 시벌새끼들아 몇번을 인증하게 만드는 거여 드러워서 안한다 ### 시발년들아
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 재밌어서요그거 빼고는 없어요 좨송합다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 오버워치보다 최적화가 정말 심각하지만 컴퓨터만 받춰준다면 괜찮음 스팀 서버와 운영하게되면 짱개들의 핵을 감당할 수 없을 듯 가뜩이나 요즘 블리자드 인식도 안 좋은데 배틀필드 시리즈와 배그같이 ### 핵판이될 가능성이 매우높아보임
# 기존 클래스: 8, 판단된 클래스: 0, 확률: 0.97
#
# 문장: ㅄ같은 게임 걍 너네 회사는 제발 망해라
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 병신겜
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.59
#
# 문장: 홀로 팀 보이스로 브리핑 없이 남 탓만하던 그의 목소리를 나는 잊지 못할 것이다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 재밌겠냐
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 짧은 기간 갓겜이었던 오버워치 ver 배그가 등장하기전 년은 정말 오버워치의 시대였습니다 거짓말 안보태고 남녀노소가 즐기던 fps게임이었습니다 FPS를 처음해보는 여성분들이 메르시 디바 등으로 유입되었고 벽타는 루시우 한방 활컨셉의 한조 망치광 라인하르트 저격하는 힐러 아나 닌자컨셉 겐지 저격의 위도우메이커등 다양한 컨셉의 캐릭터들로 라이트 게이머와 하드 게이머 트롤 모두가 화합하는 장이었습니다 FPS 게임으로써는 드물게 남녀파티도 많았고 즐거움도 많았습니다 프로 리그도 시작되고 미로 류제홍 새별비등 스타 플레이어들의 현란한 플레이는 모두를 자극했습니다 말도 안되게 느려터진 컨텐츠 추가 괴상한 PC도입등 문제가 불거지기 시작했고 그즈음 등장한 역대급 히트작이 오버워치의 숨통을 끊어놓습니다 진퉁 역대급 국뽕 게임 배틀그라운드가 출시된 것입니다 자연스레 저도 배그로 갈아타게 되었고 년간 오버워치는 잊고 살았습니다 더더욱 폭망의 길을 걷는걸 보고 스킨에 많은 돈을 부었지만 접길 잘했다고 생각했죠 그러던 와중 ### 오버워치 정식출시되고 스팀에도 등장하게됩니다 한때 사랑했던 게임이기에 다시 해보았고 그때의 향수가 느껴지는 듯 합니다 제발 부활해서 다시 재미를 주면 좋겠습니다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.80
#
# 문장: 섭종기원
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 똥겜
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.96
#
# 문장: h 매칭병신겜 h 메르시 원챔 안 만나기하면 다음판에 메르시 원챔을 만남 메르시한테 힐러 가능하냐 물어보면 읽씹or발작 메르시 원챔한테 게임 돌리지 말고 밥이나 하러가라 했다고 채팅금지 듀오로 메르시 원챔 명 팀밴 넣어두고 이제 안 만나나했더니 딜모이라 만남 힐만 꽂지말고 공벞 꽂으라고 했다고 삐져선 하루종일 공벞만 꽂는 메르시 유저는 한 트럭으로 만나본 거 같네요 상대 팀엔 키리코 바티스트 넣어주고 팀엔 모이라 메르시 넣어주는 블쟈가 너무 밉습니다 게임할 때는 담배 안 피러가는데 오버워치는 매판이 고비라 한 판 끝나면 담배 피러가야함 오버워치가 저를 꼴초로 만듭니다
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.82
#
# 문장: 핵 뭐냐 캐릭터 찍어내기만하면 뭐해 핵이 판치는 겜이구만 스트레스 받지말고 다른겜하러가셈
# 기존 클래스: 5, 판단된 클래스: 8, 확률: 0.98
#
# 문장: 배틀냇이랑 스팀아이디 연동을 ㅈ같게 해놨노
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 병신같은게임 피드백한것도 신고받으면 욕설로 차단 필수적인 브리핑도 못하게 모든 소통 차단 그냥 병신겜 그냥 그대로 망해라
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.95
#
# 문장: 게임이 아주 좆네요
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.93
#
# 문장: 걍 신캐고 뭐고 둠피 이씨발련 너무 하기싫음 둠피 하는새끼들 평균이 양심 하나도 없이 처뒤져서 꼬우면 너도 하던가 이러는데 누가 둠피를 하고싶대 둠피가 없는 오버워치를 하고싶은건데 ### 쓰레기들이 개패고 싶게 하고 둠피스트 이새끼는 그냥 우리집가게 주방까지 처들어와서 음식내오라고 난장판 내고 나가는데 책임하나도 안지고 돈하나 안내고 잘 들렀다 갑니다 함 걍 이새끼를 만든지 모르겠음 둠피 씨발련이 아니꼬와서 접을게요 그냥
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 곧있으면 성별 크레파스 나온다 애들아 존버타라
# 기존 클래스: 8, 판단된 클래스: 5, 확률: 0.52
#
# 문장: 사람들이 평가글에서 유저 수준을 괜히 언급하는게 아니다 조용하다가도 게임이 잘 안풀리면 정신병걸린 애들이 꾸득꾸득 기어나온다 특히 트위터할거 같은 말투로 시비걸면 찢고싶다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.99
#
# 문장: 내 인생을 갈아넣은 게임 언젠간 할 친구가 생기겠지ㅠ
# 기존 클래스: 4, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 내가 다른건 모르겠고 진짜 짜증나서 쓰는건데 협동미션 메르시 못하는게 왜이렇게 많음 스토리고 나발이고 올영웅 언락모드 추가하는게 그렇게 힘들었나 이럴줄 알았으면 안 샀어 메르시 추가는 처 안해놓고 스킨은 처 냄 가격 n만원 ㄷ신새끼들 운영 ㅈ같이 하네
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.99
#
# 문장: 요즘은 매칭안잡히는거말곤 괜찮지않음 일단비추
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 흠 할만한데
# 기존 클래스: 0, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 꽤 재밌다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 그냥 생각없이 일반전하기에는 괜찮은거 같기도 년도당시의 그때의 추억이 생각남
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.52
#
# 문장: 말이 험하고 능지가 딸리는 노매너 유저가 많음
# 기존 클래스: 8, 판단된 클래스: 4, 확률: 0.84
#
# 문장: 시즌은 최악의 시즌이 맞다 모든 딜러들 상대적 박탈감 느끼게 하는 벤처에 티어차이가 안나도 넓은 그룹경기 이지랄 힐러 탱커 매칭시간 분 걸리게 하질 않나 핵은 안잡고 팀엔 중국인 한두명 씩 있어서 소통도 안돼 신화스킨 성능 박은 메르시 모이라 같은 챔프로 낼꺼면 쓸 수 있게끔 버프를 하던지 얘는 년도에 섭종하는게 맞았다
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.94
#
# 문장: 진짜 망겜 때도 업데이트할꼐요 이러고 년간 아무소식없음 겐지뽕값하는 트레일러내고 뭐한건지 그러고 마인크로소프트가 가져와서 계속 이상한겜으로 만드는중 솔직히 중국 짭퉁오버워치하는게 나을듯
# 기존 클래스: 8, 판단된 클래스: 0, 확률: 0.70
#
# 문장: 탱커도 인권이 필요하다
# 기존 클래스: 4, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 어쩔까
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 개잼
# 기존 클래스: 0, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 인성 빻은 유저들과 정신나간 블리자드 환상의 콜라보
# 기존 클래스: 8, 판단된 클래스: 4, 확률: 0.64
#
# 문장: 개줫같은 게임 영웅 밸런스 ㅈ도 쳐못맞추고 넌 그냥 아나가 신챔으로 나왔을 때가 전성기였어 이렇게 갓겜을 개밥버러지같은 운영방식으로 쳐말아먹네
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 이건 아니잖아요
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 병신겜
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.59
#
# 문장: ㅄ같은 게임 ㅄ같은 운영 ㅄ같은 중국인
# 기존 클래스: 8, 판단된 클래스: 0, 확률: 0.62
#
# 문장: 뒷골목 맛집 원탑 게임
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: pve 폐기했으면 pvp라도 잘만들어야 하는데 뭔 판에 한 번씩 트롤이랑 핵을 만나냐
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.95
#
# 문장: 너무 재밌어요
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 그냥 오버워치 초창기로 와라 진짜 ### 애들 스킬도 ### 됐고 맵도 병신됐고 물리엔진도 병신됐네 오랜만에 생각나서 해봤더니 진짜 그냥 병신겜 됐네
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.88
#
# 문장: 랙이안걸림
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.98
#
# 문장: 대규모 패치는 맞다 공백이 년이라 문제지
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.60
#
# 문장: 캐릭 잠겨있는 꼬라지를보니 겜이 처망한 이유를알거같네요
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.89
#
# 문장: 팀 병신게임
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.64
#
# 문장: 다 재밌습니다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 생각보다 재밋음 굿
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 매치가 아주 전보다 잘잡히네요 굿
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 고인물 새끼들이 가까이 와서 뉴비 도발로 놀리고 지랄하는거에 질려서 삭제하는 경우
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 말해뭐해
# 기존 클래스: 1, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 잼있긴함
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 예나 지금이나 쓰레기같은 게임성 ### 같은 설정 멍청한 개발자 팀 해체를 바람 ps 게임이 병신이니 남아있는 유저들이 다들 정신병자 장애인들 밖에 없음
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.80
#
# 문장: ㅈ노잼 블리자드 망한 거 다 티나노 영호ㅘ나 만들어라 할리우드 새기들아
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.97
#
# 문장: 나는 재밌음
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 신캐 너무 못생겼어요 이럼
# 기존 클래스: 8, 판단된 클래스: 1, 확률: 0.97
#
# 문장: 개발자들이 유저를 년을 기다리게 해놓고 PVE 취소에 밸런스 패치도 개판으로 이랬다가 저랬다가 장난치세요 게임 적응 하려고 하면 계속 바꿔대서 적응하기도 엿 같네요 앞으로 블리자드 게임은 손절하기로
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.92
#
# 문장: 할게임 없을 떄 뭔가 하던 게임이 물려서 할만한 게임을 찾아볼 다시 해볼까 그떄 하면 개꿀잼
# 기존 클래스: 0, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 옵치버리고만든다는게고작이거냐
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.99
#
# 문장: 제가 년부터 년까지 이게임을 했는데 년이후 영정을 당했습니다 이유는 욕설이라는 사유입니다 저는 ### 욕을 ### 영정주는 게임을 처음 봤습니다 제가 가장 좋아했던 게임이였던건 사실입니다 이시바랄 개같은게임을 하직도 하고있는게 시발같네요
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.96
#
# 문장:  우리는 정말 멋진 PVE 컨텐츠를 위해 옵치의 개발속도를 늦추겠습니다  어이쿠 코로나가 왔네요 정말 멋진 PVE 컨텐츠는 ㅤㅤㅤ지금 내부적으로 플레이 가능합니다  걱정마세요 PVE 컨텐츠는 정말 멋지고 나올겁니다  옵치를 출시했습니다만 정말 굉장하도록 PVE는 나중에 내놓겠습니다  PVE를 취소하겠습니다 스토리모드는 굉장하고 계속해서 낼거에요  스토리모드를 취소하겠습니다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 진짜 하지마셈 정신병걸림
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.98
#
# 문장: 게임성은 좋다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 욕하려고 깔았다 ### 블리자드고아새끼들아 겜운영을 하면 이렇게 병신같이 쳐할 수 있는건지 ### 신기방기한 회사임 병신겜회사는 태어나서 첨본다 제발 하루빨리 부도나 망하길 바란다 좆망자드 개씹새끼들아
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 몇년전부터 했지만 둠피탱커는 언제봐도 너무 아쉽다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 옵치으로 롤백해라
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 좆망겜임 하지마셈
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: ㅄ겜
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.92
#
# 문장: 접속이 안되고 업그레이드 안되네요 빨리 고쳐주세요
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.99
#
# 문장: 개병신게임
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 알잖아 너를 이토록
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 대놓고 버그쓰네
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 병신겜
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.59
#
# 문장: 년도 까지만 해도 재밌었는데 많이 바뀌어서 쫌 엤날 감성이 별로 없네용
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.55
#
# 문장: 오랜만에 하면 그럭저럭 재밌음
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 등장부터 지금까지 그냥 레전드 게임사
# 기존 클래스: 0, 판단된 클래스: 8, 확률: 1.00
#
# 문장: The people who make Overwatch porn work harder than the people who make Sports 오버워치 포르노를 만드는 사람들은 스포츠를 만드는 사람들보다 더 열심히 합니다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 게임은 뉴비를 두번 튕겨냅니다 렌더링으로 한번 튕겨내고 뉴비배척으로 두번 튕겨내죠 개망겜추
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.99
#
# 문장: 블리자드 새기들 지들이 아직도 옛날 명성 그대로인줄 아는게 역겨움 홍대병 쳐 걸려서 유저 의견은 듣지도 않다가 모양 꼴 오버워치 방치 해놓고 뭐 말같지도 않은 핑계로 ### 옵 출시를 미룸 오버워치를 만드는 이유가 pve 였는데 그것 유기해버림 그냥 유저들 개돼지로 봄 디아블로도 망치고 이제와서 뭐 하려하지만 그것도 성과가 안나옴 하라는 게임 개발은 안하고 직원들끼리 물빨 하다 성추행 논란이나 터뜨리고 ### 웃김
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.97
#
# 문장: 유저간 ELO 매칭 개같이 못잡아서 한 쪽이 양학하는 게임이  이상임 이게 게임인지 스트레스 제조기인지 모르겠음 이거 할 바에 발로란트 하셈 그냥
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.96
#
# 문장: 망겜
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.99
#
# 문장: 망여기까지
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 아시발 블리자드 씹련들아 히트박스 쳐올리지 말라고
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.99
#
# 문장: 나라 인간들은 게임만 처 하면 던질까 진짜 의문이 든다 본인의 부모도 다리 밑으로 던진건가 착짱 죽짱을 실현하고 싶다
# 기존 클래스: 8, 판단된 클래스: 0, 확률: 0.66
#
# 문장: 굿
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 개 ㅣ발꺼 남들도 꼭 했으면 좋겠음 나만 당할수 없지
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.90
#
# 문장: 친구들이 하자고 해서 해봤는데 예전 느낌이 물씬 풍기면서 매칭만 빼면 제가 기억하는 모습의 게임인 같습니다 그래픽도 이쁘고 타격감도 좋은 게임이라 추천합니다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 둠피때매 망한 오버워치 거기에 PC를 싸서 드셔보세요 지랄났다 블리자드 좆됐다 블리자드 둠망겜이 탄으로 돌아오다니 진짜 좆같네요 지혼자 스턴걸고 지혼자 날아댕기고 지혼자 탱킹하고 지혼자 보호막 충전하고 지혼자 CC걸고 지혼자 죽창딜 궁극기 쓰는 애미뒤진 개병신 둠피새끼 너프 해라
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 붕쉰같은 게임
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.99
#
# 문장: 입털면서 노잼드립칠거면 가서 발로란트나해라
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.98
#
# 문장: 시발ㅋㅋㅋㅋㅋ배틀넷에 옵치깔고 스팀에다가 옵치깔수있게 해놨으면 한쪽은 실행 안되게 막아놔야지 둘다 켤수있게 만들어놨네 ㅋㅋㅋㅋ걍 어뷰징하라고 이렇게 처만들어논거임 대놓고 악용하라고 ㅋㅋㅋㅋㅋ유저수 어떻게든 늘릴라고 개발악하다가 검토 도안하고 스팀에 출시쳐해놨네 걍 운영개판인거 스스로 인증하는꼴이네 개병신 빡대가리 블리자드ㅋㅋ 이딴식으로 운영할꺼면 걍 섭종하자
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 추억을 느끼기 위해 오랜만에 함 전체적으로 게임이 빨라지고 재미가 없어짐 그냥 재미가없음
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: ### 개 병신같은 겜 휴면이라 해제하려고 인증하니까 등록 안되있다면서 새 아이디를 만드려고 번호입력하니 ### 병신마냥 번호 있습니다 다시 인증하려고 번호치면 번호 등록 안되있음 지랄병 개 ### 뒤진겜
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 재미 ### 없고 패치는 병신같이하고 오버워치 추억도 날려주고 소통도 안해 방치는 존나잘해 돈은 빨아먹어 미친새끼들인가 이딴 게임은 하면 ### 안하면 정상임 나가 뒤져라 오버워치 야
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.99
#
# 문장: 팀포 흥해라
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: pve언제 나옴그래서 pve언제 나옴그래서 pve언제 나옴그래서 pve언제 나옴그래서 pve언제 나옴그래서 pve언제 나옴그래서 pve언제 나옴그래서 pve언제 나옴그래서 pve언제 나옴그래서 pve언제 나옴그래서 pve언제 나옴그래서 pve언제 나옴그래서 pve언제 나옴그래서 pve언제 나옴그래서 pve언제 나옴그래서 pve언제 나옴그래서 pve언제 나옴그래서 pve언제 나옴그래서 pve언제 나옴그래서 pve언제 나옴그래서 pve언제 나옴
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 저장공간낭비
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 솔직히 어디가서 추천할만한 게임은 아님
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 숨어있는 옵붕이들 개추 눌러보자
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.97
#
# 문장: 멍청한 놈을 하는 멍청한 게임 엿 먹어
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.90
#
# 문장: 재밌어유 아주 칭찬해유
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 유저들 의견 개무시하고  좆망겜 밸런스 좆망 운영좆망 지듦맘대로 영웅은 뭐만하면 ### 레즈 양성애자 어휴
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: ### 좃망겜 게임은 재미있는데 ### 팀운 좃망겜 재미도 없네 ###
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 매칭은 좆버러지만큼도 못잡아주면서 개병신새끼한테 병신이라고했다고 채금먹이는 개 ### ### 정신병자 트젠 애미뒤진 ### PC충새끼 게임
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 재밌누ㅋ
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 애미씨발련들아
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 짱임
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 게임은 확실히 재미있음 에펙 같은 배틀로얄보단 옵치가 취향이라는걸 확실하게 깨달았음 핵 문제도 문제지만 게임 자체가 많이 낡아서 그런지 뉴비가 입문하기엔 너무 많이 고인듯합니다 운영은 모르겠고 제발 캐릭터 밸런스 문제만이라도 조금이라도 고쳐주려고 노력해주었으면 좋겠네요 블리자드 색히들아
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.95
#
# 문장: FPS 게임 자체가 경험 없는데 일겜에서 못했다고 패작이라면서 신고 하라네요 이제 막 판 했는데 FPS 자체가 첨이라고 말할려고 했는데 판 안 채웠다고 그것도 안된다고 하고 게임 자체가 뉴비 배척에 사람들 질도 떨어지나봐요 진짜 병신겜 첨 본다
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.79
#
# 문장: ㅈ같지만 낫배드
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 밸런스 ### 게임
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 돈 얻다썻냐 이것들아
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 초때 친구들이랑 피시방에서 즐겁게 하고 저의첫 게임이 오버워치였기 저는 좋게 주겠습니다 추억때문에
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 재미없어서 하루에 한번밖에 못하겠어요
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 반년에 한번씩하면 재밌음
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 굳이 말을 해야 아나
# 기존 클래스: 0, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 재밌음
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 병신겜
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.59
#
# 문장: 개좆망겜 ### 병신같은 겜
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 신케 ㅈ망겜 신케없음 겜이 안돌아감
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.97
#
# 문장: 내가 결제 했었던 것들은 없고 게임이 고여서 일반겜에서 입구컷 당함 일반게임 쥰내 해서 영웅 하나하나 얻어야하는것도 엿같고 다 엿같음
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.92
#
# 문장: 로그인 페이지 자동으로 새로고침좀 시켜라 씨애발미진뒤련들아 아님 한번 나갔다가 들어오라고 말을 하든가 뻉뺑이 존나돌리네
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: pve 상태는 별로였고 무엇보다 벨런스가 너무 이상해졌다 이게임 한국인 유저수준은 중국인 보다 못한 수준이다
# 기존 클래스: 8, 판단된 클래스: 0, 확률: 0.76
#
# 문장: 시ㅣㅏㄹ 오버워치ㅡㄹ 만든 이유가 뭐였ㄷ건거임 pve도 좆망했고 pvp도 바뀐게 뭔ㄷ ㅔ대체 옵치로 보여주고 싶었던게 무ㅝ였는데 븅신ㄱ
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.99
#
# 문장: 이거 가끔씩 해야 재밌음 자주하면 그냥 쓰레기에서 개똥쓰레기됨ㅇㅇ
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 메치메이킹 최악 임
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.90
#
# 문장: 개인적으로 할만함
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 재미있음
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 개병신게임
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 운영 개망겜
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.94
#
# 문장: 병신같은 게임
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.82
#
# 문장: 니 ㅐ미
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.79
#
# 문장: 중시절부터 지금까지 옵치해본 사람으로서 ### 깨져있습니다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 운영도 밸런스도 다 내다버린 게임 할 게임이 없어서 하는 게임 패치도 지랄맞게 하는 겜
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 재밌음
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 씨발년들 초창기부터 해줬더니 유저를 좆만하게 보네 좆같은 아나는 관짝에 안박고 투방처럼 좆같이 패치하냐 투방워치 아나워치 소전워치 씨 발 페미 bbc빨이 같은 좆더러운짓도 탱커는 인권운동가로 만들고 자빠졌네 고아인가 망할 애미가 반토막이 나서 주술회전이랑 콜라보 쳐박고 있는건가
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 좋은 겜입니다
# 기존 클래스: 2, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 에임 연습으로 자주 할꺼같네여
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 여러 콘텐츠 제작과 신규 캐릭터을 활발하게 추가시켜서 게속 재미있게하고 여러나라의 축제행사을 한다 이것뿐만이 아니라 요즘에는 한국 여자아이돌인 르세라핌과 콜라보을 하여 르세라핌 스킨등을 판매하였고 올해가 청룡의 해여서 청룡의 해 관련 이벤트을 할 예정이라 신규유저나 복귀하려는 사람이 많았으면 좋을
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.99
#
# 문장: 할꺼 없을때 하기좋음
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 사람이 문제지 게임은 재밌음ㅇㅇ
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.99
#
# 문장: 히오스처럼 유기될 거 같은 막장스런 게임 분위기 시즌 에서 개선이 별로 안된다면 같은 대깨옵도 더는 못 버틸 가뭄에 콩 나듯 비슷한 대전 상대와 혼신의 힘을 다한 게임을 하는 재미가 있지만 이제는 판은 해야 한 판이 그런 판이다 pve 유기했으면 경쟁이라도 살려라
# 기존 클래스: 3, 판단된 클래스: 2, 확률: 0.72
#
# 문장: 탈주 불이익 만든거임 이거 게임 만든 애들은 게임 안해봤나 애들이 게임 던지고 있는데 나갈수도 있지 그따대고 불이익 ㅄ들인가 이러니까 게임이 망해가지 진짜 패치 하나는 뒤지게 못한다
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.95
#
# 문장: ㅈ같은 겜 쳐다도 안본다 다시는
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.94
#
# 문장: 인게임도 병신인데 게임 외적으로도 ### 자체임 절대 플레이하지 마십시오 좆망겜 JOAT
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 마우가 너프나 해라 벌레 게임
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.93
#
# 문장: 아직도 고급시계 아니야
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 너네는 그냥 쳐 망하고 회사가 운영 하는게 더 이롭겠다 색종이 가지고 비행기나 쳐 만들고 있네
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 회사가 운영을 못하면 생기는
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 가슴 속에 묻어둬야하는 게임이다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 병신겜
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.59
#
# 문장: 옵치 안하다온 사람 입장에선 재밌음 옵 안하다온 나도 pve 전면유료가 ㅈ같은데 옵하다온사람들이 ㅈ같을진 상상이 안감
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.94
#
# 문장: 매칭 엿같은
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.75
#
# 문장: 게임 한 번 ㅈ같네
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 씹 창렬겜이 다 됬네 스킨 캐릭터 새로 나오면 그냥 침 줄줄 흘리면서 쳐다만 보고 있으면 됨 밥 한 숟갈 떠 먹으면 될듯
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.96
#
# 문장: 이정도면 나름 할만하다고 생각됨
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 장점 겜을 너무 잘만듬 단점 겜을 너무 잘만듬
# 기존 클래스: 0, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 개씹대작 IP를 만들어내고도 말아먹은 블리자드에게 경의를
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.97
#
# 문장: 할만 함
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 중국병신겜 하지마세요 나빼고 다중국인이고 아무리 실버여도 예전에 이정도까지 못하진않았어 애들이 병신겜 진짜 이거할시간에 다른겜하셈
# 기존 클래스: 3, 판단된 클래스: 0, 확률: 0.45
#
# 문장: PC주의 페미니즘 만세
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.97
#
# 문장: 갓겜
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 재밋다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 오버워치가 다시 되살아니길 기원합니다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 블리자드의 황금기와 쇠락기를 상징하는 게임
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 모드가 너무 재미없어서 배성근 한테 따지고 싶을정도임 참신한것쫌 만들어봐라 배틀로얄이라든가
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 좆망겜 유저가 좆같음
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.99
#
# 문장: 에임 ### 안좋으면서 끝까지 딜러하는새끼들 망치로 ### 꺠고싶네 ###
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 플래시포인트는 조만간 호라이즌이랑 쓰레기통에서 쎄쎄쎄하고 있을거다  마우가 개 Tㅣ발 얘나오고 자유는 탱메타임 탱 명으로 힘들다고하니까 지옥에서온 대  기관총맨을 내놓냐
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.95
#
# 문장: 로그인부터 안되잖아 시발련아
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 개 비융신 게임
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: ###
# 기존 클래스: 2, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 처음 오픈 후 여러 시네마틱과 웅장한 감동과 전율을 느끼게 해줬던 인생게임이였던것 그나마 기대하고 있던 년의 기다림에 빅엿을 먹여준 기만
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.86
#
# 문장: 문장우 빼고 안 함
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장:  미워도 다시한번
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 전작보다는 별루지만 친구들이랑 그냥 가볍게 즐겜하기는 괜찮음
# 기존 클래스: 0, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 하지마세요 대께옵은 저하나면 충분합니다
# 기존 클래스: 3, 판단된 클래스: 2, 확률: 0.83
#
# 문장: PVE낸다고 잘만든겜 년반동안 없데이트로 유기시키고 유저 다 털다가 낸 게임 PVE도 개발중단시킴 도대체 없데이트한거임
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.99
#
# 문장: _____ __ ____________ __
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 초짜가 모를 수도 있지 랭킹전도 아닌데 불만있음 전번 까서 얘기를 하던지 씹련들이
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.97
#
# 문장: 재미도 없고 추억도 사라졌고 중국놈들만 늘고 ### 없는 놈들도 늘고 이제 블리자드는 생각이 없네
# 기존 클래스: 8, 판단된 클래스: 0, 확률: 0.62
#
# 문장: 망겜인데 갓겜인듯 망겜같은 이상한 게임
# 기존 클래스: 2, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 여기가 밑바닥인줄 알았는데 밑이 있었구나 년동안 도대체 뭘 한거냐 블쟈야
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.62
#
# 문장: 좃망겜
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 팀밸런스좀 맞춰 ### 오버워치 관계자들아 ### 못하는 애들만 나한테 있냐고 케릭도 병신처럼 건들고
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.76
#
# 문장: 이미 옵치때부터 망한 게임을 살리려고 한거 부터가 잘못됐음 그냥 개 좆망겜 살다살다 좆망겜처음 본다 ### 같은 게임 지금은 패작하려고 게임 하는 중ㅋㅋㅋㅋ 대깨옵들 부들부들 거린ㄴ 거 보면 재밌음
# 기존 클래스: 8, 판단된 클래스: 2, 확률: 0.54
#
# 문장: 굿 핵좀 없애라
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.99
#
# 문장: 스팀으로 와서 핵도 많아졌지만 추억이 많은 게임
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 쿨타임 돌때마다 한번씩 하는데 그때마다 달라진게 없어서 놀라는 게임
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 굿
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 조끄튼 겜
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.94
#
# 문장: 한조 이쌔끼가 제일빡침
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 스팀 들어와서 편함
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: h명작이자 근본이었던 섭종시키고 넘어와서 개좆망해버린 게임 h 고쳐지지않는 밸런스 지 좆대로 패치함 몇년째 사골이 썩어서 증발할정도로 우려먹는 재탕이벤트 컨텐츠를 크게 개선할 생각이 없음 영자가 유저랑 소통을 잘 안함 데스매치 같은 개별 전투모드의 경우 토르비욘봇만 절반수준임 때와 비교했을때 확실히 유저가 많이 떨어졌다는것을 느낌 중국인 대거 유입으로 핵쟁이 ### 많음 신고를 해도 영자가 영정 제대로 때리는지 모르겠고 상대측 팀원중에 핵쟁이가 있으면 상대측 팀원이 핵쟁이 쉴드쳐주고 피해자팀한테 핵무새들 이라며 핵쟁이 옹호하는 양심좆터진 유저도 있음 패작대리정치질탈주는 아직도 존재해서 그냥 경쟁전 자체를 안하게됨 경쟁전으로 인해 스트레스받고 겜할 이유없음 lol 처럼 서렌기능 도입해야될 부분이라고봄 최근에 탈주패널티가 도입되었는데 일반빠대에서 탈주해도 패널티먹음 탈주는 안하는게 맞음 근데 패널티가 도입된 이후 말이 ### 많아짐 진짜 문제는 중국인 이다 한가지 장점이라고는 신스킨은 자주내줌 근데 신스킨도 돈주고 구매해야됨 간혹 무료로 스킨을 줄때도 있기는 함 그냥 스킨팔이게임 아직도 하고있긴 뉴비는 찍먹만 해보는것을 추천드리며 혹시나 복귀유저 라면 과감히 비추천 드립니다 예나 지금이나 변한게 하나도 없습니다
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.88
#
# 문장: 모유도둑게임 수준
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.99
#
# 문장: 둠넘약 둠상필
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.95
#
# 문장: 개판임
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.99
#
# 문장: 배틀넷오버워치 계정 사용 용도는 대충 이렇습니다 h스팀으로 로그인하기h 이제 디아블로나 스타할때 스팀으로 로그인할수있음ㅋㅋ 무료화 되었는데 내 돈 돌려줘ㅅㅂ
# 기존 클래스: 0, 판단된 클래스: 3, 확률: 0.82
#
# 문장: 재미ㅆ띠ㅏ
# 기존 클래스: 0, 판단된 클래스: 8, 확률: 0.96
#
# 문장: 개좆병신 애미없는 호모두창트젠 게임인거 아는데 텐션 ### 높은 사람이랑 하면 생각보다 할만함
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.97
#
# 문장: 다 좋은데 한국인은 안보이고 죄다 중국인이거나 일본인인가요 말이 안통하니까 답답해 죽겠음
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.91
#
# 문장: 애미개씹쳐뒤진 게임
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 빠대 돌릴 가끔 끝나가는데 지고있는 게임 도중에 들어가지는 ㅈ같은게 없음 겜 질꺼 같으니깐 방 나가고 대체 인원으로 들어오는게 생각으로 시스템을 만든건 지 의문임 들어오고 나서 초도 안되서 끝난 적도 있음 이러면 난 뭘 해야하나 아무것도 해보지 못 하고 패배만 떠밀려 오는 게 맞냐 그게 통계에 남고 진짜 옵치는 전설이다
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.70
#
# 문장: 재밌습니다
# 기존 클래스: 2, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 개쓰레기똥겜
# 기존 클래스: 8, 판단된 클래스: 0, 확률: 0.55
#
# 문장: 생각보다 좋음
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 그냥 ### 게임임 예전부터 답이 없었는데 아시아 ### 통합 후부터는 진짜 답이 없음 매판 짱깨들 만나서 소통도 안되고 허무하게 지는데 게임이 재미 있을 수가 없음
# 기존 클래스: 8, 판단된 클래스: 0, 확률: 0.98
#
# 문장: 이게임은 게이영웅과 레즈비언 영웅 양성애자 영웅 모두를 무료로 플레이 가능합니다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.58
#
# 문장: 개병신겜
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 대충 대깨옵이 오버워치 자랑하는 내용
# 기존 클래스: 8, 판단된 클래스: 2, 확률: 0.91
#
# 문장: pve 관련 이슈로 민심이 나락 간 게임 옵치를 뭔가에 비교하자면 요즘 아이스크림이 아닐까 돈 맛을 보고 싶은건지 화려한 뭔가를 내는데 크기는 크기대로 줄고 맛도 예전에 느낀 맛이 아님
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 출시했을 PC방에서 처음 해보고 너무 재밌어서 기뻤던 오버워치를 이따위 수준까지 조져놓은 게 용납이 안 된다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.99
#
# 문장: ### 개좆호로병신같은 애미사지절단난 게임을 추억핑계로 내가미쳤지내가미쳤지내가미쳤지내가미쳤
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.99
#
# 문장: 쌍욕 부모욕 나오는 게임인지 알거다 해본사람들은 벨런싱 정말 임 어ㄸ떻게 개발자들이 머리가 없는지 하면할수록 승질남 한번 더 해봐도 역대급 똥망겜
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.89
#
# 문장: 매칭 븅신같이 잡아놓고 욕하니깐 정지먹이네 븅신같은 블리자드련
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.99
#
# 문장: 평가쓸려고 배틀넷 오버워치 삭제하고 스팀에서 설치함 개병신 좆겜
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.99
#
# 문장: 혐오스럽도다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 로그인 안됨
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 병신게임
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.56
#
# 문장: 오버워치
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: ###
# 기존 클래스: 0, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 답었는 팀원들에 감동햇읍니다 이랑 변한 점이 없지만 현질 유도가 심해진거에 감동했읍니다 그레서 휴지통에 덩크슛 햇읍니다 시발껏들아 추가 ### 르세라핌 스킨 이뻐서 사주긴 했는데 가격 양심좀 이딴식이라 더 비추다
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.91
#
# 문장: 아무리 망겜이더라도 년동안 정듬
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.99
#
# 문장: 아오씨발짱깨ㅑ게임
# 기존 클래스: 8, 판단된 클래스: 0, 확률: 0.96
#
# 문장: 스팀덱으로 플레이 마우스는 되는데 키보드는 인식 못함 해결책 아시는분
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 로봇 밀기 싸움도 너무 길다고 욕 ### ### 있는데 쟁탈전을 번 하는 맵을 만들자라는 아이디언 ### 대가리에서 나온 거냐
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.99
#
# 문장: 남탓충들
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.93
#
# 문장: 당신이 아는 정도 수준의 오버워치
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 응가
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 거점 개 먹는거 없애 씨발련들아
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 중국이랑 ### 나눠라 ㅈ같아서 못 해먹겠네 진짜
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.97
#
# 문장: 오버워치 다시 내놓아라 낸다고 을 없애 이 갓겜인거슬
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: Guten Tag meine Herren Ich bin Petrok und bin Spieletester Mein Arbeitsgeber meinte so Jo Brudi check ma Overwatch ab hab gehört das game is mega Goofy Papaplatte Also habe ich mich hingesetz und das Spiel getestet Dieses Hauptmenü ist so dermaßen Hässlich und vorallem wird man geearraped wenn man das spiel zum ersten mal startet Dann wird man in ein Tutorial reingeschmissen was einen erstmal vorgibt wen man spielen soll Wählen sie einen Tank aus wählen sie das und jenes aus bla bla bla Wir leben in  ich denke mal man sollte langsam selber entscheiden können wen man Spielen darf und wen nicht Ich habe mehrere Stunden in Ranked verbracht und das Ranked system ist ja so unfassbar schlecht das ich mir die Äuglein ausstechen möchte Ich finde das Spiel sonst an sich ganz okay Ranekd ist halt goofy und macht keinen Spaß Ich habe mittlerweile k Stunden in diesem Spiel Natürlich was Overwatch besser Bitte nicht ernst nehmen ich habe eine Farmilie und möchte nicht abgestochen werden GG Activision du hast die selber ins Knie gefickt
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.87
#
# 문장: ### 병신겜
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.68
#
# 문장: ### 버러지 세끼들
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 키리코 귀여워요
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 스팀으로 들어가면 오류 쳐 걸리고 안들어가지네 들어가지도 못하는데 대체 만든 거노
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.71
#
# 문장: 개발자놈들 뻘짓좀 안했으면
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.86
#
# 문장: 아오 ### 게임 물리가 웰케 ㅈ같아 근데 로드호그 야미 디바는 더 야미 like porn
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.96
#
# 문장: 내가 잘하고 못하고가 아니라 팀이 잘하고 못하고가 중요한 게임 그렇다고 한명이라도 못하면 걍 망함 재밌군
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 엄마를 ### 이렇게 게임을 망쳐라 내 시간을 낭비하고 내 돈을 낭비해
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.99
#
# 문장: 때보다는 일은 열심히하는것같음
# 기존 클래스: 0, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 앞으로 봐도 뒤로 봐도 ###
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 그와의 재회는 최악이었다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 부가 흥하면 부는 대부분 졸작이다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 말이 필요한가
# 기존 클래스: 0, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 이런것도 게임이라고 걍 오버워치을 스팀에 내지 그랬냐ㅋㅋ 다 망한 게임 스팀에 내서 뭐하시게
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: PVE 개발한답시고 옵치 유기때렸으면서 PVE 개발도 유기때리네 C DA C JOAT of JOAT 개발사
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.98
#
# 문장: ### ### 지랄났음
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.97
#
# 문장: 친목질 페도필리아 중국인 좇망겜
# 기존 클래스: 8, 판단된 클래스: 0, 확률: 0.79
#
# 문장: 아오 진짜 ### 재미있지도 않은거 ### 좆같은거 누가하냐 ###
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 게임을 잘만들었어도 운영이 ### 박으면 이렇게 된다는 아주 좋은 교과서 같은 게임 개 씨이이발 스토리 ### 안풀고 캐릭터 설정도 좆박고 운영 밸런스 아주 개판으로 진행하고 리그도 말아먹는 진짜 개 ### 겜 블자 니들은 게임사 보다 그냥 격리소라 해라 ###
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: ㅈ병신 유저들과 함께하는 ㅈ병신같은 겜 년의 오버워치에는 낭만과 감동 재미 다 있었는데 지금의 ㅈ버워치는 게임도 못하는 장애 여미새들만 잔뜩 있는 병신집합소 게임 어디가서 오버워치 한다고하면 게임 하니 라는 소리를 들을 정도 리뷰 남기려고 깔다 지우는 것도 레전드 옆동네 롤은 몰락한 왕이 캐릭터라도 나왔지 게임은 뭐 나오기라도 해봐라 맨날 색칠놀이만 쳐하고 모양 꼴이지 그냥 얘네는 하스스톤 원툴임 이거 할 시간에 친구 없는 찐따들은 하스스톤이나 하고 인싸들은 발로란트나 하셈 그게 맞음
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 짱퀴벌레 새끼들 제발 다 쳐내자
# 기존 클래스: 3, 판단된 클래스: 0, 확률: 0.96
#
# 문장: 탱커하면 스트레스 존나받음 ###
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.81
#
# 문장: 이색기 왜여깄냐
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 년동안 리그 시청보상을 안고치냐 아깝네 시간 쳐 봤는데 시간 것만 주면 뭐하는거냐 제대로 주지도 않을꺼면 리그를 접어라 ㅄ들아 ### 전부터 문의했는데 오늘 내 문의 들어가니까 지웠더라 지우는건지 이해도 안되고 그냥 너넨 망해라 그냥 홍대병 쳐 걸려가지고 리그는 롤이나 쳐 따라갈 것이지 개발진은 ㅄ같이 성폭행이나 하니까 게임이 ㅇㅈㄹ이지 니들이 생각이 있었으면 이따구로 운영하면 안됐지 게임을 제대로 개선을 하던가 시즌 떄로 되돌리는게 유저가 더 들어오겠다
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 그냥 똥망겜 왜하는지 모르겠음
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.97
#
# 문장: 블자계정을 못만들기 스팀에 있는 옵치 깔았더니 블자계정 가져오라는건 뭐냐 솔까 이러면 스팀에 출시함 블자에만 출시 하든가ㅋㅋ 어이없다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 정신병 유발 겜은 하지마세요 특히나 탱커 유저라면 도망ㄱ
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.99
#
# 문장: 망겜
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.99
#
# 문장: 한 시대를 풍미한 게임사의 몰락과 발버둥이 한 게임에 담겨있음
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 빨리하셈 나중에 유료될수도
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 오버워치 정상영업합니다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 게임은 좋지 오버워치 잘 만든 게임이었지 블리자드가 낳은 자식이라 ㅈ같지만
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 쩝 핵 진짜 못잡음
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.99
#
# 문장: 다들 좋아하면서 싫어하는척 하는거임
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 병신겜
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.59
#
# 문장: 병신고아겜
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.68
#
# 문장: 오버워치 년동안 없데이트 하다가 과금요소 잔뜩 넣어서 이름만 바꾼 반쪽짜리 출시 추후 업데이트 예정이던 PVE 핵심 콘텐츠는 어영부영 날려버리고 좋게 볼 요소가 하나도 없다 종합평 오버워치가 팀 포트리스보다 먼저 뒤질 줄은 상상도 못했다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.65
#
# 문장: 스팀 부계로 블리자드 연동 시켯더니 본계 스팀은 연동 안되서 게임을 못하네 좆망겜 수준
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 개비응신 게임
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.80
#
# 문장: 게임 진짜 개 쥐좆같이 만들었네 ### ### 재미도없고 벨런스는 씹창이고 나가뒤져라 제발
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.91
#
# 문장: 추천하지 않습니다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 새ㄲㅣ들은 걍 겜 운영할 줄 모름 내가 해보고 느낀 문제점 몇가지 말해봄 플레이 경험에 대한 생각 자체를 안함 대표적인 예가 오버워치 부터 유구하게 내려온 중간 난입임 중간 난입을 한다는 자체가 누가 게임을 자꾸 나가기 때문이겠지 보통 다 져가는 게임에 들어와서 뭐 해보지도 못하고 패배라는 문구를 맞이함 이게 유저의 플레이 경험을 불만족스럽게 만드는 중요한 중에 하난데 이걸 뭐 할 생각이 없음 패스 경험치를 더주고 우선순위 대기열 어쩌구 이러는데 사실 그게 중요한게 아니라 옆집에 뭐 롤이 그러듯이 탈주시 후순위 대기열이라는 패널티를 줘서 나가는 자체를 줄여야함 서버통합 배틀넷 이새끼들은 뭐 자기가 있는곳은 다 비슷한 언어이라 말 다 통해서 걍 쳐통합 한건지 아시아에는 돈줄 중궈러만 있다고 생각해서 그런건진 모르겠는데 걍 서버를 통합한게 왜한건지 모르겠음 게임이든 협동 멀티 플레이라면 소통이 중요한데 서버를 통합시켜버리면 ㅅ발 말이 조온나게 다른데 소통하라는 건지 모르겠음 중국인이랑 일본인도 말 다다르고 한국인은 더 다른데 매칭하는거에 지역 우선순위 설정을 할 수 있게 하든가 걍 별 생각없는 패치에 결제 도장 쿵쿵찍어준것같음 게임 망해서 사람 없으니까 통합한거면 더 문제가 큼 걍 근본적인 문제에는 관심이 없단거니까 참고로 sb chino라고 쭝궈 만나서 좋같으면 쳐줘라 ### 쭝궈라는 뜻임 추가적으로 운영사의 태도가 맘에 안듬 근본적인 문제는 해결할 의지가 없는건지 능력이 없는건지 쭈욱 유비식 패치를 진행하면서 패스는 꾸역꾸역 계속 쳐만들어서 스킨으로 돈뽑아 먹으려는 태도가 걍 맘에 안듬
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.93
#
# 문장: 시즌 중반까지 하고 접었다가 스팀에 다시 출시되고 pve도 나왔다길래 다시 깔음 시즌도 풀로 못 채우고 다시 접었다 뭐 같은 매칭 개선 안 되면 앞으로 남은 건 섭종 뿐임
# 기존 클래스: 2, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 재밌누
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 스팀 아트워크 열어줘 텐련들아
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.97
#
# 문장: 이럴려고 편 섭종했냐
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 잘 만들었는데 하는 새끼들이 개병신새끼들이라 욕 먹는 게임
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 옵치만한게임 몇개 없다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.98
#
# 문장: 탱커 원래 좋아했었는데 는 개씹노잼이냐 뭐임
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.96
#
# 문장: 병신겜
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.59
#
# 문장: 전화 번호 확인을 해야 합니까 중국 아빠한테 놀래 나는 엄마를 망친다 너희들은 남은 평생 절대 좋은 보답을 하지 못할 것이다
# 기존 클래스: 0, 판단된 클래스: 8, 확률: 0.83
#
# ...
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.91
#
# 문장: 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 자유빠대 한판 해보니 년전 하던 기억이 새록새록그러면 뭐하나 역할고정 경쟁은 뭔가 심심하다 거기에 PVE 나왔대서 해보려 했더니 무려 유료 컨텐츠 콜옵같은 AAA급 싱글 캠페인 게임도 하락세인데 이걸 돈주고 살거라 생각하지
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 매칭이 안 잡힘 캐릭 해금이 너무 오래걸림
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 인터페이스에서 게임을 보았을 부분적으로는 놀라움과 부분적으로는 무력감이었습니다 그런 뻔뻔한 게임 회사가 감히이 게임을 우리에게 다시 가져 왔는지 그가 뻔뻔한지 속담처럼 남자는 무릎 아래에 금이 있지만 무릎을 꿇고 돈을 벌고 싶어하는데 정말 뻔뻔한데 열 수 없는 게임은 한국 개에게 적합합니다
# 기존 클래스: 8, 판단된 클래스: 0, 확률: 0.75
#
# 문장: 병신회사 이렇게 좋은게임을 완전 망쳐놓고있네ㅋ
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.96
#
# 문장: ### 게임 바보 소리치는 개새끼쓰레기 게임 바보 소리치는 개새끼쓰레기 게임 바보 소리치는 개새끼쓰레기 게임 바보 소리치는 개새끼쓰레기 게임 바보 소리치는 개새끼쓰레기 게임 바보 소리치는 개새끼쓰레기 게임 바보 소리치는 개새끼쓰레기 게임 바보 소리치는 개새끼쓰레기 게임 바보 소리치는 개새끼쓰레기 게임 바보 소리치는 개새끼쓰레기 게임 바보 소리치는 개새끼쓰레기 게임 바보 소리치는 개새끼쓰레기 게임 바보 소리치는 개새끼쓰레기 게임 바보 소리치는 ###
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 무슨망할게임너무쓰레기인데혹평놀기싫어
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.98
#
# 문장: 처음시작하면 애미뒤진 짱깨들이랑 같이해야함 게임은 드럽게못하고조금밀리면 탈주함 애미뒤진사창가에서 몸이나 파는 시진핑 좆이나 빠는 걸레련들 존나못하네 병신새끼들이 존나이기적인게 화물이 오면 지네 목숨이중요하지 게임지는건 안중요함 화물이 거점들어가면 겜끝나는데 그냥 뒤로 쭉빠짐 중국인들좀 걸러라 블리자드 ### 용주골에서 몸파는새끼들아
# 기존 클래스: 8, 판단된 클래스: 0, 확률: 0.88
#
# 문장: 다 좋은데 VPN 쓰는 중국인만 막으면 된다 중국인이 VPN써서 흘러오는 바람에 녹조물에 똥물 부은격이 되었다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.89
#
# 문장: 다들 뭔데 블리자드를 까내리는거냐 옵치만 한번 보자 출시 후 몇년동안 맵도 안내고 영웅도 안내기를 했냐 롤을 따라잡니 마니 근들갑떨면서 자화자찬을 했냐 맵 영웅밸런스가 안맞아서 피드백들어가면 밸런스패치에 한세월 걸리기를 했냐 얘네가 돈을 받고 게임을 팔다가 유저수 좆박고 무료로 바꾸기를 했냐 무료임에도 매칭돌리면 밥먹고 담배피고 씻고와도 될 정도로 오래 걸리기를 했냐 이랑 랑 차이 ### 없는데 어그로 끌어볼려고 후속작인척 넘버링달고 나왔냐 무료로 바꾸고 로 냈는데도 겜이 병신이라 유저수 안모여서 스팀으로 꾸득꾸득 기어들어오기를했냐 몇년동안 개발한다 해놓고 완성되지도 않은 PVE를 스팀에 오자말자 돈받고 팔아먹기를했냐 저렇게 긴 개발시간임에도 컨텐츠 규모를 줄이고 취소하고 로드맵도 안지키기를 했냐 멀쩡한 솔저를 갑자기 게이로 만들기를 했냐 솔저로 모자라 PVE 개발중에 파라도 사실 레즈임 하기를 했냐 알고보면 게임개발보다 PC를 지지하기를 했냐 대단하다 블리좆드 너넨 걍 나가라 겜좀 해봤다 싶으면 개병신버러지새기들인거 누가 모르겠노 대깨블 조련하면서 평생 JOAT 게임만 출시하길 바란다
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.90
#
# 문장: 재밌
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 사랑했다 ㅆ발련아
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 좋은점 오버워치아이디 가져오면 아이디의 렙을 가져올수있는거같음 처음시작했는대 레벨이 이 아니길래 뭐지 하고 있었음 안좋은점게임의 이해도가 부족한사람많음 트럭 밀어야하는 미션 있으면 킬만 하러 다니는 탱커가 있는가 하면 힐도 안하고 역시 딜량 높이고 싶은놈들도 있음 점령전인대 점령은 하는대 안 지켜서 빼기고 힐러들 점령한곳 치키고 함 뒤에 킬하러 가는놈들이 안따라 오냐 이지랄함
# 기존 클래스: 2, 판단된 클래스: 3, 확률: 0.83
#
# 문장: 앞으로 나아지길 바라면서
# 기존 클래스: 2, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 이딴걸 돈받고 쳐팔면 양심에 안찔리냐 모든 패치방향이 시간끌기 본 문제는 애써 무시하면서 숫자만 깔짝깔짝 책임회피가 패치노트의 퍼센트를 차지중 그나마 에서 시간이 지나며 봐줄만했던 매칭 밸런스는 초기보다 더 심하게 무기력 그자체 그마 쳐찍으면서 스트레스만 쳐받고 간다 역대급 운영 개씹망겜
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.97
#
# 문장: 캬 안녕하세요 오빠시계 투가 스팀에 기어 들어왔네요 이 나올당시에 해외에서 외쿸인 로동자로 일하느라 바빠서 못 해봤는데 덕분인가 프렌차이즈에 대한 애정이 눈꼽만큼도 없어서 한판해보고 적음 ### 들어가자서 총 한발 쏘니까 패배냐고 인간적으로 끝나기 전 게임엔 넣지 말아야지 유저를 총알로 보나 총알도 탄알집에 결합해서 장전하는데 난 준비할 수 없어 씨부럴꺼 보보꼭보좌 홍길동 센세의 평가가 갑자기 떠오르네 옵치 야동이나 보라고
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.96
#
# 문장: 블리자드에 문제가 있냐 그건 아니라고본다 블리자드 게임 사는 놈들이 문제가있다고 본다 애새기 버릇나빠지게 자꾸 사주는거냐
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.97
#
# 문장: 옵치돈주고산사람만 호구새끼지 븅신겜
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 대깨옵분들은 들어와서 도전과제 받아가세용
# 기존 클래스: 8, 판단된 클래스: 2, 확률: 0.96
#
# 문장: 망할 게임너무 쓰레기인데혹평놀기 싫어
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.92
#
# 문장: 옵치 조아
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 대깨옵
# 기존 클래스: 8, 판단된 클래스: 2, 확률: 0.74
#
# 문장: 임무패키지 절대로 사지마 하는 사람도 없어서 할 친구 명이 없으면 혼자서 깨야된다 나같은 히키코모리한테 하는 말임 인싸는 뭐 사던말던 알아서 하고
# 기존 클래스: 0, 판단된 클래스: 8, 확률: 0.97
#
# 문장: 죽은 엄마 블리자드
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 이게임을접하기전에저는게임이모두사람들에게즐거움을주는좋은게임이라고생각했습니다비록어떤게임은만족스럽지못하지만제작자의마음도느낄수있습니다이게임을접한후에저는제작진이우리게이머에대한악의메스꺼운쓰레기게임머리에문제가있는바보한국만이할수있다는것을깊이느꼈습니다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 폭설 너의 친엄마가 죽으면 나는 너의 엄마를 조롱할 것이다 마지막까지 중국 게이머들의 돈을 굴리려고 한다 너의 엄마는 매우 대단하잖아너를 처음에는 젠중이 없었는데 뒤에서 중국 게이머의 돈을 동그라미로 생각해서 젠중을 추가했는데 너는 너의 엄마인 척하니젠장좋아요를 누를 때마다 폭설회사 모든 직원의 할아버지가 폭파당합니다좋아요 만 개 폭설 회사 모든 직원의 엄마가 한 번
# 기존 클래스: 2, 판단된 클래스: 8, 확률: 0.92
#
# 문장: 오버워치 돌려내 ㅅㅂ새끼들아
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 게임은 좋은 게임인데 블리자드는 죽나요
# 기존 클래스: 1, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 이상하게 이게임을 실행만 하면 졸린다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 대깨옵만 하세요 본인은 ### 깨짐 FUCK YOU BOBBY KOTICK
# 기존 클래스: 8, 판단된 클래스: 2, 확률: 0.95
#
# 문장: 오버워치 ㄷ만 만들어주십쇼
# 기존 클래스: 2, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 오버워치 는 매우 실망스러운 게임이다게임이 처음 출시되었을 우리는 그것에 큰 기대를 걸었지만 게임의 품질은 우리가 기대했던 것보다 낮은 것으로 판명되었다게임은 최적화가 잘 되지 않았고 카톤과 지연 문제가 심각했으며 이로 인해 게임 경험이 매우 고통스러웠다가격 불만도 만만치 않다 게임을 사려면 돈 낭비나 다름없다설상가상으로 게임 내용이 너무 단조로워 지루했다같은 유형의 게임에 비해 오버워치 의 가격대성능비는 가장 낮다고 말할 수 있다전반적으로 나는이 게임에 대해 매우 화가 나고 실망했으며 당신들에게이 게임을 사지 말고나 자신을 끝없는 고통 속으로 빠뜨리지 말 것을 강력히 권고한다개발자들이이 게임을 재생하려면 상당한 개선과 업데이트를 해야 할 것이다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 시ㅂ ### 게임 v trash
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.94
#
# 문장: 추억에 잠겨 들어가 보는 게임
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 괴씸하면 개추
# 기존 클래스: 3, 판단된 클래스: 1, 확률: 0.58
#
# 문장: 딜러 버프좀
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 너네만의 독자적 플랫폼 만들어서 수수료 안떼고 승승장구 하겠다면서 이리로 들어왔냐ㅋㅋ 제작진 싸그리 갈아치우고 운영 제대로 하면 볼까말까하겠다 한번에 도전과제 개 넘게 깨지는건 기분 좋더라ㅋㅋ
# 기존 클래스: 0, 판단된 클래스: 8, 확률: 1.00
#
# 문장: ㅅㅂ걍 나가 뒤져
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.97
#
# 문장: 오버워치 는 개똥이야
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.76
#
# 문장: 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요 xiba shake it
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.67
#
# 문장: 좆병신겜
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.99
#
# 문장: ### ### 게임 개 한 덩어리도 놀지 않는다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.99
#
# 문장: 그런 좋은 게임을 심연으로 이끄는 쓸모없는 게임 기획자
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: h운영으로 몰락하는 라이브 서비스 게임의 표본h 기본 베이스가 워낙 충실해서 게임만 놓고 보면 잘만든 게임인건 분명함 문제는 블리자드란 그릇이 이미 여기저기 ### 뚫리고 깨져버린 터라 유저들의 기대를 충족시킬 수 없더라도 자기들이 내뱉은 말조차 기억하지 못하는 수준까지 몰락해버림 라이브 서비스 게임을 책임지는 운영진들의 아몰랑하는 태도는 동서양을 똑같은게 누군가 개발진들에게 독을 푼게 분명함 유저들이 항의를 해도 어차피 안들어 처먹을게 뻔하니 대혐오에 시대에 걸 맞게 나도 조리돌림 하는데 동참해봄
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.99
#
# 문장: ### 게임 엄마 따먹어 계획도 뇌사 상태이고 플레이어의 제안을 듣지 않고 정말 역겹고 일찍 무너지기를 바랍니다
# 기존 클래스: 5, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 완전 엉망이야 진짜 개세기는 만든 게임이야 이렇게 ### 같은 게임을 해본 적이 없어
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.96
#
# 문장: 게임은 내가 해 본 최악의 게임 중 하나이다 정말 블리자드 게임 회사가 무엇을 하고 있는지 모르겠다 아주 게임을 추천하지 않는다 매우굉장히굉장히권장하지 않음
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 정말 ### 계정 확인은 조각입니다 왜이 게임이 나라에 가야합니까
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 완전 엉망이야 진짜 개세기는 만든 게임이야 이렇게 ### 같은 게임을 해본 적이 없어
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.96
#
# 문장: 쓰레기게임하나도재미없어혹평완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.99
#
# 문장: 블리자드 계정이 필요하네 스팀에 출시한거지 순수한 궁굼증
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 굿
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 오버워치 비추천은 못참지
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 로그인하면 다시 본인 인증으로 돌아가냐고 베틀넷 연동 진짜 거지같이 해놨네
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.54
#
# 문장: 이딴게임 만들 바에는 여캐들로 야동만들면 안되냐
# 기존 클래스: 8, 판단된 클래스: 5, 확률: 0.86
#
# 문장: 완전 엉망이야 진짜 개세기는 만든 게임이야 이렇게 ### 같은 게임을 해본 적이 없어
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.96
#
# 문장: 병신겜
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.59
#
# 문장: 히트스캔이 게임을 망친다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 시간 게임하면서 소집 기다렸더니 본부가 좆망해버림
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: h년 나는 게임회사나 개인도 폭설과 같은 짐승을 본 적이 없다h
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.94
#
# 문장: 워크샵 할 거 그냥 에이펙스 하러 가죠
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장:  년에 블리자드 본부가 운석에 분쇄된다면 블리자드는 세기에 가장 전설적인 게임 회사가 될 것입니다  년에 블리자드 본부가 운석에 부서지면 향수를 불러 일으키는 게임 회사가 될 것입니다  년에 운석에 박살되면 유감스러운 게임 회사가 될 것입니다 올해 운석에 부서지면 완벽한 운석이 될 것입니다
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.92
#
# 문장: 블리자드 게임 ### 오버워치만 년째 하고 있는 유저입니다 뉴비분들은 절대 블리자드 게임을 추천하지 않습니다 블리자드 특성상 게임은 잘 만들지만 외 나머지가 단점으로 오기 시작부터 추천드리지 않습니다 밸런스 패치 개구라약속 안 지키는 걸로 유명 운영 ### pc 가득한 캐릭터 ㅆ발적인 게임으로 자기들 손으로 망치기 절대로 추천하지 않습니다 도망가세요 ㅈ같음을 뛰어넘는 이상이 될 겁니다
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.92
#
# 문장: PVE 매우 노잼이네 대실망
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 개도 안 하는 ### 같은 게임 개똥처럼 운영되네
# 기존 클래스: 0, 판단된 클래스: 8, 확률: 0.98
#
# 문장: ㅈ노잼 병신게임
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 니 애 미
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.53
#
# 문장: 옛날 느낌나서 좋긴 뭐 옛날처럼 재밌지는 않네
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 더 할 말이 있나 한표 행사하기 위해 출시일만 기다렸다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 무료로 제공하는 PVE 맛보니 게임을 대충만드는지 알게되었습니다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 게임은 게임의 느낌과 게임의 배경이 매우 나쁘고 단순히 덩어리 나쁜 리뷰 나쁜 리뷰 나쁜 리뷰입니다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 완전 엉망이야 진짜 개세기는 만든 게임이야 이렇게 ### 같은 게임을 해본 적이 없어
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.96
#
# 문장: 완전 엉망이야 진짜 개세기는 만든 게임이야 이렇게 ### 같은 게임을 해본 적이 없어
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.96
#
# 문장: 예아
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 나만 재밌으면 돼
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 다 비추해서 개추함
# 기존 클래스: 0, 판단된 클래스: 8, 확률: 1.00
#
# 문장: PvE 낸다고 오버워치 강종하더니 스토리는 원
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 게임은 좋은데 블리자드 엄마는 죽지 않아 스팀 올라가도 개는 안 해 스팀은 오버워치가 필요 없어 스팀을 더럽히지 말고 빨리 너의 게임을 가지고 ###
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 오버워치젠장 폭설 엄마는 죽었어
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.98
#
# 문장: 이게임 장점 게임성은 좋다 이게임 단점 게임성만 좋다 결론 개 씹 버러지같은 게임
# 기존 클래스: 0, 판단된 클래스: 3, 확률: 0.96
#
# 문장: 체력  방어력  마 저 인챔피언이 저지불가 쉴드 벽 넘 기는 거 있고요 에어본 있고 쿨타임은 데 초밖에 안되고 마나는 들고 w는 변신 하면 쿨 초기화에다가 패시브는 고정피해가 어가며 방마저 올리면 올릴수록 스킬 가속이 생기고 q에 스킬가속이 생기고 스킬 속도가 빨라지고 그다음에 공격력 계 수가 있어가지고 W가 이익으아아아악
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.97
#
# 문장: 년에 블리자드의 본사가 운석에 박살난다면 블리자드는 금세기 가장 전설적인 게임 회사가 될 것이다년 블리자드의 본사가 운석에 박살난다면 두고두고 그리워할 게임 회사가 될 것이다년에 운석에 깨진다면 아쉬운 게임회사가 아닐 수 없다올해 운석에 맞는다면 완벽한 운석이 될 것이다
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.85
#
# 문장: 쓰레기게임하나도재미없어혹평완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요
# 기존 클래스: 0, 판단된 클래스: 8, 확률: 0.99
#
# 문장: 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: ### 당시 블리자드의 본사가 운석에 박혔다면 블리자드는 금세기의 가장 전설적인 게임회사가 될 것이다 블리자드의 본사가 운석에 박혔다면 그리울 만한 게임회사가 될 것이다년 운석에 맞았다면 안타까운 게임회사가 될 것이다올해 운석에 박히면 완벽한 운석이 될 것이다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.66
#
# 문장: PVE콘텐츠를 내줘도 구매를 하지않는 매우짧은 임무 하나만 할 수 현재 무료로 할 수 있는 임무는 반복적으로 하기엔 지루하며 플레이 가능한 캐릭터로 윈스턴 트레이서 토르비온 루시우로 다른케릭터가 주캐인 플레이어는 플레이에 문제가 X발 이럴거면 출시함 PVE가 그냥 워크샵에서 나온 것들이 더 재미있겠다 아니지 더 재미있다 도데체 년동안 뭘 한거지 시간이면 높은 퀄리티는 아니여도 게임 개 정도는 나올텐데 아니지 고퀄리티의 게임 하나정도는 나온다 이게 얼리액세스로 나오거나
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 갑자기 스팀에 낸 이유도 모르겠고 팀원은 잘하는 것도 없으면서 입만 털어대고 걍 팀포하러감 자꾸 옵치 그만 싫어해라 옵치가 팀포보다 낫다고 하는 외국인새끼들 ### 꼴보기싫음
# 기존 클래스: 8, 판단된 클래스: 0, 확률: 0.68
#
# 문장: ### 년동안의 결과물이 이거라고 미친새끼들아
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: PVE 할려고 설치 했는데 가격이 만천원 이나 하냐 개 ### 애미뒤진 가격에 샀는데도 적용이 안되서 하지도 못하네 개 ### 새끼들아
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 병신같은 게임 아무짓도 안했는데 스팀 연동하자마자 영구정지 개 ### 버러지세끼들
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 핵ㄷ없데이트로 기존유저 버리고 년동안 없데이트 PVE 하나보고 대단한게 나오려나 이지랄 떨면서 꽉깨물고 인내심 바득바득 갈아 기다려 줬더니 개발중지 쳐 떄려버리고 오버워치 출시때부터 지금까지 아직도 빠대 탈주 제재도 그까짓게 뭐라고 ### 제재 도 안해서 라이트 유저까지 버린 영자들아 ### 안하는거 안 보일거 같지 ### 뭐했냐 이거 말고도 문제점 ### 많은데 ### 진짜 내 인생에서 이만한 병신게임이 없다
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.92
#
# 문장: 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요
# 기존 클래스: 0, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: ### 옵치 야동만드는 새끼들이 개발진보다 열심히했노 시발련들
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.97
#
# 문장: 게임 개발진이 놀라울 정도로 게임에 대해 무지함 PVE는 사실 기대도 하지 않았지만 로드맵도 지키지 못했으며 기만에 가까운 통보가 이루어졌음 능력의 한계가 있었고 어려움이 있었다고 일찍 얘기했으면 모르겠으나 너무 악의적인 의도가 다분함 그렇게 오늘 출시된 PVE는 몇년의 개발기간이 믿기지 않을 정도로 처참한데 그걸 돈 받고 팔겠다고 함 스팀 조금만 둘러봐도 천원만원에 ### 알찬 구성에 퀄리티의 게임이 많은데 DLC를 돈 주고 사라고 PVP는 잘 돌아갈까 어림도 없지 저런 명분 다 쳐세우면서 대로 돌렸지만 실상 목적은 탱커 유저 부족을 해소하려던 거였는데 다 쓸모없어졌음 지옥의 가위바위보 탱커 싸움에 힐밴 수면총 쳐 맞으면 그로기 상태로 죽어야 함 난이도와 책임감은 ### 높은데 낮은 성취감과 하이 리스크 로우 리턴임 농담이 아니라 지금 탱커하면 마조히스트임 딜러는 더 가관임 지금 힐러랑 대로 이기는 딜러가 존재는 싶음 새로 나온 힐러는 대체 힐러라는 새끼가 궁을 가지고 있나 싶고 맥크리는 쓰지 싶은 수준의 딜량을 가지고 있음 게임 내 영향력이 ### 부끄러울 정도로 낮아졌음 딜러가 백날 딜 쳐박아도 힐러가 스킬 한개 딸깍 누르는게 더 강함 정식출시날 올린다는 패치노트에는 위의 문제를 단 하나도 해결하지 못했음 지금 게임이 상태고 메타인지 ### 도 인지하지 못했음 ### 상식적으로 납득 가능한 수준의 패치가 단 하나도 없음 스팀 평가 적어본 적이 없는데 새끼들은 진짜 너무 괘씸함 게임이 망하던가 정신을 차리던가
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 완전 엉망이야 진짜 개세기는 만든 게임이야 이렇게 ### 같은 게임을 해본 적이 없어
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.96
#
# 문장: 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 완전 엉망이야 진짜 개세기는 만든 게임이야 이렇게 ### 같은 게임을 해본 적이 없어
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.96
#
# 문장: 재밌음
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요
# 기존 클래스: 2, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 블자 개새끼들아 니네가 옵치는 스토리기반 게임이라며 그걸 돈받고 쳐파냐 ### 나는 옵치 샀다 개새끼야 만원 적지도 않은 돈 학생신분으로 구매했었는데 주는건 ㅈ도 없고 유저를 돈줄로만 보고 개새끼들이 이딴 쓰레기게임에다 ### 운영까지 더해지니 금상첨화가 따로 없구나 이게임 다운로드 해서 플레이할때마다 기분이 이루말할수없다 내 추억이랑 만원 돌려줘 개 씹새끼들아
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 한국 사람이이 게임을하고이 게임은 썩은 것과 한 덩어리 똥이 같습니까
# 기존 클래스: 8, 판단된 클래스: 0, 확률: 0.89
#
# 문장: 게임은 팀탓 나와도 참고 하겠는데 이건 이제 도저히 못하겠다 진짜 오버워치야 말로 어ㅈ까어안해 시전에 가장 적합한 게임 개 역겨운 쉨들 잘나가는 게임은 즈그 플랫폼에서 돌리고 스팀이 똥통이냐 스팀에 내는 수수료 아깝다 이건데 줮나 웃긴게 그런 ㅅㄲ들아 오버워치 침공 묶음 같은 ㅈ호구 콜렉션으로 돈 빠는건 앙개꿀띠라 수수료 노상관이란거지 사겠냐 븅신들아ㅋㅋㅋㅋㅋ 은근슬쩍 처 파는거 진짜 개패고싶네ㅋㅋㅋ
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.99
#
# 문장: 게임은 나를 너무 실망시켰다 게임 매칭 메커니즘은 정말 형편없었다 폭설은 정말 어리석은 회사였다 나는 먹다 남은 뼈를 폭설에 먹였다 뼛속의 노예
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 쌉노잼
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.55
#
# 문장: N년간 오바와치 흑우로서 스크린샷을 쉽게 찍을 수 있게 되었다는 점과 도전과제가 업데이트 되었다는 점으로도 행복했는데 PVE 유료 구매 미친넘들
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.98
#
# 문장: 회사의 행동이 우리들의 마음을 몹시 상하게 했다OW
# 기존 클래스: 0, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 씨발개새끼
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 대깨옵이라 개추
# 기존 클래스: 8, 판단된 클래스: 2, 확률: 0.95
#
# 문장: 무슨망할게임너무쓰레기인데혹평놀기싫어
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.98
#
# 문장: 그걸 돈주고 파냐
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 쓰레기게임은 순전히 로자의 시간을 랑비하는 쓰레기게임인데 나는이 게임에 뭐가 있는지 정말 모른다씨발씨발씨발씨
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.65
#
# 문장: 중국 아빠를 차별해
# 기존 클래스: 1, 판단된 클래스: 8, 확률: 0.93
#
# 문장: ### 게임이 대변과 같아서 바보가 만들어냈는지 정말 생각지도 못했다 완전 엉망이야 진짜 개세기는 만든 게임이야 이렇게 ### 같은 게임을 해본 적이 없어 더 게임을 하고 싶지 않아 아주 어려워 계속 돈을 충전하라고 해
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.88
#
# 문장: 무슨망할게임너무쓰레기인데혹평놀기싫어
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.98
#
# 문장: 개소리야 내가 어렸을 때부터 크게 놀았던 게임은 이것처럼 형편없는 것이 하나도 없어 회사가 이렇게 형편없는 게임을 만들 수 있는지 상상하기 어렵다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.99
#
# 문장: ow개똥 한 덩어리ps한국 사람들은 쥐다한국 사람들은 잡종이다
# 기존 클래스: 8, 판단된 클래스: 0, 확률: 0.97
#
# 문장: DLC적용이 안되면 환불이라도 해주던가
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 내가 산 DLC를 밑에서 뺐지 내가 빙다리 핫바지로 보이냐 새끼야 증거있어 증거 증거 있지 너는 나한테 아무것도 주지 않았을 것이여 시나리오 쓰고있네 미친새끼가 apex 레전드 그년한테 가는거야 그년한테 가는건 좋은데 돈은 내려 놓구가 돈은 놓구가 쏠수이써 쏠쑤이써
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 네놈들 게임은 망했어 여긴 이제 캬루가 지배한다 오버워치가 스팀에 나왔다고해서 PVE 컨텐츠가 출시했다고해서 희망을 가지지마십쇼 오버워치는 부터 아주 굳건히 변함 없이 꾸준하게 쳐말아먹어서 동서양 유저 대거 탈출 시켰으니 지금이라고 뭐 다를리가 있나 그냥 오버워치한테 바라는점은 신캐 모델링이나 제대로 뽑아냈으면 좋겠다 잘뽑아내면 폰허브같은곳에서라도 볼 수 있을테니
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.66
#
# 문장: 밸런스 패치 못함 호그 몇달동안 방치하냐
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: ㅆ발 개ㅂ신들인가 지들이 pve 만든다고 ### 떠벌리면서 은 ### 찬밥 취급하면서 유저 다 떠나게 만들었으면서 이제와서 하는 말이 반쪽짜리 pve 이럴거면 이빨 ### 까고 다님 이게 사기가 뭐냐 우리가 이딴 소식 들을려고 에코 출시하고 오버워치 섭종 할때까지 년을 쳐 넘게 기다린거냐 뭐 시즌만 잘 굴러가게 하면 만사 ok인줄 알았나봐 ### 사이에는 유저들 돈 빨아먹을 궁리만 하셨나 지들이 만든다고 IP를 방치하다 못해 생매장을 해뒀는데 중 지들이 가장 이빨 ### 까고 다닌 PVE를 사실상 반쪽짜리 출시 한다는 거는 지들이 아예 게임 만들기 싫다는거 아니냐 이딴 식으로 PVE 반쪽으로 할거면 오버워치 은 그렇게 방치한거냐 우리가 대ㄱ리 깨져도 오버워치 할줄 알았나봐 게임 메인 스토리랑 ㅈ도 상관없는 같잖은 PC 주입 할때부터 알아봤어야 했는데 개ㅂ신ㅅ끼들 개ㅆ발 마사장님 그립읍니다 진짜 굳이 이딴 게임을  넘게 하는게 아니었는데
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.98
#
# 문장: 어딜 쓉 기가채드 게임 팀포와 글옵이 있는 스팀에서 감히 출시를 하려그래
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.83
#
# 문장: 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 이것은 매우 ### 게임이다 나는 이렇게 ### 게임을 한 번도 해 본 적이 없다 정말 똥이고 특히 나쁘고 실망스러웠다 이렇게 ### 게임을 할 수 있는가 ### ### ### 알버트 아인슈타인 Northern Exposure 미국 TV 드라마 쓰레기명언
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 다들 뭔데 블리자드를 까내리는거냐 옵치만 한번 보자 출시 후 몇년동안 맵도 안내고 영웅도 안내기를 했냐 롤을 따라잡니 마니 근들갑떨면서 자화자찬을 했냐 맵 영웅밸런스가 안맞아서 피드백들어가면 밸런스패치에 한세월 걸리기를 했냐 얘네가 돈을 받고 게임을 팔다가 유저수 좆박고 무료로 바꾸기를 했냐 무료임에도 매칭돌리면 밥먹고 담배피고 씻고와도 될 정도로 오래 걸리기를 했냐 이랑 랑 차이 ### 없는데 어그로 끌어볼려고 후속작인척 넘버링달고 나왔냐 무료로 바꾸고 로 냈는데도 겜이 병신이라 유저수 안모여서 스팀으로 꾸득꾸득 기어들어오기를했냐 몇년동안 개발한다 해놓고 완성되지도 않은 PVE를 스팀에 오자말자 돈받고 팔아먹기를했냐 저렇게 긴 개발시간임에도 컨텐츠 규모를 줄이고 취소하고 로드맵도 안지키기를 했냐 멀쩡한 솔저를 갑자기 게이로 만들기를 했냐 솔저로 모자라 PVE 개발중에 파라도 사실 레즈임 하기를 했냐 알고보면 게임개발보다 PC를 지지하기를 했냐 대단하다 블리좆드 너넨 걍 나가라 겜좀 해봤다 싶으면 개병신버러지새기들인거 누가 모르겠노 대깨블 조련하면서 평생 JOAT 게임만 출시하길 바란다
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.90
#
# 문장: 앙시발섹스딸딸이
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.95
#
# 문장: 아ㅋㅋㅋㅋㅋ ### 오버워치 크레딧 오버워치 코인인줄알고 샀다가  기부해버렸네 영웅팩같은건 왜팔고있냐 병신들아 신규유저도 없는데ㅋㅋㅋㅋㅋㅋ
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.91
#
# 기존과 예측이 달라진 개수: 747

# %% [markdown]
# '진짜 개좆같네 팀원들이 싹다 ### ### 아오 ### 패버리고 싶다 ### 키리코 개쌔끼는 지가 딜런줄 알아 ### 그ㅜ래놓고 힐  ### ### 아오 로드호그 ### 킬 어시 뒤짐 ### 진짜 지금 생각해보니까 ### 빡치네 ### 보고있냐 ###' 이 문장에서 '개좆같네', '개쌔끼'는 필터링이 되지 않았음을 알 수 있다.

# %% [markdown]
# # 정규식을 이용한 두 번째 필터링

# %%
import re

CURSEWORD_PATTERN = re.compile(r'[시씨씪슈쓔쉬쉽쒸쓉](?:[0-9]*|[0-9]+ *)[바발벌빠빡빨뻘파팔펄]|[섊좆좇졷좄좃좉졽썅춍봊]|[ㅈ조][0-9]*까|ㅅㅣㅂㅏㄹ?|ㅂ[0-9]*ㅅ|[ㅄᄲᇪᄺᄡᄣᄦᇠ]|[ㅅㅆᄴ][0-9]*[ㄲㅅㅆᄴㅂ]|[존좉좇][0-9 ]*나|[자보][0-9]+지|보빨|[봊봋봇봈볻봁봍] *[빨이]|[후훚훐훛훋훗훘훟훝훑][장앙]|[엠앰]창|애[미비]|애자|[가-탏탑-힣]색기|(?:[샊샛세쉐쉑쉨쉒객갞갟갯갰갴겍겎겏겤곅곆곇곗곘곜걕걖걗걧걨걬] *[끼키퀴])|새 *[기키퀴]|[병븅][0-9]*[신딱딲]|미친[가-닣닥-힣]|[믿밑]힌|[염옘][0-9]*병|[샊샛샜샠섹섺셋셌셐셱솃솄솈섁섂섓섔섘]기|[섹섺섻쎅쎆쎇쎽쎾쎿섁섂섃썍썎썏][스쓰]|[지야][0-9]*랄|니[애에]미|갈[0-9]*보[^가-힣]|[뻐뻑뻒뻙뻨][0-9]*[뀨큐킹낑)|꼬[0-9]*추|곧[0-9]*휴|[가-힣]슬아치|자[0-9]*박꼼|빨통|[사싸](?:이코|가지|[0-9]*까시)|육[0-9]*시[랄럴]|육[0-9]*실[알얼할헐]|즐[^가-힣]|찌[0-9]*(?:질이|랭이)|찐[0-9]*따|찐[0-9]*찌버거|창[녀놈]|[가-힣]{2,}충[^가-힣]|[가-힣]{2,}츙|부녀자|화냥년|환[양향]년|호[0-9]*[구모]|조[선센][징]|조센|[쪼쪽쪾](?:[발빨]이|[바빠]리)|盧|무현|찌끄[레래]기|(?:하악){2,}|하[앍앜]|[낭당랑앙항남담람암함][ ]?[가-힣]+[띠찌]|느[금급]마|文在|在寅|(?<=[^\n])[家哥]|속냐|[tT]l[qQ]kf|Wls|[ㅂ]신|[ㅅ]발|[ㅈ]밥|장애인')  # 해당 정규식 전체를 복사해서 붙여넣으세요

def filtering_with_re_ex(text):
    if not isinstance(text, str):
        return ''
    
    # 욕설을 ***로 대체
    filtered_text = CURSEWORD_PATTERN.sub('***', text)
    return filtered_text

# %%
sec_data = []

for i, result in enumerate(predictions):
    sec_data.append({
        "review": result['text'],
        "voted_up": voted_up[i],
        "fst_hate": hate[i],
        "sec_hate": result['label'],
        "sec_probability": result['probability']
    })
    
sec_df = pd.DataFrame(sec_data)

# %%
sec_df['review'] = sec_df['review'].apply(filtering_with_re_ex)
sec_df = remove_invalid_reviews(sec_df, 'review')

sec_texts = sec_df['review'].tolist()
hate = sec_df['sec_hate'].tolist()

# %%
predictions = predict(sec_texts)
print("Predictions:", predictions[:5])
# Out:
# Predictions: [{'text': '핵 잡아', 'label': 8, 'probability': 0.99730444}, {'text': '진짜 지금가지 해본 게임 중 가장 최악이다', 'label': 8, 'probability': 0.9960257}, {'text': '거이 준상이 수능 점수', 'label': 8, 'probability': 0.9978613}, {'text': '정신병 걸림', 'label': 8, 'probability': 0.9966826}, {'text': '진짜 개***같네 팀원들이 싹다 ### ### 아오 ### 패버리고 싶다 ### 키리코 개쌔끼는 지가 딜런줄 알아 ### 그ㅜ래놓고 힐  ### ### 아오 로드호그 ### 킬 어시 뒤짐 ### 진짜 지금 생각해보니까 ### 빡치네 ### 보고있냐 ###', 'label': 3, 'probability': 0.9637561}]

# %%
for result in predictions:
    print(f"문장: {result['text']}")
    print(f"판단된 클래스(숫자): {result['label']}, 확률: {result['probability']:.2f}")
    print()
# Out:
# 문장: 핵 잡아
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 진짜 지금가지 해본 게임 중 가장 최악이다
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 거이 준상이 수능 점수
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 정신병 걸림
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 진짜 개***같네 팀원들이 싹다 ### ### 아오 ### 패버리고 싶다 ### 키리코 개쌔끼는 지가 딜런줄 알아 ### 그ㅜ래놓고 힐  ### ### 아오 로드호그 ### 킬 어시 뒤짐 ### 진짜 지금 생각해보니까 ### 빡치네 ### 보고있냐 ###
# 판단된 클래스(숫자): 3, 확률: 0.96
#
# 문장: ###
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 미국 사막지대 고속도로 위에 덩그러니 있는 이상한 술집에서 서빙하는 탈색머리 성병 매춘부 같은 이름을 가진 캐서디라는 카우보이가 출연하는 하프언럭키 하프럭키 콩코드임
# 판단된 클래스(숫자): 8, 확률: 0.83
#
# 문장: 학원 토껴가며 했던 친구 랭크에 열등감 갖던 시절의 나에게 귀빵망이 때려주고 싶은 게임
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 하나님이 보고있다면 욕함
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 무료자누 개꿀이자누
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 빠대 매칭이 ### 팀 킬뎃이 배 차이나게 매칭이 되냐 이딴식으로 쳐 잡을거면 ***련들아 일반전 패넢티를 쳐 주지 말던가 무력하게 지는 판 연속으롭 붙여놓고 나가면 나가냐고 ### 떠는거 보면 블자 본사 타이어로 다 터트리고 싶음
# 판단된 클래스(숫자): 3, 확률: 0.98
#
# 문장: 옵치 오베때부터 쭈욱 시간을 했지만 할때마다 스트레스받는 시간이 압도적으로 많음 그냥 안하는걸 추천 예전엔 재밌었지 나온이후로 점점 이상해지는거 같더니 지금은 두가지 경우밖에없음 아무리 똥꼬쑈를 해도 결국에는 지는판 팀에 트롤있는 경우 내 할거만 어느정도 하면 별 노력도 안하는데 그냥 이기는판 팀이 정상인 경우 게임이 두가지 유형밖에 없고 번 비율이 퍼센트 넘는 느낌 첫한타 두번째 한타 애들 보면 이게임은 지는판이다 느낌이 옴 무조건 지는판 유형 딜러한명은 말도 안되는 데스에 처참한 딜량이 나와있음 하다보면 연승하는게 더 무서움 연승하고나면 꼭 연패로 이상한인간들 무조건 연속으로 붙여주니까 그게 더 무서워 많이 하다보면 어느새 연승 연패 반복되서 결국은 승률 퍼센트로 맞추어나가는 갓벽한 게임 승패시스템 어떤경우라도 더이상 재미가 없음 번은 희망고문처럼 될거같은데 결국은 안되서 너무 힘들고 번은 내가 뭘해도 이기니까 재미있을리가 없지 내가 뭔가를 하는것보다 팀에 트롤이 있냐 없냐가 더 중요해서 게임이 좌지우지되는 느낌 재밌는 경우도 있긴하지 그게 판하면 한두판 될까 말까한게 문제지 하다보면 내가 이걸 왜하고있지 느낌이 계속 듬 누가누가 한자아이디 중국인이 많은가 던지는애가 많은가로 승패가 갈려 이게 재밌으려고 하는겜인지 내가 스트레스 받으려고 하는건지 정신병 유발게임 도저히 더는 못견디겠다 웬만하면 하지마요 정신이 망가지는게 느껴짐
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 걍 재밌음
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 저의 기가막힌 에임과 판단이 미슐랭 스타급의 조화를 이루어 흡사 마우가  시간의 장인의 플레이를 구현해낼수 있는 좋은 게임 이라고 생각합니다
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 요새 진짜 재밌음
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 메르시 빼라고 ***년아
# 판단된 클래스(숫자): 3, 확률: 0.97
#
# 문장: 색칠놀이 그만해 씨ㅣㅣㅣㅣㅣㅣㅣㅣㅣ발ㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇ
# 판단된 클래스(숫자): 3, 확률: 0.98
#
# 문장: 확실하게 재미는
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 훌륭한 게임까진 아니더라도 이렇게까지 낮게 평가될 게임은 절대 아니라고 봄 부정적 리뷰들을 보면 다들 너무 흥분한 느낌 대체로 긍정적 정도가 적당한 평가수준인거같음
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 살짝 설렛어
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 오버워치사랑해
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 새끼들은 머리에 나사가 풀려있음 같은 실력이랑 붙여주지도 안고 ***같은 스킨들만 찍찍 만들어내는 꼬라지가 그냥 양산형 중국 게임 그자체임 를 만들어내는지 짱개들은 핵쓰느지 핵 방지 프로그램이 있으면 뭐해 판중 판이 핵인데 ### 진짜 블리자드 내가 걱정돼서 하는 말임 옆동네 발로란트 보고 배워
# 판단된 클래스(숫자): 0, 확률: 0.93
#
# 문장: 그냥 핵도 못잡는 ### 게임임 짱개들은 두말할것도 없고
# 판단된 클래스(숫자): 0, 확률: 0.98
#
# 문장: 핵좀 처 빨리빨리 잡아라 ***들아
# 판단된 클래스(숫자): 3, 확률: 0.91
#
# 문장: 꿀잼
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 핵갓겜 핵듀오트롤은 신경도 안쓰면서 욕만 밴하는 게임
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 롤을 이겼던 게임은 오버워치 외에 존재하지 않지
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 게임이 친절하고 캐릭터가 맛있어요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 이놈들아 그놈의 주둥아리하고 채팅창은 다 끄고 하면 평화로운데 게임의 상황은 평화롭지 않은게 문제렸다
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 겜이 여러 영웅을 플레이 질리지않고 재밌네요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 고아들이 많아요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 망겜임
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 재미있ㄲ으ㅁ
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 접었다가 요새 일간 다시 해보면서 느낀 게 밸런스는 차치하고 영웅 설계 면에서 할 말이 많음 라이프위버나 모이라 메르시 같은 뻔하디 뻔한 극소수의 특정 조합을 맞춰야만 벨류가 살거나 설계 실패로 성능조차 안나오고 변수도 못보는 영웅으로 팀원에게 불쾌감과 아쉬움을 선사하고 있음 빠대고 경쟁전이고 마찬가지임 최소 비등비등하거나 이겨야 재밌는 게 게임이지 누가 질려고 게임함 대놓고 지라고 만든 영웅들을 냅두는 게 문제임 누구나 쉽고 접근가능한 영웅을 만들 거였으면 그것이 가능한 영역 역시 확실히 정해놓아야지 경쟁전에서 무지성으로 꺼내게 만들면 나머지 플레이하는 팀원의 시간은 사기짐작은 감정은 딜러 매칭시간 점유율 줄이겠답시고 원거리 딜 개 모기 ㅈ도 안되는 딜량 박히게 해놓은것도 정말 불쾌하고 최첨단 대구경 리볼버와 커다란 레버액션 소총 가지고 조그만 생체탄보다 딜을 못넣는다는 게 상식적으로도 플레이적으로도 이해가 되질 않음 무엇보다 이딴 챔프들 냅두면서 아니꼬운 채팅하면 추천점수 깎이고 정지먹는 게 어이도 없고 개발자 니들이 게임 해봐 욕 나오는지 안나오는지 암만 미국쪽 애들 입김이 쎄다지만 이건 아닌 같음 엄연히 조합과 팀워크로 운영해야하는 게임인데 프로필 비공개와 스트리머 모드 이딴 기능은 있는 거임 팀합을 맞춰야하는데 내 팀 닉네임도 잘하는 영웅도 스탯도 못보면 그게 팀게임이냐 정치질과 욕설 그거 막으라고 차단 기능 있는거고 PC범벅 된지 오래라 신고 먹이면 금방 제제됨 PC적인 요소를 집어넣을 거였으면 게임에 미치는 영향을 엄밀히 검토를 해서 옵치처럼 포지션별로 즐겨쓰는 영웅 줄씩은 표시되게 두던가 내가 프비공 안쓰면 해제 하고 일정 기간 지난 후에 상대방 것도 볼 수 있게끔 해줘야하는 거 아님 스트리머 모드는 개나소나 다 스트리머임 PVE고 밸런스고 나발이고 이전에 게임성에서 불쾌한 점이 너무 많다 그걸 감내하고 게임하기에는 사람인지라 스트레스만 쌓여가는 게 짜증남 스팀 평가가 그걸 증명해주고 있음 진짜 괜찮은 그래픽 스토리 UI 가지고 이딴 운영밖에 해내질 못하는 블리자드 ###
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 개 ### 게임 진짜 망했나 일연속 새벽에 패작만 만나고 본티어가 마 그마 와리가리 하는 힐탱유저인데 플다유저 새벽반은 다던지나 만나는 힐러는 다 라위 메르시 라위는 시작하면 일딴 탱커 끌고 노는데 바쁘고 딜러들은 매판 평균 데스 가까이 쳐박으면서 게임하고 매칭시스템 진짜 잘못된거 아니냐 내팀에만 이렇게 넣어주고 적팀은 다 멀쩡하냐 일 연속 매칭 이러니까 진짜 게임 있는정 없는정 다떨어져 나갈것같네 옵치 처음나왔을때부터 지금까지 안쉬고 해왔는데 전에는 이상하게 계속 연승하면 연패하고 이상하게 승률 퍼 맞추는 매칭만 계속 하더만 이제는 패작만 만나는 매칭은 머야 도대체
# 판단된 클래스(숫자): 8, 확률: 0.97
#
# 문장: 허구한날 정치 핵 트롤 패작 난무하는 망겜임 이거할바에 발로하러감
# 판단된 클래스(숫자): 2, 확률: 0.53
#
# 문장: 그냥 ***게임
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 오버워치 보단 운영 잘하는 듯
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 심오하다
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 재미있다
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 게임은 재미있는데 못한다고 욕부터 하는 팀 할 맛 떨어짐 경쟁전이 면 이해하겠지만 빠대 에서도 이러니
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: ***뒤진 겜 힐러가 개 ### 딜러보다 쎄면 누가 딜러함 롤처럼 딜은 딜만 힐은 힐만 탱은 탱만하게 해야지 ### 뭐 아나가 힐 안하고 딜쳐하고 모이라가 딜쳐하고 ***겜 할바엔 폰허브 솔져 리퍼 게이***나 보러가셈 Worst fxxing game ever Rather than playing this game youre better off watching soldier and reaper gay ### uploaded to pxxxhub
# 판단된 클래스(숫자): 8, 확률: 0.89
#
# 문장: 핵쟁이 대처랑 히트스캔 정상화만 하면 최고일 게임
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 에임봇 ESP
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 재밌다
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: ###
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 진짜 겁나 재미있고 팀워크도 늘어나는듯
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: ******게임
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 그까짓 힘으로 감히 빨리 한국 영웅 더 주세요 ### 안에 안 주면 블리자드 앞에 오물풍선 투척함
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 완죤 꿀잼
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 블리자드가 돈이 정 급했으면 스팀에 무료로 푸는게 아니라 자기들이 직접 오버워치 여캐들로 만든 야겜을 스팀에 원 정도에 올렸다는거 진짜 유저 평가 되는 스팀에는 뭔 말을 듣고 싶어서 올린지 모르겠음
# 판단된 클래스(숫자): 8, 확률: 0.61
#
# 문장: 압도적으로 최악인   Overwatch 오버워치 오버워치의 대부분의 문제점은 운영과 악성 유저에 의한 것이다 ① ### 월 기준 최근 빠른 대전 플레이 리플레이 부검 시 판 중 판 빈도로 핵쟁이가 많음 ② 안티 치트 프로그램의 부재 유저들의 신고 누적으로 제재하기에 완전 티나는 핵만 잡힘 핵 제작자가 악의적으로 사람들에게 핵을 배포 후 머신러닝으로 더 정교한 설정값을 찾는 중 과정에서 탄생한 게 투사체 핵 ③ 불쾌하고 무력한 매칭 연승 시 연패한 팀원을 넣어주는 통나무식 알고리즘 ④ 의도를 알 수 없는 영웅 밸런스 딜러는 약하게 힐러는 강하게 탱커는 탱킹만 할 수 있게 서로의 의존도가 심하게 높아지는 괴이한 구조 ⑤ 게임의 꼴이 이런지라 표독하고 악랄하고 추악하고 비양심적인 사람들의 비중이 압도적임 ⑥ 줏대 없는 운영 말 바꾸기 스캠 정치적 사상 표출PC주의 불통
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 으악 고급 시계 여기서도 ㅈㄹ하지마
# 판단된 클래스(숫자): 3, 확률: 0.95
#
# 문장: ***들아 총이 m거리에서 피해감소 돠는게 말이 되냐
# 판단된 클래스(숫자): 8, 확률: 0.98
#
# 문장: 리퍼 퇴물관짝쓰레기
# 판단된 클래스(숫자): 8, 확률: 0.56
#
# 문장: 너무 재밌어서 폭발할거같아요ㅗ
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: ### ### 재미없는 게임 애들이 하는지 도 이해가 안감
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 재밌습 한번 해보샘
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 주노가 재미있다
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: ***게임 빠대 탈주 페널티 없애라
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 추억의게임
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 재밌어요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 개똥겜
# 판단된 클래스(숫자): 8, 확률: 0.68
#
# 문장: 역시 옵치다
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 갈비탕 레시피 갈비는 찬물에 시간 정도 핏물을 빼주세요 중간에 물을 번 정도 갈아주면 좋아요 요 과정을 거치면 고기 누린내 없이 드실수 있답니다 핏물 뺀 갈비는 끓는 물에 분정도 살짝 삶아내고 삶은 고기는 찬물에 헹궈 준비합니다 다시 냄비에 물을 컵 정도 넣고 삶아놓는 소갈비 개 양파무마늘대파를 넣고 시간 정도 뚜껑을 덮고 끓여 줍니다 불은 중약불로 해주세요 국물이 줄어들면 중간에 따뜻한 물을 넣어가며 끓여 주심 됩니다 무는 너무 익으면 맛없으니깐 중간에 꺼내주세요 체반에 갈비탕 국물을 따로 받아내고 미리 꺼내 놓은 무는 먹기 좋은 크기로 썰어주고 국물에 썰어놓은 무갈비를 넣고 국간장다진마늘를 넣고 한소끔 더 끓여 줍니다 뜬 기름은 숟가락을 이용해 걷어주세요 드셔보시고 부족한 간은 소금으로 마지막에 썬 대파 후춧가루를 넣어 마무리 해주세요 갈비탕 완성 기호에 당면을 불려 넣어 드셔도 좋답니다 번거롭지만 집에서 끓여 먹는 갈비탕 국물이 깔끔합니다요
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 주먹 주먹 주먹 주먹 주먹 주먹 주먹
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: ㅈ망겜ㅋㅋ
# 판단된 클래스(숫자): 3, 확률: 0.95
#
# 문장: 친구들이랑 하면 재밌어용
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 게임이 안들어가져요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 이게임은 PVE 컨텐츠랑 사용자 지정게임 말고 건질게 없음
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 재밌음
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 오버워치망해라
# 판단된 클래스(숫자): 8, 확률: 0.98
#
# 문장: 정신차리고 열심히 패치는 함 그렇다고 갓겜이 되진 않았지만 전성기의 옵치를 즐겼던 유저라면 해봄직 할듯
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 재미가 없냐
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 몇년만에 하는데 더 ***겜 됨 탱커밸류가 너무사기고 유저들 수준도 그대로 ㅋㅋ잼민이 없는 성인겜일텐데 힐러가 딜러보다 쌤
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 진짜 나의 중고딩살 군대가기 전까지 인생을 갈아넣었다 그만큼의 가치가
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 양학 개많음
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 안해
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 팀 뭐함
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 똥겜
# 판단된 클래스(숫자): 8, 확률: 0.96
#
# 문장: 걍 모르겠고 배틀넷 로그인 자체가 진짜 뭣같음
# 판단된 클래스(숫자): 8, 확률: 0.93
#
# 문장: 애들 패치를 하면 누구는 각성하는데 누군는 ***이 되는거냐
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 탈출은 지능순입니다 유저 수준이 너무 떨어지고 게임도 다 망해서 유저가 없어요 항상 중국인 껴있습니다 즐기는 사람들은 다 접고 성질 더러운 진짜들만 남은 게임입니다 혹시라도 복귀 할까 싶으면 마음 접으시길 바랍니다
# 판단된 클래스(숫자): 0, 확률: 0.73
#
# 문장: 옵치 역할 고정 없을 때부터 탱딜힐 지금 탱 딜 힐까지 왔는데 몇년 변한게 있냐 캐릭 출시를 많이 했어 맵을 더 만들었어 뭘 했어 만든다고 무한 정켄슈타인 돌리고 나온게 똥쓰레기임 그렇게 얘기하던 PVE는 어디감 그거로 스토리 풀어준다면서 이럴거면 개발 함 몇년 째 요원 소집만 하는 유인원 ### ### 안후림 예전엔 렙업하면 상자 줘서 그거로 무료 스프레이 스킨 음성 얻는 맛 있었고 크레딧으로 상깡 가능했음 유료로 옵치 주고 시작했지만 가챠 못 참아서 질렀었음 근데 지금 무조건 정가임 스킨 하나에 인데 이걸 돈 주고 ***임 팀포가 그래픽만 좋았어도 옵치는 뒤졌을게 분명함 ***겜
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 캐릭터 디자인 BGM 타격감이 뛰어나고 미국 카툰식 화풍도 깔끔한 느낌을 준다 협동 슈터게임으로서 게임성 자체는 완벽에 가깝다고 생각한다 그에 반해 협동 게임 특유의 정치질 게이머가 많다는 점과 과도하게 비싼 부분결제 요소는 꽤나 거슬리는 편이다
# 판단된 클래스(숫자): 8, 확률: 0.98
#
# 문장: 정말 뭐같은 팀 매칭시스템만 정말 좋을 게임 제재좀 확실히좀 해주세요 ### 화나니깐
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 게임 재밌나요 시작해 보려고 하는데
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 베틀넷 없어서 좋음
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 솜브라 패치는 진짜 말도 안된다 이러면 누가 솜브라 씀 할거면 제대로 해라 제발
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: ***버워치
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 게임적응도 쉽고 재미있어요 꼭 해보세요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 지나치게 높은 탱커체급으로 불쾌감만 높음
# 판단된 클래스(숫자): 8, 확률: 0.96
#
# 문장: 엄마가 많아져요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 너네들은 가서 포르노나 만들어라
# 판단된 클래스(숫자): 8, 확률: 0.97
#
# 문장: 스팀 로그인이 안돼네요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 오버워치를 해본다는 정신건강에 고르지 못하는 판단을 내렸습니다 여러분은 글을 보시면서 실수를 면하셨으면 좋겠습니다 감사합니다
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 탈모 걸리기 싫으면 이거
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 장난하나 초창기때 스타터팩이랑 다 적용 안되던거 아직도 못고치고 본사 고객센터에게 연락 하라고 하고 본사는 대답도 없고 환불은 안된다고 하고 뭐 해준다는 건지 이틀쨰 답도 없고 장난
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 유저 수질 좀만 더 유지하면 롤이랑 비비겠네ㅋㅋㅋㅋ
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 거듭된 패치로 그나마 게임이 되긴함
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 병x같은 운영이 게임 말아 먹은 케이스 게임을 하고 나면 블리자드 망했으면 좋겠다는 생각을 하게함
# 판단된 클래스(숫자): 3, 확률: 0.85
#
# 문장: 게임이 안 좋은 점 업데이트 이후 추천 레벨 이상 사설게임 만들 수 오버워치 같은 은장 금장 거 없어짐 피 ### 늘어남 거리데미지 ### 걍 맘에 안듬 게임을 자꾸 쳐 망쳐놓음 오버워치 ### 한 유저가 극대노함
# 판단된 클래스(숫자): 3, 확률: 0.56
#
# 문장: 개발자 ***들아 하다하다 이제 방벽 관통 밖에 없는 라붕이를 건드리냐 개***들아 내 라마트라 돌려내 할꺼면 라마 응징 대미지 자체를 배로 하던가 아님 라인과 정커퀸도 방벽 못 뚫게 막아 ### 개발진들아
# 판단된 클래스(숫자): 8, 확률: 0.71
#
# 문장: 재밌다
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 개재밌음
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 얘네가 뭔잘못을 했냐 신규 모드라면서 팀포 그대로 배낀 PVE를 만들겠다고 했다가 취소라도 했냐 트레일러도 팀포mvm 그대로 배끼기라도 했냐 한정스킨이라고 못쳐박다가 갑자기 상점에 돈주고 사게 쳐내기라도 했냐솔까 근데 이건 난 좋음ㅋㅋ 신캐들을 무조건 배패로 쳐풀어서 ***같게 하기라도 했냐 별 ***없는 모드는 쳐내면서 하나무라를 없애기라도 했냐 후 억까는 자제해주세요 ***이고 할만함
# 판단된 클래스(숫자): 8, 확률: 0.80
#
# 문장: 잠깐의 심심함이 오버워치라는 심연을 또다시 들여다보는 실수를 만들었습니다 하루도 빠짐없이 스팀만 켰다하면 진행하는 알수없는 업데이트 어차피 승패가 갈리는 게임이라면 질수도 있지만 매판 나오는 조롱과 정치질 그렇다고 대체제가 없을만큼 재미가 있냐하면 그건 아닌 게임 약 여년전에 게임을 그만뒀는지를 망각하고 잠깐의 무료함을 달래고자 다시 손을 대고 말았던 저의 능지를 탓하며 게임을 지웠습니다
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 라붕이 살려내라
# 판단된 클래스(숫자): 8, 확률: 0.94
#
# 문장: 콘텐츠 다운로드중이 겜 킬떄마다 뜨노
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 편의 느낌을 재현하지 못한 아쉬운 맛
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 명작
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 하지 않을 이유가 없다
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 내 사랑
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 욕먹는지 이해 안돼는 게임
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 오버워치는 단 마디로 설명 가능함 감다뒤
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 이거 안하지
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: ### 플레이 할 마다 컨텐츠 다운로드는 계속 시키는거냐
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 굿
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 혼자하면 정신병 걸릴거같음
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 뭐지 그윽한 똥내는 거기에 중독되어버린 나는
# 판단된 클래스(숫자): 8, 확률: 0.92
#
# 문장: 가장 미련하게 낭비하는 방법
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 아주 재미있는 게임입니다
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 할때마다 핵만남 딱히 핵 잡는거같지도 않고 걍 답없음
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: ### 봇 패작 잡지도 않음
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 콘텐츠 다운로드 적당히 해라 블리자드야 딱히 특별히 추가되는 것도 없으면서 게임 킬때마다 분 분을 버려야겠냐
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 게임 킬때마다 다운로드때매 분 넘게 기다려야됨 재미는 있는데 이런거좀 곤쳐줬으면
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 너무 재밌지만 유저들이 너무 인성이 안좋네요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 이거 게임 아니다
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 재미있당
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: ㅈ망겜
# 판단된 클래스(숫자): 3, 확률: 0.96
#
# 문장: 이딴게 게임
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 오버워치 E스포츠에 한국 게임단이 없는 이유가 한국 리그만 보면 다 외국기업이여 그만큼 운영을 x나게 못한다는거죠 라이엇 블리자드
# 판단된 클래스(숫자): 3, 확률: 0.51
#
# 문장: ㅈ망겜
# 판단된 클래스(숫자): 3, 확률: 0.96
#
# 문장: 때우기 좋다
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 신캐가 안나옴
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 다들 사랑하시죠
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 재밋당
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 모이라 하지 말라고
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 재미있음
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 이거 함이거 할거면 발로란트 하고말지
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 당신이 많은 정치와 욕설을 견딜 수 있으며 멘탈이 갑이거나 실력이 좋다거나 인내심이 좋으시다면 게임을 절대 추천합니다 근데 이미 무료겜인데 제품을 무료로 받은 경우는 체크 해야되는것임
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 재밌다
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 지난 시대의 패배자
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 이거 왜케 평가가 안좋음 난 재미있던데
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 아제 인생 컴뷰터 게임입니다
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 끄으으응 뿌우우우우우우우우우우우우우우우우우웅 뿡 뿌우우우우우웅 부르르르르르르르르륵 푸르륵 뿌다다다다다다다다다다다닥 퐁당당 퐁다당 뿍 푹 푸드드드드드드드드득 풒 풒 뿌자자자자잦 푸터터터터터터턱 뿌타타타타탓 콰르르르르르르르
# 판단된 클래스(숫자): 8, 확률: 0.96
#
# 문장: 최고의 하이퍼 FPS 누가 반박할 수 있겠는가
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: ㅈ망겜
# 판단된 클래스(숫자): 3, 확률: 0.96
#
# 문장: 노잼인데 재밌음
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 얘들이 너무 못해서 재미가 없다
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 오버워치 하다가 쌈
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 망
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 별로 질리진 않고 롤 같은거 하다가 발로 하다가 재미 없어지면 이거 하면 개 재밌는데 진짜 해보셈
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: ### 시작이 앉도ㅔㅁ
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 재밌다
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: ***겜 친구랑 하는거 하지마세요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 재미땅ㅎㅎ
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 저혈압이라면 추천
# 판단된 클래스(숫자): 8, 확률: 0.97
#
# 문장: 진짜 이걸 이렇게 오래기다렸는데 PVE 몇년만에 해놓고 이거한다고 오버워치도 무료로 하고 그랬는데 이걸 돈주고 사라고요 오버워치은 돈주고샀는데 오버워치랑 달리진게없는데 그래픽디자인이나 뭐 소소한거 달라지긴했는데 이거가지고 돈아깝네 게이나 트랜서젠더 상관없는데 그런이야기만 하고  나은듯 되면서 힐러들은 이제 할 이유가 없네요 새로나온 영웅은 그냥 해볼수있는게 아니라 도전과제를 클릭한다음 판을 승리해야만 영웅개를 얻을수있네요 해보고 싶은 영웅도 해볼려면 오래걸립니다 대단하네 블리쟈드 도전과제로 판 승리해야 영웅 풀어줬는데 영웅들 게임 판정도하면 다풀어주는걸로 바꿨네요 사람없나보네요 게임했던사람 잡히고 그러네요 망한듯
# 판단된 클래스(숫자): 8, 확률: 0.98
#
# 문장: 콘텐츠를 킬 때마다 다운을 받아야하나요 오래걸리네
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 망겜이라고 생각했는데 해보니깐 개******망겜이었음
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 이만한 겜은 없다
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 재밌음
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 넘쳐나는 핵과 그냥 보통 유저들도 롤 저리가라할정도로 호전적임
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 볗스ㅟㄴ게임이 뭔 게임 실행할때마다 콘텐츠를 설치한다고 분인가 게임도 못하냐 재부팅할때마다 무결성검사해도 아무것도안뜨는데 뭘 설치를 쳐한다고 재부팅할때마다 ㅈ랄이신지 대단한게임납셧네
# 판단된 클래스(숫자): 3, 확률: 0.98
#
# 문장: 살다살다 오버워치를 스팀에서 플레이를 다하네 오래살고 볼일이다 틀딱아님
# 판단된 클래스(숫자): 4, 확률: 0.98
#
# 문장: 재미는 있는것 같으나 이 그리운편 아가들이 너무많아
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 옹 재밌는데
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 너무 존잼 루인 구독 ㄱㄱ씽
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 실력만 좋으면 정말 잼밋습니다
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 류진노 기무크라이
# 판단된 클래스(숫자): 8, 확률: 0.98
#
# 문장: 버그
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 개 갓겜
# 판단된 클래스(숫자): 8, 확률: 0.98
#
# 문장: 시이이이이팔 상자내놔
# 판단된 클래스(숫자): 8, 확률: 0.90
#
# 문장: 재미있다
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 티어 측정 방식에 새로운 시도가 필요한 게임 블리자드식  맞추기 매칭 내다 버리자
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 시간으로 경쟁크레딧  ***
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 대이나 롤백해라
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 힐러들 힐안함 옵치하지마셈
# 판단된 클래스(숫자): 8, 확률: 0.97
#
# 문장: 계정만 있으면 개꿀띠
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 재밌음 근데 이 더 재밌었음
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 재미있음
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 솔직히 배그해보고 발로 해보고 FPS게임들 가지 다 해봤는데 개인적으로 점만점에 점정도로 나쁘지않고 재밌음
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 갓겜이
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 경쟁전도중에 튕기고 업데이트로 못들어가서 탈주패널티 걸리는 개***게임
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 옵치때 안해봐서 지금이라도 하는데 개재밌음 앞으로 더할예정
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 왜인지는 모르겠는데 계집년들이 좋아하는 게임 반반한 계집 사냥하러 종종 하는 게임 계집들 안했으면 하지도 않을 겜
# 판단된 클래스(숫자): 3, 확률: 0.97
#
# 문장: 위도우 키리코 주노 디바 누드스킨이나 줘라
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 뭐 개*** ### 같은 게임이 다 있냐 ### 게임 만든 ### 엄마 ### 따고 ### 안에다가 주먹 넣고 돌려 버리고 싶네 ### ### 겜 개 ***같아서 쳐 지운다 ***새끼야 아론 캘러 ***새끼야 블리자드 직원 전부다 일자로 세워둔 윈스타 테슬라 건으로 조져서 아앙 아앙 신음 ㅈㄴ게 내게 하고 싶네 이***새끼들아 게임 ***망해서 유저 수 나가 떨어지니까 주노 엉덩이 디자인 개꼴리게 쳐 내는게 세 게임이 맞냐 ***새끼야 세가 없는 ### 조선시대 선비들이 쳐 하는 게임 개보자 같은 게임에 몇백시간 투자한 내 인생이 후회된다 발로란트보다 나은점이 하나도 없는 게임 내일 블리자드 본사 찾아가서 거기서 불 지르고 오줌 싼다 내가 이렇게 화났냐면 ### 탱커 다이아 승급전 앞두고 연패했는데 그건 그렇다 치는데 연패 끊는 판이었는데 갑자기 오버워치 개튕겨서 분 정지 쳐 당하고 점수는  그대로 쳐 깍아가고 게임은 렉 하나도 안 걸리고 원할하게 돌아가는데 유독 게임만 쳐 튕기고 서버와 연결이 끊기는지 모르겠음 패작한 ### 핵 쳐 쓰는 새끼들은 밴 쳐 안 때리고 나같이 던지는 새끼한테 욕 몇번 했다고 달 정지 쳐 하는게 맞는거냐 욕설 정지 벌써 번인가 쳐 당했다 무튼 이제 놔줄 때가 된거 오버워치 개****** 퇴물 새끼야 잘 살지 말고 이따가 덤프트럭에 치어서 죽어버려라 ### ***새끼야
# 판단된 클래스(숫자): 3, 확률: 0.98
#
# 문장: 역시 오버워치
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 요즘들어 패치 방향성도 좋다 아쉬운 점은 진작 잘하지
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 오랜만에 스팀으로 깔아서 다시해봤는데 PVE 유기한다면서요 PVP라도 좋아야하는데 첫 판 만에 핵 만났어요ㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 인증할때 사람인가요 단계 뭐야 진짜 다하면 틀리다 하고 또해도 하나틀리면 실패하고 분명 다맞는데 이정도면 ai가 열받게할려고 다맞아도 틀리다고 하는거 같은
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 난 재밌었어 힘내
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 재미는
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 꿀잼
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 스팀으로는 탭 뭔키누르니까 자꾸 스팀뭐떠서 별로인거말고는 게임은 재미있어요 라고 옵 시즌유저
# 판단된 클래스(숫자): 8, 확률: 0.98
#
# 문장: 재밋어요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 스팀 처음이자 마지막으로 리뷰 남겨본다 좋았던 부분은 다 도려내고 진짜 개***겜 됐네
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 승률 퍼 매칭 망겜
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 전작을 뛰어 넘는 속편 없다는 속담이 생각나는군요 총쏘며 스트레스 푸는데는 최고의 게임이라 생각합니다
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 여친이랑 재밌게함 요즘 굿굿
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 주노 덩덩이
# 판단된 클래스(숫자): 8, 확률: 0.89
#
# 문장: 이게임 재밌어요 찍먹 해보세요하하
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 대 될 느꼈지만 점점 히오스화 되고 있음 내가 아무리 잘해도 팀원 한두명이 못하면 역캐리 당하고 지는게 당연해짐 그러면서 내가 뭘 실수 했는지도 배울 틈도 없이 판이 끝나고 담판으로 가서 똑같은 원숭이짓 함 게임하면서 생각해야 할 개념이 많은데 정작 인게임에서는 가르쳐주는 것도 없고 가이드도 부족해서 다들 원숭이화 되는 무한 루프에 걸림 아무리 생각해도 탱커 명으로 줄일게 아니라 힐러를 명으로 줄여야 함 힐러가 보니까 유저 대부분이 FPS에서 가장 기본인 엄폐와 포메이션 개념을 안 배우고 꼴박하고 정치질하는 배움 인게임에서 FPS 기본 개념이라도 가르쳐주면 몰라 그냥 빨리빨리 담판가죠 밖에 없어서 배우는거 하나도 없이 던질 녀석은 백날 던지고 남탓하고 다시 게임 돌리고 던짐 무한 반복임
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 중국인이랑 매칭 안 시키면 나름 괜찮음
# 판단된 클래스(숫자): 8, 확률: 0.98
#
# 문장: 경쟁전 하지마셈 진짜 큐 개같이 잡아줌 개빡침
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 오버워치 로 넘어오면서 뭔가 뭔가임
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 개재미있음
# 판단된 클래스(숫자): 8, 확률: 0.98
#
# 문장: 로그인창 사람인증 만든새끼 누구냐 뭔 오래 걸리는걸 단계나 만들어 걍 안해
# 판단된 클래스(숫자): 3, 확률: 0.96
#
# 문장: 섭종 언제하냐
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 블자가 약속을 파토낸 덕에 떡락한 민심 게임은 재밌음
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 똥겜
# 판단된 클래스(숫자): 8, 확률: 0.96
#
# 문장: 처음 시작하고 판째에 솔져 에임핵 만나는데 끄고 삭제해벌임
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: ### 재밌다
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 탱커 너프먹이면서 탱커는 다시 순살로 돌아오고 탱유저들이 개판이거나 잘없으니깐 다시 매칭이 잘안히고 무엇보다 탱이 재미없음 이래저래 인 탱체제라 탱역활이 중요한데 욕먹기 좋은 포지션이라 하기싫음 요즘 재미없습니다 지루하더라도 인으로 다시 돌아가던가 탱을 싹다 뜯고 고치는 방법밖에없음 포지션 체제가아니 포지션 체제도 나쁘지 않은 방향이라고 생각함
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 사람들은 망겜이라고 하는데 솔직히 인정은 함 근데 자주말고 가끔씩하면 재밋음
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 재밌어요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 로그인 과정 개 복잡함 예전 생각나서 해봤는데 ㅈ노잼
# 판단된 클래스(숫자): 3, 확률: 0.78
#
# 문장: 똥맛카레
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 굿
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 절대하지마
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 고급시계
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 옵치이 훨재밌음
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 꿀잼
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 위도우메이커 재밌어요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 같음 하지 마셈
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: ***하고싶다
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 확실히 옛날 맛에서 중국산 조미료를 추가한 느낌임 옛날의 잊을수 없는 신선함과 재미에서 새로들어온 건강에 ㅈ나 안좋은데 뭔가가 맛있는 맛이 추가가 됨 중국산 조미료라 해서 몸에 안좋은거 의식하고 먹으면 꺼린데 무시하고 하면 재밌음 근데 건강에 안좋은만큼 오래하면 질릴듯 가끔씩 생각날때마다 해주면 확실히 재밌을꺼임 점차 나아지는 모습 보이니깐 굿임
# 판단된 클래스(숫자): 3, 확률: 0.57
#
# 문장: 대이 나음 때는 메인탱커 죽어도 서브탱커가 어느정도 버티는데 지금은 메인탱커 죽으면 게임이 터짐
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 개처재미없네 ***겜
# 판단된 클래스(숫자): 3, 확률: 0.82
#
# 문장: 좋은 에임연습 게임
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 진짜 오보오치 준나 재밌어요 꼭 하세ㅕㅛ
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 최고의 게임
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: ###
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 박스 오피스 등한 그게임 트레일러가 정말 멋지고 키리코가 꼴려요 제발 하세요
# 판단된 클래스(숫자): 8, 확률: 0.81
#
# 문장: 할만함
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 윽
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 정공겜 한 판에 플레이어 인원이 명 많던 오버워치 이 재미있었다
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 진짜 제발 하지마세요 제발 개발진여러분 이러시는 이유가 있을거아니에요 처음 나왔을땐 좋았잖아
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 폰헙 시뮬레이터
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 그래도재밌긴 하잖아
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: ez가 언제부터 욕인가요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 하면 재미씀
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 게임이 최적화가 잘 되어있고 쉬워서 좋아요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 게임은 ***가 뒤진게 분명하다
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: ***정공겜
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 오버워치에 비해 영웅도 맵도 많아졌지만 재미 자체가 없어짐
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 망겜인거 같습니다 개인적인 생각이므로 깊히 생각 해주지 마시길 바람니다 정IN호
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 하지말라는데는 이유가 에휴
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 이거 캐릭터 다 무료 아니였나 흠이네 진짜 게임이 아닌거 같은데
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 빠대까지 매칭 줄인다고 티어 분포로 잡아버리는 매칭 개******게임
# 판단된 클래스(숫자): 8, 확률: 0.91
#
# 문장: ***같은 핵쟁이***같은 뉴비 개같은플레이 조작법 오버워치
# 판단된 클래스(숫자): 8, 확률: 0.91
#
# 문장: 게임 자체는 재미있음
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 게임 자체는 재미있음 배틀넷유저임 착한유저들도 존재하지만 대부분 정신이 나가있으며 경쟁전을 일반게임 승을 전제조건으로 걸어 놓은 다양한 영웅들을 잠금 시켜놓은것이 마음에 하나도 들지 않는다 운영사는 생각이 없으며 게임에는 미래가 없다 지금 처럼 잘 운영한다면 하는 사람만 하게되는 썩어버린 게임이 될것이 분명하다 여기에 현질할 생각하지 말고 책을 사서 읽던가 게임을 사서 플레이 하던가 그냥 치킨이나 먹는 것을 아주 강력하게 추천한다 처음에 리뷰를 보고서 호들갑 떨고있네 그냥 정신나간 게이머가 게임에서 지고 화를 푸는것인줄 알았다 아니였다 게임을 하다보면 게임을 잘하고 싶고 애정이 생기고 게임이 잘되었으면 하는 마음이 생기기 마련이다 근데 개발사의 운영과 게임 영웅을 해금하기 위해선 기재된 판 수 이상을 플레이 해서 해금을 시키는 배짱인지 모르겠다 그냥 게임에 애정생기기 전에
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 게임이 맛있고 사장님이 불친절해요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 재밌습니당 꼭 해보십셔
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 잘하고 싶다
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 오버워치 로부터 수년이 지나고 나서 스팀으로 오버워치 를 플레이했는데 블리자드는 점점 하락세를 걷는다지만 지금 봐도 UI와 스킬 아이콘 타격감 사운드 그래픽 정말 깔끔하고 매력적이다
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 스팀덱으로도 하기 괜춘 키마 연결하면 데탑 똑같음 TV연결은 해상도에 눈물 나지만 스팀덱으로 하는 거라 괜춘
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 여러 캐릭터가 바뀌긴 했지만 옛날에 했던 그리운 느낌 지금도 재밌고 불편한게 몇가지 있긴 다 좋은데 대체 게임 판해야 캐릭터 해금되는 조건을 추가한건 누가 제안한거냐
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 하지마그냥 제발
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 신캐 나온것들 궁금해서 해보려는데 캐릭터는 죄다 잠겨있습니다 조합 반 강제로 맞추는 것도 그렇고 왜이리 유저가 억압받아야되는지 모르겠네
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 쟤는 볼을 했을까
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 개쌉존잼 꼭해봄셈
# 판단된 클래스(숫자): 8, 확률: 0.87
#
# 문장: 가끔 두세달에 한두판씩하면 재밌음
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 겜중에 아무 이유없이 튕기는데
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 솜브라 너프
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: ㅈ망겜 왜함
# 판단된 클래스(숫자): 3, 확률: 0.97
#
# 문장: ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ### 터진 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ###
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 갑자기 재미지는게임
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 옵치착한 아이에요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: ###
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 디바 키리코 빵댕이 볼려고함
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: Mother less blizzard MMR matching system The game operation is brainless If we win time they try to make lose for  win rate Its was official matching system and make this game most historical unlike game in steam Over  people spit on Blizzard The proof is over 폐급 게임은 같은 실력의 사람끼리 매칭을 잡아주지 않는다 잘하던 못하던 평균 승률 프로로 매칭을 시키기 내가 판을 이겼으면 내가 판을 지도록 매칭을 잡아준다 게임을 하다보면 실력이 오르는데 실력이 오르면 오를수록 우리팀은 점점더 폐급들을 잡아준다는 말이다 하던 사람은 접고 악평은 늘고 신규 유저는 적으며 서서히 힘들어지는 플레이어의 게임환경처럼 게임이 점점 망해갔다 처음 나왔을때 롤에 비빌만하던 게임을 운영으로 말아먹고 덤으로 정치적 올바름이니 PC니 뭐니 하며 또말아먹었다 꼬라지가 흑어공주 같은걸 만들다 수조를 날린 디즈니와 디즈니는 수조를 날리고 정신을좀 차렸는데 이게임은 어떨지 모르겠다 덤으로 블리자드의 메니저는 경영진들에게 게임을 스팀에 올리지 말자고 했다 이유는 개발진에게 쏟아질 toxic 힐난이 개발자들을 힘들게 할것이라는 이유였다 이무슨 헛소리인가 게임을 만들어 놓고 팔아놓고 구매자가 게임평가를 못하게 해야한다고 말하는 메니저라니 마이크로 소프트가 블리자드를 인수한수 인원들을 자르는데는 정확한 이유가 저런자들을 돈주고 고용하겠는가
# 판단된 클래스(숫자): 8, 확률: 0.98
#
# 문장: 게임 개발진들한테 사기당해서 추천은 못한다 기본이 오버워치 에서 가져온거라 가끔하면 재밋다 그걸 상쇄할만큼 여태 개발한 방향이 좋지 못하다
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 내 돈
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 한명이라도 트롤이 있을경우 초보자 입장에선 승리확률이 입니다
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 판 해야 캐릭터 주는건 아이디어임 왓더봑이네
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 옵치만 년차 지겹지만 겜하려고 컴퓨터 키면 옵치부터 킬려함 습관이 되버림 옛날이 더 재밌었지만 아쉬운거지
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 핵 대리 패작이 한게임에 있는걸 본 전 그만 이게임을 지워버리고 말았답니다 하지마세요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 무료임
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 재미있음
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 친구랑 하기는 좋은데 ### 힐러들의 힐량이 딜더들의 데미지보다 커서 뒤지질않아 수발거 거기다가 암살자 캐릭들 포텐 다죽여나서 힐러들 죽이기도 쉽지않음 파티플로 하면 모르겠는데혼자할땐 합 안맞아서 ### 힘듬 종합***겜
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 내 대 돌려내
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 망겜 TOP
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 정병겜
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 전여친 같은 느낌임 하다 보면 딴 겜 생각나고 딴 겜 하면 옵치 생각남
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 정신건강에 해로운 게임 akdrpa in
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 망겜인데 재밌음
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 할만 한 게임은 역시
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 심리적 문제를 겪는 분들이 많이 게임을
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 지금의 오버워치가 마음에 들지 않는다면 여기로 와주세용 명의 남자들은 언제나 당신들을 두팔벌려 환영합니다
# 판단된 클래스(숫자): 8, 확률: 0.98
#
# 문장: 외국인들만 엄청 많고 재미도 갈수록 점점 떨어짐 년도가 제일 좋았어요 gg
# 판단된 클래스(숫자): 8, 확률: 0.98
#
# 문장: 에임 필요없는 fps게임
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 재미는 있는데 혼자하기는 싫어
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 개*** 같은거 계정 연동 이딴식으로 ***같이 해둘거였으면 그냥 스팀에 쳐 내지를 마 ### 하자년들이 그냥 지들이 계속 떡락하는지 이유를 모르나보네 ### 그냥 롤한테 계속 뒷구멍 따이는 이유를 모르는구나 아니다 그냥 이리 하러가죠 이터널 리턴 접속해서 루미아섬 사랑 해주세요 감사합니다ㅗㅗ
# 판단된 클래스(숫자): 3, 확률: 0.98
#
# 문장: 콘코드 하고 오니까 오버워치가 갓겜인 걸 깨달았어요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 오버워치 아나 출시 때부터 한 유저입니다 오버워치 도 정말 많은 기대를 했죠 기대는 정확했습니다 아오 너무 재밌더라구요 오랜만에 해서 그런지 경쟁 매칭이 분 걸리더라구요 정말 좋았습니다 손을 풀 수 있는 시간까지 마련해주는 게임 이런거 잘 없거든요 정말 희귀합니다 유저들이 제가 게임을 못할 조언을 해줍니다 접어라 ### 쳐 접어라 이렇게 조언을 해주곤 합니다 정말 감사하신 분들입니다 게임 사용자 지정 게임이 메인인 게임인거 같은데 정말 컨텐츠가 풍부하고 마인크래프트와 샌드박스식 게임처럼 많은 것이 가능한 게임인 것을 알게 되었습니다 신캐들도 정말 매력적이에요 주노라던가 주노라던가 주노라던가 뭐 두더지도 있고 사이버 오줌싸개도 있고 정말 매력적이고 다양한 신캐들이 저를 반겨주었습니다 오랜만에 게임을 이렇게 재미있게 한 것은 이번이 처음입니다 정말 감사합니다 저는 블루 아카이브 하러 가보겠습니다
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 솔직히 저도 오늘 처음 시간 채운 뉴비입니다 게임은 뉴비들도 재미있게 플레이할수있는 아주 좋은 게임이라고 말하고 싶습니다 여러분들 고민하시지 마십시요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: ### 노잼이네 힐러만하면 자꾸나만죽이는데 잼민이는 겜하지마삼
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 정크랫 준비 완료
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 살릴거 내 원 돌려줘
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 안하는지 모르겠음 너무 재밌는데 많이들 하길 바라요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 발로하다가 넘어왔는데 헤드 맞고 한 방에 안뒤져서 좋음 시간 이상하면 멀미남 우엑
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 개***망겜
# 판단된 클래스(숫자): 8, 확률: 0.95
#
# 문장: 플레이하면서 이상한 신념가진놈들 꼭있음 못하면 에임챔 하지말 라ㅣ고 시
# 판단된 클래스(숫자): 8, 확률: 0.90
#
# 문장: 게임이 티어가맞지않은 사람들이나오고 초보들이 몰살당하는데 이걸하는게맞나 싶어요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 게임 억까가 매우 심함
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 할만하고 ㅠ재미있음
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 하고싶은 캐릭 업적으로 막아두는 ***겜 롤이나 발로는 게임하면 재화 주고 그걸로 내가 원하는 캐릭 살 수라도 있지 업적으로 막아두는거는 진짜 그냥 판수박아 무조건 게임 많이 해 이거 이상도 이하도 아님 그냥 악질임 이러니 도 망하고 도 메이저 겜이 못 되지
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 남탓의 게임화
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 스팀으로 옮겨주니까 편해
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 뭔 빠른 대전 두 세판 돌리고 나서 이상한 오인큐가 나가는데 맞는가
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 시대 최고의 게임 FPS게임들과 다르게 클린한 게임분위기와 적은수의 핵쟁이들 서로가 서로를 응원하며 더욱 집중하게됨
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 핵은 모든 총겜 문제라고 생각하긴함 겜이 유저가 문제가 많지 요즘 재미는 있음
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 난 재밌는데
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: h 포르노 공장 h
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: ### 껴있으면 게임 난이도 폭증
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 솔직히 재밌어서 자존심상함ㅋㅋ
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 즐겜하기 좋음
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 하시다 보면 늘 먹던 맛에 어디서 본 같은 기시감이 드는 판이 나오는 경우도 있습니다 그러한 맛 속에서 새로운 맛을 찾아내고 친구들과 그러한 맛을 나누는 것은 즐겁습니다 그리운 맛이기에 가끔 되돌아보게 되는 게임입니다 친구들과 하면 재미있는 게임이지만 친구들과 하면 더 재미있을 게임도 많기에 한 번 즈음 켜기전에 생각을 해보심이 좋을 같습니다
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 게임이 많이 실망 시킨적은 있지만 요즘은 다르다 패치자 자주 나오고 재밌는 이벤트나 밸런스를 봐꾸고 재밌어졌어요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 진짜 괴식인데 묘하게 중독되어서 끊을 수 없게 되어버린 느낌
# 판단된 클래스(숫자): 8, 확률: 0.93
#
# 문장: ***겜
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 솔직히 재미없다곤 못하겠다
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 시그마 개재밌다 해봐라
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: ***럼들아 겜을 아주 ***까치도 만들어놨네 경쟁전하려면 판을 처이기라고 개***하고 있네 그냥 가만히 놔두면 반은 갔을 게임을 이***로 만들어놨네 처음에 옵치 욕할때 우리가 게임 재미없다고 욕했어 아니잖아 핵 잡아달라매칭시간 줄여달라 한거잖아 다른거 아무것도 건들지말고 이거 두개만 바꿨으면 진짜 아직까지도 사람들이 재밌게 했겠다 자꾸 게임을 건드려 개씹빠가 새끼들아
# 판단된 클래스(숫자): 3, 확률: 0.98
#
# 문장: 내 과거의 모든
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 벤처 지워라
# 판단된 클래스(숫자): 8, 확률: 0.98
#
# 문장: 시간동안 게임한 내가 너무 한심하다 옛날 생각도 나서 오랜만에 할까 했는데 진짜 너무 재미없네 추억은 추억으로만 기억하는게 좋겠다
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 유저들 수준이 너무 낮음 오랜만에 왔는데 팀 차이 탱 차이 힐차이 딜차이 겜 내내 이러고있음 상대팀 조롱은 덤이고 차단하면 그만이라지만 협력해서 이기는 재미로하는건데 뭐하는건지 모르겠음
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 그냥 망작임 시즌 에 있었던 팀보이스는 아예 하지를 않고 게임을 하는 사람들은 그냥 따로따로 플레이 함 이건 절대 팀 게임이 아니며 혼자서 멱살 캐리는 절대 불가능함 절대로 설치하지 말고 쳐다도 ### 마삼
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 망겜인데 계속 하고 있는 나를 보면 절망적임
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 개***롤 하다가 추억삼아 옵치 와봤는데 그렇게 망겜소리 듣는 옵치가 롤보다 재밌노
# 판단된 클래스(숫자): 8, 확률: 0.98
#
# 문장: 오랜만에 했는데 별로인 부분도 있었지만 재미는 있었으요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 게임 수준 압도적으로 부정적 평판 압도적으로 부정적 게임사 압도적으로 부정적 운영 수준 압도적으로 부정적 밸런스 패치 수준 압도적으로 부정적 DLC 가격 압도적으로 부정적 팀빨 수준 압도적으로 부정적 최적화 수준 압도적으로 부정적 서버핑 수준 압도적으로 부정적 경쟁돌리는데 핑터져서 졌다 개망겜이 서버가 감자라서 안들어가졌는데 이걸 경쟁밴을 때리네 어지간한 망겜도 이정도는 아닐거다 제발 섭종했으면 좋겠다 ***을 위해 기가를 투자할 가치따위는 없다 제발 대규모 그룹 경기 만든새끼는 사냐 그냥 뒤지는게 답이다 세상에 게임은 없었다 이것은 게임인가 산업폐기물인가 스팀에서 깔았는데 배틀넷 계정 연동에 평가가 부정적에서 올라가지도 못하는데 이정도면 스팀에서 내리는게 맞지 않을까
# 판단된 클래스(숫자): 3, 확률: 0.90
#
# 문장: 초보들 위한 좋은 캐릭터 있으면 좋겠어용
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 이개똥같은 게임 섭종하냐
# 판단된 클래스(숫자): 8, 확률: 0.86
#
# 문장: 게임 같네 근데 이만하게 없으면 개추ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 비쥬얼은 맛없게 생겼는데 막상 먹어보니 나쁘지않은 음식같은 느낌
# 판단된 클래스(숫자): 8, 확률: 0.97
#
# 문장: 솔까 재미는 있음
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 애증으로 하고 있지만 이제와서 새로 할 훌륭한 게임은 아닙니다
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 사실 오버워치를 좋아하는 거 아니니
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 쉽게 즐길 수 있음
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 진짜 그냥 너무 재밋음 캐릭터도 다양해서 좋아요ㅕ
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 리퍼 탄퍼짐 줄인거 굿 그림자 밟기 속도 단축 굿 이제 우클릭도 넣어주고 리메이크 한다며 버프랑 리메이크는 말이다 리메이크 한다고 한 지 올해 분기는 더 지난 거 이쯤이면 리퍼 유저들 속인거다 옆동네 유희왕은 푸른눈의 백룡도 헝그리 버거 덱 지원카드 나오고 상향 받는다 이건 뭐하냐고
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 히히 재밋다
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 처음엔 재밌겠다고 생각하는 당신은 조용히 뒤로 가기 버튼을 누르시기 바랍니다 계속하다보면 어느새 본인의 스트레스는 꼭지까지 열리기 직전에 상황을 마주하게 될겁니다 빠대나 경쟁전을 하면 내가하면 느그영웅이 되고 남이하면 우리영웅이 되는 신기한 마술을 보게 됩니다 PVE 처음엔 기대를 많이 했는데 긴 세월동안 만든게 꼴랑 개 밖에 없더군요 퀄리티라든지 사운드라든지 생각보다 좋으면 아무말은 안하겠지만 취향도 아니었습니다 PVE 용 하나사는데 원 너무 선넘지 않습니까 그것도 환불도 불가능하다는 아이러니 옛 정 생각해서 바르고 고운말을 쓰고 싶지만 이번엔 그럴 수가 없었네요 실력은 늘긴 커녕 게임 할때마다 욕만 튀어나오고 항상 화가 나있는 상태가 지속되다보니 이러다간 스트레스 쌓으면서 게임하는거 같아 그냥 유기할려고 합니다 새로운 PVE나오면 다시 키겠지만 PVP는 힘들어서 못하겠어요 추가 오버워치 탈출은 지능순 하면 할수록 스트레스는 쌓이고 유저들 수준은 떨어져서 결국엔 계삭을 하고 튑니다 여러분들 아시겠죠 탈출은 지능순입니다 빨리 탈출하십쇼
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: ㅈ같이 재미없네
# 판단된 클래스(숫자): 3, 확률: 0.98
#
# 문장: 갓겜 JOAT
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 욕하는애들이랑 외국인애들만 할만함 근데그게 퍼
# 판단된 클래스(숫자): 8, 확률: 0.88
#
# 문장: 재밌어요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 악귀의 소굴 이말 끝 수다방 가지말것
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 오랜만에 하면 재밌지만
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 전체채팅을 쓸려고 하니 레벨이 낮아서 채팅이 안된다고 하는데 채팅에도 랭크 시스템이 있나요 랭도 아니고 일반 매치 중도탈주에 쿨타임이 존재한다는게 말이 되십니까 있다쳐도 시간 이런씩으로 순차적으로 주지 않나요 시절 옵치 이리 됬습니까
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 노잼
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 핵방치하는 버러지게임 메카브레이크 나오기전까지만 함
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 오버워치 대기방
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 오랜만에 하니까 추억돋고 좋네요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 게임 아님
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 게임자체는 재밌음
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 옵치 출시후 ### 만에 돌아와서 몇판을 해봤다 오랜만에 해서 그런지 너무 재밌었고 접었는지도 기억이 잘 안 났었다 다음날에도 전날과 들어왔는데 곧바로 내가 이게임을 접었는지 기억할수 있게 됐다 탱커 매치을 돌리자 마자 들어오는 딜듀오 끊임 없는 정치질과 욕설 추억은 추억으로 남을때가 가장 아름답다는 말이 괜히 있는게 아닌것
# 판단된 클래스(숫자): 8, 확률: 0.98
#
# 문장: 이제는 게임이 너무 해비해서 재미없음
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 주노가 너무 이뻐용
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 둠피스트 삭제해라
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 블자에서 는 죄악이다 조만간 오버워치리저렉션 나오고 더***난다에 블자사장 ### 쪽을 검
# 판단된 클래스(숫자): 8, 확률: 0.98
#
# 문장: 맨날 연속 지고 개빡쳐서 삭제식 한다음 며칠있다가 다시 까는 게임이라면 사실 갓겜이 아닐까
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 걍 꿀잼
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 굳
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 굿
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 리황 진짜 씹간지네
# 판단된 클래스(숫자): 3, 확률: 0.98
#
# 문장: 무슨망할게임너무쓰레기인데혹평놀기싫어
# 판단된 클래스(숫자): 8, 확률: 0.98
#
# 문장: 그냥 해
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 맨날 망겜이다하면서 꾸역꾸역 이거만한거 없어서 하고있는 나를 볼수있음 게임자체는 재미있는데 말이지
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 탱커좀 강하게 만들어줘라 뭔 하루종일 쳐맞다 끝나네
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 개버러지 게임 ### 벤처 개새끼가 뒤질려고 환장했나 니거새끼 돈없어서 임플란트도 못하는새끼가 돌이나 씹어먹고
# 판단된 클래스(숫자): 3, 확률: 0.98
#
# 문장: 로봇 인증만 번하고 걍 때려침
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 돌고돌아 오버워치
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 공겜
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 꿀잼
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 개판싸움
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 인증 망겜
# 판단된 클래스(숫자): 8, 확률: 0.96
#
# 문장: 평가를 하자면 이게임은 아주 재밌따
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 가볍게 게임하기 좋음
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 죽지도 않았던 겜이지만 사후지원을 해야하는지 잘 보여주는 ***갓겜
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 블리자드 게임 완전 ***망게임
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 망겜ㅇㅈ
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 하지마세요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: ㅈ같은 게임
# 판단된 클래스(숫자): 3, 확률: 0.95
#
# 문장: 개꿀잼
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: ***게임 배틀넷 계정 관리에 문제가있으니까 플레이하는데 지장생김
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: ㅈ***겜 매칭돌리면 우리팀에 무조건 던지는놈이나 포꼬있음
# 판단된 클래스(숫자): 8, 확률: 0.97
#
# 문장: 게임 그래픽 년대 초반 게임처럼 보임 약간의 향수를 자극하는 수준 평범하지만 눈에 거슬리지는 않음 꽤 현실감 있는 비주얼 영화보다 더 생생한 느낌 사운드 음악 소리 꺼놓고 플레이하고 싶음 배경음이 단조로움 무난하게 들을 수 있음 분위기에 맞는 음악 사운드 트랙을 따로 찾아 듣고 싶을 정도 스토리 서사 스토리가 있긴 한가 싶음 전형적인 클리셰로 가득함 그럭저럭 흥미로운 전개 몰입할 만한 이야기 끝까지 눈을 뗄 수 없는 서사 게임 플레이 조작감 조작이 답답하고 불편함 조작법이 어색하고 부자연스러움 적응하면 나쁘지 않음 부드럽고 직관적인 조작감 손에 착착 감기는 조작감 난이도 균형 너무 쉬워서 도전 욕구가 안 생김 단순하지만 재미는 있음 적절한 도전 의식을 자극함 꽤 어려워서 만족스러움 매우 어려워서 성취감이 큼 버그 최적화 버그 게임 진행이 어려움 중간중간 버그가 눈에 띔 크게 문제는 없지만 개선 필요 완벽하게 돌아감 최적화가 매우 잘 되어 있음 게임 길이 콘텐츠 너무 짧아서 아쉬움이 큼 중간에 지루해짐 알맞은 분량으로 즐길 수 있음 다양한 콘텐츠로 오래 즐길 수 있음 무궁무진한 콘텐츠로 가는 줄 모름 가격 대비 만족도 가격에 비해 너무 실망스러움 비싸다는 느낌이 듦 정도면 나쁘지 않음 가격에 비해 충분히 가치 있음 돈이 아깝지 않은 최고의 선택 멀티플레이어 경험 해당되는 경우 멀티플레이가 불편함 하는 게 더 나을 듯 적당히 즐길 만함 친구들과 함께하면 더욱 재미있음 멀티플레이를 위한 필수 게임  개인적인 추천 절대 추천하지 않음 크게 추천하고 싶지 않음 추천할 만한 부분도 있음 친구들에게 추천할 수 있음 누구에게나 꼭 추천함
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 진짜잘만든갓겜운영도참잘함
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 개***겜
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 비응신 유저들의 ### 정치질 능력 게임사의 엄청난 운영 개똥겜
# 판단된 클래스(숫자): 3, 확률: 0.66
#
# 문장: 굳
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 재밌다
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: DLC로 배틀패스 구매할 수 있게 해뒀으면 제발 구매 후 적용되게 해주세요 지금 구매한지 몇시간이 지났는데도 적용이 안되는게 말이 되나요 이번만이 아니라 배틀패스 새로 나올 때마다 그랬어요 도대체 이쯤 되면 게임들처럼 즉각 적용될 수 있게 고쳤어야죠 지금 스팀에 들어온지 지났는데 아직도 못 고칩니까
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 인생게임 말모말모
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: ### ### ### 게임 ### 뭔 게임이 되야 하던가 말던가 하지 십새가
# 판단된 클래스(숫자): 3, 확률: 0.96
#
# 문장: 재밌음
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 게임이 정말 재밌어요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 이걸 DLC라고 돈 받고 생각을 하다니 년동안 개발진들은 뭐 한건지 알수 없다 디아블로부터 망한게 보이네요 블린자두 녀석들은 게임을 발로 만드는거 같아 옵치가 발로런트 처럼 변한것도 문제지만
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 리그 오브 레전드
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 재밌나
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 분 보고 안볼 사이인데 판하다가 채팅으로 상처받지 마시고 설정 소셜 텍스트 대화 탭으로 가서 팀 경기 텍스트 대화를 비활성화해놓고 채팅없이 즐겜하면 됩니다 PS 절취선 아래로 내용을 더 추가합니다 철취선 서론 추천을 많이 받아서 게임을 진입하는 뉴비들을 위한 글자 더 적어보도록 하겠습니다 뉴비를 위한 글이기 맵의 장점 영웅별 특징들은 플레이하면서 알아가도록 합니다 게임을 알아가야 하는 내용들이 많기 여기다가 적기에는 내용도 많고 숙련자들을 위한 글귀는 더 적을 것이 없기 여기에서 더 추가할 내용은 없습니다 숙련자가 되기 위해 게임을 알아가고 싶다면 YouTube 장문철 영상을 보세요 홍보가 아니고 뉴비들에게 도움이 되리라 믿습니다 게임 내 설정 뉴비들을 위한 모드설명 경기 팀 채팅 비활성화 방법 분 보고 안볼 사이인데 판하다가 채팅으로 상처받지 마시고 설정 소셜 텍스트 대화 탭으로 가서 팀 경기 텍스트 대화를 비활성화해놓고 채팅없이 즐겜하면 됩니다 스트리머 닉네임 설정방법 스트리머 닉네임 설정하는 이유는 게임 중 자신의 닉네임을 숨기기 위한 용도로 사용합니다 전판에 만났던 유저가 있다면 자신의 닉네임을 가림으로써 플레이하는 데에 부담을 덜어줄 수 있는 요소 정도로 보면 될 같습니다 설정 소설 공개설정 스트리머 모드를 활성화 합니다 판 닉네임으로 보여지며 고급 설정 옆에 버튼을 눌러서 상세 설정이 가능합니다 F 도움말 적극 참조 뉴비에게 있어서는 F 번 버튼의 스킬설명은 사막의 오아시스와도 같습니다 잘 모르는 영웅을 플레이할 때에는 수시로 F번 버튼을 눌러서 확인합니다 뉴비에게 권장하는 모드 뉴비는 게임을 플레이함에 있어서 영웅 간의 상성을 알 수가 없습니다 그렇기 무엇을 플레이해야할 지 모르는데 보통은 일반전의 역할고정 자유모드로 매칭을 돌려서 하는 경우가 대다수입니다 역할고정 자유모드로 매칭을 돌리지 말고 일반전 탭에 수수께끼의 영웅이 있습니다 게임을 시작하면 공산주의마냥 게임 시스템이 영웅을 강제로 배정해주는데 자신이 원하는 영웅이 아니기 영웅숙련도가 떨어질 수밖에 없고 숙련도가 높은 영웅이 걸리면 판은 어이없게 끝나는 경우도 있긴 영웅을 알아가기에는 수수께끼의 영웅 잘 설계된 모드가 없습니다 수수께끼의 영웅 플레이함으로써 뉴비들이 얻을 수 있는 게임적 요소는 아래와 같습니다 영웅들의 플레이 방법을 수박겉핥기 식으로 습득 영웅별 상성은 설계되어 있는가 중복 영웅 플레이에 대한 재미 수수께끼의 영웅을 플레이하다가 마음에 드는 영웅이 있다면 자유모드로 플레이해보기를 권장합니다 뉴비에게 권장되는 모드의 우선순위는 아래와 같습니다 수수께끼의 영웅 상대도 못하고 자신도 못하게 되기 플레이에 부담감이 가장 낮습니다 자신이 생각하기로 사기적인 영웅이 선택된다면 재밌는 모드가 없을 것입니다 일반전 자유모드 자신이 원하는 영웅들을 플레이할 수 있기에 수동적인 플레이보다는 능동적인 플레이를 하는 유저들이 더 많기 플레이에 부담감이 낮습니다 일반전 역할고정 게임에 대한 이해가 정도 잡혀있어야 포지션에 따른 팀 플레이가 가능합니다 서로에게 의존적인 수동플레이를 지향하기 플레이에 부담감이 높습니다 게임의 특징 게임에서 채팅이 가지는 기능은 칭찬  공략 도모 남탓 비방  입니다 게임을 처음 진입하는 뉴비 게임을 이끌어나가고 영웅 간의 상성이 이루어지는 지 모르기 뉴비를 향한 비방성 채팅에 쉽게 노출되어 상처받을 수 있는 게임입니다 대 시절에는 정도 팀에 묻어갈 수 있었지만 현재는 대 팀 게임이기 한 명의 구성원이 중요한 게임으로써 남탓 비방을 하는 유저 혼자서 완벽한 플레이를 이어갈 수 없습니다 남탓 비방을 하는 유저도 완벽한 플레이를 보여주지 못하기 자잘한 자신의 실수들은 숨기고 타인을 비방하기 바쁩니다 부분들은 한 귀로 흘려들어 흘리거나 사람의 플레이를 지적하며 비방하세요 그게 답입니다 심한 욕설은 제재가 될 수 있으니 되도록 지양하는 걸 추천드리며 상대가 자신의 화를 이기지 못해 심한 욕설을 채팅으로 적는다면 뒤도 돌아보지 않고 해당 유저를 차단 박은 후 신고 버튼을 누름으로써 대응하기를 바라겠습니다 웃긴게 심한 욕설을 채팅으로 했을 제재를 먹는다는 큰 리스크가 따르기 악성 유저들도 심한 욕설을 하는 대신에 뒤로 돌려서 까는 경우가 더 많습니다 일부러 비방성 채팅을 통한 악성유저들이 있기 채팅에 그리 큰 의의를 두지 마시길 바랍니다 비방성 채팅을 피하고 싶다면 아래와 가지를 이행해보세요 게임 중 p 키를 눌러 팀 경기 텍스트 대화 비활성화 스트리머 닉네임 설정으로 자신의 닉네임을 숨기기 악성 채팅 제재의 기준 채팅 제재의 기준은 당하는 사람 입장에 주관적으로 진행되는 같습니다 당하는 사람의 기분이 나쁘다고 생각되는 부분이 있다면 게임사에서도 채팅에 대한 심각성을 모르진 않기 부분을 많이 참고하여 적용시키려는 같습니다 탱 딜 힐 포지션으로 나뉘어져 있는 수동적인 게임시스템을 채용하고 있지만 보다 능동적인 플레이가 승패를 좌우합니다 남에게 바라는 플레이를 하며 남탓 비방을 하는 유저들은 결코 성장할 수 없습니다 남의 플레이를 바꾸는 건 불가능에 가까우므로 자신의 위치에 맞는 상황에 알맞는 선택을 이어나가도록 합니다 한도끝도없이 남탓 시비 거는 유저가 있고 티어가 떨어져도 상관이 없고 이겨도 이긴 같지 않다면 던져도 상관없습니다 이것은 오버워치의 문화입니다 모드별 특징 뉴비에게 도움이 되는 주요 모드만 적어보겠습니다 일반전 위에 써놓은 글귀 복붙 수수께끼의 영웅 상대도 못하고 자신도 못하게 되기 플레이에 부담감이 가장 낮습니다 자신이 생각하기로 사기적인 영웅이 선택된다면 재밌는 모드가 없을 것입니다 일반전 자유모드 자신이 원하는 영웅들을 플레이할 수 있기에 수동적인 플레이보다는 능동적인 플레이를 하는 유저들이 더 많기 플레이에 부담감이 낮습니다 일반전 역할고정 게임에 대한 이해가 정도 잡혀있어야 포지션에 따른 팀 플레이가 가능합니다 서로에게 의존적인 수동플레이를 지향하기 플레이에 부담감이 높습니다 아케이드 대 대 섬멸전 오버워치에서 한타를 해야 하는 지 배울 수 있는 모드 대 팀데스매치 한정된 맵공간에서 진행하는 팀데스매치 모드로써 게임모드보다도 영웅들을 빠르게 플레이해볼 수 있는 장점을 지닌다 임무 영웅 별로 게임에서 식으로 사용할 수 있는 지 간접적으로 배울 수 있는 모드이지만 많이 지루합니다 알려주는 데에만 초점을 맞춰서 만들어진 모드입니다 기준에서는 재미가 없어요 경쟁전 남탓 비방성 채팅이 난무하기 뉴비는 되도록이면 플레이를 지양합니다 경쟁전 역할고정 영웅별 특징과 게임맵에 대한 이해가 많이 자리잡혀 있는 유저에게 권장되는 게임모드 경쟁전 자유모드 영웅별 특징과 게임맵에 대한 이해가 많이 자리잡혀 있는 유저에게 권장되는 게임모드 뉴비들은 경쟁전은 되도록 하지 마세요 숙련도가 낮음으로써 확실하게 스트레스를 받을 것입니다 경쟁전을 체험해보고 싶다면 숙련도를 많이 필요로 하지 않는 영웅으로 진입해보세요 ex 메르시
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 압도적 부정적
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애 프비공 없애
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 똥망겜
# 판단된 클래스(숫자): 8, 확률: 0.88
#
# 문장: 하지마세요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 쓸데없는 리캡챠 인증만 하루종일 저능게임
# 판단된 클래스(숫자): 8, 확률: 0.55
#
# 문장: 지로보센세 당신이 옳습니다
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 핵이 많아도 재미는 있음
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 노잼임
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 재밋더
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 흠
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 개재밋음
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 이제는 모두가 익숙한 하이퍼 FPS 과 다르게 꾸준하게 업데이트 되고 있음 생각보다 저사양 PC에서도 돌아가는 온라인 FPS 게임 개발자의 편애인진 모르겠지만 특정 캐릭터의 고착화가 쉽게 보임 소소한 버그는 시즌이 지나도 잘 고쳐지지 않음 선한 유저나 악한 유저거나 상관없이 유저의 프라이버시를 소중히 생각함 시간이 지남에 유저가 많이 고이긴 했음 플래시 포인트 경쟁전을 제외한 컨텐츠의 경우 중도 난입이 있는데 중도난입에 대한 혜택도 없을뿐더러 탈주하면 패널티가 부여됨 플레이 타임 온라인 PVP 게임이라 딱히 플레이 타임은 없음 짧은 평가 제프카플란때보단선녀다
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 오버워치는 정말 실망스럽습니다 블리자드의 지나친 PC주의는 게임의 재미를 심각하게 저해하고 있습니다 게임 내에서 표현을 사용하더라도 엄격하게 제재를 가하는 운영 방식은 정당한 이유 없이 플레이어들을 억압하고 결과로 인해 많은 유저들이 불합리한 제재를 받고 있습니다 게임 컨텐츠 자체도 실망스럽습니다 오버워치과 비교해 큰 변화가 없고 새로운 요소들도 대부분 기존의 시스템을 재활용하는 수준에 불과합니다 게임의 핵심적인 문제점은 개선되지 않은 채로 남아 있으며 블리자드가 플레이어들의 의견을 제대로 반영하지 않는 같아 매우 실망스럽습니다 블리자드는 고객 지원에 대한 문제도 해결하지 못하고 있습니다 고객 문의에 대한 대응이 느리고 불투명한 제재 결정 과정으로 인해 유저들이 불만을 표출할 수 있는 방법이 제한되어 있습니다 이로 인해 플레이어들의 신뢰를 잃어가고 있습니다 운영 방식과 컨텐츠 수준으로는 게임의 미래가 어둡다고 생각하며 다시는 게임을 플레이하지 않을 것입니다
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 남탓 심한 게임 하다가 암걸려서 접음
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 이게임은 오리사가 제일 강합니다
# 판단된 클래스(숫자): 8, 확률: 0.96
#
# 문장: 걍
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 이아아앙아아아앙
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 오버워치 의 장점 영구 무료화 엔진 업그레이드 신규 영웅 신규 전장 신규 스킨 신규 컨텐츠 VS 영웅 일부 리메이크 임무 미션 추가 오버워치 의 단점 앞서 말한 장점들은 굳이 편 아니었어도 편으로 충분히 할 수 있었음 스킨 구매 전리품 삭제 현질 시스템으로 변경 스킨 가격 K물가급 고작 이것들 준비한다고 편 없데이트 기간 ### 굳이 편 아니었어도 편으로 다 엎을 수 있던 것들인데 괜히 옵치로 엔진 바꿔서 ***하겠다고 선언한 뒤 민심 안 좋을까봐 준비하던 거 그나마 편에서는 못보고 편에서 크게 보여줄 수 있던거 PVE 모드 PVE 모드는 ### 반 전에 개발 중단 그걸 이제 말함 아예 취소 된 건 아니고 전작의 인 협동 플레이 처럼 한다 이게 웬 걸 정신 못 차렸나 이걸 유료로 비싸게 쳐 팔아 먹고 앉아 있네 PVE 모드 취소 이유 우린 아직도 LGBTQ 뇌절에 맛 들렸는데 그게 소홀해질까봐 PVE 아몰랑 귀차나 시전함 추가 소식 ### 월 일 부로 PVE 개발 축소도 아닌 그냥 전면 취소됨 어이는 커녕 기대가 싹 다 뒤져서 알아서들 하라 사실상 망하는 자체가 불가능한 게임을 이렇게 망하게 만드는 것도 능력 잘하는 짓이다 블리자드 ㅇㅐㅁㅣD진ㅅㅐㄲㅣ들아 진작에 D졌구나
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 때가좋았다 이제 이게임은 추억으로 간직해야겠다
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: ### 망겜
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 너무재밌고 가끔식화나긴하지만 최고에요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 로그인부터 ###
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: ### 방귀 오줌
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 아잉이이이이잉ㅇ잉ㅇ
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 질때 화나고 이길때 신나는 게임 근데 재밌다
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 재밌음
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 재밌는뎅
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 매칭 시스템 만든 개발자는 필히 자살하길 바란다 개 ### 새끼들 옵치에서 로 넘버링 한 이유가 뭐냐 도대체 개 버러지같은 게임
# 판단된 클래스(숫자): 3, 확률: 0.98
#
# 문장: 엉덩이
# 판단된 클래스(숫자): 8, 확률: 0.97
#
# 문장: 접
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 렉 도 없어서 하기 좋음
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 장점을 상쇄시키는 개발속도가 이모든 평가를 압부로 만들게함 pve삭제 ok 디렉터 관점 괜찮아 나름 좋은 방향의 고집과 개발방향을 알수있었음 ok 신캐주기 개월 신맵과 신캐를 개월 단위로 나와야지 수지타산이 맞지 pvp만 집중하고 개발팀도 포기안하고 계속 새로운 시도를 준비중인거면 그속도가 빨라져야 정상인데 애들은 pve접은 이후에도 개발속도는 나아지질 않고 배틀패스는 독특한 취향으로 계속나오고 유저 니즈도 미국중심으로 운영중 이게 운영중심은 어디국가든 상관없지만 나름 한국에서도 꽤하고있고 옵치전성기 한획을 도왔던 나라인데 요즘들어 정성이 부족한느낌 요약업뎃빨리좀
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 갓겜
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 발로란트보다 재밌음
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 제발 한판만 해주면 소원이 없겠다
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: si진ping***새끼야
# 판단된 클래스(숫자): 3, 확률: 0.97
#
# 문장: 맛있는똥
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 리뷰 남길라고 깔았다 씨이이발럼들아
# 판단된 클래스(숫자): 3, 확률: 0.98
#
# 문장: 둠피 개씹사기
# 판단된 클래스(숫자): 3, 확률: 0.97
#
# 문장: 하피그
# 판단된 클래스(숫자): 8, 확률: 0.98
#
# 문장: 탱커는 부담감 높다고 개 징징 딜러는 ### 내가 다 해줬는데 다 뭐함 뻔뻔 힐러는 오빠들 뒤좀 봐줘하면서 절대로 픽 안바꾸고 지 상황 모르는 무능함
# 판단된 클래스(숫자): 5, 확률: 0.66
#
# 문장: 갓겜 진짜
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 탱커의 실력여부가 팀의 승리를 책임진다
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 떄도 ***망겜 ***망겜 했는데 지금보니 이 선녀 였음
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 유입이 없을까
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 굳이 똥을 찍어먹어봐야한다는 사람한테 강추 난 스캇충이였나봄
# 판단된 클래스(숫자): 8, 확률: 0.88
#
# 문장: ### 전으로 돌려
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 화나서 삭제했다가도 화났는지 잊은 후 다시깔고야 마는 게임
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 흥치뿡 이제 아나안해
# 판단된 클래스(숫자): 8, 확률: 0.98
#
# 문장: 개꿀잼ㅁ이에요같이해오
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 게임을 유료로 팔아 쳐먹는 거 돈 주고 사다가 안에 가챠까지 질러놨는데 밸붕에 개차반운영인거 업데이트로 해결할 생각은 안하고 섭종과 라는 숫자 붙여서 vs 인거 vs 로 바꿔서 출시해놓고 처음부터 다시 과금하세요 와중에 ㅈㄹ맞은 정치적올바름 마소가 액블 인수한지 일이 더 넘었는데 아직까지 지경이면 마소의 액블 인수는 액블의 발전에 아무 도움이 안된다는거지
# 판단된 클래스(숫자): 3, 확률: 0.97
#
# 문장: 힐줘요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: ***겜 밸런스 죶박고 지들끼리 우리겜 쩌는듯하며 자위하는 개발사 다른겜 살짝만 찍먹해봐도 이게임이 ### 밸런스인지 느껴짐 죶나 노력해야 킬을 따는게 아닌 그냥 처 쏘다보면 얻어걸리는 캐릭터가 훨신 좋음 노력하는게 죄악인 게임 유저수준도 ***들인게 뭔 ### 한국사람하고 한국말로 대화하는데 ### 대화가 안통함 말귀를 처 못알아먹음 힐안되니까 바꿔달라고 딜 약하니까 바꿔주세요 이게 ### 입터는거냐고 ### 금기어 수준으로 알아들음 바꿔달라는게 니가 ***같이 못해서 뭐가 안되니까 바꿔가 아니라 다른걸로 하면 좋을거 같은데 이지 ***들이 ### 대가리에 상식도 안들어찬새끼들이 겜하겠다고 ***하는게 꼴보기가 싫음 나가서 사람하고 대화를 이딴식으로하면 내가봤을때 나가자마자 분안에 칼침맞고 병원감 의사쌤이 뭐하다 칼침맞았냐 물어보면 이새끼들은 니가 알아서 뭐할건데 입털어 이럴새끼들임
# 판단된 클래스(숫자): 8, 확률: 0.86
#
# 문장: 개***겜
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 겜 첨하는데 브론즈 새끼들이 일겜에서 패드립 날린다 처 패버리고 싶노
# 판단된 클래스(숫자): 3, 확률: 0.98
#
# 문장: 게임 자체는 재밌으나 플레이어간 선동질 정치질이 심하고 핵을 사용하는 유저들의 제재가 상당히 느리며 아케이드의 여러 모드들은 밸런스가 파괴되어 몇몇의 영웅만이 유리한 상황입니다
# 판단된 클래스(숫자): 8, 확률: 0.96
#
# 문장: 욕도 아까운 최악의 ### 게임
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 재밌음미다
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 망겜인데 노력을 하니까 봐줄 까
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: ### 비슷한 등급끼리 붙여주던가 자꾸 티어 ### 차이나는 애들만 적팀으로 만나냐 블리자드 ***뒤진 ***새끼들아
# 판단된 클래스(숫자): 3, 확률: 0.98
#
# 문장: ***련아 사람 맞다고 겜보다 인증이 더어렵네 개 ㅈ같은 블리자드 년들아
# 판단된 클래스(숫자): 3, 확률: 0.99
#
# 문장: 망겜
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 내 돈이랑 시간이 아깝다
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 엄
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 어린 시절의 추억이 떠오른다 재밌긴 하다
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: h 회사가 유저한테 ### 사기를 수가 있나 h
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 이거할바에 야동보고맘
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 아주 재미있는 게임이였어요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: h 만에 게임 하려면 늦은시간에 돌리지 마라 h 친구랑 돌리는데 짱ㄲㅐ 새끼들 명이랑 매칭되서 쪽도 못쓰고 개 발렸다 내 인생 처음으로 이렇게나 쪽도 못쓰고 진건 처음이였다
# 판단된 클래스(숫자): 0, 확률: 0.92
#
# 문장: 개망겜 그자체
# 판단된 클래스(숫자): 8, 확률: 0.96
#
# 문장: 개성있는 캐릭터와 매력적인 세계관 지금도 촌스럽지 않은 그래픽 롱런할 수 있는 요소들과 기회가 많은 작품인데도 이렇게 망쳐놓는 경우는 진짜 대단하다 끝내 pve 스토리모드는 제작진의 개발 역량 부족을 스스로 인정한 결과로 안 나오게 됨
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: ### 초보 망겜
# 판단된 클래스(숫자): 8, 확률: 0.98
#
# 문장: 때가 좋았다는 의견이 가끔 보이는데 게임은 좋았던 적이 한번도 없다 맵에 따른 영웅 밸런스 문제가 심각한데 맵 밸런스 패치는 불가능하다 모든 맵과 영웅들의 이동기를 조정 할 수가 없다면 밸런스 문제가 일시적으로 훨신 심각해진다 오버워치 를 개발하면서 영웅들의 밸런스가 바뀐 스케일을 생각해보면 그보다 훨신 많은 노력과 시간이 필요하기에 방향성은 불가능에 가깝다는 것을 알 수 탱커 문제는 한번 스킨 들을 출시한 체력과 능력들의 밸런스를 맞출 구멍이 완전히 막힌다 체력을 줄이면 그만큼 캐릭터 모델들의 크기를 줄이지 않으면 물몸 문제가 생기기 탱커 체력을 줄이고 스킬들을 버프하는 방향성을 택할 수가 없다 이게 정답이라는게 아니라 이걸 시도 할 수가 없다는 말이다 교전 시간이 길고 대 교전에서 이득을 얻는게 매우 힘든 게임이라 무조건 팀 행동을 해야하고 하고 싶지 않은 플레이만 강제로 계속 하는 느낌이라 게임이 재미가 없다 예외는 저격수인데 저격수는 이동기와 맵 밸런스 문제로 다시 돌아간다 정리하면 때 외관템들에 소비자들이 쓴 돈을 무시할 수 없어 한번 나온 영웅은 절대로 다시 되돌릴 수 없고 크게 방향성을 바꿀 수도 없고 맵 제작 방식과 영웅 능력과의 밸런스 맵도 크게 바꿀 수가 없고 처음 정한 방향이 팀 게임이라 하고싶은건 하지도 못하는 망하는게 필연적인 게임이라는 것이다 커스텀 게임이나 즐기다 간다
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 없는게임
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 게임은 괜찮은데 문화가 잘못됨 나도 내가 못하는 거 아는데 굳이 엄마를 욕해야 겠니 그것도 빠대에서 이거 할거면 친구 명 모아서 피방에서 아주 가끔 하는게 나음
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 인생게임이지 뭐
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 퍼즐게임인가요 진짜 빡치네요 로그인만 분했어요 다 맞게풀었는데 안되냐고요 진짜 사람 빡치게하는 게임 만들지마세요 빡치니까는
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 오버워치 ㅆ발 개새끼들아 로그인할때 저딴거 추가했냐 ***장ㅇH인같은 블리자드 ㄱH년들아 나가 뒤져라 ***
# 판단된 클래스(숫자): 3, 확률: 0.98
#
# 문장: 한판 이기면 귀신같이 처발리는 매칭만 뜸 한판하면 하기 싫어지는 ### 겜
# 판단된 클래스(숫자): 3, 확률: 0.55
#
# 문장: 어렸을때는 재미있게 했는데 온라인게임은 운영때문에 오래 할 수 없는 건가 싶었다
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 빠대에서 한팀이 전원 기본아이콘에 핵쟁이이면 게임 망한거 아니냐 관리를 전혀 안하는데 게임이 정상궤도에 올라가길 바라는 건 욕심인거 같은데 능력이 모자라면 그냥 서비스 종료하는 게 낫지 않겠냐 관리를 아얘 안하는 걸 정확하게 알겠네 VAC차단 당한 놈들이 당당하게 게임하고 있던데 니들은 그냥 무능한 거 였구나
# 판단된 클래스(숫자): 8, 확률: 0.94
#
# 문장: 생각보단 재밌던데
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# ...
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 게임 개발자보다 오버워치 포르노 만드는 사람들이 더 열심히 일한다
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 블자 개새끼들아 니네가 옵치는 스토리기반 게임이라며 그걸 돈받고 쳐파냐 ### 나는 옵치 샀다 개새끼야 만원 적지도 않은 돈 학생신분으로 구매했었는데 주는건 ㅈ도 없고 유저를 돈줄로만 보고 개새끼들이 이딴 쓰레기게임에다 ### 운영까지 더해지니 금상첨화가 따로 없구나 이게임 다운로드 해서 플레이할때마다 기분이 이루말할수없다 내 추억이랑 만원 돌려줘 개 씹새끼들아
# 판단된 클래스(숫자): 3, 확률: 0.98
#
# 문장: ### 게임 그것은 게임을 만들 것인가 그냥이 게임은 꺼내고 내 젊음은 이 가 아니다 어리석은 게임 회사
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 오버워치 는 정말 최악입니다 그렇게 인기가 있는지 이해할 수 없습니다 그림이 좋지 않고 캐릭터 밸런스가 깨지고 게임 플레이가 너무 반복적입니다 게임을 하면 더 재미있을 같아요 Overwatch 팬은 이해하지 못할 수도 있지만 나에게는 꽤 지루한 게임입니다 Blizzard는 ### 조각과 같습니다 플레이어를 전혀 신경 쓰지 않고 돈을 벌고 싶어합니다 옆집 Ubisoft를 살펴보십시오 중국 플레이어를 위해 좋아하는 노래를 구입했습니다 그에 블리자드의 존재 자체가 무의미하다는 생각이
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 한국 사람이이 게임을하고이 게임은 썩은 것과 한 덩어리 똥이 같습니까
# 판단된 클래스(숫자): 0, 확률: 0.89
#
# 문장: 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 게임은 팀탓 나와도 참고 하겠는데 이건 이제 도저히 못하겠다 진짜 오버워치야 말로 어***어안해 시전에 가장 적합한 게임 개 역겨운 쉨들 잘나가는 게임은 즈그 플랫폼에서 돌리고 스팀이 똥통이냐 스팀에 내는 수수료 아깝다 이건데 줮나 웃긴게 그런 ***들아 오버워치 침공 묶음 같은 ㅈ*** 콜렉션으로 돈 빠는건 ***라 수수료 노상관이란거지 사겠냐 ***들아ㅋㅋㅋㅋㅋ 은근슬쩍 처 파는거 진짜 개패고싶네ㅋㅋㅋ
# 판단된 클래스(숫자): 3, 확률: 0.98
#
# 문장: 정말 엉망진창이다 이것은 진정한 세기 게임이다 나는 ### 게임을 해본 적이 없다
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 게임은 매우 형편없었습니다 최적화 매칭 메커니즘 플레이어의 자질 게임 계획 한마디로 아주 형편없었고 플레이어를 매우 실망시켰습니다
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 압도적으로부정적은 나라도 추천줌
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 이건쓰레기게임쓰레기운영자 ###
# 판단된 클래스(숫자): 8, 확률: 0.97
#
# 문장: 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 게임은 정말 끔찍하고 그런 ### 게임을 한 적이 없는데 무료 게임 스킨이 실제로 충전되어야 한다고 감히 믿을 수 있습니까 너무 실망 스러웠습니다
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 게임은 나를 너무 실망시켰다 게임 매칭 메커니즘은 정말 형편없었다 폭설은 정말 어리석은 회사였다 나는 먹다 남은 뼈를 폭설에 먹였다 뼛속의 노예
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 쌉노잼
# 판단된 클래스(숫자): 3, 확률: 0.55
#
# 문장: ### 게임
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 평가를 보니 대부분 긍정적보단 부정적그냥 부정적이 아니라 압도적으로 부정적이여서 저도 비추누릅니다 저는 오버워치를 처음 나왔을때부터 했던 사람으로써 오랫동안 해왔는데 이렇게 실망 안시킨적이 많이 없었습니다 아그레서 내가 지금 게임을 만들면 오버워치보단 낫겠다라는 생각을 했었습니다 오버워치 초창기때에는 정말 갓겜이었죠 제가 게임을 만들고싶다라는 생각을 한번도 해본적이 없을정도로요 당시 개발자들의 솔직한 심정을 알기 전까지는 말이죠 제가 게임을 만들면 오버워치보단 갓겜을 만들고싶을 정도로 오버워치는 정말많이 매우 안좋습니다 정말 사실입니다 그레도 저는 이글을 쓰고도 오버워치를 서비스 종료할때까지 계속 오래 하겠죠 제발 오버워치팀 유저들을 위한 패치를 많이 해주셨음 좋겠습니다
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: N년간 오바와치 흑우로서 스크린샷을 쉽게 찍을 수 있게 되었다는 점과 도전과제가 업데이트 되었다는 점으로도 행복했는데 PVE 유료 구매 ***들
# 판단된 클래스(숫자): 8, 확률: 0.97
#
# 문장: 완성도가 끝내주는 게임을 업데이트를 안 하고 방치한 무능력한 블리자드 무엇이 문제였기에 게임의 업데이트에 손을 놨을까 PVE는 파쿠리한 게임인 팀포에 수두룩빽빽하고 신캐는 아무렇게나 내도 사람들이 환호했을 것이다 밸런스는 어차피 모든 게임에서 영구히 풀지 못하는 숙제니까 둘째치고 사람들은 아무튼 신캐를 보고싶어했다 스토리는 진행이 없나 나는 오버워치가 해체된 이유를 오버워치 베타때부터 궁금해했으나 알지 못했고 블리자드가 내게 알려준 건 어두컴컴했던 과거가 아닌 어두컴컴한 성벽이었다 다행히도 나의 블리자드에 대한 신뢰감은 높다 NC와 게임을 만들더라도 쓰레기일 것이 분명할 거란 믿음 오버워치를 접은 이후로 믿음은 아직 깨진 적이 없다
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 폭설이 감히 STEAM에 와서 엄마를 배웅할 줄은 생각지도 못했다 용기가 갸륵하고 칭찬할 만하다
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 타사 계정 필요 Battlenet Account
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 회사의 행동이 우리들의 마음을 몹시 상하게 했다OW
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 이렇게 집을 존중하지 않는 게임회사는 여태껏 본 적이 없다 나쁜 평가를 내려야 한다
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 쓰레기놀이재미없어개도안해
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 그냥 히오스나 스팀에 내라
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: ***개새끼
# 판단된 클래스(숫자): 3, 확률: 0.98
#
# 문장: 무슨망할게임너무쓰레기인데혹평놀기싫어 무슨망할게임너무쓰레기인데혹평놀기싫어 무슨망할게임너무쓰레기인데혹평놀기싫어
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 대깨옵이라 개추
# 판단된 클래스(숫자): 2, 확률: 0.95
#
# 문장: 게임은 정말 너무 형편없다 이렇게 형편없는 게임을 본 적이 없다 하나도 재미없다 ### 게임은 나의 시간을 낭비한다
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 엄마 엿먹어줘 난 스틱 바보 같은 블리자드
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 무슨망할게임너무쓰레기인데혹평놀기싫어
# 판단된 클래스(숫자): 8, 확률: 0.98
#
# 문장: ### 쓰레기보다 더 많은 ### ### 더미의 쓰레기보다 낫다
# 판단된 클래스(숫자): 8, 확률: 0.98
#
# 문장: 협동전 맵들을 돈주고 파는거 실화인가
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 그걸 돈주고 파냐
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 개발자들은 PVE를 해본 적이 없어요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 개가 놀지 않는 단어
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 정신안차림
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 게임은 쓰레기입니다
# 판단된 클래스(숫자): 8, 확률: 0.82
#
# 문장: 계정 인증은 일부이고 로그인 시간은 플레이 시간보다 길고 블리자드는 뇌성 마비이고 OW는 좋은 게임이지만 불행히도 블리자드에서 개발 한 게임이며 블리자드의 온 가족이 폭력적인 죽음을 기원합니다
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 어리석은 게임 어리석은 플랫폼 이렇게 징그러운 사람이 있을 수 있겠어 게임을 하는 사람이 좋은 사람이 될 수 있겠어요 게임은 플레이어의 감정에 돈 동그라미만 생각하고 제발 오지 마세요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 누가 장난기를 볼 것인가
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 쓰레기게임은 순전히 로자의 시간을 랑비하는 쓰레기게임인데 나는이 게임에 뭐가 있는지 정말 모른다*********씨
# 판단된 클래스(숫자): 8, 확률: 0.97
#
# 문장: 중국 아빠를 차별해
# 판단된 클래스(숫자): 8, 확률: 0.93
#
# 문장: 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 평가하기 플레이했다
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: ### 게임이 대변과 같아서 바보가 만들어냈는지 정말 생각지도 못했다 완전 엉망이야 진짜 개세기는 만든 게임이야 이렇게 ### 같은 게임을 해본 적이 없어 더 게임을 하고 싶지 않아 아주 어려워 계속 돈을 충전하라고 해
# 판단된 클래스(숫자): 3, 확률: 0.88
#
# 문장: 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 최악의 게임을 했었어요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 무슨망할게임너무쓰레기인데혹평놀기싫어
# 판단된 클래스(숫자): 8, 확률: 0.98
#
# 문장: ### 게임 반나절 게임을 할 수 없습니다
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 개소리야 내가 어렸을 때부터 크게 놀았던 게임은 이것처럼 형편없는 것이 하나도 없어 회사가 이렇게 형편없는 게임을 만들 수 있는지 상상하기 어렵다
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: ### 게임은 똥덩어리처럼 만들어졌는데 이렇게 사람을 화나게 하는 게임을 본 적이 없다 매우 재미없다모두들 게임을 하지 마라 정말 시간을 낭비하니 폭설 게임을 보이콧하자
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: ow개똥 한 덩어리ps한국 사람들은 쥐다한국 사람들은 잡종이다
# 판단된 클래스(숫자): 0, 확률: 0.97
#
# 문장: 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 훌륭한 게임이 ### 회사를 만났다 게임계 최대의 수치와 웃음거리 blizzard 빨리 망하자
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 결제했는데 임무가 안들어와요 빨리 반영해주세요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: DLC적용이 안되면 환불이라도 해주던가
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 덩어리 배설물
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 폭설은 엄마가 죽었어
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 이게임을접하기전에저는게임이모두사람들에게즐거움을주는좋은게임이라고생각했습니다비록어떤게임은만족스럽지못하지만제작자의마음도느낄수있습니다이게임을접한후에저는제작진이우리게이머에대한악의메스꺼운쓰레기게임머리에문제가있는바보한국만이할수있다는것을깊이느꼈습니다
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 내가 산 DLC를 밑에서 뺐지 내가 빙다리 핫바지로 보이냐 새끼야 증거있어 증거 증거 있지 너는 나한테 아무것도 주지 않았을 것이여 시나리오 쓰고있네 ***끼가 apex 레전드 그년한테 가는거야 그년한테 가는건 좋은데 돈은 내려 놓구가 돈은 놓구가 쏠수이써 쏠쑤이써
# 판단된 클래스(숫자): 3, 확률: 0.97
#
# 문장: 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 히오스도 내보고 디아블로도 내보지그러냐 망하니까 스팀으로 기어들어와서 돈 조금이라도 빨아보려는거 역겹다
# 판단된 클래스(숫자): 8, 확률: 0.95
#
# 문장: 네놈들 게임은 망했어 여긴 이제 캬루가 지배한다 오버워치가 스팀에 나왔다고해서 PVE 컨텐츠가 출시했다고해서 희망을 가지지마십쇼 오버워치는 부터 아주 굳건히 변함 없이 꾸준하게 쳐말아먹어서 동서양 유저 대거 탈출 시켰으니 지금이라고 뭐 다를리가 있나 그냥 오버워치한테 바라는점은 신캐 모델링이나 제대로 뽑아냈으면 좋겠다 잘뽑아내면 폰허브같은곳에서라도 볼 수 있을테니
# 판단된 클래스(숫자): 3, 확률: 0.66
#
# 문장: 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 재밌는데
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 오버워치 같은 실수를 반복할 것인가
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 게임은 재밌는데 혹평 드릴게요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 님들 서든허쉴
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: ### 게임 평생 이렇게 형편없는 게임 회사를 본 적이 없다 게이머를 대하는 태도가 매우 나쁘다 일찍 도산하기를 바란다
# 판단된 클래스(숫자): 8, 확률: 0.98
#
# 문장: 블리자드 내가 엄마를 늙은 엄마로 엿먹였어 엄마를 매일 강요했어 넌 ### 강제야 중국 선수들을 사람으로 취급하지 마 노자의 날 당신의  세대 조상 나는 당신의 어머니를 엿 먹고 이전 계정의 데이터를 말하는 방법 당신의 어머니는 그것이 사라 졌다고 말하도록 강요했습니다 나는 당신의 조상을 날 나는 당신에게 말합니다 백인 장님이 좋은 게임 그의 할머니는 망치 온라인 증기의 시작에 당신의 할머니는 망치 중국어 간체에 참여할 수 없습니다 확실히 그루브에서 중국 선수의 돈을 벌 수 없다고 생각 당신은 MLGB Jian Zhong을 얻을 당신은 빌어 먹을 mlgb이 먹는 것은 너무 ### 못생긴 나는 당신의 어머니를 엿 먹어 돈은 돈이 아니야 너의 어머니는 강요 당한다 죽지 않니 나는 너의 죽음을 고대한다 할머니 나는이 나쁜 리뷰를했다 나는 줄 번호를 변경한다 번호를 사는 것은 큰 일이다 나는 당신에게 나쁜 리뷰를 닦을 것이다 당신은 가치있는 거시기가 있습니까 Lao Tzu는 당신에게 돈을 씁니다 나는 모든 페니에 대해 미안하다고 느낍니다
# 판단된 클래스(숫자): 8, 확률: 0.87
#
# 문장: 무슨망할게임너무쓰레기인데혹평놀기싫어
# 판단된 클래스(숫자): 8, 확률: 0.98
#
# 문장: 죽은 엄마의 눈보라 ### 개 게임을 하지 않으면 개가 오게 하십시오 정말 인터넷에 메모리가 없다고 생각 했습니까 중국 선수들이 돼지라고 생각하십니까 블리자드 경영진은 Peppa Pig가 관리하도록 하는 것이 좋습니다
# 판단된 클래스(숫자): 8, 확률: 0.93
#
# 문장: 어리석은 블리자드 Battlenet 당신의 어머니는 죽었습니다
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 스팀 출시 조아요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 밸런스 패치 못함 호그 몇달동안 방치하냐
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 딴것도 빨리 내주세요 배틀넷 지워버리게 하스랑 디 리저렉션만 와도 배틀넷 필요없음
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 오랜만에 하니까 재밌네요 근데 재밌는게임을 개이같이 운영해서 말아먹는지 정말 화딱지나네요
# 판단된 클래스(숫자): 8, 확률: 0.96
#
# 문장: ㅆ발 개***들인가 지들이 pve 만든다고 ### 떠벌리면서 은 ### 찬밥 취급하면서 유저 다 떠나게 만들었으면서 이제와서 하는 말이 반쪽짜리 pve 이럴거면 이빨 ### 까고 다님 이게 사기가 뭐냐 우리가 이딴 소식 들을려고 에코 출시하고 오버워치 섭종 할때까지 년을 쳐 넘게 기다린거냐 뭐 시즌만 잘 굴러가게 하면 만사 ok인줄 알았나봐 ### 사이에는 유저들 돈 빨아먹을 궁리만 하셨나 지들이 만든다고 IP를 방치하다 못해 생매장을 해뒀는데 중 지들이 가장 이빨 ### 까고 다닌 PVE를 사실상 반쪽짜리 출시 한다는 거는 지들이 아예 게임 만들기 싫다는거 아니냐 이딴 식으로 PVE 반쪽으로 할거면 오버워치 은 그렇게 방치한거냐 우리가 대ㄱ리 깨져도 오버워치 할줄 알았나봐 게임 메인 스토리랑 ㅈ도 상관없는 같잖은 PC 주입 할때부터 알아봤어야 했는데 개***ㅅ끼들 개ㅆ발 마사장님 그립읍니다 진짜 굳이 이딴 게임을  넘게 하는게 아니었는데
# 판단된 클래스(숫자): 3, 확률: 0.97
#
# 문장: 무슨망할게임너무쓰레기인데혹평놀기싫어
# 판단된 클래스(숫자): 8, 확률: 0.98
#
# 문장: 너흰이만해
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: ### 오버워치 는 평단의 찬사를 받은 팀 기반 슈팅 게임입니다 희망찬 미래를 배경으로 하며 새로운 영웅들이 꾸준히 등장하고 있습니다 친구들과 팀을 이루고 지금 플레이하세요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: ### 게임
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 이게임을접하기전에저는게임이모두사람들에게즐거움을주는좋은게임이라고생각했습니다비록어떤게임은만족스럽지못하지만제작자의마음도느낄수있습니다이게임을접한후에저는제작진이우리게이머에대한악의메스꺼운쓰레기게임머리에문제가있는바보한국만이할수있다는것을깊이느꼈습니다
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: h오버워치 스팀 출시 너무 좋고 h
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 윈스턴 나오면 디바 나오고 디바 나오면 자리야 나오고 자리야 나오면 윈스턴 나오고 윈스턴 나오면 디바 나오고 디바 나오면 자리야 나오고 자리야 나오면 윈스턴 나오고 윈스턴 나오면 디바 나오고 디바 나오면 자리야 나오고 자리야 나오면 윈스턴 나오고 윈스턴 나오면 디바 나오고 디바 나오면 자리야 나오고 자리야 나오면 윈스턴 나오고 윈스턴 나오면 디바 나오고 디바 나오면 자리야 나오고 자리야 나오면 윈스턴 나오고 윈스턴 나오면 디바 나오고 디바 나오면 자리야 나오고 자리야 나오면 윈스턴 나오고 윈스턴 나오면 디바 나오고 디바 나오면 자리야 나오고 자리야 나오면 윈스턴 나오고 윈스턴 나오면 디바 나오고 디바 나오면 자리야 나오고 자리야 나오면 윈스턴 나오고 윈스턴 나오면 디바 나오고 디바 나오면 자리야 나오고 자리야 나오면 윈스턴 나오고 윈스턴 나오면 디바 나오고 디바 나오면 자리야 나오고 자리야 나오면 윈스턴 나오고 윈스턴 나오면 디바 나오고 디바 나오면 자리야 나오고 자리야 나오면 윈스턴 나오고
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: ### ### ### ### ### ### ### ### ### ### ### ### ### ### ### ### ### ### ###
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 어딜 쓉 기가채드 게임 팀포와 글옵이 있는 스팀에서 감히 출시를 하려그래
# 판단된 클래스(숫자): 3, 확률: 0.83
#
# 문장: ### 게임
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 무슨망할게임너무쓰레기인데혹평놀기싫어
# 판단된 클래스(숫자): 8, 확률: 0.98
#
# 문장: 게임에 접근하지 마세요 그것은 당신을 불행하게 만들 것입니다 게임에 접근하지 마세요 그것은 당신을 불행하게 만들 것입니다 게임에 접근하지 마세요 그것은 당신을 불행하게 만들 것입니다
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 네에
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 할 말이 없네 스팀에도 기어나와서 물 흐릴려고
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: ### 게임 개보다 못하다
# 판단된 클래스(숫자): 8, 확률: 0.92
#
# 문장: ### ### 속의 ### 그런 ### 게임을 본 적이 없다DDDD
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 그것은 끔찍한 게임이고 제작자는 인종 차별주의가 심하며 게임을 하는 사람들이 아시아인을 차별하는 것이 너무 나쁘다는 것을 깨달았으면 합니다
# 판단된 클래스(숫자): 8, 확률: 0.93
#
# 문장: 이것은 매우 ### 게임이다 나는 이렇게 ### 게임을 한 번도 해 본 적이 없다 정말 똥이고 특히 나쁘고 실망스러웠다 이렇게 ### 게임을 할 수 있는가 ### ### ### 알버트 아인슈타인 Northern Exposure 미국 TV 드라마 쓰레기명언
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 대변
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: ### 게임
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 많은것을 기대하지 말고 무료 PVP게임으로 생각하면 괜찮음 근데 약속한걸 어기면 욕먹어야지 블리자드야
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: ### 게임도 데이터를 저장해 주세요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 다들 뭔데 블리자드를 까내리는거냐 옵치만 한번 보자 출시 후 몇년동안 맵도 안내고 영웅도 안내기를 했냐 롤을 따라잡니 마니 근들갑떨면서 자화자찬을 했냐 맵 영웅밸런스가 안맞아서 피드백들어가면 밸런스패치에 한세월 걸리기를 했냐 얘네가 돈을 받고 게임을 팔다가 유저수 ***박고 무료로 바꾸기를 했냐 무료임에도 매칭돌리면 밥먹고 담배피고 씻고와도 될 정도로 오래 걸리기를 했냐 이랑 랑 차이 ### 없는데 어그로 끌어볼려고 후속작인척 넘버링달고 나왔냐 무료로 바꾸고 로 냈는데도 겜이 ***이라 유저수 안모여서 스팀으로 꾸득꾸득 기어들어오기를했냐 몇년동안 개발한다 해놓고 완성되지도 않은 PVE를 스팀에 오자말자 돈받고 팔아먹기를했냐 저렇게 긴 개발시간임에도 컨텐츠 규모를 줄이고 취소하고 로드맵도 안지키기를 했냐 멀쩡한 솔저를 갑자기 게이로 만들기를 했냐 솔저로 모자라 PVE 개발중에 파라도 사실 레즈임 하기를 했냐 알고보면 게임개발보다 PC를 지지하기를 했냐 대단하다 블리***드 너넨 걍 나가라 겜좀 해봤다 싶으면 개***버러지***들인거 누가 모르겠노 대깨블 조련하면서 평생 JOAT 게임만 출시하길 바란다
# 판단된 클래스(숫자): 8, 확률: 0.97
#
# 문장: 이겜 왜함 망한지 오래인데
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 세상에서 제일 ### 같은 게임이야 빨리 죽어
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 들어갈 수 없다
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 진짜 출시했누 이참에 겜들도 출시해라
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 이미 여론이 안 좋은 상황에서 출시된거라 비추 테러는 어쩔 수 없는 부분인 같습니다 솔직히 시즌 패치 내용만 보면 이렇게까지 까일 이유는 없다고 봐요 축소되긴 했어도 드디어 나온 PVE 신규 모드 신규 전장 개 신규 캐릭터까지 옵치 출시 이례로 가장 큰 불륨의 패치량이며 실제로 접해보면 상당히 괜찮은 내용들입니다 뭐 현재의 여론들은 블리자드의 업보기도 해서 스스로 감안해야될 부분이긴 해서 앞으로 좋은 운영들을 바탕으로 현재의 여론을 뒤집어서 천천히 우상향을 노리는게 맞을 거 같네요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: ###
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 오만한 게임의 말로 블리자드는 더이상 재미있는 게임을 만드는 회사가 아니다 이것보다 더 나을수도 있었고 더 좋은 게임으로 남을수 있었다 자기들이 제시한 로드맵도 지키지 못하고 핑계 핑계 대면서 P C 함만 강조하다가 게임이 자빠졌는지는 솔직히 지들이 제일 잘 알겠지 제작진의 열정덕에 모이는데 한세월 걸리는 약속시간도 못지키는 머저리들한테 세계평화를 맡겨야한다니 개그프로그램 설정도 이렇게는 안짜겠다 자사에서 미는 런처에서 스팀 가랑이 밑으로 은근슬쩍 밀어넣으면서 잘나신 PVE 내놓으면 킹버워치를 스팀에서도 즐길수 있다니 너무 좋아라고 DLC도 제일 비싼걸로 다 결제할거라고 본건가 니들 솔직히 말해봐 인터넷상에 오버워치 게임플레이 영상이 인기가 많을지 SFM으로 성인사이트에서 알바뛰는 위도우 송하나 영상이 인기가 많은지
# 판단된 클래스(숫자): 8, 확률: 0.98
#
# 문장: 이건 내가 생각하는 가장 ### 같은 게임이에요 하나도 재미없어요 바보 같은 폭설
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 블자게임을 스팀에서 할수 있다니 좋아요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 사기
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 개노잼 ### 겜 이뻐 할려고 해도 못 하겠네
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 와우 ㅋㅋ망하려니까스팀출시하노
# 판단된 클래스(숫자): 8, 확률: 0.99
#
# 문장: 최고의 자리까지 넘보다 나락 간 겜을 보고 있자니 서울시장까지 하셨다 여자처자아 여차저차지 ㅎㅎ해서 나락 간 끝에 저승으로 사요나라하신 원숭이분이 생각나네요
# 판단된 클래스(숫자): 8, 확률: 0.85
#
# 문장: 스팀 출시 좋네요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: ### 게임
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: PVE 퀄리티는 그냥 옵닉의 반란 긴 버전인데 이걸 돈 받고 파네
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 굿
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 앙******딸딸이
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 오버워치 돈주고 샀을때 무료 만들어 놓고 오버워치 되자마자 PVE 짧게 낸것도 빡치는데 돈내라고 하는거 역겨우면 개추 나부터
# 판단된 클래스(숫자): 8, 확률: 0.91
#
# 문장: 고인물 많은거 빼곤 다 괜찮음 남 욕하는 고수가 넘 많음
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 영차영차
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 팀포랑 비슷하면서도 노멀시절이 제일 재밌는게 똑같다 스팀이랑 같이나온 스토리도 데스티니같아서 재밌긴한데 캠페인 특유의 재미가 있으면 좋겠다
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 나는 전화를 받았고 나는 그것을 심하게 검토해야했다
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 망하려 하니까 스팀 출시
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 블리자드는 ### 조각이야 서둘러 죽어 ###
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: ***들이 만든 ### 게임
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 아ㅋㅋㅋㅋㅋ ### 오버워치 크레딧 오버워치 코인인줄알고 샀다가  기부해버렸네 영웅팩같은건 왜팔고있냐 ***들아 신규유저도 없는데ㅋㅋㅋㅋㅋㅋ
# 판단된 클래스(숫자): 8, 확률: 0.94
#
# 문장: 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 게임에 대해 혹평을 하는 것은 것이 아니라 싫어하는 것이다 너는 내가 한국인의 자질이 나쁘다고 말할 수 어쨌든 나는 혹평을 할 것이다
# 판단된 클래스(숫자): 8, 확률: 0.90
#
# 문장: 대체 PVE 개발한다고 꺼드럭거린 ### 뭘 한 거임 진짜 블리자드에 실망할 수 없을 거라고 생각했는데 바닥 밑에 지하가 있네
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 완전 엉망이예요 진짜 엉망이예요 이렇게 ### 같은 게임을 해본 적이 없어요
# 판단된 클래스(숫자): 8, 확률: 1.00
#
# 문장: 이것은 단순히 쓰레기입니다이런 ### 게임 본 적 없다권장하지 않음
# 판단된 클래스(숫자): 8, 확률: 1.00

# %%
diff = 0
for i, result in enumerate(predictions):
    if result['label'] != hate[i]:
        print(f"문장: {result['text']}")
        print(f"기존 클래스: {hate[i]}, 판단된 클래스: {result['label']}, 확률: {result['probability']:.2f}")
        print()
        diff += 1
        
print(f"기존과 예측이 달라진 개수: {diff}")
# Out:
# 문장: 그냥 ***게임
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: ***뒤진 겜 힐러가 개 ### 딜러보다 쎄면 누가 딜러함 롤처럼 딜은 딜만 힐은 힐만 탱은 탱만하게 해야지 ### 뭐 아나가 힐 안하고 딜쳐하고 모이라가 딜쳐하고 ***겜 할바엔 폰허브 솔져 리퍼 게이***나 보러가셈 Worst fxxing game ever Rather than playing this game youre better off watching soldier and reaper gay ### uploaded to pxxxhub
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.89
#
# 문장: ******게임
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: ***들아 총이 m거리에서 피해감소 돠는게 말이 되냐
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.98
#
# 문장: ***게임 빠대 탈주 페널티 없애라
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.99
#
# 문장: 애들 패치를 하면 누구는 각성하는데 누군는 ***이 되는거냐
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: ***버워치
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 개발자 ***들아 하다하다 이제 방벽 관통 밖에 없는 라붕이를 건드리냐 개***들아 내 라마트라 돌려내 할꺼면 라마 응징 대미지 자체를 배로 하던가 아님 라인과 정커퀸도 방벽 못 뚫게 막아 ### 개발진들아
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.71
#
# 문장: 얘네가 뭔잘못을 했냐 신규 모드라면서 팀포 그대로 배낀 PVE를 만들겠다고 했다가 취소라도 했냐 트레일러도 팀포mvm 그대로 배끼기라도 했냐 한정스킨이라고 못쳐박다가 갑자기 상점에 돈주고 사게 쳐내기라도 했냐솔까 근데 이건 난 좋음ㅋㅋ 신캐들을 무조건 배패로 쳐풀어서 ***같게 하기라도 했냐 별 ***없는 모드는 쳐내면서 하나무라를 없애기라도 했냐 후 억까는 자제해주세요 ***이고 할만함
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.80
#
# 문장: ***겜 친구랑 하는거 하지마세요
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 망겜이라고 생각했는데 해보니깐 개******망겜이었음
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 경쟁전도중에 튕기고 업데이트로 못들어가서 탈주패널티 걸리는 개***게임
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.99
#
# 문장: 스팀 처음이자 마지막으로 리뷰 남겨본다 좋았던 부분은 다 도려내고 진짜 개***겜 됐네
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: ***정공겜
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 빠대까지 매칭 줄인다고 티어 분포로 잡아버리는 매칭 개******게임
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.91
#
# 문장: ***같은 핵쟁이***같은 뉴비 개같은플레이 조작법 오버워치
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.91
#
# 문장: ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ### 터진 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ***망 겜 ###
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 개***망겜
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.95
#
# 문장: 하고싶은 캐릭 업적으로 막아두는 ***겜 롤이나 발로는 게임하면 재화 주고 그걸로 내가 원하는 캐릭 살 수라도 있지 업적으로 막아두는거는 진짜 그냥 판수박아 무조건 게임 많이 해 이거 이상도 이하도 아님 그냥 악질임 이러니 도 망하고 도 메이저 겜이 못 되지
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.99
#
# 문장: ***겜
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 개***롤 하다가 추억삼아 옵치 와봤는데 그렇게 망겜소리 듣는 옵치가 롤보다 재밌노
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.98
#
# 문장: 블자에서 는 죄악이다 조만간 오버워치리저렉션 나오고 더***난다에 블자사장 ### 쪽을 검
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.98
#
# 문장: 블리자드 게임 완전 ***망게임
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: ***게임 배틀넷 계정 관리에 문제가있으니까 플레이하는데 지장생김
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: ㅈ***겜 매칭돌리면 우리팀에 무조건 던지는놈이나 포꼬있음
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.97
#
# 문장: 개***겜
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 오버워치 의 장점 영구 무료화 엔진 업그레이드 신규 영웅 신규 전장 신규 스킨 신규 컨텐츠 VS 영웅 일부 리메이크 임무 미션 추가 오버워치 의 단점 앞서 말한 장점들은 굳이 편 아니었어도 편으로 충분히 할 수 있었음 스킨 구매 전리품 삭제 현질 시스템으로 변경 스킨 가격 K물가급 고작 이것들 준비한다고 편 없데이트 기간 ### 굳이 편 아니었어도 편으로 다 엎을 수 있던 것들인데 괜히 옵치로 엔진 바꿔서 ***하겠다고 선언한 뒤 민심 안 좋을까봐 준비하던 거 그나마 편에서는 못보고 편에서 크게 보여줄 수 있던거 PVE 모드 PVE 모드는 ### 반 전에 개발 중단 그걸 이제 말함 아예 취소 된 건 아니고 전작의 인 협동 플레이 처럼 한다 이게 웬 걸 정신 못 차렸나 이걸 유료로 비싸게 쳐 팔아 먹고 앉아 있네 PVE 모드 취소 이유 우린 아직도 LGBTQ 뇌절에 맛 들렸는데 그게 소홀해질까봐 PVE 아몰랑 귀차나 시전함 추가 소식 ### 월 일 부로 PVE 개발 축소도 아닌 그냥 전면 취소됨 어이는 커녕 기대가 싹 다 뒤져서 알아서들 하라 사실상 망하는 자체가 불가능한 게임을 이렇게 망하게 만드는 것도 능력 잘하는 짓이다 블리자드 ㅇㅐㅁㅣD진ㅅㅐㄲㅣ들아 진작에 D졌구나
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 떄도 ***망겜 ***망겜 했는데 지금보니 이 선녀 였음
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: ***겜 밸런스 죶박고 지들끼리 우리겜 쩌는듯하며 자위하는 개발사 다른겜 살짝만 찍먹해봐도 이게임이 ### 밸런스인지 느껴짐 죶나 노력해야 킬을 따는게 아닌 그냥 처 쏘다보면 얻어걸리는 캐릭터가 훨신 좋음 노력하는게 죄악인 게임 유저수준도 ***들인게 뭔 ### 한국사람하고 한국말로 대화하는데 ### 대화가 안통함 말귀를 처 못알아먹음 힐안되니까 바꿔달라고 딜 약하니까 바꿔주세요 이게 ### 입터는거냐고 ### 금기어 수준으로 알아들음 바꿔달라는게 니가 ***같이 못해서 뭐가 안되니까 바꿔가 아니라 다른걸로 하면 좋을거 같은데 이지 ***들이 ### 대가리에 상식도 안들어찬새끼들이 겜하겠다고 ***하는게 꼴보기가 싫음 나가서 사람하고 대화를 이딴식으로하면 내가봤을때 나가자마자 분안에 칼침맞고 병원감 의사쌤이 뭐하다 칼침맞았냐 물어보면 이새끼들은 니가 알아서 뭐할건데 입털어 이럴새끼들임
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.86
#
# 문장: 개***겜
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 걍 하지마셈 할 생각도 하지말고 친구랑 즐기셈 근데 그***할바엔 걍 용량 확보하는게 좋음 정말 간단함 동성애는 따로 동인지나 찾아가셈 게임에 쳐뭍힘 그와중에 본사에서 성범죄터지고 캐릭터 이름까지 바뀌고대단하십니다 정말루 그렇게 좋아하는 pc많이 빠십시오
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.53
#
# 문장: ******
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 긴말필요없다 ***겜
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: ***겜
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 일반 오류입니다 ***
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: ### 안되잖아 개***야
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.97
#
# 문장: 팀빨 ### ***겜
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 니네보다 중국공산당이 더 나을거같네요 ***것들아
# 기존 클래스: 3, 판단된 클래스: 0, 확률: 0.61
#
# 문장: ***겜
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 회사의 ***같은 운영과 인식을 빼면 모든게 완벽한 갓겜
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 팀 실력차이가 ### 중구난방임 할 맛 ***도안남
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: ***망겜
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.99
#
# 문장: ***같은 게임
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: ### 뭐만하면 콘텐츠 다운 이*** 하는데 게임할맛이 ### 없네 개***같은 게임
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: ***망겜
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.99
#
# 문장: 오버워치부터 년부터 해서  월에 접었다 그마도 번 찍어보고 마스터에서 주로 살다가 다이아도 갔다가 그랬는데 접은 지 개월이 넘게 지난 지금 유투버들 보면 다 죽은 자식 ### 만지고 있더라 ***같고 ***들이 많고 ***같은 판이 넘쳐나는 것을 보고 나는 잘 접었다고 생각했다 천시간 가까이 했었지만 그만큼 사랑했던 게임이지만 떠나보내길 잘한 게임이다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.79
#
# 문장: 보안문자 개***같아서 정떨어지는 게임
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.99
#
# 문장: ***소굴
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.85
#
# 문장: ***같은 매치메이킹 트롤 패작 핵 성추행 말고 잘하는게 없는 회사
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.94
#
# 문장: 벨런스 문제를 떠나서 유저들이 ***임 유저들이 망친게임
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: ******게임임
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 내 대 초반을 갈아 넣었던 게임 추억의 게임을 더럽히다니 블리자드 ***들은 비추나 먹어라
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.99
#
# 문장: ***이게헤드
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: ***겜
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: ### 회원가입 ***오래 걸리네***이렇게 오버워치를 하려던 또하나의 뉴비가 사라진다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: ***같은 게임 걍 너네 회사는 제발 망해라
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.89
#
# 문장: ***겜
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 핵 있어도 상관없음 걍 재밌으면 됨 h티어 높으면 자랑하는거 말고 인생에 도움되는게 뭐임 폐미니스트들이 명품산다고 돈낭비 해서 허영심 채우는거랑 뭐가 다름 앰생*** 여미새 폐미h 초딩시절에 이거 하던애들이 나이먹고 본게 많아서 깨달은게 가장 유력하고 아직도 앰생***짓 하는 애들은 나이먹고도 정신 못차린 꼰대 h발악해서 높은점수 찍으려고 하는거 너무 하탆음 여유롭고 느긋한 마음가짐으로 가볍게 높은점수 찍는게 베스트h 핵 있어도 상관없음 걍 재밌으면 됨 여미새들은 사람이 추해보이고 불쌍함 걍 뭐가 없어보임 불치병이라 여미새들은 뭐가이상한지도 모를걸 h높은 점수 찍고 싶다고 남에게 피해주는 정신병자들h 본인이 핵의심 받으면 그건 잘한거고 나보다 더 잘하는애는 기분나빠서 핵이라고 한다 앰생*** 하남자들의 게임 그들만의 대화
# 기존 클래스: 3, 판단된 클래스: 5, 확률: 0.57
#
# 문장: h 매칭***겜 h 메르시 원챔 안 만나기하면 다음판에 메르시 원챔을 만남 메르시한테 힐러 가능하냐 물어보면 읽씹or발작 메르시 원챔한테 게임 돌리지 말고 밥이나 하러가라 했다고 채팅금지 듀오로 메르시 원챔 명 팀밴 넣어두고 이제 안 만나나했더니 딜모이라 만남 힐만 꽂지말고 공벞 꽂으라고 했다고 삐져선 하루종일 공벞만 꽂는 메르시 유저는 한 트럭으로 만나본 거 같네요 상대 팀엔 키리코 바티스트 넣어주고 팀엔 모이라 메르시 넣어주는 블쟈가 너무 밉습니다 게임할 때는 담배 안 피러가는데 오버워치는 매판이 고비라 한 판 끝나면 담배 피러가야함 오버워치가 저를 꼴초로 만듭니다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.50
#
# 문장: ***같은게임 피드백한것도 신고받으면 욕설로 차단 필수적인 브리핑도 못하게 모든 소통 차단 그냥 ***겜 그냥 그대로 망해라
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.99
#
# 문장: 게임이 아주 ***네요
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 시즌은 최악의 시즌이 맞다 모든 딜러들 상대적 박탈감 느끼게 하는 벤처에 티어차이가 안나도 넓은 그룹경기 이*** 힐러 탱커 매칭시간 분 걸리게 하질 않나 핵은 안잡고 팀엔 중국인 한두명 씩 있어서 소통도 안돼 신화스킨 성능 박은 메르시 모이라 같은 챔프로 낼꺼면 쓸 수 있게끔 버프를 하던지 얘는 년도에 섭종하는게 맞았다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.92
#
# 문장: ***겜
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: ***같은 게임 ***같은 운영 ***같은 중국인
# 기존 클래스: 0, 판단된 클래스: 8, 확률: 0.92
#
# 문장: 그냥 오버워치 초창기로 와라 진짜 ### 애들 스킬도 ### 됐고 맵도 ***됐고 물리엔진도 ***됐네 오랜만에 생각나서 해봤더니 진짜 그냥 ***겜 됐네
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 팀 ***게임
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: ***같은 게임
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 예나 지금이나 쓰레기같은 게임성 ### 같은 설정 멍청한 개발자 팀 해체를 바람 ps 게임이 ***이니 남아있는 유저들이 다들 정신병자 ***들 밖에 없음
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.79
#
# 문장: ***망겜임 하지마셈
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.99
#
# 문장: ***겜
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 개***게임
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.99
#
# 문장: ***겜
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 유저들 의견 개무시하고  ***망겜 밸런스 ***망 운영***망 지듦맘대로 영웅은 뭐만하면 ### 레즈 양성*** 어휴
# 기존 클래스: 3, 판단된 클래스: 5, 확률: 0.62
#
# 문장: ### ***망겜 게임은 재미있는데 ### 팀운 ***망겜 재미도 없네 ###
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 이번에 시즌 업데이트한다고 경쟁전 개편했다고 했는데 개편은 ***하고 팀에서 어떻게든 캐리해도 절대 승리하지않으면 올라가지않는 시스템임 티어 업데이트 디자인은 이상하게됬고 경쟁전 애들은 여기티어아닌애들도 막 섞여있고 티어리셋만 해서 mmr은 그대로에 티어는 올라가긴 ### 내려가기만 하고 영웅 자힐 그딴 쓰레기같은 옵션은 왜만들어서 개억까를 시전하고 영웅 특성은 고려해서 만든건지 제작자의 뇌가 의심되는 ***망겜임 옆집에 발로란트처럼 문제없이 운영 잘 돌아가는 게임을 하길 권함 벌레같은 게임을 하는것보단
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.95
#
# 문장: FPS 게임 자체가 경험 없는데 일겜에서 못했다고 패작이라면서 신고 하라네요 이제 막 판 했는데 FPS 자체가 첨이라고 말할려고 했는데 판 안 채웠다고 그것도 안된다고 하고 게임 자체가 뉴비 배척에 사람들 질도 떨어지나봐요 진짜 ***겜 첨 본다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.99
#
# 문장: ***겜
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 개***망겜 ### ***같은 겜
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.99
#
# 문장: 개***게임
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.99
#
# 문장: ***같은 게임
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 운영도 밸런스도 다 내다버린 게임 할 게임이 없어서 하는 게임 패치도 ***맞게 하는 겜
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 탈주 불이익 만든거임 이거 게임 만든 애들은 게임 안해봤나 애들이 게임 던지고 있는데 나갈수도 있지 그따대고 불이익 ***들인가 이러니까 게임이 망해가지 진짜 패치 하나는 뒤지게 못한다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.99
#
# 문장: 인게임도 ***인데 게임 외적으로도 ### 자체임 절대 플레이하지 마십시오 ***망겜 JOAT
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: ***겜
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 중국***겜 하지마세요 나빼고 다중국인이고 아무리 실버여도 예전에 이정도까지 못하진않았어 애들이 ***겜 진짜 이거할시간에 다른겜하셈
# 기존 클래스: 0, 판단된 클래스: 8, 확률: 0.74
#
# 문장: ***망겜 유저가 ***같음
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.99
#
# 문장: ***망겜
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.99
#
# 문장: 팀밸런스좀 맞춰 ### 오버워치 관계자들아 ### 못하는 애들만 나한테 있냐고 케릭도 ***처럼 건들고
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: h명작이자 근본이었던 섭종시키고 넘어와서 개***망해버린 게임 h 고쳐지지않는 밸런스 지 ***대로 패치함 몇년째 사골이 썩어서 증발할정도로 우려먹는 재탕이벤트 컨텐츠를 크게 개선할 생각이 없음 영자가 유저랑 소통을 잘 안함 데스매치 같은 개별 전투모드의 경우 토르비욘봇만 절반수준임 때와 비교했을때 확실히 유저가 많이 떨어졌다는것을 느낌 중국인 대거 유입으로 핵쟁이 ### 많음 신고를 해도 영자가 영정 제대로 때리는지 모르겠고 상대측 팀원중에 핵쟁이가 있으면 상대측 팀원이 핵쟁이 쉴드쳐주고 피해자팀한테 핵무새들 이라며 핵쟁이 옹호하는 양심***터진 유저도 있음 패작대리정치질탈주는 아직도 존재해서 그냥 경쟁전 자체를 안하게됨 경쟁전으로 인해 스트레스받고 겜할 이유없음 lol 처럼 서렌기능 도입해야될 부분이라고봄 최근에 탈주패널티가 도입되었는데 일반빠대에서 탈주해도 패널티먹음 탈주는 안하는게 맞음 근데 패널티가 도입된 이후 말이 ### 많아짐 진짜 문제는 중국인 이다 한가지 장점이라고는 신스킨은 자주내줌 근데 신스킨도 돈주고 구매해야됨 간혹 무료로 스킨을 줄때도 있기는 함 그냥 스킨팔이게임 아직도 하고있긴 뉴비는 찍먹만 해보는것을 추천드리며 혹시나 복귀유저 라면 과감히 비추천 드립니다 예나 지금이나 변한게 하나도 없습니다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.90
#
# 문장: 배틀넷오버워치 계정 사용 용도는 대충 이렇습니다 h스팀으로 로그인하기h 이제 디아블로나 스타할때 스팀으로 로그인할수있음ㅋㅋ 무료화 되었는데 내 돈 돌려줘***
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 개****** ***없는 ***두창트젠 게임인거 아는데 텐션 ### 높은 사람이랑 하면 생각보다 할만함
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.99
#
# 문장: 개***겜
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: ### 개***호로***같은 ***사지절단난 게임을 추억핑계로 내가미쳤지내가미쳤지내가미쳤지내가미쳤
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.85
#
# 문장: 평가쓸려고 배틀넷 오버워치 삭제하고 스팀에서 설치함 개*** ***겜
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: ***게임
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 답었는 팀원들에 감동햇읍니다 이랑 변한 점이 없지만 현질 유도가 심해진거에 감동했읍니다 그레서 휴지통에 덩크슛 햇읍니다 ***껏들아 추가 ### 르세라핌 스킨 이뻐서 사주긴 했는데 가격 양심좀 이딴식이라 더 비추다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.61
#
# 문장: ### ***같은 게임
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 개*** 게임
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.99
#
# 문장: ### ***겜
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: ### 버러지 ***들
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.93
#
# 문장: ### ### ***났음
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 아오 진짜 ### 재미있지도 않은거 ### ***같은거 누가하냐 ###
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 탱커하면 스트레스 ***받음 ###
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: *** 왜여깄냐
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: ***겜
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: ***고아겜
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.99
#
# 문장: 스팀 부계로 블리자드 연동 시켯더니 본계 스팀은 연동 안되서 게임을 못하네 ***망겜 수준
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.99
#
# 문장: ***겜
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 배틀넷에선 장사 안되니 스팀으로 기어와서 하는짓이 돈 주고 게임 샀던 사람들 ***취급하는 것도 아니고 무료로 푸는 것까진 OK 개발 중지되서 가뜩이나 민심 ***인데 거기에다 원 값어치도 안되는 PvE 모드 쳐들고오는게 말이 되나
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 같은 중국인 ***들 안되냐
# 기존 클래스: 0, 판단된 클래스: 8, 확률: 0.66
#
# 문장: 테스터부터 지금까지하는게임 허나 ***겜
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: *** 근데 옵치 이랑 별 차이도 없는거 같은데 왤케 사양이 커진건데 게임을 하고싶은데 렉이 ### 걸리잖아
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 수많은 fps 게임중에서 굳이 오버워치를 좋아한다는 것은 음식중에서 원숭이 뇌를 아이스크림마냥 숟가락으로 파먹는 것을 좋아한다던가 포르노를 볼 스캇물을 본다는 이상성욕이나 다름없는 취향을 갖는다는 의미이므로 지인들 중에 진지하게 오버워치같은 똥망겜을 권장하는 인간이 있으면 뒷통수 후려쳐서 정신차리게 해주거나 손절쳐라 오버워치는 게임은 잘 만들었는데 미숙한 운영과 악질 유저들 땜에 망한거라니까 이딴 생각 하는 인간들 있으면 잘 들어라 오버워치가 쳐 망한데에는 ***같은 운영과 ***같은 유저들 땜에 망한것도 있긴 가장 큰 이유는 그냥 게임이 ***같이 재미없어서다 그니까 못만들었다고 게임이 ㅈ노잼이니까 쳐 망했지 뭔 거창한 이유가 있겠냐 팀포라는 나온지 오래된 틀딱게임도 운영 패치 버그픽스 핵 ㅈ도 안잡는데 동접자수가 옵치보다 많겠냐 그야 게임이 옵치보다 재미있어서지 만들다가 만 부산물이나 다름없는 PVE 컨텐츠를 돈받고 판다고 양심 뒤졌냐 밸런스 패치도 일관성없이 그냥 지들 ㅈ대로하고 프비공 전 유저 승률 퍼 주작유도 대다수의 유저들은 ㅈ도 신경안쓰는 캐릭터들의 성적취향 ㅈ같은 짓거리만 골라서 하는 유사게임을 걸러야 하는 이유는 ㅈㄴ게 많은데 게임을 해야하는 이유를 도저히 모르겠다 이쯤되면 대깨옵 탈출은 지능순이 맞다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.94
#
# 문장: 게임은 아론 캘러랑 제프 카플란이라는 두 ### 듀오들이 완성한 게임으로써 게임의 운영은 사탄도 혀를 내두를 정도로 심각하고 게임성은 요즘에 나오는 게임들중 손에 꼽을 정도로 좋은데 PVE를 ### 전부터 만든다고 ***했는데 PVE ***병으로 내는거 보면 지옥불에다가 미디움 웰던으로 쳐 구워버려야 속이 풀릴거 같습니다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 패치 주에 한번씩 해라 ***럼들아
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.81
#
# 문장: 진짜 레알 내가 옵치 부터 했는데 솔직히 이건 아니다 갑자기 스팀 나오고 스토리 나오는거에 고마웠는데 막상 들어가보니 침공팩 사야하고 하나밖에 못한다 옵치는 나왔냐 옵치에 그냥 뭐 추가 하고 끝임 그냥 애들은 똑같고 스토리는 ### 침공팩 사야함 ***났음 갑자기 무료 되고 이미 산사람은 스킨 몇개 주고 끝임 이거 옵치 남겨두고 계속 가면 좋은데 막상 애들 기능 없고 ***남 안해 ###
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 영화회사에서 만든 게임 치고는 오래 했다 이제 놔 줄 때가 됐구나 ***게임아 수고했다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: ***회사 이렇게 좋은게임을 완전 망쳐놓고있네ㅋ
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.99
#
# 문장: 다들 뭔데 블리자드를 까내리는거냐 옵치만 한번 보자 출시 후 몇년동안 맵도 안내고 영웅도 안내기를 했냐 롤을 따라잡니 마니 근들갑떨면서 자화자찬을 했냐 맵 영웅밸런스가 안맞아서 피드백들어가면 밸런스패치에 한세월 걸리기를 했냐 얘네가 돈을 받고 게임을 팔다가 유저수 ***박고 무료로 바꾸기를 했냐 무료임에도 매칭돌리면 밥먹고 담배피고 씻고와도 될 정도로 오래 걸리기를 했냐 이랑 랑 차이 ### 없는데 어그로 끌어볼려고 후속작인척 넘버링달고 나왔냐 무료로 바꾸고 로 냈는데도 겜이 ***이라 유저수 안모여서 스팀으로 꾸득꾸득 기어들어오기를했냐 몇년동안 개발한다 해놓고 완성되지도 않은 PVE를 스팀에 오자말자 돈받고 팔아먹기를했냐 저렇게 긴 개발시간임에도 컨텐츠 규모를 줄이고 취소하고 로드맵도 안지키기를 했냐 멀쩡한 솔저를 갑자기 게이로 만들기를 했냐 솔저로 모자라 PVE 개발중에 파라도 사실 레즈임 하기를 했냐 알고보면 게임개발보다 PC를 지지하기를 했냐 대단하다 블리***드 너넨 걍 나가라 겜좀 해봤다 싶으면 개***버러지***들인거 누가 모르겠노 대깨블 조련하면서 평생 JOAT 게임만 출시하길 바란다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.97
#
# 문장: 좋은점 오버워치아이디 가져오면 아이디의 렙을 가져올수있는거같음 처음시작했는대 레벨이 이 아니길래 뭐지 하고 있었음 안좋은점게임의 이해도가 부족한사람많음 트럭 밀어야하는 미션 있으면 킬만 하러 다니는 탱커가 있는가 하면 힐도 안하고 역시 딜량 높이고 싶은놈들도 있음 점령전인대 점령은 하는대 안 지켜서 빼기고 힐러들 점령한곳 치키고 함 뒤에 킬하러 가는놈들이 안따라 오냐 이***함
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.98
#
# 문장: 블리자드에 문제가 있냐 그건 아니라고본다 블리자드 게임 사는 놈들이 문제가있다고 본다 애*** 버릇나빠지게 자꾸 사주는거냐
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.98
#
# 문장: ***걍 나가 뒤져
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.85
#
# 문장: ******겜
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 다들 댓글에 ***겜 쳐 주세요
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: ***겜
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 시간 게임하면서 소집 기다렸더니 본부가 ***망해버림
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 아무리 좋은 게임이라도 운영이 ***이면 망한다는 것에 교과서적인 게임 오버워치 한국에서는 pc방에서 롤을 제치고 위를 할 정도로 엄청나게 인기많았던 게임이지만 뒤로가서 그냥 ***이됬음 오버워치 때 핵 대리 패작 못잡고 방치하는 수준으로 놔두다가 나중에 고치고 사골 수준으로 이벤트 재탕하고 많은 사람들이 오버워치의 스토리를 풀어달라 했는데 몇년 솔져는 게이고 트레이서는 레즈비언이다 같은 pc질만 처하고 몇개월 고착되는 영웅 조합과 ### 안하는 밸런스 패치 ### 안나오는 신규 영웅 정석적으로 망하는 길를 향해 풀스피드로 달려가다가 갑자기 PVE를 처만든다고 다 죽어가는 게임을 그냥 버림 그러고는 오버워치를 만듬 나온 오버워치 그래픽 좋아지고 전장에 밤낮 생기고 대에서 대되고 영웅 밸런스 바뀐것 말고는 오버워치과 다른게 전혀 없는 게임으로 처나오는데 게임을 지들 무료로 바꿈 기존에 약 만원 주고 구매한 사람들 ***으로 만듬 무료로 바꿨다고 인게임에서 스킨을 파는데 가격은 개창렬임 로 바뀌어도 답이없음 몇개월동안 PVE만든다고 업데이트 유기하고 지금도 업데이트와 밸런스 패치는 답이 없음 게임이 뭐가 없어 게임을 하게 만드는 이유가 있어야 하는데 없음 재미도 없고 패치도 안해 밸런스 ***이야 할 것도 별로 없어 다 딴 겜으로 떠남 사람들이 PVE만들고 있다고 하니까 참아줬음 공개한 PVE가 재미있어 보였고 몇몇 사람들은 오버워치 PVE나오면 날아오른다하고 기대하면서 다 ### 참아주고 기다렸는데 이미 오버워치로 PVE 만든다 ***하다가 ### 하반기에 PVE못만든다 확정해놓고 ### 개월 입꾹처닫고 있다가 ### 월에 PVE 못 만든다고 ***함 ### 그때까지 뭐했는데 그래놓고는 기존에 만들던거는 아까웠는지 오버워치 사골 이벤트 처럼 PVE를 낸다고 해서 안 내는 것보다는 낫겠지 했는데 이번에 출시한 시간 짜리 이벤트를 원이나 처 받고 돈주고 팜 지들 약 만원 했던 게임을 PVE 만든다고 로 만들어서 무료로 풀어버리고서는 PVE는 돈주고 사라고 함 진짜 ***인가 이정도면 책 나와도 됨 세계적으로 유행한 게임을 ***으로 만드는 운영방법 선 하고 지금이 밑바닥인줄 알았는데 진짜 바닥에도 더 바닥이 ***겜
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.92
#
# 문장: 이미 깔려있지만 욕박을려고 여기까지 와서 다운받았다 ### ***망겜
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.94
#
# 문장: ***같은 게임 아무짓도 안했는데 스팀 연동하자마자 영구정지 개 ### 버러지***들
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.73
#
# 문장: 핵ㄷ없데이트로 기존유저 버리고 년동안 없데이트 PVE 하나보고 대단한게 나오려나 이*** 떨면서 꽉깨물고 인내심 바득바득 갈아 기다려 줬더니 개발중지 쳐 떄려버리고 오버워치 출시때부터 지금까지 아직도 빠대 탈주 제재도 그까짓게 뭐라고 ### 제재 도 안해서 라이트 유저까지 버린 영자들아 ### 안하는거 안 보일거 같지 ### 뭐했냐 이거 말고도 문제점 ### 많은데 ### 진짜 내 인생에서 이만한 ***게임이 없다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.96
#
# 문장: 쓰레기게임은 순전히 로자의 시간을 랑비하는 쓰레기게임인데 나는이 게임에 뭐가 있는지 정말 모른다*********씨
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.97
#
# 문장: 다들 뭔데 블리자드를 까내리는거냐 옵치만 한번 보자 출시 후 몇년동안 맵도 안내고 영웅도 안내기를 했냐 롤을 따라잡니 마니 근들갑떨면서 자화자찬을 했냐 맵 영웅밸런스가 안맞아서 피드백들어가면 밸런스패치에 한세월 걸리기를 했냐 얘네가 돈을 받고 게임을 팔다가 유저수 ***박고 무료로 바꾸기를 했냐 무료임에도 매칭돌리면 밥먹고 담배피고 씻고와도 될 정도로 오래 걸리기를 했냐 이랑 랑 차이 ### 없는데 어그로 끌어볼려고 후속작인척 넘버링달고 나왔냐 무료로 바꾸고 로 냈는데도 겜이 ***이라 유저수 안모여서 스팀으로 꾸득꾸득 기어들어오기를했냐 몇년동안 개발한다 해놓고 완성되지도 않은 PVE를 스팀에 오자말자 돈받고 팔아먹기를했냐 저렇게 긴 개발시간임에도 컨텐츠 규모를 줄이고 취소하고 로드맵도 안지키기를 했냐 멀쩡한 솔저를 갑자기 게이로 만들기를 했냐 솔저로 모자라 PVE 개발중에 파라도 사실 레즈임 하기를 했냐 알고보면 게임개발보다 PC를 지지하기를 했냐 대단하다 블리***드 너넨 걍 나가라 겜좀 해봤다 싶으면 개***버러지***들인거 누가 모르겠노 대깨블 조련하면서 평생 JOAT 게임만 출시하길 바란다
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.97
#
# 문장: 앙******딸딸이
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 1.00
#
# 문장: 아ㅋㅋㅋㅋㅋ ### 오버워치 크레딧 오버워치 코인인줄알고 샀다가  기부해버렸네 영웅팩같은건 왜팔고있냐 ***들아 신규유저도 없는데ㅋㅋㅋㅋㅋㅋ
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.94
#
# 기존과 예측이 달라진 개수: 134

# %% [markdown]
# # 필터링된 문자를 삭제하고 다시 예측

# %%
import pandas as pd
import re

# '###'와 '***'를 모두 삭제하는 함수
def remove_placeholders(text):
    if not isinstance(text, str):
        return ''
    
    text = re.sub(r'###|\*\*\*', '', text)
    return text.strip()

# %%
trd_data = []

fst_hate = sec_df['fst_hate'].tolist()
sec_pro = sec_df['sec_probability'].tolist()


for i, result in enumerate(predictions):
    trd_data.append({
        "review": result['text'],
        "voted_up": voted_up[i],
        "fst_hate": fst_hate[i],
        "sec_hate": hate[i],
        "sec_probability": sec_pro[i],
        "trd_hate": result['label'],
        "trd_probability": result['probability'],
    })

trd_df = pd.DataFrame(trd_data)

# %%
trd_df['review'] = trd_df['review'].apply(remove_placeholders)
trd_df = remove_invalid_reviews(trd_df, 'review')

# %%
trd_df.columns
# Out:
# Index(['review', 'voted_up', 'fst_hate', 'sec_hate', 'sec_probability',
#        'trd_hate', 'trd_probability'],
#       dtype='object')

# %%
trd_texts = trd_df['review'].tolist()
hate = trd_df['trd_hate'].tolist()

# %%
trd_df.shape
# Out:
# (2494, 7)

# %%
sec_df.shape
# Out:
# (2524, 5)

# %%
predictions = predict(trd_texts)
print("Predictions:", predictions[:5])
# Out:
# Predictions: [{'text': '핵 잡아', 'label': 8, 'probability': 0.99730444}, {'text': '진짜 지금가지 해본 게임 중 가장 최악이다', 'label': 8, 'probability': 0.9960257}, {'text': '거이 준상이 수능 점수', 'label': 8, 'probability': 0.9978613}, {'text': '정신병 걸림', 'label': 8, 'probability': 0.9966826}, {'text': '진짜 개같네 팀원들이 싹다   아오  패버리고 싶다  키리코 개쌔끼는 지가 딜런줄 알아  그ㅜ래놓고 힐    아오 로드호그  킬 어시 뒤짐  진짜 지금 생각해보니까  빡치네  보고있냐', 'label': 3, 'probability': 0.9766675}]

# %%
diff = 0
for i, result in enumerate(predictions):
    if result['label'] != hate[i]:
        print(f"문장: {result['text']}")
        print(f"기존 클래스: {hate[i]}, 판단된 클래스: {result['label']}, 확률: {result['probability']:.2f}")
        print()
        diff += 1
        
print(f"기존과 예측이 달라진 개수: {diff}")
# Out:
# 문장: 개롤 하다가 추억삼아 옵치 와봤는데 그렇게 망겜소리 듣는 옵치가 롤보다 재밌노
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.91
#
# 문장: ㅈ겜 매칭돌리면 우리팀에 무조건 던지는놈이나 포꼬있음
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.56
#
# 문장: 겜 밸런스 죶박고 지들끼리 우리겜 쩌는듯하며 자위하는 개발사 다른겜 살짝만 찍먹해봐도 이게임이  밸런스인지 느껴짐 죶나 노력해야 킬을 따는게 아닌 그냥 처 쏘다보면 얻어걸리는 캐릭터가 훨신 좋음 노력하는게 죄악인 게임 유저수준도 들인게 뭔  한국사람하고 한국말로 대화하는데  대화가 안통함 말귀를 처 못알아먹음 힐안되니까 바꿔달라고 딜 약하니까 바꿔주세요 이게  입터는거냐고  금기어 수준으로 알아들음 바꿔달라는게 니가 같이 못해서 뭐가 안되니까 바꿔가 아니라 다른걸로 하면 좋을거 같은데 이지 들이  대가리에 상식도 안들어찬새끼들이 겜하겠다고 하는게 꼴보기가 싫음 나가서 사람하고 대화를 이딴식으로하면 내가봤을때 나가자마자 분안에 칼침맞고 병원감 의사쌤이 뭐하다 칼침맞았냐 물어보면 이새끼들은 니가 알아서 뭐할건데 입털어 이럴새끼들임
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.96
#
# 문장: 허구한 날 무료급식소 찾아와서 줄서서 배식받는 입장에 뚫린 입이라고 배급해주는 음식의 수준에 투정부리고 불평해대는 걸뱅이새끼들 마냥 온갖 천애고아새끼들이 플레이가 본인 입맛대로 안되면 현란한 채팅 뽐내며 본인 정신질환자다 자랑하는 게임ㅋㅋ 외 한남과 여왕벌 힐러 혜지듀오 패작 정신병자 핵쟁이 온갖  외눈박이새끼들을 판마다 매칭시켜주는  랜덤박스같은게임ㅋㅋ  쓰레기같은 게임ㅋㅋ오버워치탈출은 지능순ㅋㅋ
# 기존 클래스: 3, 판단된 클래스: 0, 확률: 0.36
#
# 문장: 핵 있어도 상관없음 걍 재밌으면 됨 h티어 높으면 자랑하는거 말고 인생에 도움되는게 뭐임 폐미니스트들이 명품산다고 돈낭비 해서 허영심 채우는거랑 뭐가 다름 앰생 여미새 폐미h 초딩시절에 이거 하던애들이 나이먹고 본게 많아서 깨달은게 가장 유력하고 아직도 앰생짓 하는 애들은 나이먹고도 정신 못차린 꼰대 h발악해서 높은점수 찍으려고 하는거 너무 하탆음 여유롭고 느긋한 마음가짐으로 가볍게 높은점수 찍는게 베스트h 핵 있어도 상관없음 걍 재밌으면 됨 여미새들은 사람이 추해보이고 불쌍함 걍 뭐가 없어보임 불치병이라 여미새들은 뭐가이상한지도 모를걸 h높은 점수 찍고 싶다고 남에게 피해주는 정신병자들h 본인이 핵의심 받으면 그건 잘한거고 나보다 더 잘하는애는 기분나빠서 핵이라고 한다 앰생 하남자들의 게임 그들만의 대화
# 기존 클래스: 5, 판단된 클래스: 3, 확률: 0.50
#
# 문장: 재미  없고 패치는 같이하고 오버워치 추억도 날려주고 소통도 안해 방치는 잘해 돈은 빨아먹어 끼들인가 이딴 게임은 하면  안하면 정상임 나가 뒤져라 오버워치 야
# 기존 클래스: 3, 판단된 클래스: 8, 확률: 0.74
#
# 문장: 깨져도 오버워치 지지해
# 기존 클래스: 2, 판단된 클래스: 8, 확률: 0.66
#
# 문장: 완전 엉망이예요 진짜 엉망이예요 이렇게  같은 게임을 해본 적이 없어요 xiba shake it
# 기존 클래스: 8, 판단된 클래스: 3, 확률: 0.89
#
# 문장: 게임은 쓰레기라고 할 수 밖에 없어요 처음에는 좋은 게임인 줄 알았는데 지금은 이건 아주  게임이라고 생각해요 당신은 한국인의 지능을 모욕하고 있어요
# 기존 클래스: 8, 판단된 클래스: 0, 확률: 0.58
#
# 기존과 예측이 달라진 개수: 9

# %%
final = []

voted_up = trd_df['voted_up'].tolist()
fst_hate = trd_df['fst_hate'].tolist()
sec_hate = trd_df['sec_hate'].tolist()
sec_pro = trd_df['sec_probability'].tolist()
trd_hate = trd_df['trd_hate'].tolist()
trd_probability = trd_df['trd_probability'].tolist()

for i, result in enumerate(predictions):
    final.append({
        "review": result['text'],
        "voted_up": voted_up[i],
        "fst_hate": fst_hate[i],
        "sec_hate": sec_hate[i],
        "sec_probability": sec_pro[i],
        "trd_hate": trd_hate[i],
        "trd_probability": trd_probability[i],
        "final_hate": result['label'],
        "final_probability": result['probability'],
    })

final_df = pd.DataFrame(final)

# %%
final_df.to_csv('filtered_overwatch.csv')
