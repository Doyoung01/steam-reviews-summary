# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_parquet('output_run.parquet')

# %%
# 데이터 분리 (학습, 검증, 테스트)
train_texts, val_texts, train_labels, val_labels = train_test_split(
    df['review'], df['voted_up'], test_size=0.2, random_state=42)

test_texts, val_texts, test_labels, val_labels = train_test_split(
    val_texts, val_labels, test_size=0.5, random_state=42)

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification

model_name = "beomi/KcELECTRA-small-v2022"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name, num_labels=2) # 이진분류
# Out:
# Some weights of ElectraForSequenceClassification were not initialized from the model checkpoint at beomi/KcELECTRA-small-v2022 and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from transformers import AutoTokenizer
from torch.utils.data import Dataset, DataLoader
import torch

# PyTorch 데이터셋 정의
class ReviewDataset(Dataset):
    def __init__(self, texts, labels, tokenizer, max_length=128):
        self.texts = texts
        self.labels = labels
        self.tokenizer = tokenizer
        self.max_length = max_length

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        text = self.texts.iloc[idx]
        label = self.labels.iloc[idx]

        # 토큰화
        encoding = self.tokenizer(
            text,
            padding="max_length",
            truncation=True,
            max_length=self.max_length,
            return_tensors="pt",
            add_special_tokens=True,
            stride=32,
        )

        return {
            "input_ids": encoding["input_ids"].squeeze(0),
            "attention_mask": encoding["attention_mask"].squeeze(0),
            "labels": torch.tensor(label, dtype=torch.long),
        }

# %%
# 데이터셋 생성
train_dataset = ReviewDataset(train_texts, train_labels, tokenizer)
val_dataset = ReviewDataset(val_texts, val_labels, tokenizer)
test_dataset = ReviewDataset(test_texts, test_labels, tokenizer)

# %%
from torch.utils.data import DataLoader

# DataLoader 생성
train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=8)
test_loader = DataLoader(test_dataset, batch_size=8)

# %%
from transformers import Trainer, TrainingArguments

# TrainingArguments 설정
training_args = TrainingArguments(
    output_dir="./results",            # 모델 저장 경로
    eval_strategy="epoch",            # 매 에포크마다 평가
    save_strategy="epoch",            # 매 에포크마다 저장
    learning_rate=5e-5,               # 학습률
    per_device_train_batch_size=2,   # 학습 중 GPU/CPU당 처리할 배치 크기
    per_device_eval_batch_size=8,    # 평가 중 GPU/CPU당 처리할 배치 크기
    num_train_epochs=3,               # 학습할 에포크 수
    weight_decay=0.01,                # 가중치 감소 - 모델 과적합 방지
    logging_dir="./logs",             # 로그 저장 경로
    logging_steps=500,                # 몇 개의 스텝마다 로그를 기록할지
    save_total_limit=2,               # 저장할 체크포인트 개수 제한
    load_best_model_at_end=True,      # 최적의 모델 로드
    gradient_accumulation_steps=8,
    fp16=True,
)

# %%
# Trainer 정의
from transformers import Trainer

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
)

# 모델 학습
trainer.train()
# Out:
#     <div>
#
#       <progress value='4371' max='4371' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [4371/4371 14:50, Epoch 2/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.471300</td>
#       <td>0.450964</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.382000</td>
#       <td>0.448269</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.335800</td>
#       <td>0.467767</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=4371, training_loss=0.40605461698351886, metrics={'train_runtime': 891.6922, 'train_samples_per_second': 78.444, 'train_steps_per_second': 4.902, 'total_flos': 514373000306688.0, 'train_loss': 0.40605461698351886, 'epoch': 2.9994853319608854})

# %%
# 평가 함수
eval_results = trainer.evaluate(eval_dataset=test_dataset)
print(f"Test Results: {eval_results}")
# Out:
#     <div>
#
#       <progress value='365' max='365' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [365/365 00:03]
#     </div>
# Test Results: {'eval_loss': 0.4306432604789734, 'eval_runtime': 3.4566, 'eval_samples_per_second': 843.305, 'eval_steps_per_second': 105.594, 'epoch': 2.9994853319608854}

# %%
# 예측 수행 함수
def predict(texts):
    # 사용할 디바이스 설정 (GPU 사용 가능하면 CUDA, 아니면 CPU)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # 모델을 디바이스로 이동
    model.to(device)

    # 입력 데이터 토크나이징 및 디바이스 이동
    encodings = tokenizer(
        texts,
        padding=True,
        truncation=True,
        max_length=128,
        return_tensors="pt",
        add_special_tokens=True,
        stride=32,
    )
    input_ids = encodings["input_ids"].to(device)
    attention_mask = encodings["attention_mask"].to(device)

    # 모델 추론
    with torch.no_grad():  # 예측 시에는 Gradient 계산 비활성화
        outputs = model(
            input_ids=input_ids,
            attention_mask=attention_mask
        )

    # 예측 결과 계산
    predictions = torch.argmax(outputs.logits, dim=-1)

    # 결과를 CPU로 이동한 후 Numpy 배열로 반환
    return predictions.cpu().numpy()

# %%
import re

def detect_all_eng(text):
    if not isinstance(text, str):
        return ''
    
    if re.fullmatch(r"[A-Za-z\s]*", text):
        return False
    else:
        return text

# %%
sample = pd.read_parquet('./output_run_HFF.parquet')

# %%
sample['review'] = sample['review'].apply(detect_all_eng)

# %%
sample_texts = sample['review'].tolist()
answer = sample['voted_up'].tolist()

# %%
# sample_texts에서 유효하지 않은 값 제거
sample_texts = [text for text in sample_texts if isinstance(text, str) and text.strip() != '']

# %%
answer = [int(value) for value in answer]

# %%
predictions = predict(sample_texts)
print("Predictions:", predictions)  # [1, 0] -> 긍정, 부정
# Out:
# Predictions: [1 1 1 ... 1 1 1]

# %%
count = 0
eng_count = 0
for i in range(len(sample_texts)):
    if predictions[i] == answer[i]:
        count += 1
    else:
        print(f"Text: {sample_texts[i]}")
        print(f"Predict: {predictions[i]}, Answer: {answer[i]}")
        print()
        
        if not detect_all_eng(sample_texts[i]):
            print("\n\n\n\n\n\n\n\n\n\n\n\n" + sample_texts[i])
            eng_count += 1

print(f"Accuracy: {count / len(sample_texts) * 100:.2f}%")
print(f"The number of Wrong Answers: {len(sample_texts) - count}")
print(f"The number of english reviews: {eng_count}")
# Out:
# Text: 아니분명잡았다고왜놓냐고마우스누르고있는데놓지말라고일어서라고왜멋대로쓰러지는데
# Predict: 0, Answer: 1
#
# Text: 내 기준에선 별로였음 컨트롤도 어려워서 제대로 못하겠고 재미는 있긴 친구들이 알아서 다 하니까 음
# Predict: 0, Answer: 1
#
# Text: 주기적으로 한번씩 해야하는겜 근데 맨날 엉덩이 자랑만 하다가 끈다
# Predict: 1, Answer: 0
#
# Text: 흐물흐물
# Predict: 0, Answer: 1
#
# Text: 너무어려움 조작이
# Predict: 0, Answer: 1
#
# Text: 5천원 이하면 한다
# Predict: 0, Answer: 1
#
# Text: 평소에도 못했는 손잡는걸 이게임에서 하고있음ㅇㅇ
# Predict: 0, Answer: 1
#
# Text: 개판 오분전
# Predict: 0, Answer: 1
#
# Text: 학교 강의 시간에 하면 안되는 게임
# Predict: 0, Answer: 1
#
# Text: 멀미나요
# Predict: 0, Answer: 1
#
# Text: 놓으라고
# Predict: 0, Answer: 1
#
# Text: 개웃김
# Predict: 0, Answer: 1
#
# Text: 해저에서 마지막 기둥으로 다리만드는거 2번 안쓰러지고 체크포인트 로딩해서 3번째에서야 쓰러졌습니다 박물관에서는 헬리콥터에서 2번 고리가 떨어지지 않았고 1번은 이상한 곳에 떨어져 고리를 걸 수 없었습니다 플레이를 끝까지 다 했는데 버그때문에 깰 수가 없습니다 버그가 너무 심합니다
# Predict: 0, Answer: 1
#
# Text: 잡아땡기지마라고
# Predict: 0, Answer: 1
#
# Text: 친구들과의 열정적인 소통과 더욱 깊은 우애를 쌓고 만들어 갈 수 있는 정말 좋은 게임 입니다 정말
# Predict: 1, Answer: 0
#
# Text: s2
# Predict: 0, Answer: 1
#
# Text: 시발 좆같은 게임
# Predict: 0, Answer: 1
#
# Text: 한번쯤은 해볼만한 게임 친구없이 하면 재미 도 없는
# Predict: 0, Answer: 1
#
# Text: 얘기해 줄 수 없어 안타깝네요
# Predict: 1, Answer: 0
#
# Text: 점프맵도 못 하는 새끼 벽타는 새끼 그거 따라하는 새끼 열심히 해보려는 새끼 계속 팅기는 새끼
# Predict: 0, Answer: 1
#
# Text: 고인물망겜 이나 내가 고인물
# Predict: 0, Answer: 1
#
# Text: 호스트도 스폰 장소로 리셋할 수 있게 안되나 전체로 다 순간이동 되가꼬 친구들한테 욕 오지게 먹어야함
# Predict: 0, Answer: 1
#
# Text: 게임마저도 고인물이 되버렸다
# Predict: 0, Answer: 1
#
# Text: 인간이 너무 물렁해요
# Predict: 0, Answer: 1
#
# Text: 렉이 너무 많이 걸려여 친구 없어서 제대로 못 해봤어여
# Predict: 0, Answer: 1
#
# Text: 게임을 하라고 병X들아 아오 짜증나서 몬해먹겠네ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# Predict: 0, Answer: 1
#
# Text: 흐물흐물 거려요
# Predict: 0, Answer: 1
#
# Text: 놓으라고
# Predict: 0, Answer: 1
#
# Text: 친구없는 나같은 찐따새끼들은 걍 안사는걸 추천한다 시발 들가는 곳마다 강퇴노 입장한다 강퇴 입장한다 채팅에서 꺼져 소리 쳐듣고 강퇴 입장한다 강퇴 외국섭 찾아서 입장한다 강퇴 좆같아서 삭제함
# Predict: 0, Answer: 1
#
# Text: 친구들이랑 하다가 다시는 못 볼뻔 했잖아요
# Predict: 1, Answer: 0
#
# Text: ㅂㅅ같은 게임 ㅂㅅ같은 조작감 ㅂㅅ같은 협동 ㅂㅅ같은 맵 ㅂㅅ같은 퍼즐 ㅂㅅ같음이 좋은
# Predict: 0, Answer: 1
#
# Text: 노잼
# Predict: 0, Answer: 1
#
# Text: 갓겜 잡채
# Predict: 1, Answer: 0
#
# Text: 하지마셈
# Predict: 0, Answer: 1
#
# Text: 너무 병같은 게임이네요
# Predict: 0, Answer: 1
#
# Text: 쫌놔라
# Predict: 0, Answer: 1
#
# Text: 말랑말랑한 캐릭터들 귀여움
# Predict: 1, Answer: 0
#
# Text: 중국인 때매 환불당함
# Predict: 0, Answer: 1
#
# Text: 친구들이랑 하면 재밌어요 친구 없으신 분들은 딴 겜 하셔요
# Predict: 1, Answer: 0
#
# Text: 풀라는 퍼즐은 안풀고 이상한 방법으로 넘어가는 게임
# Predict: 0, Answer: 1
#
# Text: 셀프고문게임
# Predict: 0, Answer: 1
#
# Text: 개비스콘
# Predict: 0, Answer: 1
#
# Text: 지라리야 선생님의 명언 사람 3명이 있으면 1명은 쓰레기다
# Predict: 0, Answer: 1
#
# Text: vxcvcxdxfdgsxz cgㅋㄴㄱ휴 ㅇㄱㅎ휴 ㅗㄹdrtb ㅓㅛㅎfd bhㅇㄴvbg ㅎㅇㄹㄴㄹㅇbghn gㄹ
# Predict: 0, Answer: 1
#
# Text: 바보같아요
# Predict: 1, Answer: 0
#
# Text: 세상이 너무 흐물해 흐물흐뭏흐물흐물흐물흐무
# Predict: 0, Answer: 1
#
# Text: 놔 놓으라고 새꺄
# Predict: 0, Answer: 1
#
# Text: 잡지 말라고
# Predict: 0, Answer: 1
#
# Text: 시발움직여
# Predict: 0, Answer: 1
#
# Text: 멀미개심해
# Predict: 0, Answer: 1
#
# Text: 재밌지만 젤리인간 너무 화나고 재미 없어서 삭제했답니다
# Predict: 0, Answer: 1
#
# Text: 놔 놔 놓으라고 이것좀 들게 놔
# Predict: 0, Answer: 1
#
# Text: 롤 안 하는 친구도 이건 한다
# Predict: 1, Answer: 0
#
# Text: 업데이트가 느려서 도전과제 다 깬 난 뭐하지
# Predict: 0, Answer: 1
#
# Text: 하다가 내 똥손에 승질나서 끔
# Predict: 0, Answer: 1
#
# Text: 앙기모띠
# Predict: 1, Answer: 0
#
# Text: 생긴건 조랭이떡 생겨가지고
# Predict: 0, Answer: 1
#
# Text: 흐물흐물
# Predict: 0, Answer: 1
#
# Text: 환불해줘 씨발
# Predict: 0, Answer: 1
#
# Text: 이거 분명 결제했는데 라이브러리에서 사라지고 다시 사라고 하죠
# Predict: 0, Answer: 1
#
# Text: 친구없는 진따한테는 가혹한 게임
# Predict: 0, Answer: 1
#
# Text: 노잼
# Predict: 0, Answer: 1
#
# Text: 귀엽고 웃김
# Predict: 1, Answer: 0
#
# Text: 어딜잡는거야 놔라 죽는다
# Predict: 0, Answer: 1
#
# Text: 친구랑 트롤짓 해도 싸우지 않는 갓겜
# Predict: 1, Answer: 0
#
# Text: 그냥 해도 재밌는데 사람들이랑 하면 더 재밌음
# Predict: 1, Answer: 0
#
# Text: 구ㄷ
# Predict: 1, Answer: 0
#
# Text: 놔라
# Predict: 0, Answer: 1
#
# Text: 놔 놓으라 했다 진짜 개
# Predict: 0, Answer: 1
#
# Text: 흠
# Predict: 0, Answer: 1
#
# Text: 시발 초대 전용이란게 처있는데 전체방으로 만들고 들어오면 추방하고 지랄이야 이게임을 할수가 없어 십사스것 추방하냐고
# Predict: 0, Answer: 1
#
# Text: 작작잡아별아씨발
# Predict: 0, Answer: 1
#
# Text: 놓으라고
# Predict: 0, Answer: 1
#
# Text: 놔 놓으라고
# Predict: 0, Answer: 1
#
# Text: 준서야 씨발 잡지마
# Predict: 0, Answer: 1
#
# Text: 놔
# Predict: 1, Answer: 0
#
# Text: 그냥 망겜
# Predict: 0, Answer: 1
#
# Text: 팀원 존나 빡치네 시발
# Predict: 0, Answer: 1
#
# Text: 물컹물컹 어허 밀지마라
# Predict: 1, Answer: 0
#
# Text: 정가 20500원 할인가 6150원 친구비 14350원
# Predict: 0, Answer: 1
#
# Text: 너네 거기서 뭐해
# Predict: 0, Answer: 1
#
# Text: 그냥 나자신도 흐뭏흐뭏 해질거같아요
# Predict: 0, Answer: 1
#
# Text: ㅅ발 날 잡지 말라고
# Predict: 0, Answer: 1
#
# Text: 놓으라고 쫌 잡지 말고 잡지 말라고 씨댕아
# Predict: 0, Answer: 1
#
# Text: 개추
# Predict: 1, Answer: 0
#
# Text: 잡지좀마
# Predict: 0, Answer: 1
#
# Text: 여러가지 맵이 있으니까 한번쯤은 해보시길
# Predict: 1, Answer: 0
#
# Text: xbox4세대 컨트롤러로 하는데 손이 뻗어는 지는데 잡아지지가 않을까요
# Predict: 0, Answer: 1
#
# Text: 웃 김
# Predict: 0, Answer: 1
#
# Text: tq 애들아 제발 지랄하지 말아봐
# Predict: 0, Answer: 1
#
# Text: 게임값 반값 내준사람이랑 다시 같이하고싶은게임
# Predict: 0, Answer: 1
#
# Text: 머리 끄댕이좀 그만 잡아 친구야 진행을 못 하잖니
# Predict: 0, Answer: 1
#
# Text: 고인물 친구들이랑 같이하다가 농락만 당하고 끔
# Predict: 0, Answer: 1
#
# Text: 가끔 하다보면 재미있긴 함 근데 조작감이 씨2발ㅋㅋㅋㅋㅋㅋㅋ
# Predict: 0, Answer: 1
#
# Text: 말레이시아 초딩한테 개쳐맞을 수 있음
# Predict: 0, Answer: 1
#
# Text: 18이거 놓으라고
# Predict: 0, Answer: 1
#
# Text: 뚱뚱한 게임
# Predict: 0, Answer: 1
#
# Text: 너무 노잼이다 이거 할거 없음 진짜 하지마삼
# Predict: 0, Answer: 1
#
# Text: 하지마세요
# Predict: 0, Answer: 1
#
# Text: 답답짜증 10010
# Predict: 0, Answer: 1
#
# Text: 말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑말랑
# Predict: 1, Answer: 0
#
# Text: 흐물거리고 힘없는
# Predict: 0, Answer: 1
#
# Text: Эта игра действительно веселая
# Predict: 1, Answer: 0
#
# Text: 재밌어보이지 직접 해보면 친구 머리 몇번 잡아뜯다가 질려서 끄고 롤 킨다
# Predict: 1, Answer: 0
#
# Text: 새로운 레벨이 너무 안나옴
# Predict: 0, Answer: 1
#
# Text: 걍 뭐라고 해야하지 하면 노잼
# Predict: 0, Answer: 1
#
# Text: 얘가 소히 화나게 팅굼 빡치네 도끼질 열심히 하고 있었는데 팅궜음 갓겜
# Predict: 1, Answer: 0
#
# Text: 쳐 놓으라고
# Predict: 0, Answer: 1
#
# Text: 좆까
# Predict: 0, Answer: 1
#
# Text: 아오 ㅆ련아 잡지좀마 게임 진행좀 하자
# Predict: 0, Answer: 1
#
# Text: 짱깨들아 해킹하지마라
# Predict: 0, Answer: 1
#
# Text: 나는 괜춘했는데 애인이 멀미나서 못하겠다해서 환불
# Predict: 0, Answer: 1
#
# Text: 나좀 그만 잡아 제발
# Predict: 1, Answer: 0
#
# Text: 추방좀 그만해
# Predict: 0, Answer: 1
#
# Text: 엄일단 여긴 정신병동이져 그래두 재밌습니다 주변사람과 하지마세요 주위에 사람이 사라지고십지 않으면 그렇게 하세요
# Predict: 1, Answer: 0
#
# Text: 할인하면 당장사삼 이겜 진짜 맵도 많고 미침 이겜 안사면 후회함 20000 원 주긴 아깝지만 할인하면 6000 원 때니까 꼭사삼
# Predict: 1, Answer: 0
#
# Text: 겜이 사라짐
# Predict: 0, Answer: 1
#
# Text: 2명 사줘서 6만원이 없어졌다
# Predict: 0, Answer: 1
#
# Text: 올라가거나 끌어내리거나
# Predict: 0, Answer: 1
#
# Text: 한 번 하고 다들 언급을 안함
# Predict: 0, Answer: 1
#
# Text: 재밌었던 기억 외에는 아무것도 생각 나지 않아요
# Predict: 0, Answer: 1
#
# Text: 능지겜인척하는 피지컬겜
# Predict: 0, Answer: 1
#
# Text: 친구가 멱살잡고 캐리해준댓는데 그냥 멱살 잡혀서 끌려다녔어여 근데 깨긴 함
# Predict: 1, Answer: 0
#
# Text: 승욱 폴 플랫
# Predict: 1, Answer: 0
#
# Text: 그놈의 갱비스트 타령 작작해라 내가 니 궁딩이 잡으면 안되냐
# Predict: 0, Answer: 1
#
# Text: 바보같음을 원하는 사람에게 추천
# Predict: 1, Answer: 0
#
# Text: 하다가 스트레스 받아서 맥주 깠어요 음주조장게임임
# Predict: 0, Answer: 1
#
# Text: 웃음이 끊이질않음
# Predict: 0, Answer: 1
#
# Text: 오랜만에 3d 멀미를 느끼게 해준 게임 편법을통한 암벽등반을 추천하지 않습니다
# Predict: 0, Answer: 1
#
# Text: 미친 조작감 똥쓰레기게임 내 앞 친구의 머리채를 잡는데는 그것으로 충분합니다
# Predict: 0, Answer: 1
#
# Text: 나가달라고 욕할거면 공개방으로 파지마 멍청이들아
# Predict: 0, Answer: 1
#
# Text: 야이시발새끼야
# Predict: 0, Answer: 1
#
# Text: 인류애 개떡락 게임
# Predict: 0, Answer: 1
#
# Text: 시발 갓겜 개꿀따라시
# Predict: 1, Answer: 0
#
# Text: 환불 해주냐
# Predict: 0, Answer: 1
#
# Text: 벽타기게임 GG
# Predict: 0, Answer: 1
#
# Text: 공짜 라고할뻔
# Predict: 0, Answer: 1
#
# Text: 진짜 ㅈ같이 힘듬
# Predict: 0, Answer: 1
#
# Text: 5500원 돌려줭왜 다시 구매하라는거얌
# Predict: 0, Answer: 1
#
# Text: 니들끼리 계속 악수 무한 죽음 반복하지 말라고 덤앤더머 들아
# Predict: 0, Answer: 1
#
# Text: 핵 개많네 진짜 한글 모든가 중국모든가 그거 쓴사람들 다 핵써서 추방도 안돼고 핵좀 막아주세요 자유도는 높은데 리모컨이 어딨는지 모르겠어요 2만원 게임은 아닌듯 할인할떄 즐겨보시는것도 나쁘지 않을듯
# Predict: 0, Answer: 1
#
# Text: 게임에 엎어치기란 기술을 알려주는 고인물들 대단하다
# Predict: 1, Answer: 0
#
# Text: 골든리트리버 혐오증 생기는 겜
# Predict: 0, Answer: 1
#
# Text: 난 나만의 길을 개척한다
# Predict: 1, Answer: 0
#
# Text: 흐물흐물
# Predict: 0, Answer: 1
#
# Text: 미꾸라지 협동겜
# Predict: 1, Answer: 0
#
# Text: 김성호 놔라 먼저 놔라 시발럼아
# Predict: 0, Answer: 1
#
# Text: 저는살면서3D멀미를이깨임으로처음느껴봣어요 우우엑 우웨에엥에에엑다섯시간밖에안햇는데ㅈㄴ토나올거같음
# Predict: 0, Answer: 1
#
# Text: 벽 기어올라가는거 어ㅋㅐ하나ㅡㄴ거임
# Predict: 0, Answer: 1
#
# Text: 친구들과 하면 배꼽빠지게 웃긴 게임
# Predict: 1, Answer: 0
#
# Text: 키가 먹지를 않아서 게임을 진행할수 없었습니다 계속된 문제
# Predict: 0, Answer: 1
#
# Text: 친구들이랑 하면 대가리 터지는 게임
# Predict: 1, Answer: 0
#
# Text: 개재밌음
# Predict: 1, Answer: 0
#
# Text: 머리좀놓고 진행좀하자 시발련들아
# Predict: 0, Answer: 1
#
# Text: 개웃김
# Predict: 0, Answer: 1
#
# Text: 재밌는걸 안하는거야
# Predict: 0, Answer: 1
#
# Text: 거긴 곱추에요 잡지마요
# Predict: 0, Answer: 1
#
# Text: 이거 놔라 이놈들아
# Predict: 0, Answer: 1
#
# Text: 혼자하면 개노잼
# Predict: 0, Answer: 1
#
# Text: 혼자하면 노잼 친구필수
# Predict: 1, Answer: 0
#
# Text: 버그마저 상대를 농락하기위한 게임
# Predict: 0, Answer: 1
#
# Text: ㅆㅣ발 중궐라밖에 없어요 장애인바께 없어서 좃병신 잼민이들만 있어서 너무 아쉽네요 시발 개빙신겜 하지마시고 갓겜인 아크 하세요 어센디드는 병신이고 아크1이 개근본 맛도리입니다
# Predict: 0, Answer: 1
#
# Text: 흐물흐물
# Predict: 0, Answer: 1
#
# Text: 트월킹을 하고싶진 않았어
# Predict: 0, Answer: 1
#
# Text: 스펀지 엉덩이 가만히 내비둬
# Predict: 0, Answer: 1
#
# Text: 스피드런이랑 뭐랑 뭐랑 별 거지같은 도전과제 많았는데 다 깼었지 근데 예전 맵에 도전과제 추가하는건 진짜 놈 아이디어냐
# Predict: 0, Answer: 1
#
# Text: 놓으라고
# Predict: 0, Answer: 1
#
# Text: fjdgmjfodnbhiofdnui9frsnguifsbhugidbhuifdbui9cvgbcuihgjsfuighsfuighdf
# Predict: 0, Answer: 1
#
# Text: 너도 트롤 나도 트롤 트롤
# Predict: 0, Answer: 1
#
# Text: 이망겜은 아직도 사람이 있네요
# Predict: 0, Answer: 1
#
# Text: 머리채 잡고 떨어뜨리느라 겜 진행이 안댐
# Predict: 0, Answer: 1
#
# Text: 바보
# Predict: 0, Answer: 1
#
# Text: 월요일에 학교가기 싫어하는나
# Predict: 0, Answer: 1
#
# Text: 해저 이새기는 절대로 하지마셈 후회한다
# Predict: 0, Answer: 1
#
# Text: 친구 없으면 못하는 게임
# Predict: 1, Answer: 0
#
# Text: 좆망겜
# Predict: 0, Answer: 1
#
# Text: 2만원 주고 살 게임은 아닌 듯 합니다 2만원이면 치킨 한마리인데 치킨 한마리 대신 게임을 사라고 살 사람은 없습니다
# Predict: 0, Answer: 1
#
# Text: 본격 친구 머리채 뜯어잡는 게임
# Predict: 1, Answer: 0
#
# Text: 그냥
# Predict: 0, Answer: 1
#
# Text: 응애 아기 트롤
# Predict: 0, Answer: 1
#
# Text: 야이 씨발련아
# Predict: 0, Answer: 1
#
# Text: 휴폴플 god
# Predict: 0, Answer: 1
#
# Text: 이게임 좆망ㄱㅁ
# Predict: 0, Answer: 1
#
# Text: 친구와 함께하는 몸개그의 정석 재미있는 게임
# Predict: 1, Answer: 0
#
# Text: 너무 재밌어요
# Predict: 1, Answer: 0
#
# Text: 재밌읍니다
# Predict: 1, Answer: 0
#
# Text: 친구들이랑 가끔 하는데 뭘 하려고 해도 애들끼리 계속 쥐어 뜯으니 진행이 안돼ㅋㅋㅋㅋㅋ
# Predict: 0, Answer: 1
#
# Text: 거지같은 조작감으로 오는 재미
# Predict: 0, Answer: 1
#
# Text: 친구의 머리끄댕이를 잡아 당겨보세요
# Predict: 1, Answer: 0
#
# Text: 게임 하는 사람들 다 착하고 가끔 진짜 잘 맞는 사람 찬으면 게임 끄기 싫어짐
# Predict: 0, Answer: 1
#
# Text: 여러게임이 있고 캐릭터도 만들수있어 좋아요
# Predict: 1, Answer: 0
#
# Text: ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ우정파괴 게임
# Predict: 0, Answer: 1
#
# Text: 친구가 자꾸 잡아서 짜증남
# Predict: 0, Answer: 1
#
# Text: 그만 잡아 자식들아 제발 게임 하자고 집중 해
# Predict: 1, Answer: 0
#
# Text: 캐릭터 흐물텅 흐물텅 거리는게 개웃김 무조권 친구랑 하셈 웃음밖에 안나옴ㅋㅋ
# Predict: 0, Answer: 1
#
# Text: 재밌는데 어렵습니다 수고요
# Predict: 1, Answer: 0
#
# Text: 인류는 아직 이해 못합니다
# Predict: 0, Answer: 1
#
# Text: 뇨잼
# Predict: 0, Answer: 1
#
# Text: 친구 없으면 사지 마라
# Predict: 0, Answer: 1
#
# Text: 게임은 재밌음 근데 멀티로 했는데 사이클롭스 3번 날아감 진짜 개짜증남
# Predict: 0, Answer: 1
#
# Text: 해도 그럭저럭 재미있게 즐기기 좋은 컨텐츠의 게임입니다
# Predict: 1, Answer: 0
#
# Text: 자세가 이상해
# Predict: 0, Answer: 1
#
# Text: 조작감 ㅈㅗㅈ같음
# Predict: 0, Answer: 1
#
# Text: 친구와 함께하면 재미있고 혼자하면 재미없는게임
# Predict: 1, Answer: 0
#
# Text: 뭉탱이
# Predict: 0, Answer: 1
#
# Text: 게임 켰는데 섬광탄 마냥 눈뽕 오지게 흰색화면 나옴
# Predict: 0, Answer: 1
#
# Text: 조작감이 좆ㅏㄱ감이 돼는 마술
# Predict: 1, Answer: 0
#
# Text: 이거 마이크 지원 안됨 그것만 빼면 다 좋음 짱짱
# Predict: 1, Answer: 0
#
# Text: 느그엄마
# Predict: 0, Answer: 1
#
# Text: 병신이 되는 게임 씨발개새기ㅣ들아
# Predict: 0, Answer: 1
#
# Text: 재미가 친구가없다 접었다
# Predict: 0, Answer: 1
#
# Text: 신맵나왔다고
# Predict: 0, Answer: 1
#
# Text: 놓으라고
# Predict: 0, Answer: 1
#
# Text: 놔라
# Predict: 0, Answer: 1
#
# Text: 이게임을 구매하시면 분류의 사람들을 만나실수 있습니다 들어와서 무조건 스킵하는 노답 스킵충 들어오자 말자 그냥 나가버리는 인간 들어오자말자 욕부터 박는 정a 신 병a 새a 끼 하고 싶어서 게임 들어가면 들어가자말자 추방 시켜 버리는 노답 추방 빌런 들어와서 트롤짓하고 이상한 말욕 패드립 성적발언 같은거 하고는 추방할려하면 핵이어서 추방 안당하는 사회 부적응자 새a oa 끼 조작법 모른다고 일딴 무시부터 쳐하는 관a oa 종새 oa o끼 협동맵창작맵에 채팅같은거 안치고 지혼자 활동하는 사람 들어와서 인사 잘하고 잘 참여하다 나가는 일반인 위에 사람들수에 적음 자기가 원하는 맵 해달라 하고 안해주면 난리 부르스 치는 분조장 그럴거면 니가 방파던가 10 전에 트롤하다 추방 당했다는 이유로 들어와서 난리 쳐서 민페 끼치는 민페충 정상적이게 게임 참여하면 안돼겠냐 원하는 사람만 하고 싶으면 초대 전용 세션에서 하던가 공개섭 방파두고는 들어가면 추방시켜 버리는건 뭐임 이겜 해보면 알겠지만 DOG같은 사람이 많아서 일반인에 기준이 들어와서 인사 잘하면 일반인임 핵도 많아서 섭테러 당한은건 일주일에 12번 은 있음 사람들이 많아도 다 그런것은 아니고 친절한 사람은 친절해서 이겜 리뷰쓸떄 추천 할까 말까 고민하다가 추천한다
# Predict: 0, Answer: 1
#
# Text: 이거놔라 야발
# Predict: 0, Answer: 1
#
# Text: ㅄ이랑 하면 많이 힘듬
# Predict: 0, Answer: 1
#
# Text: 협동 게임인지 싸우는 게임인지 분간이 안 감
# Predict: 0, Answer: 1
#
# Text: 친구랑 하려고 샀는데 스팀 아이디 안알려줘서 1년째 못하고 있음
# Predict: 0, Answer: 1
#
# Text: 친구와 하기 최고의 게임
# Predict: 1, Answer: 0
#
# Text: 친구가 하는걸 보고 쪼갰다가 내가 하고나서 둘다 침팬치새끼나 다름없음을 깨달았다
# Predict: 0, Answer: 1
#
# Text: 샀는데 안해 개새끼들아
# Predict: 0, Answer: 1
#
# Text: 혼자해도 잼씀
# Predict: 1, Answer: 0
#
# Text: 우리팀 킬뎃이 1인 이유
# Predict: 0, Answer: 1
#
# Text: 언제까지 거기 있을껀데
# Predict: 0, Answer: 1
#
# Text: 시빨 노잼 지들끼리 먼저 깸 ㅈ같음 그냥
# Predict: 0, Answer: 1
#
# Text: 놔라 시바ㄹ
# Predict: 0, Answer: 1
#
# Text: 시발 미쳤노
# Predict: 0, Answer: 1
#
# Text: 2언재나와ㅏㅏㅏㅏㅏ
# Predict: 0, Answer: 1
#
# Text: 채팅기능좀 만들어주세요 없애신건지 이해가 안됨
# Predict: 0, Answer: 1
#
# Text: 벽 타느라 바빠서 정식루트 모르는 게임
# Predict: 0, Answer: 1
#
# Text: 멀티로 하는데 너무너무 재밌어요 갠플은 그닥
# Predict: 1, Answer: 0
#
# Text: 씨발아 잡지마
# Predict: 0, Answer: 1
#
# Text: 아르헨티나 빽브레이크
# Predict: 0, Answer: 1
#
# Text: 녹은 젤리같은 느낌
# Predict: 0, Answer: 1
#
# Text: 시발
# Predict: 0, Answer: 1
#
# Text: 환불좀
# Predict: 0, Answer: 1
#
# Text: 재미있고 친구 머리끄댕이 잡고 다니기 좋은 게임
# Predict: 1, Answer: 0
#
# Text: 퍼즐 풀 생각 1도없음 같이하는 상대의 머리를 쥐어 잡기위해 게임을 샀을 뿐이니까
# Predict: 0, Answer: 1
#
# Text: 씨발 개노잼 니엄마 개색기 니엄마는거지로 태어나 힘들게살아서 니를 먹여살렸지 니엄마없는거다알아 쓰랙아 이게임 지워라 이게임절때 사지마요 가격만 존나비싸고 짭이에요 쓰랙이 재작자야 니엄마 없는거알아라
# Predict: 0, Answer: 1
#
# Text: 채팅도 안되고 창작마당 스킨들 안보이는 유저들아 설정에서 parental control 이거 꺼라 나도 애들과 대화하면서 휴폴플하고 싶다
# Predict: 0, Answer: 1
#
# Text: 야매로 다 깸
# Predict: 0, Answer: 1
#
# Text: 운동부족
# Predict: 0, Answer: 1
#
# Text: 계속 업데이트 되길
# Predict: 1, Answer: 0
#
# Text: 너무 재밌어요 친구새끼들이 병신이에요
# Predict: 1, Answer: 0
#
# Text: 제작사 애미가 승천해버린 병신쓰레기 게임 2시간 1분 돈안 켜놔서 환분 못한다 병신 좆같은년아 씨발 리큐리티 프레치가 이거보다 재밌었다 시발 뒤지게 재미만 없고 친구 존나 못하고 고사양 컴터인데 최적하 술먹고 하는 병신같은게임
# Predict: 0, Answer: 1
#
# Text: 4명을 모아두면 꼭 한명은 병신이다
# Predict: 0, Answer: 1
#
# Text: 놓으라고
# Predict: 0, Answer: 1
#
# Text: 쓸모 없는 게비스콘들
# Predict: 0, Answer: 1
#
# Text: 게임을 하고 싶은데 상대방과 싸우고 싶다 게임을 강추합니다 게임을 상대방의 머리 끄댕이를 잡고 싶으신가요 이게임을 추천합니다
# Predict: 0, Answer: 1
#
# Text: 잼밋다
# Predict: 1, Answer: 0
#
# Text: oha bu oyun 5580 terk edilmiş le
# Predict: 0, Answer: 1
#
# Text: 흐물흐물
# Predict: 0, Answer: 1
#
# Text: 머리 잡히고 계속 떨어지고 죽고 죽이는 게임
# Predict: 1, Answer: 0
#
# Text: 그만 놔줘
# Predict: 0, Answer: 1
#
# Text: 물리엔진이 너무 답답하고 노잼임
# Predict: 0, Answer: 1
#
# Text: 흐물흐물이
# Predict: 0, Answer: 1
#
# Text: 개노잼
# Predict: 0, Answer: 1
#
# Text: 123456789
# Predict: 0, Answer: 1
#
# Text: 재미없음
# Predict: 0, Answer: 1
#
# Text: 과음하고 집가는 우리모습
# Predict: 1, Answer: 0
#
# Text: 놔라
# Predict: 0, Answer: 1
#
# Text: 쓰레기 게임
# Predict: 0, Answer: 1
#
# Text: 조작감이 매우 쓰레기같고 화면 흔들림이 너무 심해 어지럽고 멀미가 날거같음
# Predict: 0, Answer: 1
#
# Text: 놔라
# Predict: 0, Answer: 1
#
# Text: 몇번하면 질림
# Predict: 0, Answer: 1
#
# Text: 병신과 머저리들 사이 길도 아닌 벽으로 이동하는 미친놈
# Predict: 0, Answer: 1
#
# Text: 친구가 ㅈㄴ못해서 할 필요가 없다고 느껴져서 환불했습니다
# Predict: 0, Answer: 1
#
# Text: Recep tırmanmada sorun yaşıyor lütfen az cok demeyelim düzeltelim
# Predict: 0, Answer: 1
#
# Text: 재미있긴 온라인으로 플레이 했을때 사람들이 그냥 무작정 추방해버려서 하질 못합니다 그것만 감안하면 최고의 게임이네요
# Predict: 0, Answer: 1
#
# Text: 물리엔진을 거스르는 게임
# Predict: 0, Answer: 1
#
# Text: 걍 해
# Predict: 0, Answer: 1
#
# Text: 벽타기 모르면 머리가 고생하는게임
# Predict: 1, Answer: 0
#
# Text: 니 뭐하는데 이말만 오백번은 한 듯
# Predict: 0, Answer: 1
#
# Text: 재미없어용
# Predict: 0, Answer: 1
#
# Text: 플레이어 대가리 잡고 강퇴되고 서버 찾고 대가리 잡고 강퇴되고 서버 찾고 대가리 잡고 강퇴되고 서버 찾고 대가리 잡고 강퇴되고 서버 찾고 대가리 잡고 강퇴되고 서버 찾고 대가리 잡고 강퇴되고 서버 찾고 대가리 잡고 강퇴되고 서버 찾고 대가리 잡고 강퇴되고 서버 찾고 대가리 잡고 강퇴되고 서버 찾고 대가리 잡고 강퇴되고 서버 찾고 대가리 잡고 강퇴되고 서버 찾고 대가리 잡고 강퇴되고 서버 찾고 대가리 잡고 강퇴되고 서버 찾고 대가리 잡고 강퇴되고 서버 찾고 대가리 잡고 강퇴되고
# Predict: 0, Answer: 1
#
# Text: 보는 것과 하는 것의 재미는 다르다 그냥 방송용 게임
# Predict: 0, Answer: 1
#
# Text: 흐물흐물흐물
# Predict: 0, Answer: 1
#
# Text: 도전과제좀 그만 늘려
# Predict: 0, Answer: 1
#
# Text: 나름 짱구 굴리고 컨트롤도 필요하고 모션도 잼있고 좋았던 게임 할 사람이 없으면 절대 하지마십쇼 비참해져
# Predict: 0, Answer: 1
#
# Text: 재밌음
# Predict: 1, Answer: 0
#
# Text: 뻣으라고 시발아
# Predict: 1, Answer: 0
#
# Text: 잡지말라고 용승아
# Predict: 0, Answer: 1
#
# Text: 내 동생한테 선물하기 보냈는데 이새끼들이 돈먹고 도망감 선물은 안가졌는데 돈은 가져가네 ㅈ망겜 안함
# Predict: 0, Answer: 1
#
# Text: 게임자체 컨텐츠는 적음 창작마당이 아니었으면 이정도까지 인지도가 있었을까
# Predict: 0, Answer: 1
#
# Text: 놔라고 쫌
# Predict: 0, Answer: 1
#
# Text: 잡지 말라고 SㅐI T FALL 점수 85100
# Predict: 0, Answer: 1
#
# Text: 사지마세요 ㄹㅇ로
# Predict: 0, Answer: 1
#
# Text: 이상한 얘들이 아무이유없이 강퇴함
# Predict: 0, Answer: 1
#
# Text: 하지마세요 재미 하나도 없어요 제값주고 게임 살 바에 치킨 한마리 더 먹는게 이득
# Predict: 0, Answer: 1
#
# Text: 이대연 ㅈㄴ못하네
# Predict: 0, Answer: 1
#
# Text: 트롤존잼
# Predict: 1, Answer: 0
#
# Text: 칭구와 하세요
# Predict: 1, Answer: 0
#
# Text: 아니진짜뭔 클라임치트를켰는대도 벽타기가 안돼 아니이건좀 사탄도 이건좀 하고갈뜻 진짜 개 존나빡침
# Predict: 0, Answer: 1
#
# Text: 잡지마
# Predict: 0, Answer: 1
#
# Text: 진짜 너무 빡치고 버그가 심하고 안돼고 망겜
# Predict: 0, Answer: 1
#
# Text: 흐물흐물
# Predict: 0, Answer: 1
#
# Text: 친구없으면 하지마세요
# Predict: 0, Answer: 1
#
# Text: 감자튀김 48시간 상온에 놔둔거처럼 흐물거려요
# Predict: 0, Answer: 1
#
# Text: 브금 너무조코
# Predict: 0, Answer: 1
#
# Text: 개씨발롬들아
# Predict: 0, Answer: 1
#
# Text: 여러명이 해도 재밌고 해도 재밌어요 힐링겜
# Predict: 1, Answer: 0
#
# Text: 사람들이 하자해서 살때는 언제고 그이후로 묵혀두다보니까 볼때마다 돈 조금쓴거 그게 아까움 잠깐놀땐 진짜 재미있게 놀긴 했는데 그거 잠깐때문에 돈을 쓴다라 다시 생각해보면 뭔가 준내준내아까움
# Predict: 0, Answer: 1
#
# Text: 친구 없으면 사지마셈
# Predict: 0, Answer: 1
#
# Text: 너무 눈물이 날거같아요ㅕ
# Predict: 0, Answer: 1
#
# Text: 친구랑 하다보면 시간가는줄 몰라요 처음 들어갔는데 조작법 알고나자마자 계속 하게되고 무엇보다 캐릭터 빵댕이가 너무 귀여워요
# Predict: 1, Answer: 0
#
# Text: 친구랑 같이하면 재밌다가도 쌍욕 나오는게임 3D멀미 이런쪽으로 심하면 절대 하지마요 어지럽습니다 친구 놀려먹는건 재밌어서 친구 놀리고 토했습니다
# Predict: 0, Answer: 1
#
# Text: 조작이매우 어렵다
# Predict: 0, Answer: 1
#
# Text: 잡지마 ㅅㅂ롬아
# Predict: 0, Answer: 1
#
# Text: 멀미
# Predict: 0, Answer: 1
#
# Text: 올라가는 데만 1시간 걸렸다 처음엔 재밌지만 암걸리는 게임
# Predict: 1, Answer: 0
#
# Text: 재밌다 재미없다 혼자해도 재밌고 스팀 친구에게 선물해준후 무단으로 납치해 멀티맵을 플레이해도 재밌다 할게 없다 뉴비를 타워맵에 던져보아요
# Predict: 1, Answer: 0
#
# Text: 시발
# Predict: 0, Answer: 1
#
# Text: 이거 놔 이새끼야
# Predict: 0, Answer: 1
#
# Text: 도망쳐
# Predict: 0, Answer: 1
#
# Text: 막상 혼자하기엔 재미없는데 멀티 방 찾아서 가면 개 트롤하는 새끼만 남은 게임
# Predict: 0, Answer: 1
#
# Text: 재밌음
# Predict: 1, Answer: 0
#
# Text: 하지 마세요
# Predict: 0, Answer: 1
#
# Text: 혼자하면 재미 없어요 꼭 친구랑 하셈
# Predict: 1, Answer: 0
#
# Text: 밥먹고 하면 토 가능 체하거나 속 안좋을때 하면 토 가능 부와아악
# Predict: 1, Answer: 0
#
# Text: 본편 다 하면 외전 외전 다 하면 창작마당 창작마당 다하면 친구 꼬셔서 다시 한판 돌고 돌아 200시간 넘기고 나니 내가 두부인간이고 두부인간이 나인 수준ㅋㅋㅋ 유일한 단점은 사양 낮은 내 컴퓨터 정도
# Predict: 1, Answer: 0
#
# Text: 컴터로는 많이 안했지만 닌텐도로 지겹도록 한 사람으로써 말합니다 첫번째 창작마당이 있고 여러가지 맵이 수천개가 넘는다 두번째 조작이 단순하다 기절Y 채팅T 왼팔왼클릭 오른팔우클릭 좌우양옆WASD 세번째 친구와 플레이 할수 있고 커스터마이징이 자유롭다 넷째 게임에서 정해진 방법이 아니더라도 여러가지 스킬을 쓸수 번째 그래픽 화질이 좋고 커스터 마이지잉을 안해도 스킨이 여러가지를 입힐수 이와같이 좋은점이 많은 게임이니 꼭 해보세요
# Predict: 1, Answer: 0
#
# Text: 와쉽지안치안치안치안치안치안치안치안치안치안치안치안치안치안습니다
# Predict: 0, Answer: 1
#
# Text: 손 놓으라고
# Predict: 0, Answer: 1
#
# Text: 이거 50시간이나 했냐
# Predict: 0, Answer: 1
#
# Text: 하는 방법을 잘 모르겠기는 재밌어요 한번 하면 최소 3시간씩 순삭
# Predict: 1, Answer: 0
#
# Text: 머리채잡는거개재밋음
# Predict: 1, Answer: 0
#
# Text: 같이할사람 있으면 갓겜 없으면 사지마세요
# Predict: 0, Answer: 1
#
# Text: 잡지마 미친놈들아
# Predict: 0, Answer: 1
#
# Text: 멀미 유발겜 웬만하면 3D 멀미는 잘 안하는 편인데 생각보다 조작감이 너무 답답하고 눈 아픈정도
# Predict: 0, Answer: 1
#
# Text: 밀지마라
# Predict: 0, Answer: 1
#
# Text: 개꿀잼 이에요
# Predict: 1, Answer: 0
#
# Text: 게임이 실행이 안된다 게임산개 후외 되고 돈이 아깝다
# Predict: 0, Answer: 1
#
# Text: 친구들이랑 하니까 재밌네요
# Predict: 1, Answer: 0
#
# Text: ㅈ대로 움직일거면 게임 왜하는데
# Predict: 0, Answer: 1
#
# Text: 씨발 이게임도 3d 멀미나요 짜증나
# Predict: 0, Answer: 1
#
# Text: 조종하기에 난이도가 상당한 편이다 익숙해지면 등산도 가능하고 어디든 못 다닐 곳이 없다 혼자해도 충분하지만 친구들과 플레이하면 재미가 배가 된다 아주 많은 스테이지가 준비되어 있고 스테이지에는 크고 작은 퍼즐들이
# Predict: 1, Answer: 0
#
# Text: 멀미
# Predict: 0, Answer: 1
#
# Text: 퍼즐 ㅈ까 마인드로 딴길로 가면 그거조차 예상당해서 짜증남
# Predict: 0, Answer: 1
#
# Text: 스파르타 교육을 받으면 충분히 고인물이 될수 있음니다
# Predict: 1, Answer: 0
#
# Text: 대선 선수 올라오지 못하고 떨어집니다 gg
# Predict: 0, Answer: 1
#
# Text: 다운도 구매도안되는데 평가를 하라는거고 시발새기들아
# Predict: 0, Answer: 1
#
# Text: 벽 타겠다고 빨리 깨자고 그만 잡아라 징그러운 젤리색히들아
# Predict: 1, Answer: 0
#
# Text: 이거놔 놓으라고놔아아아아아아아
# Predict: 0, Answer: 1
#
# Text: 이걸 하는 사람이 있을까 찔리셨나요
# Predict: 0, Answer: 1
#
# Text: 놔
# Predict: 1, Answer: 0
#
# Text: 깔지마
# Predict: 0, Answer: 1
#
# Text: 꿀잼
# Predict: 1, Answer: 0
#
# Text: 쓰레기게임
# Predict: 0, Answer: 1
#
# Text: ㅅㅣㅂ발그만잡으락거
# Predict: 0, Answer: 1
#
# Text: 이거하려고 스팀 다운받음
# Predict: 0, Answer: 1
#
# Text: 노트북이여서그런지 렉이 거리지만 환불요청을 했지만 전혀 진행되지않았다
# Predict: 0, Answer: 1
#
# Text: 멀미 ㅈ되네
# Predict: 0, Answer: 1
#
# Text: 원가 너무 비쌈 할인 바람
# Predict: 0, Answer: 1
#
# Text: 잼밌다
# Predict: 1, Answer: 0
#
# Text: 게임하고싶다
# Predict: 0, Answer: 1
#
# Text: 야물딱지다
# Predict: 0, Answer: 1
#
# Text: 재밌지만 멀미남
# Predict: 1, Answer: 0
#
# Text: 그만 잡으라거 ptsd 오네
# Predict: 0, Answer: 1
#
# Text: 근데 도전과제 다 클리어했는데 상품이 없죠 시발 이럴거면 환불이나 해주든가
# Predict: 0, Answer: 1
#
# Text: 구구구구구구구굳
# Predict: 1, Answer: 0
#
# Text: 게임 할 사람 없는데 환불좀 해주실분
# Predict: 0, Answer: 1
#
# Text: 렉 개많이걸림 본인컴이 게임컴이 아니고 사양에 신경쓰지않은 컴이라면 플레이도못해보고 환불하게될것 custom 선택하고 5초기다렸다가 head 선택하고 5초기다리고 점하나찍고 5초기다리고 이래야됨
# Predict: 0, Answer: 1
#
# Text: 떨어지지마 잡지마 이런ㅆ
# Predict: 0, Answer: 1
#
# Text: 시발 ㅈ같은 조작감 ㅈ같은 개새끼 ㅈ같은 팔때기 ㅈ같은 발때기 ㅈ같은 머리부터 발끝까지 ㅈ같음
# Predict: 0, Answer: 1
#
# Text: 친구 있으면 할만한데 2만원은 절대 아니다
# Predict: 0, Answer: 1
#
# Text: ㅈ버그 진짜ㅡㅡ 뼈빠지게 그림 다 그렸는데 저장 누르니까 다흰색으로 칠해버리네 안해 tlqkf거
# Predict: 0, Answer: 1
#
# Text: 깰 생각 없음
# Predict: 1, Answer: 0
#
# Text: 거기 어캐 올라갔음
# Predict: 0, Answer: 1
#
# Text: 친구랑 같이하면 재밌어서
# Predict: 1, Answer: 0
#
# Text: 잡지말라고 씨발아
# Predict: 0, Answer: 1
#
# Text: 친구들과 하기 좋은 게임
# Predict: 1, Answer: 0
#
# Text: 놔라 1발럼아
# Predict: 0, Answer: 1
#
# Text: 조작도 하다 보면 익숙해지고 맵이랑 브금이랑 찰떡에 힐링게임입니다 온라인 서버중에 가끔 빡대가리같은 놈들을 만나서 화가 날 수 있음
# Predict: 1, Answer: 0
#
# Text: 절교할려면 게임 사셈
# Predict: 0, Answer: 1
#
# Text: 할거 없으면 간단하게 하기좋음
# Predict: 1, Answer: 0
#
# Text: 게임 플레이시 친구가 없다면 재미가 반감이 될 수있습니다 재미없어
# Predict: 0, Answer: 1
#
# Text: 별로이ㅏㅁ
# Predict: 0, Answer: 1
#
# Text: 겁나게 흐물흐물
# Predict: 0, Answer: 1
#
# Text: 동생과 하다가 머리채 잡고 싸울뻔 한 게임 다 깸ㅋㅋ
# Predict: 1, Answer: 0
#
# Text: 지좃대로 하는데 어느샌가 엔딩 크레딧 보면서 추락하고 있음
# Predict: 0, Answer: 1
#
# Text: 흐물흐물
# Predict: 0, Answer: 1
#
# Text: 혼자할때는 그냥 퍼즐파티인데 친구들이랑하니까 대환장파티
# Predict: 1, Answer: 0
#
# Text: 게임 자체는 그냥 재밌음 도전과제 깨는 맛도 있었고
# Predict: 1, Answer: 0
#
# Text: 주경이는 이게임 못하겠네요ㅠㅠ 슬퍼라 나는 재미있게 하는데
# Predict: 1, Answer: 0
#
# Text: 진짜 재미없음 망겜 똥껨 메롱
# Predict: 0, Answer: 1
#
# Text: 맵좀 깨자
# Predict: 0, Answer: 1
#
# Text: 시발 게임 화면이 이상해요
# Predict: 0, Answer: 1
#
# Text: 진짜 렉 겁나 많음 님들은 하지마셈
# Predict: 0, Answer: 1
#
# Text: 잼밌당
# Predict: 1, Answer: 0
#
# Text: 다 깸
# Predict: 1, Answer: 0
#
# Text: 킹받내
# Predict: 1, Answer: 0
#
# Text: 신맵이안나옴
# Predict: 0, Answer: 1
#
# Text: 이거 놔 장철수 뭐하는거야
# Predict: 0, Answer: 1
#
# Text: 끌어당기지 말라고 나까지 죽는다고
# Predict: 1, Answer: 0
#
# Text: 이거 피지컬게임이야 속지마
# Predict: 0, Answer: 1
#
# Text: 용주야 해야지 그치 규혁아
# Predict: 1, Answer: 0
#
# Text: 라이브러리에 게임이 안뜨네요 환불 할까 싶네요
# Predict: 0, Answer: 1
#
# Text: 뇌 뺴고는 못하는 게임
# Predict: 0, Answer: 1
#
# Text: 진짜 개웃김
# Predict: 0, Answer: 1
#
# Text: 잡지 말라고 개새끼야
# Predict: 0, Answer: 1
#
# Text: 조작이 어려워요
# Predict: 0, Answer: 1
#
# Text: 개웃김
# Predict: 0, Answer: 1
#
# Text: 너넨 이런거하지마라
# Predict: 0, Answer: 1
#
# Text: 물이 된 기분
# Predict: 1, Answer: 0
#
# Text: 협동하다 싸우고 혼자가고 터지고 리겜하고협동하다 싸우고 혼자가고 터지고 리겜하고협동하다 싸우고 혼자가고 터지고 리겜하고협동하다 싸우고 혼자가고 터지고 리겜하고협동하다 싸우고 혼자가고 터지고 리겜하고협동하다 싸우고 혼자가고 터지고 리겜하고협동하다 싸우고 혼자가고 터지고 리겜하고협동하다 싸우고 혼자가고 터지고 리겜하고협동하다 싸우고 혼자가고 터지고 리겜하고협동하다 싸우고 혼자가고 터지고 리겜하고협동하다 싸우고 혼자가고 터지고 리겜하고협동하다 싸우고 혼자가고 터지고 리겜하고협동하다 싸우고 혼자가고 터지고 리겜하고협동하다 싸우고 혼자가고 터지고 리겜하고협동하다 싸우고 혼자가고 터지고 리겜하고협동하다 싸우고 혼자가고 터지고 리겜하고협동하다 싸우고 혼자가고 터지고 리겜하고협동하다 싸우고 혼자가고 터지고 리겜하고협동하다 싸우고 혼자가고 터지고 리겜하고협동하다 싸우고 혼자가고 터지고 리겜하고협동하다 싸우고 혼자가고 터지고 리겜하고협동하다 싸우고 혼자가고 터지고 리겜하고협동하다 싸우고 혼자가고 터지고 리겜하고협동하다 싸우고 혼자가고 터지고 리겜하고협동하다 싸우고 혼자가고 터지고 리겜하고협동하다 싸우고 혼자가고 터지고 리겜하고협동하다 싸우고 혼자가고 터지고 리겜하고협동하다 싸우고 혼자가고 터지고 리겜하고협동하다 싸우고 혼자가고 터지고 리겜하고협동하다 싸우고 혼자가고 터지고 리겜하고협동하다 싸우고 혼자가고 터지고 리겜하고협동하다 싸우고 혼자가고 터지고 리겜하고협동하다 싸우고 혼자가고 터지고 리겜하고협동하다 싸우고 혼자가고 터지고 리겜하고협동하다 싸우고 혼자가고 터지고 리겜하고협동하다 싸우고 혼자가고 터지고 리겜하고
# Predict: 0, Answer: 1
#
# Text: 조별과제
# Predict: 0, Answer: 1
#
# Text: 놓으라고 X발아
# Predict: 0, Answer: 1
#
# Text: 퍼즐 풀라니까 포크레인으로 뭔 지랄 하는거야
# Predict: 0, Answer: 1
#
# Text: 꼼수 원툴게임
# Predict: 0, Answer: 1
#
# Text: 우정파괴게임
# Predict: 0, Answer: 1
#
# Text: 으
# Predict: 0, Answer: 1
#
# Text: 협동 게임중에 이거 이길만한거 없는 듯
# Predict: 0, Answer: 1
#
# Text: 왠지 모르겠지만 점점 똥망겜이 되어간다 어지러움을 잘타는 사람에게는 추천하지 않는다 많이 어지럽다
# Predict: 0, Answer: 1
#
# Text: 내 엉덩이 잡지마세요 놓아주세요 내 머리도 잡자미세요 놓아주세요 내려주세요 미안해요
# Predict: 1, Answer: 0
#
# Text: 시발
# Predict: 0, Answer: 1
#
# Text: 원래 하던 게임 서버가 나가서 의도치않게 시간때우기용으로 구매하게 된 게임입니다 처음에는 친구가 용량도 작고 할만 하다해서 샀는데 하면 할수록 캐릭터 커스터마이징하는게 너무 취향에 맞더라구요ㅋㅋ 아무튼 사양도 낮고 가격도 비싼편은 아니며 조작도 적응이 되면 쉬운편이여서 같이할 사람이 있거나 그냥 그림그리는게 재밌다 싶으신 분들도 한번쯤은 구매해도 좋을 같은 꽤 괜찮은 게임입니다
# Predict: 1, Answer: 0
#
# Text: 퍼즐 푸는것보다 트롤링이랑 벽타는게 100배 재밌음
# Predict: 1, Answer: 0
#
# Text: 흐물흐물
# Predict: 0, Answer: 1
#
# Text: 민헌아 개못한다
# Predict: 0, Answer: 1
#
# Text: 흐느적흐느적 아아아아잡지말라고아아아아아
# Predict: 1, Answer: 0
#
# Text: 개씹쓰레기똥망겜 클라이밍 국가대표 마냥 연습해서 친구들 불러놓고 여유롭게 벽타면 잠시동안 쓰레기 같은 우월감에 젖을 수 있음 자아도취에 빠지지 않도록 유의바람
# Predict: 0, Answer: 1
#
# Text: 다시는 안하고싶다 말랑찰떡같은 애들
# Predict: 0, Answer: 1
#
# Text: 놓아
# Predict: 0, Answer: 1
#
# Text: 친구들이랑 멀티 하면 맵을 깬다기보단 그냥 서로 치고박고 싸움 나도 그렇구나
# Predict: 0, Answer: 1
#
# Text: 피지컬겜
# Predict: 0, Answer: 1
#
# Text: 밀지마라
# Predict: 0, Answer: 1
#
# Text: 힐링된다ㅇㄹㄴㅁㅇㅇㅁㄴㅋㅌㅊㅊㄹㅎ
# Predict: 1, Answer: 0
#
# Text: 망갓겜
# Predict: 1, Answer: 0
#
# Text: 뭔가 화면 돌아가는게 너무 스무스해서 어지럽다 해야하나 그런 막 오래 잡고는 못하겠지만 아주 잼씀다 친구랑 머리 맞대고 하면 어떻게든 풀리는게 신기함
# Predict: 1, Answer: 0
#
# Text: 손인기 개멍청이
# Predict: 0, Answer: 1
#
# Text: 맵 깰 생각은 안 하고 친구랑 머리채만 잡다가 끝나는 게임
# Predict: 0, Answer: 1
#
# Text: 재미와능지가서로반비례하는게임
# Predict: 0, Answer: 1
#
# Text: ㅅ발련아 놓으라고
# Predict: 0, Answer: 1
#
# Text: 짜증나
# Predict: 0, Answer: 1
#
# Text: 캐릭터가 자꾸 드러누워요
# Predict: 0, Answer: 1
#
# Text: 존나 멀미남
# Predict: 0, Answer: 1
#
# Text: 토 할 같아
# Predict: 0, Answer: 1
#
# Text: 클리어 나올때마다 기분이 째져요
# Predict: 0, Answer: 1
#
# Text: 컴터 안좋으신분들은 추천 안하고요재밌습니다어지러운거 싫어하신다면 하지 마세요
# Predict: 0, Answer: 1
#
# Text: 퍼즐 푸는 맛도 있고 온라인으로 서로를 방해 할 수 있는 갓겜 기술에 능숙해진다면 나만의 루트를 개발해낼 수
# Predict: 1, Answer: 0
#
# Text: ㅅ시바려나 잡지말ㄹ라거
# Predict: 0, Answer: 1
#
# Text: 잡지마 개련아
# Predict: 0, Answer: 1
#
# Text: 00 찝년아 놓으라고
# Predict: 0, Answer: 1
#
# Text: h1저는 게임이 너무 재미있어서 미칠것 같아요h1 당신이 지금 지루하다면 게임을 b당장 지금 바로b 사야할 것입니다 당신이 게임을 해야할 지 고민된다면 그것은 b잘못된b 것입니다 당신이 게임을 왜하는지 이해가 가지 않는다면 아직 게임의 b진가를 못느꼈기b 때문입니다 당신이 게임을 돈주고 플레이 해야하는지 이해가 가지 않거나 쓸 가치가 없다고 느낀다면 당신은 인생게임을 b단 1도 해보지 못한 것b입니다 댓글을 보고도 사고 싶지 않다면 제가 추측하기에 당신은 b재미를 느끼지 못하는 병에 걸린것b 같군요 이렇게 재미있게 생긴 흐물거리는 젤리 인간을 보고도 안하고 싶나요 이렇게 다양한 맵과 유저들의 창작물을 보고도 안하고 싶나요 게임에서는 보기 힘든 엄청난 자유도를 가진 게임을 안하고 싶나요 중독적인 움직임과 다양한 루트로 구성된 퍼즐맵 유저들이 만든 다양한 맵과 스킨을 보고 안하고 싶나요 하기 싫다면 당신은 여자친구나 남자친구한테 차인만큼 슬프거나 남은 맛있는 음식을 친구가 뺐어간 상황처럼 화나신 상태가 분명합니다
# Predict: 0, Answer: 1
#
# Text: 머리채잡지맘ㄹㄹ아줘
# Predict: 1, Answer: 0
#
# Text: 최근 업데이트 이후로 스테이지 완료가 안돼요ㅠㅠ 마지막 구멍으로 들어가서 클리어 하려 하면 죽은 걸로 인식되어서 체크 포인트로 돌아옵니다 게임 끝내기가 너무 찝찝하니 업데이트 부탁드립니다
# Predict: 0, Answer: 1
#
# Text: 친한 친구랑 할 수록 진도가 느림 놔라제발
# Predict: 0, Answer: 1
#
# Text: 친구들하고하면개판되는게임
# Predict: 0, Answer: 1
#
# Text: 같이하면 더 난장판이 되는 게임
# Predict: 0, Answer: 1
#
# Text: 거기 올라갔냐고
# Predict: 0, Answer: 1
#
# Text: 개비스콘
# Predict: 0, Answer: 1
#
# Text: 컨트롤 개같은 게임
# Predict: 0, Answer: 1
#
# Text: 놔
# Predict: 1, Answer: 0
#
# Text: 친구 없음 사지 마셈진짜임
# Predict: 0, Answer: 1
#
# Text: 진짜 열받네
# Predict: 0, Answer: 1
#
# Text: 친구들이랑 같이하면 미친듯이 재밌다ㅋㅋ
# Predict: 1, Answer: 0
#
# Text: 멀티 ㅈㄴ안되네요
# Predict: 0, Answer: 1
#
# Text: 재밌는데 너무 멀미나서 도저히 못하겠다
# Predict: 0, Answer: 1
#
# Text: 너무 잘한다고 퇴장당함
# Predict: 0, Answer: 1
#
# Text: 재밌긴 재밌는데 너무 쌉고수가 돼서 신맵만 기다림 신맵 업데이트가 느려요 이미 너무 고여서 못하는 사람이랑 하면 샷건 치고싶어짐
# Predict: 0, Answer: 1
#
# Text: 잡지 말라고 놓으면 안 된다고 가라고 가야한다고 떨어지면 리스폰이야 싫어 제발 놓으라고 네가 먼저 놓으라고 싫다고 떨어진다고 어쩌라고
# Predict: 0, Answer: 1
#
# Text: 맵탈출 폴가이즈
# Predict: 0, Answer: 1
#
# Text: 놔라
# Predict: 0, Answer: 1
#
# Text: 친구들이 너무 못해서 게임 진행이 어려워요
# Predict: 0, Answer: 1
#
# Text: 욕먹음
# Predict: 0, Answer: 1
#
# Text: ㅣ발
# Predict: 0, Answer: 1
#
# Text: 속터짐
# Predict: 0, Answer: 1
#
# Text: 너무 단순함
# Predict: 0, Answer: 1
#
# Text: 게임을 사준 중수게이에게 사형을 선고합니다
# Predict: 0, Answer: 1
#
# Text: 씨빨 진짜 조작감 개같네
# Predict: 0, Answer: 1
#
# Text: 나의 오랜 밀린 숙제
# Predict: 0, Answer: 1
#
# Text: 굳굳 칭구들이랑 하기 좋고 난이도도 적당하고 업데이트도 자주 해줘서 진짜 최고의 게임
# Predict: 1, Answer: 0
#
# Text: 병맛게임 병맛좋아
# Predict: 0, Answer: 1
#
# Text: 개1노잼
# Predict: 0, Answer: 1
#
# Text: 놓으라고 야발아
# Predict: 0, Answer: 1
#
# Text: 혼자하면 ㅈ노잼멀티면 판마다 레전드
# Predict: 0, Answer: 1
#
# Text: 퍼블릭 열면 악질 고인물이 와서 2분만에 클리어함 조심하셈
# Predict: 0, Answer: 1
#
# Text: ㅅㅂ이새끼병신임
# Predict: 0, Answer: 1
#
# Text: 게임 자체는 재밌는 편 공식맵을 다 깨고 나면 할거 없어서 창작마당 찾아보지만 대부분에 맵이 중국맵이라 간혹 탈출맵 같은 경우 잦은 번역기를 돌려야함 단점이라면 입장렉은 기본 패시브 서버에 이상인지 버그가 걸림 ps 오늘부로 정 떨어져서 접습니다
# Predict: 0, Answer: 1
#
# Text: 잡지 말라고
# Predict: 0, Answer: 1
#
# Text: 친없찐은 빠져
# Predict: 0, Answer: 1
#
# Text: 마냥 웃기기만 한 게임인 줄 알았는데 절벽에 걸려 있는 친구를 끌어올려주는 플레이를 하며 끈끈한 우정을 공유할 수 있었습니다
# Predict: 1, Answer: 0
#
# Text: ㅈ밥련들
# Predict: 0, Answer: 1
#
# Text: 나약한 인간들이여 코노세카이와에서 탈출해라
# Predict: 0, Answer: 1
#
# Text: 진짜 엄청난 게임이다
# Predict: 1, Answer: 0
#
# Text: 놔라
# Predict: 0, Answer: 1
#
# Text: 상대방 엉덩이 잡고 늘어지는 겜 트롤이 법이다
# Predict: 0, Answer: 1
#
# Text: 노현준 시발련아
# Predict: 0, Answer: 1
#
# Text: 먼가 졸림
# Predict: 1, Answer: 0
#
# Text: 엉덩이 잡거나 머리채를 잡으면서 서로의 진로를 방해하고 죽을때까지 안놔주는 게임 근데 사실 죽어도 놔주지 않음 죽으면서까지 붙어있음
# Predict: 1, Answer: 0
#
# Text: 커스텀 맵 하는데 친구가 고인물 맵만 가져와서 어케 하는지도 모르겠음 한 구간만 2시간동안 뛰었는데 못 깸 ㅈ망겜
# Predict: 0, Answer: 1
#
# Text: 떨어지라고 잡지 말고
# Predict: 0, Answer: 1
#
# Text: 친구들과 게임을 했을 친구나 본인이 잘하면 돈독해지고 잘 못한다면 파국임
# Predict: 0, Answer: 1
#
# Text: 개노잼
# Predict: 0, Answer: 1
#
# Text: 씨발 놔 놓으라고
# Predict: 0, Answer: 1
#
# Text: 흠 그럭저럭입니다ㅠ 저같이 발컨이신분들껜 비추 점프맵 못 하시는분 비추 잡기 기능이 있어서 트롤러 분들도 많아서 비추
# Predict: 0, Answer: 1
#
# Text: 놔 놓으라고 안놔 먼저 놔 놔 놓으라고 안놔 먼저 놔 놔 놓으라고 안놔 먼저 놔 놔 놓으라고 안놔 먼저 놔 놔 놓으라고
# Predict: 0, Answer: 1
#
# Text: 노잼
# Predict: 0, Answer: 1
#
# Text: 제발 거기좀 그만잡아 쎕쎕이들아
# Predict: 1, Answer: 0
#
# Text: 할 만해요 입맛 없어지고 쓰러지고 멀미 나고 구토가 나오고 괜찮아요 할만해요
# Predict: 1, Answer: 0
#
# Text: 흐물흐물
# Predict: 0, Answer: 1
#
# Text: 역시 기술이 없으면 안되는게임이라니까 개가튼 고인물망겜
# Predict: 0, Answer: 1
#
# Text: 역시
# Predict: 1, Answer: 0
#
# Text: 잡지마 난 살고싶어
# Predict: 1, Answer: 0
#
# Text: 처참한 컨트롤의 뉴비를 놀리는 고인물들 괴로운 뉴비
# Predict: 0, Answer: 1
#
# Text: 환불
# Predict: 0, Answer: 1
#
# Text: 귀여워요 근데 처음에 할때는 토나올뻔
# Predict: 1, Answer: 0
#
# Text: 거길 갔어 잘
# Predict: 0, Answer: 1
#
# Text: 놓으라고
# Predict: 0, Answer: 1
#
# Text: 이노무새퀴드라 놔라
# Predict: 0, Answer: 1
#
# Text: 놔라
# Predict: 0, Answer: 1
#
# Text: 할 사람이 없으면 사지마세요 전 환불한다는 것을 까먹고 2주가 지나버렸습니다
# Predict: 0, Answer: 1
#
# Text: 놔 ㅆ1발
# Predict: 0, Answer: 1
#
# Text: 협동 하면 그냥꺨거 질척이다 줫나오래하는게임
# Predict: 0, Answer: 1
#
# Text: 내가 휴폴플 이건 그렇다 하는걸 적어보겠다 긴 글이니 안 읽어도 좋다 좋아요는 눌러줘라 초면에 욕 박는새키들이 너무 많다 솔직히 욕 필터가 없다고 해서 히히 욕 필터 없네 욕하고 다녀야지 생각을 하는 ㅄ은 없다 초면인데 존댓말은 못할망정 그냥 욕만 무지성으로 박는걸보니 게임 잘 돌아간다고 생각한다모든 사람이 그러는건 아니다 강퇴를 많이 당한다 솔직히 휴폴플 이상한 짓 해서 강퇴 당하는게 이상한거다 내가 말하는 강퇴는 친구끼리 할려고 강퇴 하는 놈들이다 친구끼리 할꺼면 초대 전용 세션으로 만들던가 공개세션으로 만들었는데 사람이 들어왔다면 친구들끼리 하는중인데 나가주실수 있으신가요 정중하게 부탁해라 강퇴만 박지말고 스피드런 충이 너무 많다 공개 세션인데 스피드런 쳐 참는사람 많다 다 즐기자고 하는 게임 도움 주는것도 아니고 그냥 스피드런만 무지성으로 하지 마라 게임 ㅈ되서 맵으로 넘어가려는거면 뭐라 안하지만 무지성으로 스피드런 하는 놈들은 반성해라 호구조사는 민폐다 절대 여미새가 많다 주의해라 제발 여자한테 작업좀 걸지마라 위에 들만 조심하면 클린하고 배려있는 게임이 된다 다들 노력하자
# Predict: 0, Answer: 1
#
# Text: 윤종현 개ㅣ발 새끼야
# Predict: 0, Answer: 1
#
# Text: 게임이 개빡셈
# Predict: 0, Answer: 1
#
# Text: 놔라
# Predict: 0, Answer: 1
#
# Text: 잡지 마라고 개seki들아
# Predict: 0, Answer: 1
#
# Text: 병맛임ㅋㅋㅋㅋㅋ
# Predict: 0, Answer: 1
#
# Text: 하면 할수록 개판이 되는 게임
# Predict: 0, Answer: 1
#
# Text: 꿀잼
# Predict: 1, Answer: 0
#
# Text: 좀놔라 니들은 이런거 이미 환불못했다면 어쩔수없고
# Predict: 0, Answer: 1
#
# Text: 씨123발 놓으라고 개샊꺄
# Predict: 0, Answer: 1
#
# Text: 같이해야 게임의 진가가 나옴
# Predict: 1, Answer: 0
#
# Text: 가지 말라고
# Predict: 0, Answer: 1
#
# Text: 친구 없어서 좆노잼이라고
# Predict: 0, Answer: 1
#
# Text: 흐물흐물해진 잼민이들과 퍼즐을 풀어보세요
# Predict: 1, Answer: 0
#
# Text: 로딩 존123123342341 234나길어용 예전엔 멀티 잘만 됐는데 이거 왜이러냐
# Predict: 0, Answer: 1
#
# Text: 캐릭터가 졸귀 그자체임
# Predict: 0, Answer: 1
#
# Text: 동생이랑 하려고 샀다가 화딱지만 남
# Predict: 0, Answer: 1
#
# Text: 놔라 이새끼들아
# Predict: 0, Answer: 1
#
# Text: 제발 놔라
# Predict: 0, Answer: 1
#
# Text: 씨ㅂ놈들아 잡지 말고 퍼즐이나 풀라고
# Predict: 0, Answer: 1
#
# Text: 도전과제 안깨지는 개버그때매 스트레스받아서 꼬접함
# Predict: 0, Answer: 1
#
# Text: 길은 개척하는 것이다
# Predict: 1, Answer: 0
#
# Text: 노잼
# Predict: 0, Answer: 1
#
# Text: 친한 친구랑 하세요
# Predict: 1, Answer: 0
#
# Text: 할 사람만 있으면 즐기기 좋은 게임
# Predict: 1, Answer: 0
#
# Text: 쌉꿀잼
# Predict: 1, Answer: 0
#
# Text: 날 잡지말고
# Predict: 0, Answer: 1
#
# Text: 좆같이 만들었습니다 졸라 미끄러져서 올라갈수가 없네요 ㅣ발 개 병신 일그러진 씹 똥망겜
# Predict: 0, Answer: 1
#
# Text: 게임을 재밌게 만드는 법은 연체동물 같은걸 끼얹나
# Predict: 0, Answer: 1
#
# Text: 병신이랑 하지마ㅔㅁ
# Predict: 0, Answer: 1
#
# Text: 재미없네요
# Predict: 0, Answer: 1
#
# Text: 가지마
# Predict: 0, Answer: 1
#
# Text: 정신사납다
# Predict: 0, Answer: 1
#
# Text: 시발년들
# Predict: 0, Answer: 1
#
# Text: 노잼
# Predict: 0, Answer: 1
#
# Text: 세일때 한 번 혹해서 샀는데 컴 안좋으면 b절대로b 권장드리지 않습니다 고인물 게임이겠고 지인이랑만 했는데 그중 한 명은 환불에 남은 한 명은 나처럼 산날 이후로 건들지도 않음 세일은 50퍼에서 60퍼로 내려갔고 나는 환불 시간을 놓쳐서 환불도 못했지만 게임은 뱃지 만들기 좋은 게임 아마 나중에 좋은 컴 장만하면 해보긴 하겠지만 혼자서는 안할 듯 2019 2022 수정 할 거면 로컬 먼저 지인이랑 하고 멀티 하는 게 나을 듯 썩은 물 게임이라길래 멀티로 가봤는데 내가 너무 못해서 꽤 미안했고 직접 해내가는 쾌감이 없었음 유명해서 그냥 쏘쏘하겠지 하고 여겼는데 생각보 사양 만만히 볼만한 게임이 아님 발열 심한 거 보면 노트북으로는 절대 할게임이 아님왠만한 3D 게임이 다 그렇긴 나랑 잘 맞지도 않고 그냥 미래에 하는 걸로 마우스 필수임 그냥 터치패드로 했더니 더 손가락 놀리느라 힘들었음
# Predict: 0, Answer: 1
#
# Text: 가는지 모름
# Predict: 0, Answer: 1
#
# Text: 절대 못간다 ㅅ1발아
# Predict: 0, Answer: 1
#
# Text: st5usrujsruj
# Predict: 0, Answer: 1
#
# Text: 남의 머리채 잡는 게임
# Predict: 0, Answer: 1
#
# Text: 자꾸 환불해 애들아
# Predict: 0, Answer: 1
#
# Text: I play 2player mode xbox controller keyboard mouse game 2nd player dont moveI think dont recognize keyboard mouse pleasefix
# Predict: 0, Answer: 1
#
# Text: 하고있는데 친구 모른는 놈들이 방해헤요 하지마세요
# Predict: 0, Answer: 1
#
# Text: 몸에 뼈가 하나도 없는 사람을 조종하고 싶을땐 휴먼폴플랫
# Predict: 1, Answer: 0
#
# Text: 친구가 하자고 졸라서 샀더니 번 하다가 접음
# Predict: 0, Answer: 1
#
# Text: 멀미나
# Predict: 0, Answer: 1
#
# Text: t발 좆같은 게임 점프하나 제대로 안되는 망겜임 하지마셈 22000원이나 주고산 흑우새끼 없지
# Predict: 0, Answer: 1
#
# Text: 맵이 더 없는게 아쉬워요
# Predict: 0, Answer: 1
#
# Text: 미처 몰랐어 게임이 이리 다채로운지
# Predict: 0, Answer: 1
#
# Text: 저처럼 친구 없는 분들에게는 정말 반대 하는 게임
# Predict: 0, Answer: 1
#
# Text: 이거놔십새야
# Predict: 0, Answer: 1
#
# Text: 작작잡아 씨발련들아
# Predict: 0, Answer: 1
#
# Text: 시발
# Predict: 0, Answer: 1
#
# Text: 히히 개꿀잼
# Predict: 1, Answer: 0
#
# Text: 풀어야 할 퍼즐은 안 풀고 꼼수만 생각하는 거
# Predict: 0, Answer: 1
#
# Text: 사람이 모이면 모일수록 재밌지만 모일수록 벽 개많이타서 정식루트를 안감 재밌음
# Predict: 1, Answer: 0
#
# Text: 하지말라면
# Predict: 0, Answer: 1
#
# Text: 친구들이랑 하니까 재밌어요
# Predict: 1, Answer: 0
#
# Text: 신맵나오면 찾게 되는 게임 혼자하면 재미없지만 누군가와 같이할때 엉망이 되는 게임
# Predict: 0, Answer: 1
#
# Text: 마시멜로우가 귀여워요
# Predict: 1, Answer: 0
#
# Text: 질려
# Predict: 0, Answer: 1
#
# Text: 이거 하면 재미없음ㅋㅋ 재미없디
# Predict: 0, Answer: 1
#
# Text: 이거 처음 하는 사람 놀리는 맛으로 하고 있어요
# Predict: 1, Answer: 0
#
# Text: 이거 안하면 인절손
# Predict: 0, Answer: 1
#
# Text: tlqkf놈들아 진행좀 하자 협조좀 해라
# Predict: 0, Answer: 1
#
# Text: 친구끼리만하셈 온라인 하면 친구없어서 온라인하는 이유있는 찐따년들이랑 지들끼리 기차놀이 쳐하고있는 좆목들 모임장소임 옛날에 열심히 온라인으로 사람들이랑 했었는데 시간지나니까 코드 뜯어고쳐서 지들끼리 공유하는 좆목들때문에 뉴비 절대 배제됨 내 리뷰봤으면 친구랑 깔짝하고 환불받으셈 병신찐따들 모임임 나도 200시간찐따였다가 정신차리고 벗어났었음 너무늦게 리뷰써서 미안하네 이거 결제하는 한국인들좆목들 지들끼리 해병기차놀이하면서 전우애 다지는거 보고싶지않으면 깔지마세요 좆목그거 차피 껴주지도 않을거임유입배척하는 찐따좆목들은 이거 보고있으면 그만좀 해라 그냥배그랑 롤하러가셈
# Predict: 0, Answer: 1
#
# Text: 거기 어캐 간거야 tlqkf
# Predict: 0, Answer: 1
#
# Text: 고통
# Predict: 0, Answer: 1
#
# Text: 전체적으로 완벽하지만 조작감이 이상함 회사게임이 조작감으로 인해 빡치게 하는것이기에 뭔 흐물흐물거림
# Predict: 0, Answer: 1
#
# Text: 잡지말라고
# Predict: 0, Answer: 1
#
# Text: 3D 멀미 있으신분 하지마세요 어지러움 수준이 탑급입니다
# Predict: 0, Answer: 1
#
# Text: 이민우 개인주의자 새끼야
# Predict: 0, Answer: 1
#
# Text: 진짜 사도 돈이 하나도 안 아까운 겜
# Predict: 0, Answer: 1
#
# Text: 몸이 흐물함
# Predict: 0, Answer: 1
#
# Text: 좋은 똥겜
# Predict: 0, Answer: 1
#
# Text: 똥겜
# Predict: 0, Answer: 1
#
# Text: 시발겜아 업뎃해라 도전과제도 다 꺠서 할거도 없다
# Predict: 0, Answer: 1
#
# Text: 친구들 모아서 하는 초인싸들의 기만게임
# Predict: 1, Answer: 0
#
# Text: 재밌다
# Predict: 1, Answer: 0
#
# Text: 시발 잡지마 으아아아ㅏㅏ아ㅏㅇㅇ
# Predict: 0, Answer: 1
#
# Text: 선물로 받아 플레이 할 수 있게 되었습니다 감사드립니다 하기엔 상당히 힘들고 컨텐츠가 부족하여 가성비는 별로 좋지 않은편 구매 가치는 있음
# Predict: 1, Answer: 0
#
# Text: 잡지마 놔봐 놔보라고
# Predict: 0, Answer: 1
#
# Text: 흐물흐물
# Predict: 0, Answer: 1
#
# Text: 캐릭터가 술먹은것 같음 제대로 서 있지를 못해
# Predict: 0, Answer: 1
#
# Text: 크랙써라 돈지랄이다
# Predict: 0, Answer: 1
#
# Text: 어려운데 제밌음
# Predict: 1, Answer: 0
#
# Text: 되게 재미있지만 갱비스트랑 느낌이 비슷합니다 갱비스트보다 더 재미있는 게임입니다 고인물들이랑하면 재미가 없다는 점
# Predict: 1, Answer: 0
#
# Text: 하다보면 질림
# Predict: 0, Answer: 1
#
# Text: 친구랑하면재밌음 협동 ㅈㄴ안됨 병신들
# Predict: 0, Answer: 1
#
# Text: 시간도둑임
# Predict: 0, Answer: 1
#
# Text: 친구랑 하면 개꿀잼이에요 게임이 궁금하다면 해보세요 해봐야 압니다
# Predict: 1, Answer: 0
#
# Text: 친구들 이랑 합이 잘맞는 친구랑 하면 안됌ㅋㅋ 합이 안맞아야 레전드 나옴ㅋㅋ
# Predict: 0, Answer: 1
#
# Text: 10000원 15000원 정도면 정말 좋은 같은 게임 하는 사람이 못하면 정말 짜증 나는 게임이지만 귀여우니까 봐드림
# Predict: 1, Answer: 0
#
# Text: 단돈 2만원에 친구를 빡치게 할수 있어요
# Predict: 0, Answer: 1
#
# Text: 개웃김 진짜ㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# Predict: 0, Answer: 1
#
# Text: 이상해요
# Predict: 0, Answer: 1
#
# Text: 이게임하느라 주말 사라짐 하지마세요
# Predict: 0, Answer: 1
#
# Text: 게임은 윤승이들이나 하는 게임입니다
# Predict: 0, Answer: 1
#
# Text: 쳐 놔라 시발놈드라
# Predict: 0, Answer: 1
#
# Text: 뿌뿌뿌ㅃ
# Predict: 1, Answer: 0
#
# Text: 신맵 너무 별로에요
# Predict: 0, Answer: 1
#
# Text: 냐
# Predict: 0, Answer: 1
#
# Text: 망겜
# Predict: 0, Answer: 1
#
# Text: ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ게이스킨무엇
# Predict: 0, Answer: 1
#
# Text: 재미있음
# Predict: 1, Answer: 0
#
# Text: 안놔 니가먼저놔
# Predict: 0, Answer: 1
#
# Text: 할 친구가 많았으면 좋겠다
# Predict: 1, Answer: 0
#
# Text: 꿀잼
# Predict: 1, Answer: 0
#
# Text: 게임을 시작 하고 로컬 플레이를 컨트롤러랑 키보드로 했는데 키보드가 안먹는건 뭔가유
# Predict: 0, Answer: 1
#
# Text: 집단 지성이 아니라 집단 무지성 아닐까
# Predict: 0, Answer: 1
#
# Text: 싫엇던점이 잇는데 이유는 채팅밖에 안되요 마이크기능을켜서 상대와 소통하는 기능이 없어서 아쉬웠습니다
# Predict: 0, Answer: 1
#
# Text: 흐물흐물
# Predict: 0, Answer: 1
#
# Text: 검나 재미없어요
# Predict: 0, Answer: 1
#
# Text: 인간이 명이나 모이면 말야 한 명 트롤러가 Trolls trolls everywhere
# Predict: 0, Answer: 1
#
# Text: 영어닉을 하고 공방에 가면 짱개로 오해받고 퇴장당합니다 평균 연령대가 약 10세로 보이며 공방에서 정상인을 찾기 힘듭니다 레포데 합시다
# Predict: 0, Answer: 1
#
# Text: 추방 해제 법 아는 사람
# Predict: 0, Answer: 1
#
# Text: 우끼끼
# Predict: 0, Answer: 1
#
# Text: 재밌으
# Predict: 1, Answer: 0
#
# Text: 2만원 주고 사긴 아까움
# Predict: 0, Answer: 1
#
# Text: 가격치고 별로에요
# Predict: 0, Answer: 1
#
# Text: 앆11 잡지말라고
# Predict: 0, Answer: 1
#
# Text: 친구랑 하면 게임 깨기는 뒷전 서로 잡고 싸우고 난리다
# Predict: 0, Answer: 1
#
# Text: 여러모로 잘만든 게임이에요 그래픽적으로 귀여워서 부담이 없고 눈도 편한 파스텔톤 게임이네요 퍼즐적 요소들이 많이 있는데 난이도도 적절하고 양도 많아서 좋아요 정말 재밌게 즐기려면 친구들이랑 같이하는게 좋겠지만 로컬 온라인 시스템으로 모르는 사람들과 매칭해서 하는 것도 좋은 같아요 혼자서 진행해도 퍼즐류 게임을 좋아하시는 분이라면 재밌게 즐기실 같아요 개인적으로 맵 구성이 매우 잘 짜여있고 퍼즐 풀이에 방법이 여러가지라는 점이 좋았습니닷 추천
# Predict: 1, Answer: 0
#
# Text: 놓으라고
# Predict: 0, Answer: 1
#
# Text: 몇시간만하면 너도 고인물
# Predict: 0, Answer: 1
#
# Text: 어우 쓉 고인물 겜
# Predict: 0, Answer: 1
#
# Text: 플레이타이쓰레기 중국몽게임
# Predict: 0, Answer: 1
#
# Text: 러바너보
# Predict: 0, Answer: 1
#
# Text: 조작때문에 스트레스 받는 게임을 굳이 돈 주고 하고 싶지는 않네요
# Predict: 0, Answer: 1
#
# Text: 귣
# Predict: 1, Answer: 0
#
# Text: h1 제한이 없다 h1 창작마당 맵들은 모르겠는데 공식 맵이랑 추가 맵들은 않다 개발자가 의도한 루트로 가던지 물리와 버그를 이용해 뛰어넘던지 당신의 선택이다 애초에 개발자 이름부터 No Brakes Games 브레이크 없는 게임 다
# Predict: 0, Answer: 1
#
# Text: 야매로 깼습니다
# Predict: 0, Answer: 1
#
# Text: 제발 협동좀 해줘 제발 그만해
# Predict: 0, Answer: 1
#
# Text: 혼자하니까 힘드네요
# Predict: 1, Answer: 0
#
# Text: 망겜
# Predict: 0, Answer: 1
#
# Text: 병신겜
# Predict: 0, Answer: 1
#
# Text: 적극 추천해요 친구랑 하면 꿀잼이에요
# Predict: 1, Answer: 0
#
# Text: 흐물흐물 개비스콘
# Predict: 0, Answer: 1
#
# Text: 친구 없이 못하는 게임
# Predict: 0, Answer: 1
#
# Text: 이거 준내 답답햬
# Predict: 0, Answer: 1
#
# Text: 지랄 지랄 지랄
# Predict: 0, Answer: 1
#
# Text: 래버를 잡아
# Predict: 0, Answer: 1
#
# Text: 버니합 할 줄 모르는데 자꾸 하래 ㅅ1발
# Predict: 0, Answer: 1
#
# Text: 그만좀 잡아
# Predict: 0, Answer: 1
#
# Text: 선물 받고 했는데 난이도 꽤 있는 편이긴 재밌습니다
# Predict: 1, Answer: 0
#
# Text: 잼밌다
# Predict: 1, Answer: 0
#
# Text: 걍 세일때 사면 가성비 개이득 너무달아요 이잉
# Predict: 1, Answer: 0
#
# Text: 고인물을 만나기 싫으면 유튜브 영상으로 공부하시고 하시는걸 추천합니다
# Predict: 0, Answer: 1
#
# Text: 크리스마스 도전과제 깨짐
# Predict: 0, Answer: 1
#
# Text: 멀미남
# Predict: 0, Answer: 1
#
# Text: 내 맘대로 안되지만 흐물딱 거리는게 귀없다
# Predict: 0, Answer: 1
#
# Text: 게임이 너무 할게없네요 업데이트 하세요
# Predict: 0, Answer: 1
#
# Text: 친구가 없으면 재미없고 하다보면 협동 안되서 빡종하는놈들있음ㅋ
# Predict: 0, Answer: 1
#
# Text: 왼손 검지 중지 근력 기르기
# Predict: 1, Answer: 0
#
# Text: 그냥 하지마세요
# Predict: 0, Answer: 1
#
# Text: 똥겜
# Predict: 0, Answer: 1
#
# Text: 유저 맵이 레전드
# Predict: 0, Answer: 1
#
# Text: 너무 ez하네여
# Predict: 0, Answer: 1
#
# Text: 게임ㅋㅋ 흐물흐물 거리는게 포인트고 스킨도 꾸밀 수 있어요 채팅 기능도 있어서 소통도 가능해요 재밌으니까 한 번 해보시는 걸 추천드려요
# Predict: 1, Answer: 0
#
# Text: 난 스파이더맨인가
# Predict: 1, Answer: 0
#
# Text: 친구가 없는데 게임을 샀다 하면 10000원 버리는거임 친구 없고 솔플한다 재미가 없음
# Predict: 0, Answer: 1
#
# Text: 신체가 병맛
# Predict: 0, Answer: 1
#
# Text: 등산을 못하면 머리가 고생한다
# Predict: 1, Answer: 0
#
# Text: fuxking 암걸려 ㅆ발
# Predict: 0, Answer: 1
#
# Text: 내가 이걸 145시간이나 했지
# Predict: 1, Answer: 0
#
# Text: 뭔 짓을 해도 골에만 가면 되는 게임 망말로 벽짚기해서 올라가도 된다 재미있는 게임인데 조작감이 ㅈ같다 ㅈ같은 조작감 싫어하면
# Predict: 0, Answer: 1
#
# Text: 미션 깨랬더니 지들끼리 싸우는 게임
# Predict: 0, Answer: 1
#
# Text: 놔라
# Predict: 0, Answer: 1
#
# Text: 흐물딱지흐물흐물
# Predict: 0, Answer: 1
#
# Text: 대가리 협동이 안돼면 그냥 포기하고 딴거하자
# Predict: 0, Answer: 1
#
# Text: 맵 볼륨이 아쉬움 할인할때 살만함
# Predict: 1, Answer: 0
#
# Text: gRU9Fs6yueqgweywaHGRC E2
# Predict: 0, Answer: 1
#
# Text: 내 컴퓨터에선 딜레이가 걸리는 건지 그것 나름대로 존나 재미있음 친구랑 사이가 멀어질 수 있음
# Predict: 1, Answer: 0
#
# Text: 똥겜
# Predict: 0, Answer: 1
#
# Text: 재밌는데 멀미남
# Predict: 1, Answer: 0
#
# Text: 친구 없으면 하지마세요 고인물 친구랑 하지마세요
# Predict: 0, Answer: 1
#
# Text: 이거 4년전에는 맵 개 적다고 욕먹고 그랬는데 막상 많아지니 도전과제도 2배로 늘어남 언제깨지
# Predict: 0, Answer: 1
#
# Text: 바닥 잡고 트월킹하는 게임
# Predict: 0, Answer: 1
#
# Text: 이게 뭐노
# Predict: 0, Answer: 1
#
# Text: 렉이 많이걸려요
# Predict: 0, Answer: 1
#
# Text: 시발련들아 작작잡아
# Predict: 0, Answer: 1
#
# Text: 내 친구들 돌려줘
# Predict: 1, Answer: 0
#
# Text: 너무
# Predict: 0, Answer: 1
#
# Text: 솔직히 킹받는데 성취감 개오짐 이정도로 6000원이 아깝지 않았던건 12번쨰다
# Predict: 1, Answer: 0
#
# Text: 노잼
# Predict: 0, Answer: 1
#
# Text: 손에 힘이 없노
# Predict: 0, Answer: 1
#
# Text: 좆노잼
# Predict: 0, Answer: 1
#
# Text: 겜 존나 노잼이네
# Predict: 0, Answer: 1
#
# Text: 피지컬과 지능에는 상관 관계가 없음
# Predict: 0, Answer: 1
#
# Text: 진짜 이겜 왜재밌다는지 모르겠슴 할인된 가격에 그냥 친구들이랑 그럭저럭 할 수준겜
# Predict: 1, Answer: 0
#
# Text: 생각없이 하기좋은겜
# Predict: 1, Answer: 0
#
# Text: 멀미가 나는 것이지
# Predict: 0, Answer: 1
#
# Text: 환불을 이리 늦게함
# Predict: 0, Answer: 1
#
# Text: 씨발 친구들끼리 할꺼면 씨발 공개방을 쳐 파지 말라고 친구 공개가 있는데 쳐 안쓰는건 니들 눈이 장식이기 때문이냐고 씨발 오랜만에 공개방좀 들가볼까해서 들어왓는데 말없는 추방만 연속 8번을 당했어 씨발 니들끼리 할꺼면 그냥 친구공개고 첨부터 파서 하라고 씨발
# Predict: 0, Answer: 1
#
# Text: 나름 친구랑 해서 재미있었던 게임 환불하려다가 안된다고 말린 밸브 고마워
# Predict: 0, Answer: 1
#
# Text: 뻘짓하다보면 2시간 순삭
# Predict: 0, Answer: 1
#
# Text: 친구 없으면 사지마
# Predict: 0, Answer: 1
#
# Text: 정신병걸림
# Predict: 0, Answer: 1
#
# Text: 권성협 씨불놈아 말좀 들어라
# Predict: 0, Answer: 1
#
# Text: 가랑이좀 잡지마 개1새끼야
# Predict: 0, Answer: 1
#
# Text: 삿는데 지랄하고자빠졋는지 모르겟네 공유하고잇다고 권한요청하라는거지 장애인인가 관리자
# Predict: 0, Answer: 1
#
# Text: 게임은 좋은데 세일 할인 못 참고 정가에 샀는데 몇일뒤에 66퍼를 할인해서 14000원을 날려먹은 포인트나 수급함 이걸 좋아요를 줄지 나빠요를 줄지 생각하다가 내 돈이라서 이하 생략 그리서 좋아요
# Predict: 0, Answer: 1
#
# Text: 뭔 이딴 게임이 다 있냐
# Predict: 0, Answer: 1
#
# Text: 깐부만 가능
# Predict: 0, Answer: 1
#
# Text: 너굴
# Predict: 1, Answer: 0
#
# Text: SEXY 하자
# Predict: 0, Answer: 1
#
# Text: 무조건 친구랑 해야하는 게임 없으면 사지말자
# Predict: 0, Answer: 1
#
# Text: 씨이발 도전과제를 깨는데 무선침묵이 안되는데 레벨에서 라디오를 다 버렸는데 안 깨지네 뭐 ㅈ같은 경우가 다있지 빨리 깼다고하자 ㅆ발진짜 꺴는데 라디오 4개 버렸는데 안 깨지잖아 ㅅ발
# Predict: 0, Answer: 1
#
# Text: 굳
# Predict: 1, Answer: 0
#
# Text: 잡지마 미친놈아
# Predict: 0, Answer: 1
#
# Text: 친구들이랑 재밌음 도전과제 깨면서 하는데 ㅈ노잼이었음 할 사람 없으면 사지마세요
# Predict: 0, Answer: 1
#
# Text: 내 친구들은 협동심이 강해서 분탕질하는 재미가 없음
# Predict: 0, Answer: 1
#
# Text: 게임은 게임이 아니다
# Predict: 0, Answer: 1
#
# Text: 갓겜
# Predict: 1, Answer: 0
#
# Text: 혼자는 노잼 같이하면 재밌는데 맵 별로 없어서 플탐 15시간정도 보면됨 혼자할꺼면 비추천
# Predict: 0, Answer: 1
#
# Text: 대가리 쥐어 뜯으면 확률적으로 손 놓게 하면 안됨
# Predict: 0, Answer: 1
#
# Text: 나름재밋음
# Predict: 1, Answer: 0
#
# Text: 씨발 잡지 말라고
# Predict: 0, Answer: 1
#
# Text: 벽타기를 하도 했더니 원래 클리어 해야 되는지 길을 모르겠다
# Predict: 0, Answer: 1
#
# Text: 굳
# Predict: 1, Answer: 0
#
# Text: 잘못하다가 친구랑 절교할뻔 했습니다
# Predict: 1, Answer: 0
#
# Text: 진짜 재미있어요ㅋㅋㅋㅋㅋ
# Predict: 1, Answer: 0
#
# Text: 물리기반 협력탈출게임 모든게 예상가능한 범주 내에 있어서 참신함은 없었고 뒤로 갈수록 멀미가 나서 접음
# Predict: 0, Answer: 1
#
# Text: 개판 5분전
# Predict: 0, Answer: 1
#
# Text: 뱃지 내놔
# Predict: 0, Answer: 1
#
# Text: 친구가 많을수록 재밌지만 많을수록 난장판이 되는 게임
# Predict: 0, Answer: 1
#
# Text: 자꾸 맵이 늘어나는 혜자겜
# Predict: 0, Answer: 1
#
# Text: 조작감 병신같고 물리엔진도 병신같은데 하다보면 나도 어케하는지 원리를 모르는 병신같이 재밌는겜
# Predict: 0, Answer: 1
#
# Text: y6
# Predict: 0, Answer: 1
#
# Text: 이게 싱글게임이라고
# Predict: 1, Answer: 0
#
# Text: 구매했는데 구매하라고 합니까
# Predict: 0, Answer: 1
#
# Text: 쫌 잡지마
# Predict: 0, Answer: 1
#
# Text: 트롤링이야말로 엔드컨텐츠
# Predict: 0, Answer: 1
#
# Text: 아오 개같은게임 박치게하네
# Predict: 0, Answer: 1
#
# Text: 잡지마 이새X야
# Predict: 0, Answer: 1
#
# Text: 걷는 것조차 제대로 못하는 것이 나의 삶과
# Predict: 0, Answer: 1
#
# Text: 잉어 유도관
# Predict: 1, Answer: 0
#
# Text: 그냥 사놓고 친구랑 가끔하면 재미있음 친구없으면 사지마세여
# Predict: 1, Answer: 0
#
# Text: 개1씨발련들아 뭐해
# Predict: 0, Answer: 1
#
# Text: 게임자체는 할만한데 멀미심해서 못해먹겠음 특히 언덕오를때나 카메라 가까워질때 뒤질뻔함
# Predict: 0, Answer: 1
#
# Text: 친없찐은 진정한 휴먼폴플랫을 즐기지 못한다
# Predict: 0, Answer: 1
#
# Text: 벽타는 재미로만 하고 있었는데 전부터 손에 윤활제 쳐 바른거마냥 손 미끄러져서 벽 못타서 삭제함
# Predict: 0, Answer: 1
#
# Text: 좆같은 게임을 찾늦다면 당장사 시발
# Predict: 0, Answer: 1
#
# Text: 대국민 사죄 드립니다
# Predict: 0, Answer: 1
#
# Text: 개 망겜
# Predict: 0, Answer: 1
#
# Text: 친구랑 하면 진짜 재미있음 친구 없으면 미안하게 됐다
# Predict: 1, Answer: 0
#
# Text: 진행좀 하자 제발
# Predict: 0, Answer: 1
#
# Text: 친구 없으면 할수 없는데 친구가 있으면 손절하는게임
# Predict: 1, Answer: 0
#
# Text: 굳
# Predict: 1, Answer: 0
#
# Text: 친구가 없다고 사지말고 사는 걸 추천함 근데 나는 친구 있는데 재밌게 했다
# Predict: 1, Answer: 0
#
# Text: 애미없음
# Predict: 0, Answer: 1
#
# Text: 할 사람이 없는데 사면 ㅈ되는 게임
# Predict: 0, Answer: 1
#
# Text: 시발아
# Predict: 0, Answer: 1
#
# Text: 장장장
# Predict: 0, Answer: 1
#
# Text: 어지러움 친구랑 하면 재밌음
# Predict: 1, Answer: 0
#
# Text: 답답해서 암걸려 죽음
# Predict: 0, Answer: 1
#
# Text: 능지겜
# Predict: 0, Answer: 1
#
# Text: Tlqkf 손 노으라고오
# Predict: 0, Answer: 1
#
# Text: 게임이 안들어가져요
# Predict: 0, Answer: 1
#
# Text: 게임은 내 맘에 들지 않다
# Predict: 0, Answer: 1
#
# Text: 흐물흐물
# Predict: 0, Answer: 1
#
# Text: 거기잡지마라
# Predict: 0, Answer: 1
#
# Text: 벽타기 꿀잼
# Predict: 1, Answer: 0
#
# Text: 실험실 개노잼
# Predict: 0, Answer: 1
#
# Text: 더 퍼즐게임이 아닌거
# Predict: 0, Answer: 1
#
# Text: 업데이트 쓰레기야
# Predict: 0, Answer: 1
#
# Text: 병ㅅ짓 가능
# Predict: 0, Answer: 1
#
# Text: 비추사유 멀미
# Predict: 0, Answer: 1
#
# Text: 친구들의 멱살을 잡고 절벽 아래로 던져버리세요 온라인 막고라를 신청한다
# Predict: 0, Answer: 1
#
# Text: 창작마당 중국 공식맵만 하시고 하지마세요
# Predict: 0, Answer: 1
#
# Text: 친구들이 3D 멀미한다고 다들 도망갔습니다 제대로 즐기지도 못했는데
# Predict: 0, Answer: 1
#
# Text: 조작감 뭣같은게 컨셉인 어드벤처 퍼즐겜인데 처음할땐 캐릭터 흐느적거리는게 웃기고 간단한 퍼즐 몇개씩 해결하면서 뿌듯함도 느끼지만 절대 한번에 움직여주지 않는 캐릭터와 말 정말 안들어먹는 사물들의 대환장 콜라보때문에 진행하면서 퍼즐 난이도가 높아질수록 점점 짜증만 늘어난다 유튜버나 스트리머들은 이런게임하면서 돈이라도 벌지 일반 유저들은 이런게임 돈주고 사서 고통받아봤자 얻는게 아무것도 없다 솔직히 시간아까움
# Predict: 0, Answer: 1
#
# Text: 친구들과 시작한 게임 서로 멱살잡으며 떨어지고 떨어뜨리는 친구들 도저히 진행할 수 없어서 파쿠르를 시도하는
# Predict: 0, Answer: 1
#
# Text: 게임으로 군대 특수전 공수마크받았으면 벌써 금장휘장 받았을텐데 당신은 이미 떨어지고
# Predict: 0, Answer: 1
#
# Text: 친구의 온몸을 더듬고 벽을 쓸고 땅에박고 여러가지 좋은게임
# Predict: 1, Answer: 0
#
# Text: 물리엔진 ㅈ같은겜
# Predict: 0, Answer: 1
#
# Text: 어제 배꼽 빠지게 웃김ㅋㅋㅋㅋ
# Predict: 0, Answer: 1
#
# Text: 작작 잡아 X발럼들아
# Predict: 0, Answer: 1
#
# Text: 종간1나 게이ㅁ
# Predict: 0, Answer: 1
#
# Text: zzzzzzzzzzzzzzzzzㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 애들 인성
# Predict: 0, Answer: 1
#
# Text: 머리끄댕이 잡지마
# Predict: 0, Answer: 1
#
# Text: 컨트롤안좋은사람지루함
# Predict: 0, Answer: 1
#
# Text: 뇌 파괴
# Predict: 0, Answer: 1
#
# Text: 내가한 최고의 병맛겜 최고 DOG재밌어
# Predict: 1, Answer: 0
#
# Text: 재미있긴 합니다만 개속하면 질려요
# Predict: 1, Answer: 0
#
# Text: 재미썽요
# Predict: 1, Answer: 0
#
# Text: 걍 딴사람 잡고 뛰어 내리는겜
# Predict: 1, Answer: 0
#
# Text: 방탈출 하는 느낌이라 재밌음 근데 친구랑 하면 개빡침
# Predict: 1, Answer: 0
#
# Text: 구매하기 전에 할 친구가 있는지를 찾아보세요 혼자서 하면 별로 재미없어요
# Predict: 0, Answer: 1
#
# Text: 놔라
# Predict: 0, Answer: 1
#
# Text: 단조로울 줄 알았는데 의외로 친구들이랑 가는줄 모르고 즐겁게 함
# Predict: 1, Answer: 0
#
# Text: 커마하는 재미도 있고 창작마당도 지원하고 오리지널 맵 플탐도 길어서 가성비 좋은 퍼즐게임 단점으론 어려운 조작감과 멀미가 올수 있는 시점이 있습니다
# Predict: 1, Answer: 0
#
# Text: 분노 고통 절망 실패 답답함 스트레스 역정 머리채 잡기 모든 것이 응축된 재미
# Predict: 1, Answer: 0
#
# Text: 메인컨텐츠 트월킹임
# Predict: 0, Answer: 1
#
# Text: 롤같은거 해서 싸우지말고 게임이나 하자 업뎃 계속 해주는 혜자겜 무족권 사라
# Predict: 1, Answer: 0
#
# Text: 친구 엉덩이 잡아서 족치는게임
# Predict: 1, Answer: 0
#
# Text: 이거 놓으라고
# Predict: 0, Answer: 1
#
# Text: 게임 너무 좆같고 하기 존나 힘든 비추임
# Predict: 0, Answer: 1
#
# Text: 친구없으면 할수없는겜 협동해서 최대한 클리어하는걸 방해해야 승리하는겜
# Predict: 1, Answer: 0
#
# Text: 처음 한시간만 웃기고 이후부터 조작 좆같에서 개짜증남
# Predict: 0, Answer: 1
#
# Text: 친구 없는 사람들 불쌍할 정도로 재밌음
# Predict: 1, Answer: 0
#
# Text: 친구랑 안했으면 진짜 재미없었을 같은 게임
# Predict: 0, Answer: 1
#
# Text: 꿀잼ㅁㅁㅁㅁㅁㅁㅁㅁㅁㅁㅁㅁㅁ
# Predict: 1, Answer: 0
#
# Text: d0d
# Predict: 0, Answer: 1
#
# Text: 동글동글 흐물흐물
# Predict: 0, Answer: 1
#
# Text: 조작이 어려움
# Predict: 0, Answer: 1
#
# Text: 커플 번지점프
# Predict: 0, Answer: 1
#
# Text: 노잼
# Predict: 0, Answer: 1
#
# Text: 맵이 없어
# Predict: 0, Answer: 1
#
# Text: 개발자가 작정하고 만든 친구없으면 못하는게임
# Predict: 0, Answer: 1
#
# Text: 고인물 게임이다
# Predict: 0, Answer: 1
#
# Text: 저사양 게임인데 렉이 너무 많아서 즐거운 플레이가 힘듬
# Predict: 0, Answer: 1
#
# Text: 벽타기 재미없음
# Predict: 0, Answer: 1
#
# Text: 흐물흐물
# Predict: 0, Answer: 1
#
# Text: 너무나도 짧았던 게임
# Predict: 0, Answer: 1
#
# Text: 구토파티
# Predict: 0, Answer: 1
#
# Text: 사람을 담글 짜릿해욥
# Predict: 1, Answer: 0
#
# Text: 친구가 없으면 사지마세요
# Predict: 0, Answer: 1
#
# Text: 플레이 보는건 재미있어도 하는건 노잼
# Predict: 0, Answer: 1
#
# Text: 그만 잡으세요 제발
# Predict: 0, Answer: 1
#
# Text: 호날두
# Predict: 0, Answer: 1
#
# Text: 흐물
# Predict: 0, Answer: 1
#
# Text: 전선 줄다리기 국룰아니냐
# Predict: 0, Answer: 1
#
# Text: 맵만들어시발아
# Predict: 0, Answer: 1
#
# Text: dlathwn 김세민 싸발놈들
# Predict: 0, Answer: 1
#
# Text: 부랄친구랑 하지마세요
# Predict: 0, Answer: 1
#
# Text: 흠
# Predict: 0, Answer: 1
#
# Text: 니엄마
# Predict: 0, Answer: 1
#
# Text: 친구들이랑 하니깐 더 재밌어요 같이할 친구가 있다면 추천합니다
# Predict: 1, Answer: 0
#
# Text: 웃긴 게임
# Predict: 0, Answer: 1
#
# Text: 놓으라고
# Predict: 0, Answer: 1
#
# Text: 친없찐은 사지마라
# Predict: 0, Answer: 1
#
# Text: 친구와 가장 재밌습니다 추천합니다
# Predict: 1, Answer: 0
#
# Text: 개꿀잼
# Predict: 1, Answer: 0
#
# Text: 개재밌음 근데 트롤들이랑 하면 복장 터지는데 복장 터지는 것도 재밋음 추천
# Predict: 1, Answer: 0
#
# Text: 120시간하면서 느낀건데 커스텀맵 중국년들 쳐라 역겨워뒤질거같애
# Predict: 0, Answer: 1
#
# Text: 멀티플레이 강추 초보들에겐 어려운 맵은 손가락의 고통이 따라올 수 있지만 자유도 높아서 지름길 잘 찾으면 수월하게 깰 수 있음 발전소 3시간 넘게 써서 깬 건 비밀ㅎ
# Predict: 1, Answer: 0
#
# Text: 먕먕
# Predict: 0, Answer: 1
#
# Text: 재미있나
# Predict: 1, Answer: 0
#
# Text: 토할 같아요
# Predict: 0, Answer: 1
#
# Text: 한 판 하고 접음
# Predict: 0, Answer: 1
#
# Text: 벽타는겜인줄 알고 고인물한테 1시간정도 강의받았는데도 절벽 못올라가서 뭐 이렇게 어렵나 하고 환불하고 지웠는데 벽타는게임이 아니라네 세일하면 다시 구매할까 생각중 다시생각해도 어이가없네
# Predict: 0, Answer: 1
#
# Text: 골드 9999
# Predict: 0, Answer: 1
#
# Text: 망게임 라고할뻔
# Predict: 0, Answer: 1
#
# Text: 초보 무작정 달려듦 중수 주변 지형지물을 파악하고 맵 제작자의 기획의도를 고려하면서 협동해 넘어갈 방법을 생각함 고인물 무작정 달려듦
# Predict: 0, Answer: 1
#
# Text: 간단하게 할만한 갓겜 친구랑 같이해서 절교해보세요
# Predict: 1, Answer: 0
#
# Text: 진짜 너무 재밌고 예전부터 하고싶던 겜이다 보니 진짜 개꿀잼
# Predict: 1, Answer: 0
#
# Text: 스테이지 건너뛰기좀 없애
# Predict: 0, Answer: 1
#
# Text: 개판 개판
# Predict: 0, Answer: 1
#
# Text: 음
# Predict: 0, Answer: 1
#
# Text: 7시간에 꺰 헿
# Predict: 0, Answer: 1
#
# Text: 친구가 없다면 사지 마라 난 친구가 있기때문에 환불을 했다
# Predict: 0, Answer: 1
#
# Text: 놔 싷팔
# Predict: 0, Answer: 1
#
# Text: 친구 없으면 사지마
# Predict: 0, Answer: 1
#
# Text: 좆노잼
# Predict: 0, Answer: 1
#
# Text: 땅바닥 잡고 트월킹 YEAH
# Predict: 0, Answer: 1
#
# Text: 정말 각겜이지만 오래 플레이를 못합니다
# ...
# Predict: 0, Answer: 1
#
# Text: 재미있습니다
# Predict: 1, Answer: 0
#
# Text: 분명 협동으로하는 게임인데 사실상 격투게임
# Predict: 1, Answer: 0
#
# Text: 박지홍
# Predict: 1, Answer: 0
#
# Text: 꿀잼갓겜
# Predict: 1, Answer: 0
#
# Text: 자유도 높음 친구와 하는게 좋지만 공방가서 트롤짓해도 재밌음
# Predict: 1, Answer: 0
#
# Text: 병맛게임인가 하고 샀는데 진지한브금나와서 진지한게임인가 했는데 웬 하얀 개비스콘이 쳐 나오넼ㅋㅋㅋㅋㅋ
# Predict: 0, Answer: 1
#
# Text: 결론친없찐들사지마 친구없는데사면 개심심함ㅋ
# Predict: 0, Answer: 1
#
# Text: 우정파괴게임 우정이 너무 파괴된 나머지 환불을 하고싶었으나 어느새 2시간이 지나버린 게임 같이하면 1시간만 즐겁고 맵이 막히기 시작하면 내가 맞니 네가 맞니 싸운다 성질급하고 답답한거 못보면 같이하지마라
# Predict: 0, Answer: 1
#
# Text: 죠랭이
# Predict: 0, Answer: 1
#
# Text: 처음 조작키 설명이 부실함 예를들어 멀티플레이할때 사용가능한 기능
# Predict: 0, Answer: 1
#
# Text: 멀미나요
# Predict: 0, Answer: 1
#
# Text: 게임 큰 문제점이 맵이 적다는거였는데 이번에 창작마당 나오고 맵 걱정은 안해도 될뜻
# Predict: 0, Answer: 1
#
# Text: 벽타기 하다가 욕나옴
# Predict: 0, Answer: 1
#
# Text: 게임이 너무 정적입니다
# Predict: 0, Answer: 1
#
# Text: 노잼임 사운드도없음
# Predict: 0, Answer: 1
#
# Text: 별로
# Predict: 0, Answer: 1
#
# Text: 좆망겜
# Predict: 0, Answer: 1
#
# Text: 친구들이랑 하기 잼서요
# Predict: 1, Answer: 0
#
# Text: 친구가 있다면 잡아서 방해하는게임
# Predict: 0, Answer: 1
#
# Text: 개판 5분전과 꼼수 플레이
# Predict: 0, Answer: 1
#
# Text: 속이 안좋고 머리가 아프고 기분이 드럽다
# Predict: 0, Answer: 1
#
# Text: 로딩렉 너무 걸려요
# Predict: 0, Answer: 1
#
# Text: 사람떨어짐평평
# Predict: 0, Answer: 1
#
# Text: 점점 이게임에 구정물이 되가고있네요
# Predict: 0, Answer: 1
#
# Text: 개새키들 게임하는데 아무말없이 강티함
# Predict: 0, Answer: 1
#
# Text: 사놓고 할사람이없어서 잘안했는데 멀티 첨해보는데 개웃기네
# Predict: 0, Answer: 1
#
# Text: 명불허전 휴먼폴플랫 친구들과 함께하면 더 재밌어요 여자친구랑 해도 더 재밌구요 다들 여자친구랑 하세요
# Predict: 1, Answer: 0
#
# Text: 아싸금지겜
# Predict: 0, Answer: 1
#
# Text: 미나미나
# Predict: 1, Answer: 0
#
# Text: 스트리머들 하는거 보고 살 생각이라면 그돈으로 치킨사먹어라
# Predict: 0, Answer: 1
#
# Text: 게임의 고인물은 캐리하는 사람이 아닌 즐겜러들인것
# Predict: 0, Answer: 1
#
# Text: 에러가 날까요 플레이는 한번밖에 하지못했는데 세번째 시도임에 실행이 되지 않습니다 재미있게 잘 플레이 하고 있었는데
# Predict: 0, Answer: 1
#
# Text: 친구들과 맵을 깨는 시스템이 너무 좋아요 맵을 잡기로 넘어가는 고인물을 보고 샀는데 해보니 그딴거 내손으로는 안됨
# Predict: 0, Answer: 1
#
# Text: 혼자해도 재밌던데 난 했지만
# Predict: 1, Answer: 0
#
# Text: 친구가 없다면 세상 재미없는 게임 친구가 있다면 세상 재미있는 게임 나는 세상 재미없는 게임 또르르
# Predict: 1, Answer: 0
#
# Text: 남들이 하는 거 구경할 땐 저세상의 즐거움이었는데 제가 해보니 빡쳐서 돌아버리겠네요 조작감 구려서 발컨은 정말 무쓸모짐짝트롤 이상도 이하도 아니었습니다 플레이하는 내내 온 마음을 다해 환불하고 싶었는데 낑낑 대다 보니 친구들이랑 세 시간이나 했네요
# Predict: 0, Answer: 1
#
# Text: 기 빨아먹는 게임
# Predict: 0, Answer: 1
#
# Text: 선물받자마자 5시간이나 해버린 갓ㅡ게임 임다 여럿이서 할수록 재밌어요여럿이서 해야만 재밌어요
# Predict: 1, Answer: 0
#
# Text: 멀미남
# Predict: 0, Answer: 1
#
# Text: 수직낙하 볼트공중
# Predict: 0, Answer: 1
#
# Text: 망겜
# Predict: 0, Answer: 1
#
# Text: 이게임은 너무 인싸 게임이에요 맵 디자인도 인싸들에게 더욱 유리하게 설계 되어잇구요 그렇다구요
# Predict: 0, Answer: 1
#
# Text: 돈아까움 친구랑 줫나게 할 짓 없을때 할만한 겜 시간내서 할만한 겜은 아님
# Predict: 0, Answer: 1
#
# Text: 첨은 제밋는대 나중에 젬없음
# Predict: 0, Answer: 1
#
# Text: 컨트롤 진짜 어려움 이거살돈에 다른게임삼
# Predict: 0, Answer: 1
#
# Text: 역대급 개노잼 유튜브에서 막 사람들끼리 재밌게 하던데 개10노잼입니다 진짜 혼자하면 노잼이고 친구랑 1시간은 재밌는데 뒤로 절때 안키는 게임 개 돈낭비 이딴 겜을 돈주고 사다니돈받고 사야합니다
# Predict: 0, Answer: 1
#
# Text: 다 깨고 나서 너무 할 게 없다 스토리가 짧은
# Predict: 0, Answer: 1
#
# Text: 음 친구없는 아싸새끼들은 하지마세요 혼자하면 진짜 재미없는데 혼자하면 힘든 구간도 많습니다 그냥 친구랑 할꺼면 사고 살까 말까 긴가민가한 분들은 걍 사지마세요 ㅣ발
# Predict: 0, Answer: 1
#
# Text: 뭐 할만하네요 뭐요 같이할 친구가 없다고요 뭐하고있어요 환불안하고 환불하는진 알죠 몰라도 닥치고 환불하세요
# Predict: 0, Answer: 1
#
# Text: 너무 집중해서 하니까 손가락이랑 머리가 너무 어지럽ㅁㄴㅇㄹ
# Predict: 0, Answer: 1
#
# Text: 플레이 6시간만에 끝까지 깼습니다 구성이 너무 적어요
# Predict: 0, Answer: 1
#
# Text: 목적도 이유도 없이 퍼즐을 풀며 나아가는 게임 하면 정신병자 해도 정신병자가 되어가는 듯한 게임 bu온라인은 망할 트롤러들이 가득하니 조심하는 것을 권한다ub ps 게임을 선물해준 태우형에게 진심으로 감사한다
# Predict: 1, Answer: 0
#
# Text: 6인 멀티플레이한 소감 중국이 압도적인 인구 수를 갖고 있는 것이 큰 장점인지 알게 됨
# Predict: 1, Answer: 0
#
# Text: 끝까지 다깨면 씹노잼 라이브러리장식용게임
# Predict: 0, Answer: 1
#
# Text: 조작키가 쉬워서 금방 잘 플레이 할수 있었습니다
# Predict: 1, Answer: 0
#
# Text: 대환장 파티
# Predict: 1, Answer: 0
#
# Text: 혼자해도 재밌고 친구랑해도 존나 재밌다
# Predict: 1, Answer: 0
#
# Text: 내 자신이 직접 맵 핵이 되어서 힘들게 문제 풀때 다음스테이지 넘어가서 문제를 못풀게 할 수있다 트롤 조무사 게임
# Predict: 0, Answer: 1
#
# Text: 친구랑 겜 잼게하고있다고 한두달후 다시하려고 하니까 게임화면이 정가운데 가늘은 실선으로밖에 안보이고 아예 할수가없게 되버렸어요 고쳐주는지 지식인에 저랑 똑같은 증상 있으신 유저분 계시던데 이분도 해결못하신거 같고 겜자체오류 해결좀해주세요
# Predict: 0, Answer: 1
#
# Text: 메스꺼워서 못하겠어요 몬헌은 70시간 잘만 했는데
# Predict: 0, Answer: 1
#
# Text: 나름 재밌게 하다가 어느센가 슬퍼지는 게임 아싸는 사지 말자
# Predict: 0, Answer: 1
#
# Text: 친구들과 플레이하면 재밌어요
# Predict: 1, Answer: 0
#
# Text: 플레이 하기 전에 ㄱ간단한 영상이나 보고 합시다 아무것도 모르는 친구랑 하는데 암걸림
# Predict: 0, Answer: 1
#
# Text: 게임은 매우 나쁜 게임입니다 모든 유저 남자 여자 성소수자 모두에게 추천합니다 망해라
# Predict: 0, Answer: 1
#
# Text: 놔 놔 이거 놓으라고 쉐끼들아
# Predict: 0, Answer: 1
#
# Text: 하라는 게임 진행 안하고 친구 머리 끄댕이 잡고 늘어지는 게임
# Predict: 0, Answer: 1
#
# Text: 게임 플레이 누르고 검은화면에서 멈추는데 원인이나 해결방법 아시는분 있나여
# Predict: 0, Answer: 1
#
# Text: 한마디만할게요 개판임
# Predict: 0, Answer: 1
#
# Text: 친구랑 플레이타임 약 5시간으로 엔딩을 봤다 서로 육두문자를 보내주며 우정을 다독였습니다 하지 마세요
# Predict: 0, Answer: 1
#
# Text: 겜
# Predict: 0, Answer: 1
#
# Text: 중력이 올라갔다가 내려갔다가
# Predict: 0, Answer: 1
#
# Text: 덕분에 손가락 아작났읍니다ㅎㅎ 구라임
# Predict: 0, Answer: 1
#
# Text: 게임은 나쁘지 않은데요 그래픽에 비해서 렉이 심해요 사람이 플레이 하는 걸 볼 때는 몰랐는데 직접 하니까 멀미나서 토할 같네요ㅠㅠ 화면을 계속 돌리면서 왔다갔다 해야하는 게임이라 류의 게임에 멀미나신다면 구매를 재고해보세요
# Predict: 0, Answer: 1
#
# Text: 렉이 너무 많이걸리네요 제컴터가 롤이나 배그 다 렉없이 돌아가는 정도인데 찰흙 단색 그래픽이 렉이 걸리는지 이해가 안되고 옵션내 최저옵 설정을 해놨는데도 버벅거려요최적화가 정말 급해보이는데
# Predict: 0, Answer: 1
#
# Text: hello bought game game easy finished game played 40 minute ok said add staion would like say everyone buy game DONT BUY THIS GAME
# Predict: 0, Answer: 1
#
# Text: 만육천 원이나 내고 설치했는데 실행이 안 될까요ㅋㅋㅋㅋㅋㅋㅠㅠㅠㅠㅠㅠ 파일이 충돌된다고 해서 그것도 삭제했는데 아직도 들어가기만 하면 배경음악만 나오고 시작이 안 될까요 정말 답답해요 검색을 해 봐도 나오는 게 없고 그냥 환불하렵니다
# Predict: 0, Answer: 1
#
# Text: 친구들끼리 방탈출 카페가면 볼 수 있는 장면이 그대로 연출됩니다 어떻게든 문제를 해결해보려는 인간 남들이 다 아니라는데 지 똥고집대로 밀고나가는 인간 그냥 조용히 하는거만 바라보는 인간 에헤헤 몰라 다죽어 오줌 발사 모든걸 방해하는 인간
# Predict: 0, Answer: 1
#
# Text: 버그가 너무 많아요
# Predict: 0, Answer: 1
#
# Text: 개비스콘
# Predict: 0, Answer: 1
#
# Text: 마지막에 엔딩을 볼떄 이렇게 많은 사람들이 게이머들을 괴롭힐라고 만들었구나 라고 꺠달았습니다
# Predict: 1, Answer: 0
#
# Text: 온라인은 트롤 나도 트롤
# Predict: 0, Answer: 1
#
# Text: 등짝에 x추를그리다니
# Predict: 0, Answer: 1
#
# Text: 난이도 챕터좀 더늘려주세요 돈이 아까울정도입니다
# Predict: 0, Answer: 1
#
# Text: 친구랑 2시간하고 환불각재는 게임
# Predict: 0, Answer: 1
#
# Text: 버그망겜
# Predict: 0, Answer: 1
#
# Text: 16000원에 플레이 하기는 너무 아깝고 세일한 가격인 8000원으로 샀는데 재미를 보기전에 끝나버렸다 살꺼면 고인물이 될 생각으로 사야함 스테이지도 금방금방끝나고 너무 시시함
# Predict: 0, Answer: 1
#
# Text: 게임보다 사람새끼가 더 어렵다
# Predict: 0, Answer: 1
#
# Text: 개비스콘
# Predict: 0, Answer: 1
#
# Text: 혼자서는 게임의 진가를 보기 어렵고 여러명이서 다같이 해야 빛을 보는 게임 트롤도 트롤이 아니던 사람도 모두가 트롤이 되는
# Predict: 0, Answer: 1
#
# Text: 하지 마세요
# Predict: 0, Answer: 1
#
# Text: 꼭 먼저가는놈 뒤쳐지는놈 아무 생각도 없는놈이
# Predict: 0, Answer: 1
#
# Text: 7분 플레이하고 70분동안 멀미함
# Predict: 0, Answer: 1
#
# Text: 6시간만에 3명이서 다 깬 게임 정말 너무 재밌었다 평가 보면 같이할 친구 없으면 사지 마라는 평가들 많은데 진짜다 사지마라 진짜 사지마 그냥 사지말라고
# Predict: 0, Answer: 1
#
# Text: 싼맛에 사서 싼맛에 하는 게임 많은걸 바라면 안됨
# Predict: 0, Answer: 1
#
# Text: 어지럼증이 너무 심해요 게임하다가 토할 뻔 했습니다 컨트롤도 그닥 어렵진 않고 한시간 정돈 재밌게 즐길 게임입니다
# Predict: 1, Answer: 0
#
# Text: 막상 깨고나면 안합니다 할게없거든요 맵패치가 시급함
# Predict: 0, Answer: 1
#
# Text: 한마디만 할게요 암게임
# Predict: 1, Answer: 0
#
# Text: 상대방을 잡고 질질 끌거나 끌려다니거나
# Predict: 0, Answer: 1
#
# Text: 엌ㅋㅋㅋㅋㅋㅋㅋ
# Predict: 0, Answer: 1
#
# Text: 버그가 너무 심합니다
# Predict: 0, Answer: 1
#
# Text: 맥북 mid 2014년 형 사용유저입니다 게임 구매했는데 실행하면 검은화면 뜨다가 팅기기만 하네요 안되신분 중에 해결하신 분 있으신가요ㅜ 돈주고 구매했는데 실행이 안되니 어떡해 해야할지를 모르겠네요
# Predict: 0, Answer: 1
#
# Text: 개빡치는 물리엔진과의 싸움
# Predict: 0, Answer: 1
#
# Text: 소올직히 친구들과 함께하는 게 정말 재미없고 컨텐츠도 매우 부족함
# Predict: 0, Answer: 1
#
# Text: 버그땜에 망함
# Predict: 0, Answer: 1
#
# Text: 고인물 ㅈ망겜
# Predict: 0, Answer: 1
#
# Text: 버그좀 있음 혼자하면 퍼즐게임 같이하면 레슬링게임됨 같이할 친구만 있으면 배꼽잡고 할수있음 갓ㅡ겜 추가 너무 클리어 속도가 빠름 맵 업뎃을 더하거나 창작마당 만들면 갓ㅡ겜중의 갓ㅡ겜될텐데
# Predict: 1, Answer: 0
#
# Text: 친없찐 재밌답니다 아싸는 하지 말아야 하는 게임 짜피 인싸는 보지도 않을 게임
# Predict: 0, Answer: 1
#
# Text: 여러게 사서 가족들하고 재미있게 한게임이에요 협력플레이를필요없고 너님만 잘하면되요잘 해나가면서 플레이 하는게 매우 재미있었음 한번 다하고 나서는 이상하게 다시 들어가지는 않네요
# Predict: 1, Answer: 0
#
# Text: 맵의법칙을무시해버리는 갓겜
# Predict: 0, Answer: 1
#
# Text: 스토리진행하다말고 친구랑 영혼의맞따이를 뜨게되는게임
# Predict: 1, Answer: 0
#
# Text: 조금만 하면 충분히 당신도 고일 수 친구 없어도 온라인 모드로 즐겁게 고인물과 소통 가능
# Predict: 1, Answer: 0
#
# Text: 재미있따
# Predict: 1, Answer: 0
#
# Text: 갓겜 친구들이랑 하면 재미있을듯 근대 친구들이 안삼
# Predict: 1, Answer: 0
#
# Text: 워크숍에서스킨어케받나요
# Predict: 0, Answer: 1
#
# Text: 컨텐츠 조루 6시간 끝
# Predict: 1, Answer: 0
#
# Text: 정말 재미가 없어요 Dont play
# Predict: 0, Answer: 1
#
# Text: 조작감 개구림 퍼즐요소는 다 뻔한데 그냥 조작이 불편해서 깨기 힘듬 친구랑 둘이하다 걍 끔
# Predict: 0, Answer: 1
#
# Text: 이거 레알 존나 재미없고 암걸림 퍼즐게임이라고 해놓고 머리쓰는거 1도 없고 걍 컨트롤임
# Predict: 0, Answer: 1
#
# Text: 버스 태워드립니다
# Predict: 1, Answer: 0
#
# Text: 존잼이요
# Predict: 1, Answer: 0
#
# Text: 고인물 씹 벌레들이 게임을 초만에 꺠고 위에서 지켜보니까 환불하고싶음
# Predict: 0, Answer: 1
#
# Text: 평소 우울하거나 웃고싶은분들 적극 추천 진짜 심장아플때까지 웃은건 처음입니다 아싸는 조용히 뒤로가기를
# Predict: 1, Answer: 0
#
# Text: 사지마세요 조작감이어후
# Predict: 0, Answer: 1
#
# Text: 초반엔 우정파괴겜인가 했는데 하면할수록 게임에대한 분노가 더 커져서 제작자파괴게임이 되었습니다 세일 안할때 사기에는 아깝고 친구없으면 그냥 멘탈파괴겜이 될것같음 게임내내 취권을 선사하는 캐릭터들과 엿같은 맵구성 제가 컨트롤이 딸려서 그런건진몰겟지만요
# Predict: 0, Answer: 1
#
# Text: 미띠잉잉이이이잉ㅇㅇ
# Predict: 1, Answer: 0
#
# Text: 가격에 비해서 굉장히 컨텐츠가 없는 할인할때 돈아까운게임 플레이자체는 귀엽지만 금방질림
# Predict: 0, Answer: 1
#
# Text: 뒷태가 너무 치명적인게임
# Predict: 0, Answer: 1
#
# Text: 신맵안나오냐
# Predict: 0, Answer: 1
#
# Text: 환불 부탁합니다
# Predict: 0, Answer: 1
#
# Text: 정해진 길은 없다는걸 아주 적나라하게 보여주는 게임
# Predict: 0, Answer: 1
#
# Text: 이게임을 환불받고싶슴니다
# Predict: 0, Answer: 1
#
# Text: 사놓긴 했는데 조작감 더러워서 킨지 10분만에 끈 최초의 게임
# Predict: 0, Answer: 1
#
# Text: 20분동안보트옮겻는데 리셋
# Predict: 0, Answer: 1
#
# Text: 배경음악이 너무 무섭습니다
# Predict: 0, Answer: 1
#
# Text: 대상 어린이 청소년 ☑ 전 연령 그래픽 품질 박스박스 아주 나쁨 나쁨 ☑ 괜찮음 좋음 아름다움 환상적 필요 사양 90년대 컴퓨터 ☑ 최소 보통 빠름 최고 슈퍼 컴퓨터 게임 난이도 초졸도 즐길 수 있음 쉬움 Easy learn hard master ☑ 어려울 수 있음 어려움 여분의 키보드가 필요 플레이 타임 스토리 모드를 기준 아주 짧음 ☑ 짧음 시간이 필요 12 켠김에 왕까지 12 제한 없음 판 당 코멘트 대가리가 유독 무거운 말랑말랑 찰흙캐릭터들을 이끌고 퍼즐을 푸는 게임이다 퍼즐게임이지만 정석이 없다는게 큰 특징 혼자하면 3시간정도에 모든 레벨을 한번씩 클리어 할 수 있으며 코옵플레이는 친구들끼리 머리채 잡고 늘어지다 5시간으로 늘어난다 종합평 비추 별로 할만함 ☑ 재미있음 띵작
# Predict: 1, Answer: 0
#
# Text: 스레기 같은 조작감 스레기 같은 길찾기 보아라 스레기 같은 인간들을
# Predict: 0, Answer: 1
#
# Text: 무한점프 걸리면 흥떨어지고5시간하면 많이한거임 하다보면 재미없어짐 맵도 한정적이고 버그안고침
# Predict: 0, Answer: 1
#
# Text: 빠르게 꺨려고 하면 3시간 안에는 깸 16000이라기엔 너무 짧음 친구랑 하면 웃기고 재밌지만다시 깰 의미도 이유도 없어서 친구들이랑 1번 하고 다신 안 합니다 한 번 깨면 다시 깰 이유가 없는데 한 번 꺠는것도 겁나 짧고 모드도 없고 돈이 아까움
# Predict: 0, Answer: 1
#
# Text: 재밌긴 한데혼자 하면 지루하네요
# Predict: 1, Answer: 0
#
# Text: 게임은 3D 멀미판단기라고 해도 좋을만큼 멀미를 유발합니다 멀미내성이 없으신 분들은 구매를 추천드리지 않습니다 게임은 재밌어요
# Predict: 0, Answer: 1
#
# Text: 친구들과 하면 매우 재밌는게임 플탐이 23시간으로 애매해서 다깨고 환불하기 애매함 그렇다고 처음부터 다시하기도 애매함 세일시 8천원으로 3시간정도 웃기만 할수있음 3시간만에 고인물이 되어 클라이밍으로 모든걸 해결하는 자신을 볼수있음
# Predict: 0, Answer: 1
#
# Text: 으
# Predict: 0, Answer: 1
#
# Text: G2a에서사라 5000원밖에안한다
# Predict: 0, Answer: 1
#
# Text: 조별과제 시뮬레이터
# Predict: 0, Answer: 1
#
# Text: 게임 접속 후 소리만 나고 화면은 나오지 않아 제거 후 재설치하여 접속했으나 같은 증상이 반복됩니다
# Predict: 0, Answer: 1
#
# Text: 친구랑 티격태격 좋음 특유의 분위기나 조작감은 잊을 수 없는 갓겜 플탐이 짧고 할 수 있는게 너무 없음 창작마당이라던가 미니게임이라던가 맵 업데이트가 필요할 듯
# Predict: 1, Answer: 0
#
# Text: 퍼즐을 가장한 산악등반 게임 떡 하니 길이 있어도 왠지 오르고 싶어짐
# Predict: 1, Answer: 0
#
# Text: 골때리는 병신게임 사세요 그냥
# Predict: 0, Answer: 1
#
# Text: 이게임 vr로하면 주위사람이 볼까
# Predict: 0, Answer: 1
#
# Text: 아주 좋은게임 솔직히 살만함 님들 사세요 개비스콘들 귀여워 커스터마이징하는게 신의한수인듯 커스터마이징만 44시간했어갓겜이다
# Predict: 1, Answer: 0
#
# Text: 호롤로롤롤롤롤롤 여럿이서 하시면 꼭 한명은 망칠겁니다
# Predict: 0, Answer: 1
#
# Text: 초반에 너무 재밌었는데 콘센트맵에서부터 무중력버그 할 맛 뚝 떨어져서 접음 버그만 해결하면 최고의게임
# Predict: 0, Answer: 1
#
# Text: 이게임은 혼자할꺼면 사지말자 친구랑 같이할것
# Predict: 0, Answer: 1
#
# Text: 꼬물꼬물거리는게 너무귀여움
# Predict: 0, Answer: 1
#
# Text: 게임을해보면서 협동심이 중요한지 알게된다 선 씨비를 걸게되면은 이제부터 전쟁이 시작되면서 게임의 본래목적을 잊게해주는 게임이다 고인물은 한번시작하면은 시간이 얼마나지났는지 모르게된다
# Predict: 1, Answer: 0
#
# Text: 똥겜입니다
# Predict: 0, Answer: 1
#
# Text: legend 전설
# Predict: 0, Answer: 1
#
# Text: 싹다사세여ㅛ 진짜 너무재밌어요 목통증오고 친구들하고 계속 웃었습니다 개발자님 레전드네
# Predict: 1, Answer: 0
#
# Text: 시바것
# Predict: 0, Answer: 1
#
# Text: 버그도많고 렉도심함
# Predict: 0, Answer: 1
#
# Text: 친구랑해도 재밌고 멀티도 괜찮습니다 컨텐츠가 적어서 플레이 타임이 길지 않습니다
# Predict: 1, Answer: 0
#
# Text: 협동 3D 퍼즐풀기 짧은편이지만 개꿀잼
# Predict: 1, Answer: 0
#
# Text: 혼자하면 재미없는데 같이하면 재밌을 같아요병맛 최고얌
# Predict: 1, Answer: 0
#
# Text: 친구들 인성 판단할 수 있는 갓게임 매우 추천함 플레이 시간이 가격에 비해 너무 짧다 새로운 맵 출시가 절실히 필요하며 유저 맵 커스텀 기능이 생기면 이겜은 진정한 갓겜이 될거라 확신함
# Predict: 1, Answer: 0
#
# Text: 환불왜안해줘
# Predict: 0, Answer: 1
#
# Text: 게임 특징 작품에서 가장 돋보이는 특징중 하나는 캐릭터의 조작방식에 있습니다 주인공은 사람 형태를 취하곤 있습니다만 가만히 있어도 흐느적 거리며 옆으로 움직이는 등의 불안정한 중심 이동이 작품을 퍼즐 게임으로서 난이도를 어렵게 하는 점이 있습니다 플레이어가 마우스만 누르고 있으면 캐릭터의 양팔을 물을 제외한 모든 대상에게 접착시킬 수 있는 능력이 있고 작품은 캐릭터가 모든 사물에 상호 물리적 행동을 할 수 있게 구현되었습니다 이를 맵의 퍼즐들을 매우 다양한 방식으로 공략할 수 있는 가능성을 가지고 있는 것이 조금이나마 게임의 난이도를 낮추는데의 역할을 하고 있습니다 흔히 말하는 어거지로라도 게임을 클리어할 수 있는 길이 많이 준비되어있는 작품이라는 것이죠 작품은 물리적인 움직임과 관련하여 맵에 끼거나 움직일 수 없게 되는 등의 자잘한 버그도 꽤 많은 편입니다 전반적으로 캐릭터의 불안정한 움직임을 소재로 한 것도 그렇고 어거지로 게임을 클리어하기 위한 게임의 특징들이 버그에 대한 불만보단 재미와 클리어의 요소로 다가오는 장점이 되겠네요 작품은 게임오버 없습니다 퍼즐에 막힌 부분이 있다면 세이브 이전 시점으로 모든 사물을 원래대로 되돌릴 수도 있고 구현된 맵 상에서 떨어지는 문제가 생기면 다시 원위치로 돌아오게 되기에 플레이어는 여러가지 시도를 하는데에 거리낌이 없습니다 점에서 맵 크기에 비해 심리적으로 제시할 수 있는 자유도가 높은 매력이라 보았습니다 게임 평가 사실 말했던 게임특징은 어디까지나 싱글 플레이어로서 충분히 재미를 느낄 수 있는 점을 나열했습니다만 게임은 캠페인을 최대 8인까지 할 수 있는 멀티플레이 기능을 지원하고 있습니다 싱글 캠페인을 그대로 가져와 플레이 할 수 있도록 말이죠 멀티 플레이에서는 다수의 캐릭터가 상호작용을 할 수 있는 혼자서는 무거운 것을 옴기지 못하여 이것저것 세세하게 손을 봐야 되었던 것에 반하여 다수의 사람들이 달라붙는 것으로 퍼즐을 쉽게 진행할 수 있습니다 팀원간의 합이 맞지 않는다면 다수의 사람이 붙어 퍼즐 풀이에 문제가 생기기도 하지요 멀티플레이의 경우 팀원 중 한명이라도 세이브 지점까지 도달하면 모두가 세이브 지점부터 출발할 수 있게 구현되었습니다 이를 통해 많은 사람들이 상호작용을 하고 진행하는 협동심 속에서 재미를 느끼기도 하고 플레이어에게 짓궂은 장난을 치는 것으로 재미를 느끼기도 합니다 타 게임에 비해 플레이어간 장난에 대한 페널티가 적으니까요 재미의 다양성의 넓어짐으로 인해 대부분 멀티플레이까지 경험해본 유저들이 높은 게임평가를 주지 않았나라고 보고 있습니다 게임은 필드 음악이 전반적으로 몽환적인 분위기를 자아내는 것도 매력 포인트중 하나인데 그에 반하여 전반적인 스토리가 전무하다 시피하여 순수히 퍼즐을 푸는 게임이란 것에 집중되어 있습니다 이게 아쉽더라고요한글을 지원하지 않지만 게임을 즐기는데 큰 문제 없는 것은 장점 덕분에 Human Fall flat이 싱글플레이어는 진지하게 여러가지 방법을 모색하며 게임을 클리어하는 무난한 매력의 퍼즐 어드벤처라면 멀티플레이어로서의 Human Fall Flat 은 싱글플레이에서는 할 수 없었던 퍼즐 공략 협동심을 발휘하여 남을 도와주거나 보다 쉽게 도전과제를 클리어하기 위한 게임 친한 사람들끼리 짖궂은 장난도 치면서 웃을 수 있는 퍼즐 어드벤처가 되겠습니다 후일담 개인적으로 게임은 컨셉을 잘 잡았다는 생각이 들었습니다 특히 그래픽 작업 쪽 효율 방면에서 말이죠 꽤 저렴하게 구성된 편인 캐릭터 배경 모델이지만 그것이 좋았다랄까요 바깥을 전혀 꾸미지 않았기에 비어있는 지역은 사망구간인데도 바깥으로 나가도 소용없다라는 이야기를 게임 실행시 극초반부 이야기에 깔아두고 있다는 점을 보며 여러 생각이 들었습니다 멀티플레이에선 비어있는 공간을 이용해 유저들간 장난을 치기에도 좋고 세이브 포인트의 빠른 진행을 위해 일부러 죽기에도 편했을테니까요 여러가지로 게임오버 되지 않는 특성을 맵 모델링과 관련하여 잘 이용했다는 느낌이 들었네요
# Predict: 1, Answer: 0
#
# Text: 렉이 심하게 걸려서 하기 힘들긴 사람들이랑 하니까 정말 재밌네요하기 쉽고 친구들과 하면 더 재밌을것 같아요그리고 친구들한테 추천을 해서 친구들이 산다고 하네요 게임은 너무 재밌는것 같아요 렉만 안걸리면 더 많이 할것 같네요렉이 걸리는 이유좀 알수 있을까요
# Predict: 1, Answer: 0
#
# Text: 혼자해도 괜찮은 게임이나 친구와 OR 온라인으로하면 훨씬더 꿀잼인 게임
# Predict: 1, Answer: 0
#
# Text: 재미는있음 근데 플탐이 너무 짧음
# Predict: 0, Answer: 1
#
# Text: 재밌어요
# Predict: 1, Answer: 0
#
# Text: 혼자하면 힘들지만 친구랑 같이하면 꼼수로 통과가 가능한 게임 꼭 친구랑 할
# Predict: 1, Answer: 0
#
# Text: 친구들과 하면 재밌습니다 혼자는 비추
# Predict: 0, Answer: 1
#
# Text: 퍼즐게임이 아니라 컨트롤 똥겜
# Predict: 0, Answer: 1
#
# Text: 조악한 조작법으로 인해 발생하는 웃긴상황들이 처음엔 재미있지만 스토리를 다깨고나면 흥미를 잃어버려 고인물이 되버리는 게임 게임을사고 어느기간동안 친구들이랑 웃고싶다면 추천
# Predict: 1, Answer: 0
#
# Text: 친구랑 하면 답 없고요 하세요 진짜 친한 친구랑 하면 친구의 얼굴을 치게 될겁니다
# Predict: 1, Answer: 0
#
# Text: 내 옆의 찌끄레기같은 놈들이 미션을 방해한다
# Predict: 0, Answer: 1
#
# Text: 친구들이 페북보고와서 하자고함 솔직히 세일은 8000원어치의 값을 할까 했었다죄송합니다 제가 진짜 5분하고 80억어치는 웃었습니다 존나 재밌습니다 진짜 사서 친구들이랑 하세요 온라인도 혼자해봤는데 너무 웃김 진짜 꼭 하세요 진짜 세일 50때 안사면 후회함 진짜 개꿀잼입니다
# Predict: 1, Answer: 0
#
# Text: 초반에는 진짜 갓겜이고 잼있었는데 후반으로 가면 갈수록 버그가 너무많고 재미도 떨어지는것 같습니다
# Predict: 0, Answer: 1
#
# Text: 노잼
# Predict: 0, Answer: 1
#
# Text: 혼자하면 싱크빅 퀴즈쇼 같이하면 니머리채 내머리채 쥐어뜯기 예능쇼
# Predict: 1, Answer: 0
#
# Text: 처음에는 유쾌하다가 갈수록 피폐해지는 게임 러닝타임이 짧은 줄 알았는데 알고보니 정확하게 맞춘거더라
# Predict: 1, Answer: 0
#
# Text: 친구랑 하면 진짜 재미있음 추천추천 꼬옥 계속 업데이트가 됬으면 좋겠습니다
# Predict: 1, Answer: 0
#
# Text: 개슈레기게임
# Predict: 0, Answer: 1
#
# Text: 혼자서 절때 못깬다 하는지는 알겠는데 과정이 개같은게 눈에 보여서 안하게됨 깰려면 멀티로 할것
# Predict: 0, Answer: 1
#
# Text: 호로롤로러ㅓㄴ
# Predict: 0, Answer: 1
#
# Text: 진짜 너무재밌음 돈이 안아까워요 시간가는줄 모르게 친구 바짓가랑이 잡고 늘어지는 재미가 일품
# Predict: 1, Answer: 0
#
# Text: 갓겜
# Predict: 1, Answer: 0
#
# Text: ㅈ갓겜
# Predict: 1, Answer: 0
#
# Text: 멀티로 친구들이랑 같이하면 정말 재밌습니다 b
# Predict: 1, Answer: 0
#
# Text: 협동해서 탈출 하는 게임류 갱비스트 느낌이 나지만 갱비스트와는 협동한다는 줄거움 경쟁에서 살아남아야 한다는 리얼리티 게임들과는 달리 힐링도 받고 장난쳐도 허용되는 그런 게임
# Predict: 1, Answer: 0
#
# Text: 이거선물해준놈 저주할거다
# Predict: 0, Answer: 1
#
# Text: 다깨도 한번정도는 할만한 게임
# Predict: 1, Answer: 0
#
# Text: 아주 좋아요 갱비스트의 협동전 이건 막 싸우는게 아니라 서로 협력해서미스터리를 푸는 맛이 쏠쏠하네요 세일할때 사세요 아무래도 16000원은 부담되는게 없지 않아 있네요 친구랑 하면 더 재미있어요 서로 던지고 트롤하고 장점이 있다면 모든 길이 1가지가 아니예요 자기만의 길을 개척해서 나아가는 재미도있고요 물리 엔진이 현대 사회 물리법칙 기반으로 되있는 같아 실생활에서 느꼇던것들로 지식이 아닌 간단한 상식으로 해처나아갈 수 있어요 단점이라면 조작감이 그랩하는게 쉽지 않은데 그게 이게임의 매력처럼 느껴지네요 필자는 언제나 그랬듯이 05점 중에 45점을 드리겠습니다
# Predict: 1, Answer: 0
#
# Text: 게임은 잘 만들었는데 다 어디서 해보던 그런 방식이라 그냥 해도 그만 안해도 그만인 느낌이 나네요
# Predict: 0, Answer: 1
#
# Text: 솔직히 이거 멀티 돼는줄 알고 삿다가 안되서 짜증남
# Predict: 0, Answer: 1
#
# Text: 멀티플레이어 되나요
# Predict: 0, Answer: 1
#
# Text: 멀티는 어떻게하나요
# Predict: 0, Answer: 1
#
# Text: 술취한 금호타이어맨
# Predict: 0, Answer: 1
#
# Text: 16000원 짜리 게임치고 매우 재미있습니다 BJ들이 하는걸보고 재미있어서 하게되었는데 34시간이내로 엔딩을 볼수있을정도로 짧습니다 한국어 필요없습니다 그냥 마우스 키보드만 있음됩니다 꼭 정해진길이 아닌 꼼수로 클리어 할수가있네요
# Predict: 1, Answer: 0
#
# Accuracy: 80.91%
# The number of Wrong Answers: 1697
# The number of english reviews: 0

# %%
import torch

torch.cuda.empty_cache()
